# %%
import tensorflow as tf
from Compute_Jacobian import jacobian # Please download 'Compute_Jacobian.py' in the repository 
import numpy as np
import timeit
from scipy.interpolate import griddata
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import os



os.environ["KMP_WARNINGS"] = "FALSE" 
import timeit

import sys

import scipy
import scipy.io
import time

class Sampler:
    # Initialize the class
    def __init__(self, dim, coords, func, name = None):
        self.dim = dim
        self.coords = coords
        self.func = func
        self.name = name
    def sample(self, N):
        x = self.coords[0:1,:] + (self.coords[1:2,:]-self.coords[0:1,:])*np.random.rand(N, self.dim)
        y = self.func(x)
        return x, y

# Define the exact solution and its derivatives
def u(x, a, c):
    """
    :param x: x = (t, x)
    """
    t = x[:,0:1]
    x = x[:,1:2]
    return np.sin(np.pi * x) * np.cos(c * np.pi * t) + a * np.sin(2 * c * np.pi* x) * np.cos(4 * c  * np.pi * t)

def u_t(x,a, c):
    t = x[:,0:1]
    x = x[:,1:2]
    u_t = -  c * np.pi * np.sin(np.pi * x) * np.sin(c * np.pi * t) -  a * 4 * c * np.pi * np.sin(2 * c * np.pi* x) * np.sin(4 * c * np.pi * t)
    return u_t

def u_tt(x, a, c):
    t = x[:,0:1]
    x = x[:,1:2]
    u_tt = -(c * np.pi)**2 * np.sin( np.pi * x) * np.cos(c * np.pi * t) - a * (4 * c * np.pi)**2 *  np.sin(2 * c * np.pi* x) * np.cos(4 * c * np.pi * t)
    return u_tt

def u_xx(x, a, c):
    t = x[:,0:1]
    x = x[:,1:2]
    u_xx = - np.pi**2 * np.sin( np.pi * x) * np.cos(c * np.pi * t) -  a * (2 * c * np.pi)** 2 * np.sin(2 * c * np.pi* x) * np.cos(4 * c * np.pi * t)
    return  u_xx


def r(x, a, c):
    return u_tt(x, a, c) - c**2 * u_xx(x, a, c)

def operator(u, t, x, c, sigma_t=1.0, sigma_x=1.0):
    u_t = tf.gradients(u, t)[0] / sigma_t
    u_x = tf.gradients(u, x)[0] / sigma_x
    u_tt = tf.gradients(u_t, t)[0] / sigma_t
    u_xx = tf.gradients(u_x, x)[0] / sigma_x
    residual = u_tt - c**2 * u_xx
    return residual


class PINN:
    # Initialize the class
    def __init__(self, layers, operator, ics_sampler, bcs_sampler, res_sampler, c, kernel_size , sess):
        # Normalization 
        X, _ = res_sampler.sample(np.int32(1e5))
        self.mu_X, self.sigma_X = X.mean(0), X.std(0)
        self.mu_t, self.sigma_t = self.mu_X[0], self.sigma_X[0]
        self.mu_x, self.sigma_x = self.mu_X[1], self.sigma_X[1]


        # Samplers
        self.operator = operator
        self.ics_sampler = ics_sampler
        self.bcs_sampler = bcs_sampler
        self.res_sampler = res_sampler

        self.sess = sess
        # Initialize network weights and biases
        self.layers = layers
        self.weights, self.biases = self.initialize_NN(layers)
        
        # weights
        self.lam_u_val = np.array(2.0)
        self.lam_ut_val = np.array(2.0)
        self.lam_r_val = np.array(1.0)

        self.lam_bc1_val = np.array(2.0)
        self.lam_bc2_val = np.array(2.0)
        self.lam_res_val = np.array(2.0)
      
        
        self.weight_bc_val =  np.array(2.0) # tf.Variable([1.0], dtype=tf.float32)
        self.weight_ic_val =  np.array(2.0) # tf.Variable([1.0], dtype=tf.float32)

        self.weight_bc_tf =  tf.placeholder(tf.float32, shape=self.weight_bc_val.shape)
        self.weight_ic_tf =  tf.placeholder(tf.float32, shape=self.weight_ic_val.shape)

        # Wave constant
        self.c = tf.constant(c, dtype=tf.float32)
        
        self.kernel_size = kernel_size # Size of the NTK matrix

        # Define Tensorflow session
        self.sess = tf.Session(config=tf.ConfigProto(log_device_placement=False))

        # Define placeholders and computational graph
        self.t_u_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_u_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_ics_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_ics_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.u_ics_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_r_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_r_tf = tf.placeholder(tf.float32, shape=(None, 1))
        
        self.lam_u_tf = tf.placeholder(tf.float32, shape=self.lam_u_val.shape)
        self.lam_ut_tf = tf.placeholder(tf.float32, shape=self.lam_u_val.shape)
        # self.lam_r_tf = tf.placeholder(tf.float32, shape=self.lam_u_val.shape)
        self.lam_bc1_tf = tf.placeholder(tf.float32, shape=self.lam_bc1_val.shape)
        self.lam_bc2_tf = tf.placeholder(tf.float32, shape=self.lam_bc2_val.shape)
        
        self.lam_res_tf = tf.placeholder(tf.float32, shape=self.lam_res_val.shape)

        self.u_pred = self.net_u(self.t_u_tf, self.x_u_tf)


        # Evaluate predictions
        self.u_ics_pred = self.net_u(self.t_ics_tf, self.x_ics_tf)
        self.u_bc1_pred = self.net_u(self.t_bc1_tf, self.x_bc1_tf)
        self.u_bc2_pred = self.net_u(self.t_bc2_tf, self.x_bc2_tf)

        self.r_pred = self.net_r(self.t_r_tf, self.x_r_tf)
        
        
        # Boundary loss and Initial loss
        self.loss_ics_u = tf.reduce_mean(tf.square(self.u_ics_tf - self.u_ics_pred))
        self.loss_ics_ut =  tf.reduce_mean(tf.square( tf.gradients(self.u_ics_pred, self.t_ics_tf)[0] / self.sigma_t))
        self.loss_bc1 = tf.reduce_mean(tf.square(self.u_bc1_pred)) #+ tf.reduce_mean(tf.square(self.u_bc2_pred))
        self.loss_bc2 = tf.reduce_mean(tf.square(self.u_bc2_pred))

        # Residual loss
        self.loss_res = tf.reduce_mean(tf.square(self.r_pred))

        # Total loss
        self.loss = self.loss_res + self.weight_bc1_tf * self.loss_bc1 + self.weight_bc2_tf* self.loss_bc2 + self.weight_ic_tf * (self.loss_ics_u + self.loss_ics_ut ) # + self.lam_ut_tf * self.loss_ics_u_t 

        self.count = 1
        self.loss_bc_avg = 0
        self.loss_ics_u_avg = 0
        self.loss_res_avg = 0

        # Define optimizer with learning rate schedule
        self.global_step = tf.Variable(0, trainable=False)
        starter_learning_rate = 1e-3
        self.learning_rate = tf.train.exponential_decay(starter_learning_rate, self.global_step,  1000, 0.9, staircase=False)
        # Passing global_step to minimize() will increment it at each step.
        self.train_op = tf.train.AdamOptimizer(self.learning_rate).minimize(self.loss, global_step=self.global_step , var_list=self.weights +  self.biases)

        self.train_op_bc = tf.train.AdamOptimizer(self.learning_rate).minimize(-self.loss, global_step=self.global_step , var_list=self.weights +  self.biases)
        self.train_op_ic = tf.train.AdamOptimizer(self.learning_rate).minimize(-self.loss, global_step=self.global_step , var_list=self.weights +  self.biases)
        
         # Initialize Tensorflow variables
        init = tf.global_variables_initializer()
        self.sess.run(init)

    # Initialize network weights and biases using Xavier initialization
    def initialize_NN(self, layers):
        # Xavier initialization
        def xavier_init(size):
            in_dim = size[0]
            out_dim = size[1]
            xavier_stddev = 1. / np.sqrt((in_dim + out_dim) / 2.)
            return tf.Variable(tf.random.normal([in_dim, out_dim], dtype=tf.float32) * xavier_stddev,  dtype=tf.float32)

        weights = []
        biases = []
        num_layers = len(layers)
        for l in range(0, num_layers - 1):
            W = xavier_init(size=[layers[l], layers[l + 1]])
            b = tf.Variable(tf.zeros([1, layers[l + 1]], dtype=tf.float32), dtype=tf.float32)
            weights.append(W)
            biases.append(b)
        return weights, biases

    # Evaluates the forward pass
    def forward_pass(self, H, layers, weights, biases):
        num_layers = len(layers)
        for l in range(0, num_layers - 2):
            W = weights[l]
            b = biases[l]
            H = tf.tanh(tf.add(tf.matmul(H, W), b))
        W = weights[-1]
        b = biases[-1]
        H = tf.add(tf.matmul(H, W), b)
        return H

    # Forward pass for u
    def net_u(self, t, x):
        u = self.forward_pass(tf.concat([t, x], 1),  self.layers, self.weights, self.biases)
        return u

    # Forward pass for du/dt
    def net_u_t(self, t, x):
        u_t = tf.gradients(self.net_u(t, x), t)[0] / self.sigma_t
        return u_t

    # Forward pass for the residual
    def net_r(self, t, x):
        u = self.net_u(t, x)
        residual = self.operator(u, t, x, self.c, self.sigma_t,  self.sigma_x)
        return residual
    
    

    def fetch_minibatch(self, sampler, N):
        X, Y = sampler.sample(N)
        X = (X - self.mu_X) / self.sigma_X
        return X, Y

        # Trains the model by minimizing the MSE loss

    def trainmb(self, nIter=10000, batch_size=128, log_NTK=False, update_lam=False):

        start_time = timeit.default_timer()
        for it in range(1 , nIter):
            # Fetch boundary mini-batches
            X_ics_batch, u_ics_batch = self.fetch_minibatch(self.ics_sampler, batch_size // 3)
            X_bc1_batch, _ = self.fetch_minibatch(self.bcs_sampler[0], batch_size // 3)
            X_bc2_batch, _ = self.fetch_minibatch(self.bcs_sampler[1], batch_size // 3)
            
            # Fetch residual mini-batch
            X_res_batch, _ = self.fetch_minibatch(self.res_sampler, batch_size)
            # Define a dictionary for associating placeholders with data
            tf_dict = {self.t_ics_tf: X_ics_batch[:, 0:1], 
                       self.x_ics_tf: X_ics_batch[:, 1:2],
                       self.u_ics_tf: u_ics_batch,
                       self.t_bc1_tf: X_bc1_batch[:, 0:1],
                       self.x_bc1_tf: X_bc1_batch[:, 1:2],
                       self.t_bc2_tf: X_bc2_batch[:, 0:1], 
                       self.x_bc2_tf: X_bc2_batch[:, 1:2],
                       self.t_r_tf: X_res_batch[:, 0:1], 
                       self.x_r_tf: X_res_batch[:, 1:2],
                       self.weight_bc_tf:self.weight_ic_val,
                       self.weight_ic_tf:self.weight_bc_val
                       }

            # Run the Tensorflow session to minimize the loss
            self.sess.run(self.train_op, tf_dict)

            # Print
            if it % 100 == 0:
                elapsed = timeit.default_timer() - start_time

                loss , loss_bc1 , loss_bc2 , loss_ics_u , loss_ics_ut , loss_res = self.sess.run( [self.loss  , self.loss_bc1 ,self.loss_bc2 , self.loss_ics_u, self.loss_ics_ut, self.loss_res ] , tf_dict)

                print('It: %d, Loss: %.3e,  loss_bc1: %.3e,  loss_bc2: %.3e, loss_ics_u: %.3e, loss_ics_ut: %.3e,  Loss_res: %.3e , Time: %.2f' %(it, loss, loss_bc1 , loss_bc2 , loss_ics_u, loss_ics_ut , loss_res , elapsed))
                
 
                # start_time = timeit.default_timer()

                # self.loss_bc_avg += (loss_bc1 + loss_bc2 ) /self.count
                # self.loss_ics_u_avg += (loss_ics_u + loss_ics_ut )  /self.count
                # self.loss_res_avg += loss_res  /self.count
                # self.count +=1
          
                if it % 100== 0: 
                        # alpha   = 10000
                        # self.lam_bc_val = alpha *  (loss_bc1 + loss_bc2 )
                        # # self.lam_bc2_val = alpha * loss_bc2
                        # self.lam_u_val = alpha * (loss_ics_u + loss_ics_ut )
                        # self.lam_res_val = 100 *loss_res
                        _ , _ , weight_bc_val  , weight_ic_val = self.sess.run([self.train_op_bc , self.train_op_ic , self.weight_bc_tf , self.weight_ic_tf], tf_dict)

                        self.weight_bc_val = weight_bc_val
                        self.weight_ic_val = weight_ic_val
                        print('loss_bc1: {:.3e}'.format(self.weight_bc_val))
                        print('loss_ics_u: {:.3e}'.format(self.weight_ic_val))

                sys.stdout.flush()

####################################################################################################
    def train(self, nIter , bcbatch_size , ubatch_size):

        start_time = timeit.default_timer()

        # Fetch boundary mini-batches
        X_ics_batch, u_ics_batch = self.fetch_minibatch(self.ics_sampler, bcbatch_size)
        X_bc1_batch, _ = self.fetch_minibatch(self.bcs_sampler[0], bcbatch_size )
        X_bc2_batch, _ = self.fetch_minibatch(self.bcs_sampler[1], bcbatch_size )
        
        # Fetch residual mini-batch
        X_res_batch, _ = self.fetch_minibatch(self.res_sampler, ubatch_size)
        # print("inside trainmb: " , X_res_batch.shape)
        # Define a dictionary for associating placeholders with data
        tf_dict = {self.t_ics_tf: X_ics_batch[:, 0:1], 
                   self.x_ics_tf: X_ics_batch[:, 1:2],
                    self.u_ics_tf: u_ics_batch,
                    self.t_bc1_tf: X_bc1_batch[:, 0:1],
                    self.x_bc1_tf: X_bc1_batch[:, 1:2],
                    self.t_bc2_tf: X_bc2_batch[:, 0:1], 
                    self.x_bc2_tf: X_bc2_batch[:, 1:2],
                    self.t_r_tf: X_res_batch[:, 0:1], 
                    self.x_r_tf: X_res_batch[:, 1:2],
                    self.lam_u_tf: self.lam_u_val,
                    self.lam_bc_tf: self.lam_bc_val,
                    self.lam_res_tf: self.lam_res_val,
                    }
    
        for it in range(nIter):

            # Run the Tensorflow session to minimize the loss
            self.sess.run(self.train_op, tf_dict)

            # Print
            if it % 100 == 0:
                elapsed = timeit.default_timer() - start_time

                loss = self.sess.run(self.loss, tf_dict)
                loss_bc1 = self.sess.run(self.loss_bc1, tf_dict)
                # loss_bc2 = self.sess.run(self.loss_bc2, tf_dict)
                loss_ics_u = self.sess.run(self.loss_ics_u, tf_dict)
                loss_res = self.sess.run(self.loss_res, tf_dict)

             # Print
            if it % 100 == 0:
                elapsed = timeit.default_timer() - start_time

                loss , loss_bc1 , loss_bc2 , loss_ics_u , loss_ics_ut , loss_res = self.sess.run( [self.loss  , self.loss_bc1 ,self.loss_bc2 , self.loss_ics_u, self.loss_ics_ut, self.loss_res ] , tf_dict)

                print('It: %d, Loss: %.3e,  loss_bc1: %.3e,  loss_bc2: %.3e, loss_ics_u: %.3e, loss_ics_ut: %.3e,  Loss_res: %.3e , Time: %.2f' %(it, loss, loss_bc1 , loss_bc2 , loss_ics_u, loss_ics_ut , loss_res , elapsed))
                
              
 
                start_time = timeit.default_timer()

                # self.loss_bc_avg += (loss_bc1 + loss_bc2 ) /self.count
                # self.loss_ics_u_avg += (loss_ics_u + loss_ics_ut )  /self.count
                # self.loss_res_avg += loss_res  /self.count
                # self.count +=1
          
                if it % 100 == 0: 
                        alpha   = 10000
                        self.lam_bc_val = alpha *  (loss_bc1 + loss_bc2 )
                        # self.lam_bc2_val = alpha * loss_bc2
                        self.lam_u_val = alpha * (loss_ics_u + loss_ics_ut )
                        self.lam_res_val = 100 *loss_res
                        
                        print('loss_bc1: {:.3e}'.format(self.lam_bc_val))
                        # print('loss_bc2: {:.3e}'.format(self.lam_bc2_val))
                        print('loss_ics_u: {:.3e}'.format(self.lam_u_val))
                        print('loss_res_val: {:.3e}'.format(self.lam_res_val))

                sys.stdout.flush()


    # Evaluates predictions at test points
    def predict_u(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.t_u_tf: X_star[:, 0:1], self.x_u_tf: X_star[:, 1:2]}
        u_star = self.sess.run(self.u_pred, tf_dict)
        return u_star

        # Evaluates predictions at test points

    def predict_r(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.t_r_tf: X_star[:, 0:1], self.x_r_tf: X_star[:, 1:2]}
        r_star = self.sess.run(self.r_pred, tf_dict)
        return r_star
    
   ###############################################################################################################################################
   # 
   # ###############################################################################################################################################
   # 
   # ###############################################################################################################################################
   # 
   #

# %%
#test_method(mtd , layers,  X_u, Y_u, X_r, Y_r ,  X_star , u_star , r_star  , nIter ,batch_size , bcbatch_size , ubatch_size)
def test_method(method , layers,  ics_sampler, bcs_sampler, res_sampler, c ,kernel_size , X_star , u_star , r_star , nIter ,mbbatch_size , bcbatch_size , ubatch_size ):

    tf.reset_default_graph()
    gpu_options = tf.GPUOptions(visible_device_list="0")
    with tf.Session(config=tf.ConfigProto(gpu_options=gpu_options,allow_soft_placement=False, log_device_placement=False)) as sess:
        # sess.run(init)

        model = PINN(layers, operator, ics_sampler, bcs_sampler, res_sampler, c, kernel_size , sess)
        # Train model
        start_time = time.time()

        if method =="full_batch":
            print("full_batch method is used")
            model.train(nIter  , bcbatch_size , ubatch_size  )
        elif method =="mini_batch":
            print("mini_batch method is used")
            model.trainmb(nIter, mbbatch_size)
        else:
            print("unknown method!")
        elapsed = time.time() - start_time

        # Predictions
        u_pred = model.predict_u(X_star)
        # Predictions

        sess.close()   

    error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)

    print('elapsed: {:.2e}'.format(elapsed))

    print('Relative L2 error_u: {:.2e}'.format(error_u))


    return [elapsed, error_u  , model]

###############################################################################################################################################

# %%
# Define PINN model
a = 0.5
c = 2

kernel_size = 300

# Domain boundaries
ics_coords = np.array([[0.0, 0.0],  [0.0, 1.0]])
bc1_coords = np.array([[0.0, 0.0],  [1.0, 0.0]])
bc2_coords = np.array([[0.0, 1.0],  [1.0, 1.0]])
dom_coords = np.array([[0.0, 0.0],  [1.0, 1.0]])

# Create initial conditions samplers
ics_sampler = Sampler(2, ics_coords, lambda x: u(x, a, c), name='Initial Condition 1')

# Create boundary conditions samplers
bc1 = Sampler(2, bc1_coords, lambda x: u(x, a, c), name='Dirichlet BC1')
bc2 = Sampler(2, bc2_coords, lambda x: u(x, a, c), name='Dirichlet BC2')
bcs_sampler = [bc1, bc2]

# Create residual sampler
res_sampler = Sampler(2, dom_coords, lambda x: r(x, a, c), name='Forcing')



nIter =40000
bcbatch_size = 500
ubatch_size = 5000
mbbatch_size = 300



# Define model
mode = 'M4'
layers = [2, 500, 500, 500, 1]


nn = 200
t = np.linspace(dom_coords[0, 0], dom_coords[1, 0], nn)[:, None]
x = np.linspace(dom_coords[0, 1], dom_coords[1, 1], nn)[:, None]
t, x = np.meshgrid(t, x)
X_star = np.hstack((t.flatten()[:, None], x.flatten()[:, None]))

u_star = u(X_star, a,c)
r_star = r(X_star, a, c)

iterations = 1
methods = [  "mini_batch"]

result_dict =  dict((mtd, []) for mtd in methods)

for mtd in methods:
    print("Method: ", mtd)
    time_list = []
    error_u_list = []
    error_r_list = []
    
    for index in range(iterations):

        print("Epoch: ", str(index+1))

        # Create residual sampler

        # [elapsed, error_u , model] = test_method(mtd , layers,  ics_sampler, bcs_sampler, res_sampler, c ,kernel_size , X_star , u_star , r_star , nIter ,mbbatch_size , bcbatch_size , ubatch_size )
        tf.reset_default_graph()
        gpu_options = tf.GPUOptions(visible_device_list="0")
        with tf.Session(config=tf.ConfigProto(gpu_options=gpu_options,allow_soft_placement=False, log_device_placement=False)) as sess:
            # sess.run(init)

            model = PINN(layers, operator, ics_sampler, bcs_sampler, res_sampler, c, kernel_size , sess)
            # Train model
            start_time = time.time()

            if mtd =="full_batch":
                print("full_batch method is used")
                model.train(nIter  , bcbatch_size , ubatch_size  )
            elif mtd =="mini_batch":
                print("mini_batch method is used")
                model.trainmb(nIter, mbbatch_size)
            else:
                print("unknown method!")
            elapsed = time.time() - start_time

            # Predictions
            u_pred = model.predict_u(X_star)
            r_pred = model.predict_r(X_star)
            # Predictions

            sess.close()   

            error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)
            error_r = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)

            print('elapsed: {:.2e}'.format(elapsed))

            print('Relative L2 error_u: {:.2e}'.format(error_u))
            print('Relative L2 error_r: {:.2e}'.format(error_r))


        print('elapsed: {:.2e}'.format(elapsed))
        print('Relative L2 error_u: {:.2e}'.format(error_u))
        print('Relative L2 error_r: {:.2e}'.format(error_r))

        time_list.append(elapsed)
        error_u_list.append(error_u)
        error_r_list.append(error_r)

    print("\n\nMethod: ", mtd)
    print("\naverage of time_list:" , sum(time_list) / len(time_list) )
    print("average of error_u_list:" , sum(error_u_list) / len(error_u_list) )
    print("average of error_r_list:" , sum(error_r_list) / len(error_r_list) )

    result_dict[mtd] = [time_list ,error_u_list,error_r_list]
    # scipy.io.savemat("M2_result_"+str(iterations)+"_"+mtd+".mat" , {'time_list':np.array(time_list),'error_u_list':np.array(error_u_list),'error_f_list':np.array(error_f_list)})

    scipy.io.savemat("./1DWave_database/"+mtd+"_1Dwave_"+mode+"_result_mb"+str(mbbatch_size)+"_fb"+str(ubatch_size)+"_bc"+str(mbbatch_size)+"_"+str(iterations)+".mat" , result_dict)

###############################################################################################################################################
# Out:
# Method:  mini_batch
# Epoch:  1
# WARNING:tensorflow:From /tmp/ipykernel_27569/794721725.py:65: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_27569/794721725.py:66: The name tf.GPUOptions is deprecated. Please use tf.compat.v1.GPUOptions instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_27569/794721725.py:67: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_27569/794721725.py:67: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_27569/3559053648.py:107: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# 2023-11-28 01:15:57.749854: I tensorflow/core/platform/cpu_feature_guard.cc:145] This TensorFlow binary is optimized with Intel(R) MKL-DNN to use the following CPU instructions in performance critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in non-MKL-DNN operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-28 01:15:57.773055: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2899885000 Hz
# 2023-11-28 01:15:57.773556: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55f501072780 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-11-28 01:15:57.773570: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2023-11-28 01:15:57.774208: I tensorflow/core/common_runtime/process_util.cc:115] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# WARNING:tensorflow:From /tmp/ipykernel_27569/3559053648.py:174: The name tf.train.exponential_decay is deprecated. Please use tf.compat.v1.train.exponential_decay instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_27569/3559053648.py:176: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_27569/3559053648.py:182: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# mini_batch method is used
# It: 100, Loss: 8.876e-01,  loss_bc1: 5.061e-02,  loss_bc2: 2.895e-02, loss_ics_u: 3.400e-01, loss_ics_ut: 2.356e-02,  Loss_res: 1.411e-03 , Time: 4.65
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 200, Loss: 9.318e-01,  loss_bc1: 4.567e-02,  loss_bc2: 2.244e-02, loss_ics_u: 3.729e-01, loss_ics_ut: 2.477e-02,  Loss_res: 1.981e-04 , Time: 10.46
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 300, Loss: 8.679e-01,  loss_bc1: 4.441e-02,  loss_bc2: 1.611e-02, loss_ics_u: 3.584e-01, loss_ics_ut: 1.487e-02,  Loss_res: 3.349e-04 , Time: 13.39
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 400, Loss: 8.334e-01,  loss_bc1: 5.366e-02,  loss_bc2: 2.521e-02, loss_ics_u: 3.178e-01, loss_ics_ut: 1.987e-02,  Loss_res: 3.252e-04 , Time: 16.34
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 500, Loss: 7.757e-01,  loss_bc1: 4.080e-02,  loss_bc2: 1.943e-02, loss_ics_u: 3.151e-01, loss_ics_ut: 1.206e-02,  Loss_res: 9.744e-04 , Time: 19.32
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 600, Loss: 7.623e-01,  loss_bc1: 5.249e-02,  loss_bc2: 3.203e-02, loss_ics_u: 2.846e-01, loss_ics_ut: 1.125e-02,  Loss_res: 1.625e-03 , Time: 22.25
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 700, Loss: 7.413e-01,  loss_bc1: 5.592e-02,  loss_bc2: 2.300e-02, loss_ics_u: 2.766e-01, loss_ics_ut: 1.016e-02,  Loss_res: 9.933e-03 , Time: 25.41
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 800, Loss: 7.899e-01,  loss_bc1: 5.312e-02,  loss_bc2: 2.752e-02, loss_ics_u: 3.042e-01, loss_ics_ut: 8.759e-03,  Loss_res: 2.732e-03 , Time: 28.84
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 900, Loss: 6.788e-01,  loss_bc1: 5.718e-02,  loss_bc2: 2.343e-02, loss_ics_u: 2.489e-01, loss_ics_ut: 4.801e-03,  Loss_res: 1.010e-02 , Time: 32.17
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 1000, Loss: 5.598e-01,  loss_bc1: 5.276e-02,  loss_bc2: 2.841e-02, loss_ics_u: 1.917e-01, loss_ics_ut: 1.101e-03,  Loss_res: 1.181e-02 , Time: 35.40
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 1100, Loss: 8.152e-01,  loss_bc1: 5.920e-02,  loss_bc2: 2.398e-02, loss_ics_u: 3.159e-01, loss_ics_ut: 2.763e-03,  Loss_res: 1.147e-02 , Time: 38.80
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 1200, Loss: 5.338e-01,  loss_bc1: 5.455e-02,  loss_bc2: 1.053e-02, loss_ics_u: 1.936e-01, loss_ics_ut: 2.445e-03,  Loss_res: 1.167e-02 , Time: 42.15
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 1300, Loss: 7.091e-01,  loss_bc1: 6.369e-02,  loss_bc2: 1.682e-02, loss_ics_u: 2.668e-01, loss_ics_ut: 1.550e-03,  Loss_res: 1.132e-02 , Time: 45.41
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 1400, Loss: 5.514e-01,  loss_bc1: 4.943e-02,  loss_bc2: 9.918e-03, loss_ics_u: 2.084e-01, loss_ics_ut: 2.196e-03,  Loss_res: 1.154e-02 , Time: 48.79
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 1500, Loss: 4.898e-01,  loss_bc1: 6.000e-02,  loss_bc2: 1.150e-02, loss_ics_u: 1.631e-01, loss_ics_ut: 3.797e-03,  Loss_res: 1.297e-02 , Time: 52.15
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 1600, Loss: 6.430e-01,  loss_bc1: 6.224e-02,  loss_bc2: 1.378e-02, loss_ics_u: 2.406e-01, loss_ics_ut: 6.832e-04,  Loss_res: 8.282e-03 , Time: 55.45
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 1700, Loss: 5.574e-01,  loss_bc1: 6.959e-02,  loss_bc2: 2.518e-02, loss_ics_u: 1.780e-01, loss_ics_ut: 1.018e-03,  Loss_res: 9.856e-03 , Time: 58.83
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 1800, Loss: 4.807e-01,  loss_bc1: 7.634e-02,  loss_bc2: 9.908e-03, loss_ics_u: 1.477e-01, loss_ics_ut: 3.798e-03,  Loss_res: 5.130e-03 , Time: 62.31
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 1900, Loss: 5.057e-01,  loss_bc1: 5.420e-02,  loss_bc2: 9.083e-03, loss_ics_u: 1.833e-01, loss_ics_ut: 2.074e-03,  Loss_res: 8.368e-03 , Time: 65.75
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 2000, Loss: 4.864e-01,  loss_bc1: 6.677e-02,  loss_bc2: 5.526e-03, loss_ics_u: 1.648e-01, loss_ics_ut: 2.380e-03,  Loss_res: 7.341e-03 , Time: 69.06
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 2100, Loss: 4.830e-01,  loss_bc1: 5.355e-02,  loss_bc2: 6.243e-03, loss_ics_u: 1.764e-01, loss_ics_ut: 2.306e-03,  Loss_res: 5.961e-03 , Time: 72.50
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 2200, Loss: 4.384e-01,  loss_bc1: 4.073e-02,  loss_bc2: 6.582e-03, loss_ics_u: 1.657e-01, loss_ics_ut: 4.068e-03,  Loss_res: 4.242e-03 , Time: 75.81
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 2300, Loss: 4.176e-01,  loss_bc1: 5.194e-02,  loss_bc2: 9.744e-03, loss_ics_u: 1.378e-01, loss_ics_ut: 5.989e-03,  Loss_res: 6.559e-03 , Time: 79.11
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 2400, Loss: 3.978e-01,  loss_bc1: 4.793e-02,  loss_bc2: 1.093e-02, loss_ics_u: 1.330e-01, loss_ics_ut: 4.385e-03,  Loss_res: 5.236e-03 , Time: 82.38
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 2500, Loss: 4.302e-01,  loss_bc1: 5.032e-02,  loss_bc2: 9.036e-03, loss_ics_u: 1.499e-01, loss_ics_ut: 3.858e-03,  Loss_res: 3.961e-03 , Time: 85.71
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 2600, Loss: 4.071e-01,  loss_bc1: 3.403e-02,  loss_bc2: 8.235e-03, loss_ics_u: 1.559e-01, loss_ics_ut: 2.755e-03,  Loss_res: 5.354e-03 , Time: 89.00
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 2700, Loss: 4.093e-01,  loss_bc1: 4.077e-02,  loss_bc2: 1.006e-02, loss_ics_u: 1.490e-01, loss_ics_ut: 2.813e-03,  Loss_res: 4.099e-03 , Time: 92.29
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 2800, Loss: 3.613e-01,  loss_bc1: 3.842e-02,  loss_bc2: 8.196e-03, loss_ics_u: 1.277e-01, loss_ics_ut: 4.347e-03,  Loss_res: 4.036e-03 , Time: 95.66
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 2900, Loss: 3.634e-01,  loss_bc1: 4.151e-02,  loss_bc2: 8.421e-03, loss_ics_u: 1.269e-01, loss_ics_ut: 3.060e-03,  Loss_res: 3.590e-03 , Time: 98.94
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 3000, Loss: 4.006e-01,  loss_bc1: 4.524e-02,  loss_bc2: 8.084e-03, loss_ics_u: 1.417e-01, loss_ics_ut: 3.183e-03,  Loss_res: 4.242e-03 , Time: 102.23
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 3100, Loss: 4.060e-01,  loss_bc1: 4.170e-02,  loss_bc2: 7.369e-03, loss_ics_u: 1.498e-01, loss_ics_ut: 2.668e-03,  Loss_res: 2.816e-03 , Time: 105.54
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 3200, Loss: 4.384e-01,  loss_bc1: 4.272e-02,  loss_bc2: 1.002e-02, loss_ics_u: 1.543e-01, loss_ics_ut: 8.524e-03,  Loss_res: 7.214e-03 , Time: 108.88
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 3300, Loss: 4.527e-01,  loss_bc1: 4.136e-02,  loss_bc2: 7.134e-03, loss_ics_u: 1.738e-01, loss_ics_ut: 2.588e-03,  Loss_res: 2.907e-03 , Time: 112.16
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 3400, Loss: 3.332e-01,  loss_bc1: 4.262e-02,  loss_bc2: 8.917e-03, loss_ics_u: 1.102e-01, loss_ics_ut: 3.358e-03,  Loss_res: 2.877e-03 , Time: 115.43
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 3500, Loss: 3.830e-01,  loss_bc1: 3.189e-02,  loss_bc2: 6.147e-03, loss_ics_u: 1.481e-01, loss_ics_ut: 3.580e-03,  Loss_res: 3.613e-03 , Time: 118.71
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 3600, Loss: 3.936e-01,  loss_bc1: 3.405e-02,  loss_bc2: 7.383e-03, loss_ics_u: 1.503e-01, loss_ics_ut: 3.158e-03,  Loss_res: 3.687e-03 , Time: 121.97
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 3700, Loss: 3.195e-01,  loss_bc1: 3.526e-02,  loss_bc2: 8.209e-03, loss_ics_u: 1.101e-01, loss_ics_ut: 4.455e-03,  Loss_res: 3.385e-03 , Time: 125.27
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 3800, Loss: 3.556e-01,  loss_bc1: 3.637e-02,  loss_bc2: 9.226e-03, loss_ics_u: 1.247e-01, loss_ics_ut: 5.541e-03,  Loss_res: 3.892e-03 , Time: 128.56
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 3900, Loss: 3.749e-01,  loss_bc1: 3.460e-02,  loss_bc2: 9.337e-03, loss_ics_u: 1.360e-01, loss_ics_ut: 5.504e-03,  Loss_res: 4.087e-03 , Time: 131.86
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 4000, Loss: 2.912e-01,  loss_bc1: 3.225e-02,  loss_bc2: 9.221e-03, loss_ics_u: 9.544e-02, loss_ics_ut: 7.007e-03,  Loss_res: 3.357e-03 , Time: 135.25
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 4100, Loss: 3.400e-01,  loss_bc1: 3.489e-02,  loss_bc2: 1.283e-02, loss_ics_u: 1.150e-01, loss_ics_ut: 5.729e-03,  Loss_res: 3.041e-03 , Time: 138.58
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 4200, Loss: 3.202e-01,  loss_bc1: 3.424e-02,  loss_bc2: 9.854e-03, loss_ics_u: 1.097e-01, loss_ics_ut: 5.092e-03,  Loss_res: 2.523e-03 , Time: 141.91
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 4300, Loss: 3.416e-01,  loss_bc1: 3.166e-02,  loss_bc2: 1.096e-02, loss_ics_u: 1.204e-01, loss_ics_ut: 6.698e-03,  Loss_res: 2.139e-03 , Time: 145.22
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 4400, Loss: 3.455e-01,  loss_bc1: 3.111e-02,  loss_bc2: 1.109e-02, loss_ics_u: 1.236e-01, loss_ics_ut: 5.265e-03,  Loss_res: 3.389e-03 , Time: 148.54
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 4500, Loss: 3.212e-01,  loss_bc1: 3.009e-02,  loss_bc2: 9.662e-03, loss_ics_u: 1.129e-01, loss_ics_ut: 6.496e-03,  Loss_res: 2.907e-03 , Time: 152.11
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 4600, Loss: 3.546e-01,  loss_bc1: 2.920e-02,  loss_bc2: 1.023e-02, loss_ics_u: 1.328e-01, loss_ics_ut: 3.982e-03,  Loss_res: 2.203e-03 , Time: 158.78
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 4700, Loss: 3.596e-01,  loss_bc1: 3.386e-02,  loss_bc2: 9.895e-03, loss_ics_u: 1.309e-01, loss_ics_ut: 4.057e-03,  Loss_res: 2.216e-03 , Time: 162.66
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 4800, Loss: 3.868e-01,  loss_bc1: 2.826e-02,  loss_bc2: 8.799e-03, loss_ics_u: 1.503e-01, loss_ics_ut: 3.907e-03,  Loss_res: 4.314e-03 , Time: 166.52
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 4900, Loss: 2.929e-01,  loss_bc1: 3.146e-02,  loss_bc2: 1.047e-02, loss_ics_u: 9.918e-02, loss_ics_ut: 3.975e-03,  Loss_res: 2.705e-03 , Time: 170.09
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 5000, Loss: 3.310e-01,  loss_bc1: 2.455e-02,  loss_bc2: 1.068e-02, loss_ics_u: 1.253e-01, loss_ics_ut: 3.379e-03,  Loss_res: 3.291e-03 , Time: 173.51
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 5100, Loss: 3.223e-01,  loss_bc1: 3.086e-02,  loss_bc2: 1.026e-02, loss_ics_u: 1.145e-01, loss_ics_ut: 3.689e-03,  Loss_res: 3.652e-03 , Time: 176.92
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 5200, Loss: 3.115e-01,  loss_bc1: 3.177e-02,  loss_bc2: 8.869e-03, loss_ics_u: 1.101e-01, loss_ics_ut: 2.872e-03,  Loss_res: 4.317e-03 , Time: 180.32
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 5300, Loss: 3.413e-01,  loss_bc1: 2.399e-02,  loss_bc2: 1.065e-02, loss_ics_u: 1.328e-01, loss_ics_ut: 1.936e-03,  Loss_res: 2.488e-03 , Time: 183.84
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 5400, Loss: 2.956e-01,  loss_bc1: 2.396e-02,  loss_bc2: 9.709e-03, loss_ics_u: 1.093e-01, loss_ics_ut: 2.776e-03,  Loss_res: 4.036e-03 , Time: 187.33
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 5500, Loss: 2.647e-01,  loss_bc1: 1.869e-02,  loss_bc2: 8.905e-03, loss_ics_u: 1.012e-01, loss_ics_ut: 1.063e-03,  Loss_res: 5.098e-03 , Time: 190.79
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 5600, Loss: 2.888e-01,  loss_bc1: 2.469e-02,  loss_bc2: 1.306e-02, loss_ics_u: 1.036e-01, loss_ics_ut: 8.913e-04,  Loss_res: 4.258e-03 , Time: 194.23
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 5700, Loss: 2.908e-01,  loss_bc1: 1.895e-02,  loss_bc2: 1.128e-02, loss_ics_u: 1.122e-01, loss_ics_ut: 8.074e-04,  Loss_res: 4.349e-03 , Time: 197.70
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 5800, Loss: 2.662e-01,  loss_bc1: 1.822e-02,  loss_bc2: 1.469e-02, loss_ics_u: 9.654e-02, loss_ics_ut: 7.613e-04,  Loss_res: 5.728e-03 , Time: 201.12
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 5900, Loss: 2.649e-01,  loss_bc1: 2.571e-02,  loss_bc2: 9.603e-03, loss_ics_u: 9.466e-02, loss_ics_ut: 1.116e-03,  Loss_res: 2.733e-03 , Time: 204.64
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 6000, Loss: 3.061e-01,  loss_bc1: 2.448e-02,  loss_bc2: 1.001e-02, loss_ics_u: 1.173e-01, loss_ics_ut: 4.311e-04,  Loss_res: 1.675e-03 , Time: 208.59
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 6100, Loss: 3.364e-01,  loss_bc1: 2.438e-02,  loss_bc2: 1.249e-02, loss_ics_u: 1.294e-01, loss_ics_ut: 9.965e-04,  Loss_res: 1.840e-03 , Time: 213.81
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 6200, Loss: 2.926e-01,  loss_bc1: 2.597e-02,  loss_bc2: 1.010e-02, loss_ics_u: 1.082e-01, loss_ics_ut: 1.002e-03,  Loss_res: 2.105e-03 , Time: 217.93
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 6300, Loss: 2.744e-01,  loss_bc1: 2.155e-02,  loss_bc2: 1.296e-02, loss_ics_u: 9.956e-02, loss_ics_ut: 2.278e-03,  Loss_res: 1.709e-03 , Time: 221.69
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 6400, Loss: 2.842e-01,  loss_bc1: 2.101e-02,  loss_bc2: 1.125e-02, loss_ics_u: 1.078e-01, loss_ics_ut: 1.124e-03,  Loss_res: 1.773e-03 , Time: 225.21
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 6500, Loss: 2.898e-01,  loss_bc1: 2.059e-02,  loss_bc2: 1.205e-02, loss_ics_u: 1.103e-01, loss_ics_ut: 9.957e-04,  Loss_res: 1.887e-03 , Time: 228.64
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 6600, Loss: 2.725e-01,  loss_bc1: 2.300e-02,  loss_bc2: 1.040e-02, loss_ics_u: 1.006e-01, loss_ics_ut: 1.249e-03,  Loss_res: 2.038e-03 , Time: 232.12
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 6700, Loss: 2.580e-01,  loss_bc1: 1.641e-02,  loss_bc2: 1.001e-02, loss_ics_u: 9.968e-02, loss_ics_ut: 1.526e-03,  Loss_res: 2.758e-03 , Time: 235.59
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 6800, Loss: 3.002e-01,  loss_bc1: 1.871e-02,  loss_bc2: 1.248e-02, loss_ics_u: 1.168e-01, loss_ics_ut: 1.204e-03,  Loss_res: 1.786e-03 , Time: 239.04
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 6900, Loss: 3.118e-01,  loss_bc1: 1.756e-02,  loss_bc2: 1.337e-02, loss_ics_u: 1.206e-01, loss_ics_ut: 3.337e-03,  Loss_res: 2.060e-03 , Time: 242.46
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 7000, Loss: 2.559e-01,  loss_bc1: 1.913e-02,  loss_bc2: 1.090e-02, loss_ics_u: 9.549e-02, loss_ics_ut: 1.610e-03,  Loss_res: 1.669e-03 , Time: 245.96
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 7100, Loss: 2.605e-01,  loss_bc1: 2.271e-02,  loss_bc2: 1.112e-02, loss_ics_u: 9.485e-02, loss_ics_ut: 9.526e-04,  Loss_res: 1.236e-03 , Time: 249.98
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 7200, Loss: 3.078e-01,  loss_bc1: 1.993e-02,  loss_bc2: 9.725e-03, loss_ics_u: 1.223e-01, loss_ics_ut: 1.347e-03,  Loss_res: 1.237e-03 , Time: 253.47
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 7300, Loss: 2.953e-01,  loss_bc1: 2.250e-02,  loss_bc2: 8.901e-03, loss_ics_u: 1.133e-01, loss_ics_ut: 1.852e-03,  Loss_res: 2.196e-03 , Time: 256.86
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 7400, Loss: 2.513e-01,  loss_bc1: 2.013e-02,  loss_bc2: 1.037e-02, loss_ics_u: 9.337e-02, loss_ics_ut: 1.094e-03,  Loss_res: 1.340e-03 , Time: 260.45
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 7500, Loss: 2.889e-01,  loss_bc1: 2.136e-02,  loss_bc2: 1.466e-02, loss_ics_u: 1.060e-01, loss_ics_ut: 1.762e-03,  Loss_res: 1.470e-03 , Time: 263.81
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 7600, Loss: 3.005e-01,  loss_bc1: 2.288e-02,  loss_bc2: 1.461e-02, loss_ics_u: 1.099e-01, loss_ics_ut: 1.680e-03,  Loss_res: 2.334e-03 , Time: 267.28
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 7700, Loss: 2.911e-01,  loss_bc1: 2.084e-02,  loss_bc2: 1.243e-02, loss_ics_u: 1.101e-01, loss_ics_ut: 1.309e-03,  Loss_res: 1.898e-03 , Time: 270.76
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 7800, Loss: 2.851e-01,  loss_bc1: 1.573e-02,  loss_bc2: 1.348e-02, loss_ics_u: 1.106e-01, loss_ics_ut: 1.962e-03,  Loss_res: 1.642e-03 , Time: 274.26
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 7900, Loss: 3.003e-01,  loss_bc1: 1.740e-02,  loss_bc2: 1.195e-02, loss_ics_u: 1.176e-01, loss_ics_ut: 1.836e-03,  Loss_res: 2.659e-03 , Time: 277.66
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 8000, Loss: 2.654e-01,  loss_bc1: 1.583e-02,  loss_bc2: 1.045e-02, loss_ics_u: 1.036e-01, loss_ics_ut: 1.532e-03,  Loss_res: 2.691e-03 , Time: 282.48
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 8100, Loss: 2.873e-01,  loss_bc1: 2.287e-02,  loss_bc2: 1.323e-02, loss_ics_u: 1.053e-01, loss_ics_ut: 1.331e-03,  Loss_res: 1.970e-03 , Time: 286.14
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 8200, Loss: 2.721e-01,  loss_bc1: 1.722e-02,  loss_bc2: 1.100e-02, loss_ics_u: 1.054e-01, loss_ics_ut: 1.347e-03,  Loss_res: 2.254e-03 , Time: 290.06
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 8300, Loss: 2.923e-01,  loss_bc1: 1.740e-02,  loss_bc2: 1.247e-02, loss_ics_u: 1.143e-01, loss_ics_ut: 1.087e-03,  Loss_res: 1.786e-03 , Time: 294.32
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 8400, Loss: 2.721e-01,  loss_bc1: 1.662e-02,  loss_bc2: 1.349e-02, loss_ics_u: 1.034e-01, loss_ics_ut: 1.457e-03,  Loss_res: 2.301e-03 , Time: 297.81
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 8500, Loss: 2.767e-01,  loss_bc1: 1.827e-02,  loss_bc2: 1.288e-02, loss_ics_u: 1.049e-01, loss_ics_ut: 1.597e-03,  Loss_res: 1.325e-03 , Time: 301.20
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 8600, Loss: 2.543e-01,  loss_bc1: 1.734e-02,  loss_bc2: 1.292e-02, loss_ics_u: 9.428e-02, loss_ics_ut: 1.546e-03,  Loss_res: 2.149e-03 , Time: 304.66
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 8700, Loss: 3.120e-01,  loss_bc1: 1.401e-02,  loss_bc2: 1.471e-02, loss_ics_u: 1.245e-01, loss_ics_ut: 1.786e-03,  Loss_res: 1.928e-03 , Time: 308.06
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 8800, Loss: 2.816e-01,  loss_bc1: 2.007e-02,  loss_bc2: 1.134e-02, loss_ics_u: 1.065e-01, loss_ics_ut: 2.165e-03,  Loss_res: 1.419e-03 , Time: 311.46
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 8900, Loss: 2.569e-01,  loss_bc1: 1.393e-02,  loss_bc2: 1.262e-02, loss_ics_u: 9.835e-02, loss_ics_ut: 2.070e-03,  Loss_res: 2.985e-03 , Time: 314.96
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 9000, Loss: 2.571e-01,  loss_bc1: 1.250e-02,  loss_bc2: 1.719e-02, loss_ics_u: 9.640e-02, loss_ics_ut: 1.273e-03,  Loss_res: 2.348e-03 , Time: 318.44
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 9100, Loss: 2.882e-01,  loss_bc1: 1.373e-02,  loss_bc2: 1.523e-02, loss_ics_u: 1.131e-01, loss_ics_ut: 1.093e-03,  Loss_res: 1.942e-03 , Time: 321.94
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 9200, Loss: 2.572e-01,  loss_bc1: 1.622e-02,  loss_bc2: 1.199e-02, loss_ics_u: 9.736e-02, loss_ics_ut: 2.225e-03,  Loss_res: 1.619e-03 , Time: 325.41
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 9300, Loss: 2.977e-01,  loss_bc1: 1.369e-02,  loss_bc2: 1.592e-02, loss_ics_u: 1.173e-01, loss_ics_ut: 1.334e-03,  Loss_res: 1.294e-03 , Time: 328.81
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 9400, Loss: 2.972e-01,  loss_bc1: 1.654e-02,  loss_bc2: 1.267e-02, loss_ics_u: 1.171e-01, loss_ics_ut: 1.222e-03,  Loss_res: 2.131e-03 , Time: 332.21
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 9500, Loss: 2.368e-01,  loss_bc1: 1.004e-02,  loss_bc2: 1.270e-02, loss_ics_u: 9.353e-02, loss_ics_ut: 1.206e-03,  Loss_res: 1.887e-03 , Time: 335.69
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 9600, Loss: 2.771e-01,  loss_bc1: 1.302e-02,  loss_bc2: 1.460e-02, loss_ics_u: 1.080e-01, loss_ics_ut: 1.678e-03,  Loss_res: 2.498e-03 , Time: 339.18
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 9700, Loss: 2.897e-01,  loss_bc1: 1.379e-02,  loss_bc2: 1.519e-02, loss_ics_u: 1.130e-01, loss_ics_ut: 1.335e-03,  Loss_res: 3.031e-03 , Time: 346.57
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 9800, Loss: 2.779e-01,  loss_bc1: 1.440e-02,  loss_bc2: 1.423e-02, loss_ics_u: 1.081e-01, loss_ics_ut: 1.174e-03,  Loss_res: 1.982e-03 , Time: 350.20
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 9900, Loss: 2.838e-01,  loss_bc1: 1.371e-02,  loss_bc2: 1.432e-02, loss_ics_u: 1.111e-01, loss_ics_ut: 9.895e-04,  Loss_res: 3.578e-03 , Time: 353.75
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 10000, Loss: 2.723e-01,  loss_bc1: 1.429e-02,  loss_bc2: 1.620e-02, loss_ics_u: 1.032e-01, loss_ics_ut: 1.602e-03,  Loss_res: 1.750e-03 , Time: 357.27
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 10100, Loss: 2.953e-01,  loss_bc1: 1.206e-02,  loss_bc2: 1.370e-02, loss_ics_u: 1.191e-01, loss_ics_ut: 1.534e-03,  Loss_res: 2.540e-03 , Time: 360.76
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 10200, Loss: 2.840e-01,  loss_bc1: 1.391e-02,  loss_bc2: 1.223e-02, loss_ics_u: 1.140e-01, loss_ics_ut: 1.112e-03,  Loss_res: 1.539e-03 , Time: 364.19
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 10300, Loss: 2.844e-01,  loss_bc1: 1.117e-02,  loss_bc2: 1.245e-02, loss_ics_u: 1.162e-01, loss_ics_ut: 1.718e-03,  Loss_res: 1.318e-03 , Time: 367.63
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 10400, Loss: 2.823e-01,  loss_bc1: 1.161e-02,  loss_bc2: 1.151e-02, loss_ics_u: 1.153e-01, loss_ics_ut: 1.793e-03,  Loss_res: 1.845e-03 , Time: 371.16
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 10500, Loss: 2.459e-01,  loss_bc1: 1.608e-02,  loss_bc2: 1.381e-02, loss_ics_u: 9.108e-02, loss_ics_ut: 1.360e-03,  Loss_res: 1.243e-03 , Time: 374.57
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 10600, Loss: 2.467e-01,  loss_bc1: 1.543e-02,  loss_bc2: 1.435e-02, loss_ics_u: 9.119e-02, loss_ics_ut: 1.708e-03,  Loss_res: 1.341e-03 , Time: 378.12
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 10700, Loss: 2.640e-01,  loss_bc1: 1.152e-02,  loss_bc2: 1.289e-02, loss_ics_u: 1.056e-01, loss_ics_ut: 1.374e-03,  Loss_res: 1.310e-03 , Time: 381.65
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 10800, Loss: 3.107e-01,  loss_bc1: 1.385e-02,  loss_bc2: 1.471e-02, loss_ics_u: 1.249e-01, loss_ics_ut: 1.153e-03,  Loss_res: 1.572e-03 , Time: 385.26
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 10900, Loss: 2.676e-01,  loss_bc1: 1.140e-02,  loss_bc2: 1.352e-02, loss_ics_u: 1.069e-01, loss_ics_ut: 1.307e-03,  Loss_res: 1.432e-03 , Time: 388.71
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 11000, Loss: 2.662e-01,  loss_bc1: 1.360e-02,  loss_bc2: 1.362e-02, loss_ics_u: 1.041e-01, loss_ics_ut: 1.124e-03,  Loss_res: 1.286e-03 , Time: 392.27
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 11100, Loss: 2.654e-01,  loss_bc1: 1.520e-02,  loss_bc2: 1.135e-02, loss_ics_u: 1.041e-01, loss_ics_ut: 1.077e-03,  Loss_res: 1.893e-03 , Time: 395.90
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 11200, Loss: 2.539e-01,  loss_bc1: 1.128e-02,  loss_bc2: 1.522e-02, loss_ics_u: 9.830e-02, loss_ics_ut: 1.384e-03,  Loss_res: 1.503e-03 , Time: 399.82
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 11300, Loss: 2.843e-01,  loss_bc1: 1.548e-02,  loss_bc2: 1.547e-02, loss_ics_u: 1.087e-01, loss_ics_ut: 9.643e-04,  Loss_res: 3.047e-03 , Time: 403.28
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 11400, Loss: 2.610e-01,  loss_bc1: 9.986e-03,  loss_bc2: 1.660e-02, loss_ics_u: 1.014e-01, loss_ics_ut: 1.550e-03,  Loss_res: 1.958e-03 , Time: 406.74
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 11500, Loss: 2.606e-01,  loss_bc1: 1.135e-02,  loss_bc2: 1.488e-02, loss_ics_u: 1.013e-01, loss_ics_ut: 2.161e-03,  Loss_res: 1.247e-03 , Time: 410.26
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 11600, Loss: 2.331e-01,  loss_bc1: 1.122e-02,  loss_bc2: 1.256e-02, loss_ics_u: 9.045e-02, loss_ics_ut: 1.275e-03,  Loss_res: 2.100e-03 , Time: 413.64
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 11700, Loss: 2.741e-01,  loss_bc1: 1.235e-02,  loss_bc2: 1.323e-02, loss_ics_u: 1.097e-01, loss_ics_ut: 1.255e-03,  Loss_res: 1.020e-03 , Time: 417.07
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 11800, Loss: 2.634e-01,  loss_bc1: 1.012e-02,  loss_bc2: 1.129e-02, loss_ics_u: 1.086e-01, loss_ics_ut: 9.501e-04,  Loss_res: 1.590e-03 , Time: 420.53
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 11900, Loss: 2.646e-01,  loss_bc1: 1.422e-02,  loss_bc2: 1.300e-02, loss_ics_u: 1.030e-01, loss_ics_ut: 1.259e-03,  Loss_res: 1.690e-03 , Time: 423.96
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 12000, Loss: 2.503e-01,  loss_bc1: 1.105e-02,  loss_bc2: 1.339e-02, loss_ics_u: 9.900e-02, loss_ics_ut: 1.005e-03,  Loss_res: 1.372e-03 , Time: 427.38
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 12100, Loss: 2.541e-01,  loss_bc1: 1.112e-02,  loss_bc2: 1.200e-02, loss_ics_u: 1.020e-01, loss_ics_ut: 1.184e-03,  Loss_res: 1.591e-03 , Time: 430.84
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 12200, Loss: 2.742e-01,  loss_bc1: 9.879e-03,  loss_bc2: 1.388e-02, loss_ics_u: 1.118e-01, loss_ics_ut: 9.816e-04,  Loss_res: 1.027e-03 , Time: 434.26
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 12300, Loss: 2.716e-01,  loss_bc1: 1.264e-02,  loss_bc2: 1.375e-02, loss_ics_u: 1.076e-01, loss_ics_ut: 1.040e-03,  Loss_res: 1.550e-03 , Time: 437.67
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 12400, Loss: 2.447e-01,  loss_bc1: 1.233e-02,  loss_bc2: 1.481e-02, loss_ics_u: 9.281e-02, loss_ics_ut: 1.324e-03,  Loss_res: 2.107e-03 , Time: 441.15
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 12500, Loss: 2.682e-01,  loss_bc1: 1.154e-02,  loss_bc2: 1.363e-02, loss_ics_u: 1.065e-01, loss_ics_ut: 1.710e-03,  Loss_res: 1.402e-03 , Time: 444.54
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 12600, Loss: 2.494e-01,  loss_bc1: 1.116e-02,  loss_bc2: 1.536e-02, loss_ics_u: 9.640e-02, loss_ics_ut: 1.113e-03,  Loss_res: 1.306e-03 , Time: 448.04
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 12700, Loss: 2.343e-01,  loss_bc1: 1.028e-02,  loss_bc2: 1.340e-02, loss_ics_u: 9.176e-02, loss_ics_ut: 1.204e-03,  Loss_res: 1.003e-03 , Time: 451.53
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 12800, Loss: 2.659e-01,  loss_bc1: 8.562e-03,  loss_bc2: 1.307e-02, loss_ics_u: 1.066e-01, loss_ics_ut: 4.112e-03,  Loss_res: 1.280e-03 , Time: 454.96
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 12900, Loss: 2.641e-01,  loss_bc1: 1.252e-02,  loss_bc2: 1.087e-02, loss_ics_u: 1.059e-01, loss_ics_ut: 1.163e-03,  Loss_res: 3.295e-03 , Time: 458.40
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 13000, Loss: 2.317e-01,  loss_bc1: 1.049e-02,  loss_bc2: 1.199e-02, loss_ics_u: 9.195e-02, loss_ics_ut: 8.393e-04,  Loss_res: 1.186e-03 , Time: 461.87
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 13100, Loss: 2.549e-01,  loss_bc1: 1.597e-02,  loss_bc2: 1.131e-02, loss_ics_u: 9.868e-02, loss_ics_ut: 8.490e-04,  Loss_res: 1.253e-03 , Time: 465.30
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 13200, Loss: 2.788e-01,  loss_bc1: 1.055e-02,  loss_bc2: 1.164e-02, loss_ics_u: 1.157e-01, loss_ics_ut: 9.645e-04,  Loss_res: 1.011e-03 , Time: 468.71
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 13300, Loss: 2.215e-01,  loss_bc1: 1.235e-02,  loss_bc2: 1.295e-02, loss_ics_u: 8.304e-02, loss_ics_ut: 1.637e-03,  Loss_res: 1.562e-03 , Time: 472.18
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 13400, Loss: 2.749e-01,  loss_bc1: 1.381e-02,  loss_bc2: 1.321e-02, loss_ics_u: 1.089e-01, loss_ics_ut: 5.587e-04,  Loss_res: 1.914e-03 , Time: 475.57
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 13500, Loss: 2.698e-01,  loss_bc1: 1.298e-02,  loss_bc2: 1.327e-02, loss_ics_u: 1.071e-01, loss_ics_ut: 9.701e-04,  Loss_res: 1.089e-03 , Time: 478.96
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 13600, Loss: 2.572e-01,  loss_bc1: 1.097e-02,  loss_bc2: 1.263e-02, loss_ics_u: 1.033e-01, loss_ics_ut: 9.143e-04,  Loss_res: 1.478e-03 , Time: 482.41
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 13700, Loss: 2.678e-01,  loss_bc1: 1.232e-02,  loss_bc2: 1.214e-02, loss_ics_u: 1.077e-01, loss_ics_ut: 9.873e-04,  Loss_res: 1.595e-03 , Time: 485.82
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 13800, Loss: 2.659e-01,  loss_bc1: 1.112e-02,  loss_bc2: 1.100e-02, loss_ics_u: 1.091e-01, loss_ics_ut: 1.050e-03,  Loss_res: 1.398e-03 , Time: 489.24
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 13900, Loss: 2.346e-01,  loss_bc1: 1.291e-02,  loss_bc2: 1.299e-02, loss_ics_u: 8.871e-02, loss_ics_ut: 1.994e-03,  Loss_res: 1.356e-03 , Time: 492.70
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 14000, Loss: 2.443e-01,  loss_bc1: 1.137e-02,  loss_bc2: 1.366e-02, loss_ics_u: 9.541e-02, loss_ics_ut: 9.363e-04,  Loss_res: 1.546e-03 , Time: 496.14
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 14100, Loss: 2.589e-01,  loss_bc1: 1.089e-02,  loss_bc2: 1.216e-02, loss_ics_u: 1.048e-01, loss_ics_ut: 8.457e-04,  Loss_res: 1.605e-03 , Time: 499.55
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 14200, Loss: 2.768e-01,  loss_bc1: 1.203e-02,  loss_bc2: 1.449e-02, loss_ics_u: 1.097e-01, loss_ics_ut: 1.163e-03,  Loss_res: 1.962e-03 , Time: 503.03
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 14300, Loss: 2.725e-01,  loss_bc1: 1.149e-02,  loss_bc2: 1.218e-02, loss_ics_u: 1.110e-01, loss_ics_ut: 8.571e-04,  Loss_res: 1.385e-03 , Time: 506.49
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 14400, Loss: 2.542e-01,  loss_bc1: 8.913e-03,  loss_bc2: 1.507e-02, loss_ics_u: 1.010e-01, loss_ics_ut: 1.321e-03,  Loss_res: 1.714e-03 , Time: 509.96
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 14500, Loss: 2.560e-01,  loss_bc1: 9.409e-03,  loss_bc2: 1.154e-02, loss_ics_u: 1.055e-01, loss_ics_ut: 8.511e-04,  Loss_res: 1.409e-03 , Time: 513.63
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 14600, Loss: 2.895e-01,  loss_bc1: 1.484e-02,  loss_bc2: 1.350e-02, loss_ics_u: 1.146e-01, loss_ics_ut: 1.108e-03,  Loss_res: 1.339e-03 , Time: 517.16
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 14700, Loss: 2.643e-01,  loss_bc1: 1.548e-02,  loss_bc2: 1.195e-02, loss_ics_u: 1.018e-01, loss_ics_ut: 2.173e-03,  Loss_res: 1.616e-03 , Time: 520.63
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 14800, Loss: 2.451e-01,  loss_bc1: 1.059e-02,  loss_bc2: 1.160e-02, loss_ics_u: 9.843e-02, loss_ics_ut: 1.321e-03,  Loss_res: 1.239e-03 , Time: 524.11
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 14900, Loss: 2.698e-01,  loss_bc1: 1.404e-02,  loss_bc2: 1.288e-02, loss_ics_u: 1.056e-01, loss_ics_ut: 1.720e-03,  Loss_res: 1.309e-03 , Time: 527.57
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 15000, Loss: 2.602e-01,  loss_bc1: 1.235e-02,  loss_bc2: 1.038e-02, loss_ics_u: 1.050e-01, loss_ics_ut: 1.637e-03,  Loss_res: 1.411e-03 , Time: 531.10
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 15100, Loss: 2.363e-01,  loss_bc1: 1.069e-02,  loss_bc2: 1.051e-02, loss_ics_u: 9.508e-02, loss_ics_ut: 1.168e-03,  Loss_res: 1.411e-03 , Time: 534.57
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 15200, Loss: 2.406e-01,  loss_bc1: 9.297e-03,  loss_bc2: 1.147e-02, loss_ics_u: 9.797e-02, loss_ics_ut: 9.435e-04,  Loss_res: 1.193e-03 , Time: 538.93
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 15300, Loss: 2.626e-01,  loss_bc1: 1.112e-02,  loss_bc2: 1.331e-02, loss_ics_u: 1.055e-01, loss_ics_ut: 8.742e-04,  Loss_res: 1.092e-03 , Time: 543.17
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 15400, Loss: 2.489e-01,  loss_bc1: 1.221e-02,  loss_bc2: 1.262e-02, loss_ics_u: 9.626e-02, loss_ics_ut: 2.495e-03,  Loss_res: 1.727e-03 , Time: 546.97
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 15500, Loss: 2.521e-01,  loss_bc1: 1.250e-02,  loss_bc2: 1.057e-02, loss_ics_u: 1.006e-01, loss_ics_ut: 1.644e-03,  Loss_res: 1.443e-03 , Time: 550.42
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 15600, Loss: 2.553e-01,  loss_bc1: 8.303e-03,  loss_bc2: 1.142e-02, loss_ics_u: 1.060e-01, loss_ics_ut: 1.196e-03,  Loss_res: 1.466e-03 , Time: 554.01
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 15700, Loss: 2.379e-01,  loss_bc1: 7.959e-03,  loss_bc2: 1.163e-02, loss_ics_u: 9.768e-02, loss_ics_ut: 1.078e-03,  Loss_res: 1.220e-03 , Time: 557.44
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 15800, Loss: 2.525e-01,  loss_bc1: 1.016e-02,  loss_bc2: 1.213e-02, loss_ics_u: 1.025e-01, loss_ics_ut: 9.073e-04,  Loss_res: 1.142e-03 , Time: 560.92
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 15900, Loss: 2.414e-01,  loss_bc1: 1.075e-02,  loss_bc2: 1.048e-02, loss_ics_u: 9.774e-02, loss_ics_ut: 1.167e-03,  Loss_res: 1.081e-03 , Time: 565.54
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 16000, Loss: 2.603e-01,  loss_bc1: 1.014e-02,  loss_bc2: 1.185e-02, loss_ics_u: 1.067e-01, loss_ics_ut: 9.070e-04,  Loss_res: 1.041e-03 , Time: 569.53
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 16100, Loss: 2.532e-01,  loss_bc1: 1.038e-02,  loss_bc2: 1.271e-02, loss_ics_u: 1.017e-01, loss_ics_ut: 1.188e-03,  Loss_res: 1.203e-03 , Time: 573.01
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 16200, Loss: 2.538e-01,  loss_bc1: 8.630e-03,  loss_bc2: 1.290e-02, loss_ics_u: 1.036e-01, loss_ics_ut: 7.707e-04,  Loss_res: 1.993e-03 , Time: 576.55
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 16300, Loss: 2.355e-01,  loss_bc1: 9.649e-03,  loss_bc2: 1.031e-02, loss_ics_u: 9.614e-02, loss_ics_ut: 8.972e-04,  Loss_res: 1.499e-03 , Time: 579.98
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 16400, Loss: 2.424e-01,  loss_bc1: 1.059e-02,  loss_bc2: 1.172e-02, loss_ics_u: 9.673e-02, loss_ics_ut: 1.459e-03,  Loss_res: 1.418e-03 , Time: 583.38
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 16500, Loss: 2.487e-01,  loss_bc1: 1.107e-02,  loss_bc2: 1.152e-02, loss_ics_u: 1.001e-01, loss_ics_ut: 1.043e-03,  Loss_res: 1.330e-03 , Time: 586.83
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 16600, Loss: 2.618e-01,  loss_bc1: 1.088e-02,  loss_bc2: 1.145e-02, loss_ics_u: 1.067e-01, loss_ics_ut: 9.172e-04,  Loss_res: 1.891e-03 , Time: 590.24
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 16700, Loss: 2.587e-01,  loss_bc1: 1.107e-02,  loss_bc2: 1.224e-02, loss_ics_u: 1.046e-01, loss_ics_ut: 1.019e-03,  Loss_res: 8.933e-04 , Time: 593.70
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 16800, Loss: 2.349e-01,  loss_bc1: 7.597e-03,  loss_bc2: 1.122e-02, loss_ics_u: 9.675e-02, loss_ics_ut: 1.313e-03,  Loss_res: 1.150e-03 , Time: 597.11
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 16900, Loss: 2.679e-01,  loss_bc1: 1.162e-02,  loss_bc2: 1.052e-02, loss_ics_u: 1.097e-01, loss_ics_ut: 1.152e-03,  Loss_res: 1.927e-03 , Time: 600.66
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 17000, Loss: 2.631e-01,  loss_bc1: 5.874e-03,  loss_bc2: 1.237e-02, loss_ics_u: 1.101e-01, loss_ics_ut: 2.345e-03,  Loss_res: 1.836e-03 , Time: 604.10
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 17100, Loss: 2.447e-01,  loss_bc1: 8.409e-03,  loss_bc2: 1.023e-02, loss_ics_u: 1.021e-01, loss_ics_ut: 1.011e-03,  Loss_res: 1.248e-03 , Time: 607.54
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 17200, Loss: 2.474e-01,  loss_bc1: 1.152e-02,  loss_bc2: 1.169e-02, loss_ics_u: 9.903e-02, loss_ics_ut: 8.990e-04,  Loss_res: 1.110e-03 , Time: 611.08
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 17300, Loss: 2.730e-01,  loss_bc1: 1.349e-02,  loss_bc2: 1.004e-02, loss_ics_u: 1.111e-01, loss_ics_ut: 1.104e-03,  Loss_res: 1.488e-03 , Time: 614.47
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 17400, Loss: 2.436e-01,  loss_bc1: 7.567e-03,  loss_bc2: 1.008e-02, loss_ics_u: 1.029e-01, loss_ics_ut: 6.566e-04,  Loss_res: 1.155e-03 , Time: 617.89
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 17500, Loss: 2.650e-01,  loss_bc1: 8.430e-03,  loss_bc2: 1.239e-02, loss_ics_u: 1.101e-01, loss_ics_ut: 1.091e-03,  Loss_res: 9.020e-04 , Time: 621.39
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 17600, Loss: 2.817e-01,  loss_bc1: 1.012e-02,  loss_bc2: 9.506e-03, loss_ics_u: 1.199e-01, loss_ics_ut: 5.860e-04,  Loss_res: 1.461e-03 , Time: 624.85
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 17700, Loss: 2.307e-01,  loss_bc1: 9.990e-03,  loss_bc2: 1.039e-02, loss_ics_u: 9.330e-02, loss_ics_ut: 9.857e-04,  Loss_res: 1.323e-03 , Time: 628.28
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 17800, Loss: 2.641e-01,  loss_bc1: 9.278e-03,  loss_bc2: 1.162e-02, loss_ics_u: 1.097e-01, loss_ics_ut: 9.943e-04,  Loss_res: 9.102e-04 , Time: 631.77
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 17900, Loss: 2.132e-01,  loss_bc1: 9.195e-03,  loss_bc2: 1.027e-02, loss_ics_u: 8.551e-02, loss_ics_ut: 9.793e-04,  Loss_res: 1.323e-03 , Time: 635.36
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 18000, Loss: 2.171e-01,  loss_bc1: 1.008e-02,  loss_bc2: 1.096e-02, loss_ics_u: 8.597e-02, loss_ics_ut: 7.531e-04,  Loss_res: 1.567e-03 , Time: 641.54
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 18100, Loss: 2.330e-01,  loss_bc1: 9.522e-03,  loss_bc2: 1.094e-02, loss_ics_u: 9.470e-02, loss_ics_ut: 8.403e-04,  Loss_res: 9.739e-04 , Time: 648.49
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 18200, Loss: 2.431e-01,  loss_bc1: 6.906e-03,  loss_bc2: 1.190e-02, loss_ics_u: 1.014e-01, loss_ics_ut: 7.642e-04,  Loss_res: 1.261e-03 , Time: 652.30
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 18300, Loss: 2.348e-01,  loss_bc1: 9.021e-03,  loss_bc2: 1.076e-02, loss_ics_u: 9.601e-02, loss_ics_ut: 1.074e-03,  Loss_res: 1.089e-03 , Time: 655.69
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 18400, Loss: 2.400e-01,  loss_bc1: 8.369e-03,  loss_bc2: 1.152e-02, loss_ics_u: 9.739e-02, loss_ics_ut: 1.884e-03,  Loss_res: 1.645e-03 , Time: 658.98
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 18500, Loss: 2.201e-01,  loss_bc1: 9.899e-03,  loss_bc2: 1.198e-02, loss_ics_u: 8.593e-02, loss_ics_ut: 1.224e-03,  Loss_res: 2.067e-03 , Time: 662.28
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 18600, Loss: 2.517e-01,  loss_bc1: 1.036e-02,  loss_bc2: 9.471e-03, loss_ics_u: 1.047e-01, loss_ics_ut: 9.249e-04,  Loss_res: 8.419e-04 , Time: 665.60
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 18700, Loss: 2.630e-01,  loss_bc1: 8.633e-03,  loss_bc2: 1.081e-02, loss_ics_u: 1.107e-01, loss_ics_ut: 9.889e-04,  Loss_res: 8.434e-04 , Time: 668.88
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 18800, Loss: 2.359e-01,  loss_bc1: 8.748e-03,  loss_bc2: 1.071e-02, loss_ics_u: 9.672e-02, loss_ics_ut: 1.246e-03,  Loss_res: 1.010e-03 , Time: 672.16
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 18900, Loss: 2.563e-01,  loss_bc1: 7.383e-03,  loss_bc2: 1.063e-02, loss_ics_u: 1.090e-01, loss_ics_ut: 7.153e-04,  Loss_res: 8.732e-04 , Time: 675.45
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 19000, Loss: 2.314e-01,  loss_bc1: 9.987e-03,  loss_bc2: 1.032e-02, loss_ics_u: 9.367e-02, loss_ics_ut: 1.239e-03,  Loss_res: 9.866e-04 , Time: 678.72
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 19100, Loss: 2.748e-01,  loss_bc1: 7.833e-03,  loss_bc2: 9.761e-03, loss_ics_u: 1.185e-01, loss_ics_ut: 8.032e-04,  Loss_res: 9.972e-04 , Time: 682.02
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 19200, Loss: 2.311e-01,  loss_bc1: 7.755e-03,  loss_bc2: 1.152e-02, loss_ics_u: 9.474e-02, loss_ics_ut: 9.551e-04,  Loss_res: 1.165e-03 , Time: 685.32
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 19300, Loss: 2.309e-01,  loss_bc1: 8.227e-03,  loss_bc2: 1.065e-02, loss_ics_u: 9.531e-02, loss_ics_ut: 8.789e-04,  Loss_res: 7.331e-04 , Time: 688.61
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 19400, Loss: 2.405e-01,  loss_bc1: 7.258e-03,  loss_bc2: 1.053e-02, loss_ics_u: 1.004e-01, loss_ics_ut: 1.605e-03,  Loss_res: 7.891e-04 , Time: 691.97
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 19500, Loss: 2.632e-01,  loss_bc1: 9.484e-03,  loss_bc2: 1.014e-02, loss_ics_u: 1.106e-01, loss_ics_ut: 8.373e-04,  Loss_res: 1.123e-03 , Time: 695.31
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 19600, Loss: 2.496e-01,  loss_bc1: 9.367e-03,  loss_bc2: 9.820e-03, loss_ics_u: 1.036e-01, loss_ics_ut: 1.476e-03,  Loss_res: 9.977e-04 , Time: 698.58
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 19700, Loss: 2.477e-01,  loss_bc1: 9.299e-03,  loss_bc2: 1.034e-02, loss_ics_u: 1.027e-01, loss_ics_ut: 9.547e-04,  Loss_res: 1.129e-03 , Time: 702.05
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 19800, Loss: 2.451e-01,  loss_bc1: 1.110e-02,  loss_bc2: 9.313e-03, loss_ics_u: 1.004e-01, loss_ics_ut: 1.209e-03,  Loss_res: 1.130e-03 , Time: 705.34
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 19900, Loss: 2.297e-01,  loss_bc1: 1.043e-02,  loss_bc2: 1.004e-02, loss_ics_u: 9.280e-02, loss_ics_ut: 1.058e-03,  Loss_res: 1.067e-03 , Time: 708.63
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 20000, Loss: 2.326e-01,  loss_bc1: 9.558e-03,  loss_bc2: 1.092e-02, loss_ics_u: 9.468e-02, loss_ics_ut: 6.901e-04,  Loss_res: 8.634e-04 , Time: 711.98
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 20100, Loss: 2.471e-01,  loss_bc1: 1.047e-02,  loss_bc2: 9.175e-03, loss_ics_u: 1.021e-01, loss_ics_ut: 1.348e-03,  Loss_res: 9.043e-04 , Time: 715.25
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 20200, Loss: 2.439e-01,  loss_bc1: 8.120e-03,  loss_bc2: 9.517e-03, loss_ics_u: 1.027e-01, loss_ics_ut: 1.084e-03,  Loss_res: 1.117e-03 , Time: 718.55
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 20300, Loss: 2.527e-01,  loss_bc1: 9.675e-03,  loss_bc2: 1.010e-02, loss_ics_u: 1.050e-01, loss_ics_ut: 1.193e-03,  Loss_res: 8.604e-04 , Time: 721.86
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# It: 20400, Loss: 2.292e-01,  loss_bc1: 9.172e-03,  loss_bc2: 8.581e-03, loss_ics_u: 9.508e-02, loss_ics_ut: 1.320e-03,  Loss_res: 8.503e-04 , Time: 725.18
# loss_bc1: 2.000e+00
# loss_ics_u: 2.000e+00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_27569/794721725.py in <module>
#      77             elif mtd =="mini_batch":
#      78                 print("mini_batch method is used")
# ---> 79                 model.trainmb(nIter, mbbatch_size)
#      80             else:
#      81                 print("unknown method!")
#
# /tmp/ipykernel_27569/3559053648.py in trainmb(self, nIter, batch_size, log_NTK, update_lam)
#     265
#     266             # Run the Tensorflow session to minimize the loss
# --> 267             self.sess.run(self.train_op, tf_dict)
#     268
#     269             # Print
#
# ~/anaconda3/envs/twoPhase/lib/python3.7/site-packages/tensorflow_core/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     954     try:
#     955       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 956                          run_metadata_ptr)
#     957       if run_metadata:
#     958         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/envs/twoPhase/lib/python3.7/site-packages/tensorflow_core/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1178     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1179       results = self._do_run(handle, final_targets, final_fetches,
# -> 1180                              feed_dict_tensor, options, run_metadata)
#    1181     else:
#    1182       results = []
#
# ~/anaconda3/envs/twoPhase/lib/python3.7/site-packages/tensorflow_core/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1357     if handle is None:
#    1358       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1359                            run_metadata)
#    1360     else:
#    1361       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/anaconda3/envs/twoPhase/lib/python3.7/site-packages/tensorflow_core/python/client/session.py in _do_call(self, fn, *args)
#    1363   def _do_call(self, fn, *args):
#    1364     try:
# -> 1365       return fn(*args)
#    1366     except errors.OpError as e:
#    1367       message = compat.as_text(e.message)
#
# ~/anaconda3/envs/twoPhase/lib/python3.7/site-packages/tensorflow_core/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1348       self._extend_graph()
#    1349       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
# -> 1350                                       target_list, run_metadata)
#    1351
#    1352     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~/anaconda3/envs/twoPhase/lib/python3.7/site-packages/tensorflow_core/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1441     return tf_session.TF_SessionRun_wrapper(self._session, options, feed_dict,
#    1442                                             fetch_list, target_list,
# -> 1443                                             run_metadata)
#    1444
#    1445   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
# Predictions
u_pred = model.predict_u(X_star)
r_pred = model.predict_r(X_star)
# Predictions

error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)
error_r = np.linalg.norm(r_star - r_pred, 2)# / np.linalg.norm(r_star, 2)

# print('elapsed: {:.2e}'.format(elapsed))

print('Relative L2 error_u: {:.2e}'.format(error_u))
print('Relative L2 error_r: {:.2e}'.format(error_r))
# Out:
# Relative L2 error_u: 5.13e-01
# Relative L2 error_r: 7.59e+00

# %%
# Predictions
u_pred = model.predict_u(X_star)
# Predictions

error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)

print('elapsed: {:.2e}'.format(elapsed))

print('Relative L2 error_u: {:.2e}'.format(error_u))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_27569/3423908231.py in <module>
#       5 error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)
#       6
# ----> 7 print('elapsed: {:.2e}'.format(elapsed))
#       8
#       9 print('Relative L2 error_u: {:.2e}'.format(error_u))
#
# NameError: name 'elapsed' is not defined

# %%
r_pred =r_pred.reshape(200,200)

U_star = griddata(X_star, u_star.flatten(), (t, x), method='cubic')
r_star = griddata(X_star, r_star.flatten(), (t, x), method='cubic')
U_pred = griddata(X_star, u_pred.flatten(), (t, x), method='cubic')
# R_pred = griddata(X_star, r_pred.flatten(), (t, x), method='cubic')


plt.figure(figsize=(18, 9))
plt.subplot(2, 3, 1)
plt.pcolor(t, x, U_star, cmap='jet')
plt.colorbar()
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.title('Exact u(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 2)
plt.pcolor(t, x, U_pred, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Predicted u(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 3)
plt.pcolor(t, x, np.abs(U_star - U_pred), cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Absolute error')
plt.tight_layout()

plt.subplot(2, 3, 4)
plt.pcolor(t, x, r_star, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Exact r(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 5)
plt.pcolor(t, x, r_pred, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Predicted r(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 6)
plt.pcolor(t, x, np.abs(r_star - r_pred), cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Absolute error')
plt.tight_layout()
plt.show()

# %%
# Define PINN model
a = 0.5
c = 2

kernel_size = 300

# Domain boundaries
ics_coords = np.array([[0.0, 0.0],  [0.0, 1.0]])
bc1_coords = np.array([[0.0, 0.0],  [1.0, 0.0]])
bc2_coords = np.array([[0.0, 1.0],  [1.0, 1.0]])
dom_coords = np.array([[0.0, 0.0],  [1.0, 1.0]])

# Create initial conditions samplers
ics_sampler = Sampler(2, ics_coords, lambda x: u(x, a, c), name='Initial Condition 1')

# Create boundary conditions samplers
bc1 = Sampler(2, bc1_coords, lambda x: u(x, a, c), name='Dirichlet BC1')
bc2 = Sampler(2, bc2_coords, lambda x: u(x, a, c), name='Dirichlet BC2')
bcs_sampler = [bc1, bc2]

# Create residual sampler
res_sampler = Sampler(2, dom_coords, lambda x: r(x, a, c), name='Forcing')



nIter =40000
bcbatch_size = 500
ubatch_size = 5000
mbbatch_size = 300



# Define model
mode = 'M4'
layers = [2, 500, 500, 500, 1]


nn = 200
t = np.linspace(dom_coords[0, 0], dom_coords[1, 0], nn)[:, None]
x = np.linspace(dom_coords[0, 1], dom_coords[1, 1], nn)[:, None]
t, x = np.meshgrid(t, x)
X_star = np.hstack((t.flatten()[:, None], x.flatten()[:, None]))

u_star = u(X_star, a,c)
r_star = r(X_star, a, c)

iterations = 1
methods = [  "mini_batch"]

result_dict =  dict((mtd, []) for mtd in methods)

for mtd in methods:
    print("Method: ", mtd)
    time_list = []
    error_u_list = []
    
    for index in range(iterations):

        print("Epoch: ", str(index+1))

        # Create residual sampler

        [elapsed, error_u , model] = test_method(mtd , layers,  ics_sampler, bcs_sampler, res_sampler, c ,kernel_size , X_star , u_star , r_star , nIter ,mbbatch_size , bcbatch_size , ubatch_size )


        print('elapsed: {:.2e}'.format(elapsed))
        print('Relative L2 error_u: {:.2e}'.format(error_u))

        time_list.append(elapsed)
        error_u_list.append(error_u)

    print("\n\nMethod: ", mtd)
    print("\naverage of time_list:" , sum(time_list) / len(time_list) )
    print("average of error_u_list:" , sum(error_u_list) / len(error_u_list) )
    # print("average of error_r_list:" , sum(error_r_list) / len(error_r_list) )

    result_dict[mtd] = [time_list ,error_u_list]
    # scipy.io.savemat("M2_result_"+str(iterations)+"_"+mtd+".mat" , {'time_list':np.array(time_list),'error_u_list':np.array(error_u_list),'error_f_list':np.array(error_f_list)})

    scipy.io.savemat("./1DWave_database/"+mtd+"_1Dwave_"+mode+"_result_mb"+str(mbbatch_size)+"_fb"+str(ubatch_size)+"_bc"+str(mbbatch_size)+"_"+str(iterations)+".mat" , result_dict)

###############################################################################################################################################
# Out:
# Method:  mini_batch
# Epoch:  1
# WARNING:tensorflow:From /tmp/ipykernel_9685/1247141941.py:4: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_9685/1247141941.py:5: The name tf.GPUOptions is deprecated. Please use tf.compat.v1.GPUOptions instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_9685/1247141941.py:6: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_9685/1247141941.py:6: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_9685/930390821.py:39: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# 2023-11-26 15:05:13.752303: I tensorflow/core/platform/cpu_feature_guard.cc:145] This TensorFlow binary is optimized with Intel(R) MKL-DNN to use the following CPU instructions in performance critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in non-MKL-DNN operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-26 15:05:13.777152: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2899885000 Hz
# 2023-11-26 15:05:13.777588: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55e5d2b18e20 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-11-26 15:05:13.777603: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2023-11-26 15:05:13.781503: I tensorflow/core/common_runtime/process_util.cc:115] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# WARNING:tensorflow:From /tmp/ipykernel_9685/930390821.py:94: The name tf.train.exponential_decay is deprecated. Please use tf.compat.v1.train.exponential_decay instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_9685/930390821.py:96: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_9685/930390821.py:99: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# mini_batch method is used
# It: 0, Loss: 4.827e+01,  loss_bc1: 2.607e+00,  loss_bc2: 2.707e+00, loss_ics_u: 1.369e+00, loss_ics_ut: 8.358e+00,  Loss_res: 9.092e+00 , Time: 1.51
# loss_bc1: 5.314e+04
# loss_ics_u: 9.728e+04
# loss_res_val: 9.092e+02
# It: 100, Loss: 3.623e+04,  loss_bc1: 9.761e-02,  loss_bc2: 3.962e-02, loss_ics_u: 2.837e-01, loss_ics_ut: 1.377e-02,  Loss_res: 2.132e-03 , Time: 3.01
# loss_bc1: 5.383e+04
# loss_ics_u: 9.876e+04
# loss_res_val: 9.093e+02
# It: 200, Loss: 2.505e+04,  loss_bc1: 5.122e-02,  loss_bc2: 4.537e-02, loss_ics_u: 1.893e-01, loss_ics_ut: 1.101e-03,  Loss_res: 1.152e+00 , Time: 3.09
# loss_bc1: 5.415e+04
# loss_ics_u: 9.940e+04
# loss_res_val: 9.478e+02
# It: 300, Loss: 2.490e+04,  loss_bc1: 4.457e-02,  loss_bc2: 2.164e-02, loss_ics_u: 1.861e-01, loss_ics_ut: 1.787e-02,  Loss_res: 1.107e+00 , Time: 3.01
# loss_bc1: 5.431e+04
# loss_ics_u: 9.991e+04
# loss_res_val: 9.754e+02
# It: 400, Loss: 1.634e+04,  loss_bc1: 4.384e-02,  loss_bc2: 1.383e-02, loss_ics_u: 1.133e-01, loss_ics_ut: 9.906e-03,  Loss_res: 9.158e-01 , Time: 3.06
# loss_bc1: 5.443e+04
# loss_ics_u: 1.002e+05
# loss_res_val: 9.938e+02
# It: 500, Loss: 1.856e+04,  loss_bc1: 4.399e-02,  loss_bc2: 1.034e-02, loss_ics_u: 1.456e-01, loss_ics_ut: 4.305e-03,  Loss_res: 5.937e-01 , Time: 3.24
# loss_bc1: 5.452e+04
# loss_ics_u: 1.004e+05
# loss_res_val: 1.004e+03
# It: 600, Loss: 1.909e+04,  loss_bc1: 3.961e-02,  loss_bc2: 1.190e-02, loss_ics_u: 1.491e-01, loss_ics_ut: 5.215e-03,  Loss_res: 7.827e-01 , Time: 3.95
# loss_bc1: 5.459e+04
# loss_ics_u: 1.006e+05
# loss_res_val: 1.015e+03
# It: 700, Loss: 1.693e+04,  loss_bc1: 4.032e-02,  loss_bc2: 1.039e-02, loss_ics_u: 1.326e-01, loss_ics_ut: 3.295e-03,  Loss_res: 4.722e-01 , Time: 3.54
# loss_bc1: 5.466e+04
# loss_ics_u: 1.008e+05
# loss_res_val: 1.021e+03
# It: 800, Loss: 1.511e+04,  loss_bc1: 2.885e-02,  loss_bc2: 1.549e-02, loss_ics_u: 1.116e-01, loss_ics_ut: 1.007e-02,  Loss_res: 4.158e-01 , Time: 3.46
# loss_bc1: 5.471e+04
# loss_ics_u: 1.009e+05
# loss_res_val: 1.025e+03
# It: 900, Loss: 1.714e+04,  loss_bc1: 4.178e-02,  loss_bc2: 1.996e-02, loss_ics_u: 1.290e-01, loss_ics_ut: 3.116e-03,  Loss_res: 4.123e-01 , Time: 4.13
# loss_bc1: 5.477e+04
# loss_ics_u: 1.011e+05
# loss_res_val: 1.029e+03
# It: 1000, Loss: 1.952e+04,  loss_bc1: 3.226e-02,  loss_bc2: 1.252e-02, loss_ics_u: 1.257e-01, loss_ics_ut: 3.995e-02,  Loss_res: 3.136e-01 , Time: 3.39
# loss_bc1: 5.481e+04
# loss_ics_u: 1.012e+05
# loss_res_val: 1.032e+03
# It: 1100, Loss: 1.535e+04,  loss_bc1: 3.257e-02,  loss_bc2: 1.375e-02, loss_ics_u: 9.781e-02, loss_ics_ut: 2.019e-02,  Loss_res: 8.393e-01 , Time: 3.31
# loss_bc1: 5.485e+04
# loss_ics_u: 1.013e+05
# loss_res_val: 1.039e+03
# It: 1200, Loss: 1.411e+04,  loss_bc1: 3.429e-02,  loss_bc2: 1.448e-02, loss_ics_u: 1.087e-01, loss_ics_ut: 1.978e-03,  Loss_res: 2.106e-01 , Time: 3.51
# loss_bc1: 5.488e+04
# loss_ics_u: 1.014e+05
# loss_res_val: 1.041e+03
# It: 1300, Loss: 1.362e+04,  loss_bc1: 2.497e-02,  loss_bc2: 1.457e-02, loss_ics_u: 1.066e-01, loss_ics_ut: 3.287e-03,  Loss_res: 2.997e-01 , Time: 3.47
# loss_bc1: 5.491e+04
# loss_ics_u: 1.015e+05
# loss_res_val: 1.043e+03
# It: 1400, Loss: 1.558e+04,  loss_bc1: 3.440e-02,  loss_bc2: 1.363e-02, loss_ics_u: 1.062e-01, loss_ics_ut: 1.845e-02,  Loss_res: 2.815e-01 , Time: 3.46
# loss_bc1: 5.494e+04
# loss_ics_u: 1.016e+05
# loss_res_val: 1.045e+03
# It: 1500, Loss: 1.183e+04,  loss_bc1: 1.758e-02,  loss_bc2: 1.232e-02, loss_ics_u: 9.498e-02, loss_ics_ut: 1.531e-03,  Loss_res: 3.694e-01 , Time: 3.61
# loss_bc1: 5.496e+04
# loss_ics_u: 1.016e+05
# loss_res_val: 1.047e+03
# It: 1600, Loss: 1.500e+04,  loss_bc1: 2.720e-02,  loss_bc2: 1.249e-02, loss_ics_u: 1.002e-01, loss_ics_ut: 2.433e-02,  Loss_res: 1.572e-01 , Time: 3.43
# loss_bc1: 5.499e+04
# loss_ics_u: 1.017e+05
# loss_res_val: 1.048e+03
# It: 1700, Loss: 1.510e+04,  loss_bc1: 2.644e-02,  loss_bc2: 1.344e-02, loss_ics_u: 1.142e-01, loss_ics_ut: 7.314e-03,  Loss_res: 5.243e-01 , Time: 3.41
# loss_bc1: 5.501e+04
# loss_ics_u: 1.018e+05
# loss_res_val: 1.051e+03
# It: 1800, Loss: 1.216e+04,  loss_bc1: 2.343e-02,  loss_bc2: 9.552e-03, loss_ics_u: 9.835e-02, loss_ics_ut: 1.144e-03,  Loss_res: 2.145e-01 , Time: 3.42
# loss_bc1: 5.503e+04
# loss_ics_u: 1.018e+05
# loss_res_val: 1.052e+03
# It: 1900, Loss: 1.553e+04,  loss_bc1: 2.711e-02,  loss_bc2: 1.268e-02, loss_ics_u: 1.154e-01, loss_ics_ut: 1.373e-02,  Loss_res: 1.879e-01 , Time: 3.32
# loss_bc1: 5.505e+04
# loss_ics_u: 1.019e+05
# loss_res_val: 1.053e+03
# It: 2000, Loss: 1.373e+04,  loss_bc1: 1.808e-02,  loss_bc2: 9.872e-03, loss_ics_u: 1.044e-01, loss_ics_ut: 1.305e-02,  Loss_res: 2.167e-01 , Time: 3.40
# loss_bc1: 5.506e+04
# loss_ics_u: 1.019e+05
# loss_res_val: 1.054e+03
# It: 2100, Loss: 1.357e+04,  loss_bc1: 1.812e-02,  loss_bc2: 1.200e-02, loss_ics_u: 1.121e-01, loss_ics_ut: 2.765e-03,  Loss_res: 1.928e-01 , Time: 3.42
# loss_bc1: 5.507e+04
# loss_ics_u: 1.020e+05
# loss_res_val: 1.055e+03
# It: 2200, Loss: 1.536e+04,  loss_bc1: 2.163e-02,  loss_bc2: 1.349e-02, loss_ics_u: 1.110e-01, loss_ics_ut: 1.290e-02,  Loss_res: 7.527e-01 , Time: 3.37
# loss_bc1: 5.509e+04
# loss_ics_u: 1.020e+05
# loss_res_val: 1.058e+03
# It: 2300, Loss: 1.280e+04,  loss_bc1: 3.042e-02,  loss_bc2: 1.270e-02, loss_ics_u: 9.456e-02, loss_ics_ut: 5.691e-03,  Loss_res: 1.876e-01 , Time: 3.48
# loss_bc1: 5.511e+04
# loss_ics_u: 1.021e+05
# loss_res_val: 1.059e+03
# It: 2400, Loss: 1.228e+04,  loss_bc1: 2.248e-02,  loss_bc2: 1.306e-02, loss_ics_u: 9.533e-02, loss_ics_ut: 3.357e-03,  Loss_res: 2.351e-01 , Time: 3.39
# loss_bc1: 5.512e+04
# loss_ics_u: 1.021e+05
# loss_res_val: 1.060e+03
# It: 2500, Loss: 1.329e+04,  loss_bc1: 2.375e-02,  loss_bc2: 1.531e-02, loss_ics_u: 1.048e-01, loss_ics_ut: 1.362e-03,  Loss_res: 2.777e-01 , Time: 3.43
# loss_bc1: 5.514e+04
# loss_ics_u: 1.022e+05
# loss_res_val: 1.061e+03
# It: 2600, Loss: 1.297e+04,  loss_bc1: 3.540e-02,  loss_bc2: 1.187e-02, loss_ics_u: 8.898e-02, loss_ics_ut: 9.161e-03,  Loss_res: 3.154e-01 , Time: 3.51
# loss_bc1: 5.515e+04
# loss_ics_u: 1.022e+05
# loss_res_val: 1.062e+03
# It: 2700, Loss: 1.206e+04,  loss_bc1: 2.014e-02,  loss_bc2: 1.088e-02, loss_ics_u: 9.354e-02, loss_ics_ut: 3.421e-03,  Loss_res: 4.164e-01 , Time: 6.67
# loss_bc1: 5.516e+04
# loss_ics_u: 1.022e+05
# loss_res_val: 1.064e+03
# It: 2800, Loss: 1.186e+04,  loss_bc1: 1.765e-02,  loss_bc2: 1.423e-02, loss_ics_u: 8.974e-02, loss_ics_ut: 4.060e-03,  Loss_res: 4.857e-01 , Time: 5.40
# loss_bc1: 5.517e+04
# loss_ics_u: 1.023e+05
# loss_res_val: 1.065e+03
# It: 2900, Loss: 1.183e+04,  loss_bc1: 2.330e-02,  loss_bc2: 1.183e-02, loss_ics_u: 9.238e-02, loss_ics_ut: 1.615e-03,  Loss_res: 2.651e-01 , Time: 4.08
# loss_bc1: 5.519e+04
# loss_ics_u: 1.023e+05
# loss_res_val: 1.066e+03
# It: 3000, Loss: 1.106e+04,  loss_bc1: 1.882e-02,  loss_bc2: 1.360e-02, loss_ics_u: 8.589e-02, loss_ics_ut: 2.512e-03,  Loss_res: 2.104e-01 , Time: 3.62
# loss_bc1: 5.520e+04
# loss_ics_u: 1.023e+05
# loss_res_val: 1.067e+03
# It: 3100, Loss: 1.217e+04,  loss_bc1: 1.682e-02,  loss_bc2: 1.417e-02, loss_ics_u: 9.728e-02, loss_ics_ut: 3.035e-03,  Loss_res: 1.825e-01 , Time: 3.72
# loss_bc1: 5.521e+04
# loss_ics_u: 1.024e+05
# loss_res_val: 1.068e+03
# It: 3200, Loss: 1.279e+04,  loss_bc1: 2.165e-02,  loss_bc2: 1.391e-02, loss_ics_u: 1.014e-01, loss_ics_ut: 1.403e-03,  Loss_res: 2.820e-01 , Time: 3.77
# loss_bc1: 5.522e+04
# loss_ics_u: 1.024e+05
# loss_res_val: 1.068e+03
# It: 3300, Loss: 1.278e+04,  loss_bc1: 1.976e-02,  loss_bc2: 1.281e-02, loss_ics_u: 9.681e-02, loss_ics_ut: 8.132e-03,  Loss_res: 2.258e-01 , Time: 3.69
# loss_bc1: 5.523e+04
# loss_ics_u: 1.024e+05
# loss_res_val: 1.069e+03
# It: 3400, Loss: 1.175e+04,  loss_bc1: 1.895e-02,  loss_bc2: 1.062e-02, loss_ics_u: 8.754e-02, loss_ics_ut: 8.988e-03,  Loss_res: 2.168e-01 , Time: 5.01
# loss_bc1: 5.524e+04
# loss_ics_u: 1.024e+05
# loss_res_val: 1.070e+03
# It: 3500, Loss: 1.352e+04,  loss_bc1: 2.627e-02,  loss_bc2: 1.540e-02, loss_ics_u: 9.328e-02, loss_ics_ut: 1.242e-02,  Loss_res: 3.605e-01 , Time: 4.93
# loss_bc1: 5.525e+04
# loss_ics_u: 1.025e+05
# loss_res_val: 1.071e+03
# It: 3600, Loss: 1.178e+04,  loss_bc1: 1.230e-02,  loss_bc2: 1.581e-02, loss_ics_u: 9.504e-02, loss_ics_ut: 1.773e-03,  Loss_res: 2.854e-01 , Time: 3.83
# loss_bc1: 5.525e+04
# loss_ics_u: 1.025e+05
# loss_res_val: 1.072e+03
# It: 3700, Loss: 1.004e+04,  loss_bc1: 1.245e-02,  loss_bc2: 1.195e-02, loss_ics_u: 8.049e-02, loss_ics_ut: 9.335e-04,  Loss_res: 3.182e-01 , Time: 3.72
# loss_bc1: 5.526e+04
# loss_ics_u: 1.025e+05
# loss_res_val: 1.072e+03
# It: 3800, Loss: 1.094e+04,  loss_bc1: 1.485e-02,  loss_bc2: 1.429e-02, loss_ics_u: 8.671e-02, loss_ics_ut: 2.771e-03,  Loss_res: 1.492e-01 , Time: 3.73
# loss_bc1: 5.527e+04
# loss_ics_u: 1.025e+05
# loss_res_val: 1.073e+03
# It: 3900, Loss: 1.187e+04,  loss_bc1: 1.513e-02,  loss_bc2: 1.681e-02, loss_ics_u: 9.083e-02, loss_ics_ut: 5.614e-03,  Loss_res: 2.001e-01 , Time: 4.29
# loss_bc1: 5.528e+04
# loss_ics_u: 1.026e+05
# loss_res_val: 1.073e+03
# It: 4000, Loss: 1.123e+04,  loss_bc1: 1.934e-02,  loss_bc2: 1.184e-02, loss_ics_u: 8.309e-02, loss_ics_ut: 5.893e-03,  Loss_res: 3.518e-01 , Time: 5.47
# loss_bc1: 5.528e+04
# loss_ics_u: 1.026e+05
# loss_res_val: 1.074e+03
# It: 4100, Loss: 1.055e+04,  loss_bc1: 1.644e-02,  loss_bc2: 1.278e-02, loss_ics_u: 7.779e-02, loss_ics_ut: 2.122e-03,  Loss_res: 6.881e-01 , Time: 3.78
# loss_bc1: 5.529e+04
# loss_ics_u: 1.026e+05
# loss_res_val: 1.076e+03
# It: 4200, Loss: 1.050e+04,  loss_bc1: 1.844e-02,  loss_bc2: 1.345e-02, loss_ics_u: 8.115e-02, loss_ics_ut: 2.330e-03,  Loss_res: 1.545e-01 , Time: 4.83
# loss_bc1: 5.530e+04
# loss_ics_u: 1.026e+05
# loss_res_val: 1.076e+03
# It: 4300, Loss: 1.040e+04,  loss_bc1: 1.675e-02,  loss_bc2: 1.380e-02, loss_ics_u: 8.116e-02, loss_ics_ut: 1.082e-03,  Loss_res: 2.527e-01 , Time: 3.56
# loss_bc1: 5.531e+04
# loss_ics_u: 1.026e+05
# loss_res_val: 1.077e+03
# It: 4400, Loss: 1.019e+04,  loss_bc1: 1.965e-02,  loss_bc2: 1.077e-02, loss_ics_u: 7.849e-02, loss_ics_ut: 1.886e-03,  Loss_res: 2.424e-01 , Time: 3.47
# loss_bc1: 5.531e+04
# loss_ics_u: 1.027e+05
# loss_res_val: 1.077e+03
# It: 4500, Loss: 1.124e+04,  loss_bc1: 1.991e-02,  loss_bc2: 1.265e-02, loss_ics_u: 8.266e-02, loss_ics_ut: 6.039e-03,  Loss_res: 3.074e-01 , Time: 3.41
# loss_bc1: 5.532e+04
# loss_ics_u: 1.027e+05
# loss_res_val: 1.078e+03
# It: 4600, Loss: 9.086e+03,  loss_bc1: 1.352e-02,  loss_bc2: 1.160e-02, loss_ics_u: 6.719e-02, loss_ics_ut: 5.677e-03,  Loss_res: 1.992e-01 , Time: 3.43
# loss_bc1: 5.532e+04
# loss_ics_u: 1.027e+05
# loss_res_val: 1.078e+03
# It: 4700, Loss: 1.027e+04,  loss_bc1: 9.919e-03,  loss_bc2: 9.886e-03, loss_ics_u: 8.505e-02, loss_ics_ut: 1.872e-03,  Loss_res: 2.314e-01 , Time: 3.48
# loss_bc1: 5.533e+04
# loss_ics_u: 1.027e+05
# loss_res_val: 1.079e+03
# It: 4800, Loss: 1.084e+04,  loss_bc1: 1.596e-02,  loss_bc2: 9.479e-03, loss_ics_u: 8.293e-02, loss_ics_ut: 6.096e-03,  Loss_res: 2.698e-01 , Time: 3.39
# loss_bc1: 5.533e+04
# loss_ics_u: 1.027e+05
# loss_res_val: 1.079e+03
# It: 4900, Loss: 1.044e+04,  loss_bc1: 1.507e-02,  loss_bc2: 1.129e-02, loss_ics_u: 8.004e-02, loss_ics_ut: 4.682e-03,  Loss_res: 2.575e-01 , Time: 3.37
# loss_bc1: 5.534e+04
# loss_ics_u: 1.028e+05
# loss_res_val: 1.080e+03
# It: 5000, Loss: 1.036e+04,  loss_bc1: 1.212e-02,  loss_bc2: 7.684e-03, loss_ics_u: 8.220e-02, loss_ics_ut: 3.851e-03,  Loss_res: 3.909e-01 , Time: 3.35
# loss_bc1: 5.534e+04
# loss_ics_u: 1.028e+05
# loss_res_val: 1.081e+03
# It: 5100, Loss: 1.002e+04,  loss_bc1: 1.284e-02,  loss_bc2: 1.022e-02, loss_ics_u: 7.480e-02, loss_ics_ut: 7.888e-03,  Loss_res: 2.322e-01 , Time: 3.31
# loss_bc1: 5.535e+04
# loss_ics_u: 1.028e+05
# loss_res_val: 1.081e+03
# It: 5200, Loss: 9.354e+03,  loss_bc1: 1.675e-02,  loss_bc2: 7.655e-03, loss_ics_u: 6.846e-02, loss_ics_ut: 6.900e-03,  Loss_res: 2.381e-01 , Time: 3.42
# loss_bc1: 5.535e+04
# loss_ics_u: 1.028e+05
# loss_res_val: 1.082e+03
# It: 5300, Loss: 8.991e+03,  loss_bc1: 5.829e-03,  loss_bc2: 8.885e-03, loss_ics_u: 7.388e-02, loss_ics_ut: 3.385e-03,  Loss_res: 2.163e-01 , Time: 3.47
# loss_bc1: 5.535e+04
# loss_ics_u: 1.028e+05
# loss_res_val: 1.082e+03
# It: 5400, Loss: 9.256e+03,  loss_bc1: 9.210e-03,  loss_bc2: 9.739e-03, loss_ics_u: 6.904e-02, loss_ics_ut: 8.328e-03,  Loss_res: 2.328e-01 , Time: 3.38
# loss_bc1: 5.536e+04
# loss_ics_u: 1.028e+05
# loss_res_val: 1.082e+03
# It: 5500, Loss: 1.232e+04,  loss_bc1: 1.793e-02,  loss_bc2: 7.007e-03, loss_ics_u: 7.719e-02, loss_ics_ut: 2.716e-02,  Loss_res: 1.952e-01 , Time: 3.34
# loss_bc1: 5.536e+04
# loss_ics_u: 1.028e+05
# loss_res_val: 1.083e+03
# It: 5600, Loss: 9.926e+03,  loss_bc1: 1.282e-02,  loss_bc2: 8.782e-03, loss_ics_u: 7.857e-02, loss_ics_ut: 4.264e-03,  Loss_res: 1.956e-01 , Time: 3.58
# loss_bc1: 5.537e+04
# loss_ics_u: 1.029e+05
# loss_res_val: 1.083e+03
# It: 5700, Loss: 8.467e+03,  loss_bc1: 1.240e-02,  loss_bc2: 5.432e-03, loss_ics_u: 6.511e-02, loss_ics_ut: 4.797e-03,  Loss_res: 2.660e-01 , Time: 3.33
# loss_bc1: 5.537e+04
# loss_ics_u: 1.029e+05
# loss_res_val: 1.083e+03
# It: 5800, Loss: 7.869e+03,  loss_bc1: 4.052e-03,  loss_bc2: 7.784e-03, loss_ics_u: 6.603e-02, loss_ics_ut: 2.006e-03,  Loss_res: 1.975e-01 , Time: 3.35
# loss_bc1: 5.537e+04
# loss_ics_u: 1.029e+05
# loss_res_val: 1.084e+03
# It: 5900, Loss: 8.148e+03,  loss_bc1: 7.261e-03,  loss_bc2: 5.956e-03, loss_ics_u: 6.521e-02, loss_ics_ut: 3.221e-03,  Loss_res: 3.468e-01 , Time: 3.41
# loss_bc1: 5.537e+04
# loss_ics_u: 1.029e+05
# loss_res_val: 1.084e+03
# It: 6000, Loss: 9.279e+03,  loss_bc1: 1.084e-02,  loss_bc2: 7.103e-03, loss_ics_u: 7.721e-02, loss_ics_ut: 1.437e-03,  Loss_res: 1.787e-01 , Time: 3.36
# loss_bc1: 5.538e+04
# loss_ics_u: 1.029e+05
# loss_res_val: 1.085e+03
# It: 6100, Loss: 9.186e+03,  loss_bc1: 6.782e-03,  loss_bc2: 5.058e-03, loss_ics_u: 6.951e-02, loss_ics_ut: 1.065e-02,  Loss_res: 2.591e-01 , Time: 4.06
# loss_bc1: 5.538e+04
# loss_ics_u: 1.029e+05
# loss_res_val: 1.085e+03
# It: 6200, Loss: 8.259e+03,  loss_bc1: 6.273e-03,  loss_bc2: 7.767e-03, loss_ics_u: 6.837e-02, loss_ics_ut: 2.131e-03,  Loss_res: 2.079e-01 , Time: 5.17
# loss_bc1: 5.538e+04
# loss_ics_u: 1.029e+05
# loss_res_val: 1.085e+03
# It: 6300, Loss: 8.283e+03,  loss_bc1: 5.677e-03,  loss_bc2: 9.249e-03, loss_ics_u: 6.770e-02, loss_ics_ut: 1.633e-03,  Loss_res: 2.945e-01 , Time: 5.02
# loss_bc1: 5.538e+04
# loss_ics_u: 1.029e+05
# loss_res_val: 1.086e+03
# It: 6400, Loss: 8.099e+03,  loss_bc1: 8.088e-03,  loss_bc2: 7.561e-03, loss_ics_u: 6.551e-02, loss_ics_ut: 2.391e-03,  Loss_res: 2.231e-01 , Time: 5.21
# loss_bc1: 5.539e+04
# loss_ics_u: 1.030e+05
# loss_res_val: 1.086e+03
# It: 6500, Loss: 8.018e+03,  loss_bc1: 1.221e-02,  loss_bc2: 6.193e-03, loss_ics_u: 5.955e-02, loss_ics_ut: 5.336e-03,  Loss_res: 2.936e-01 , Time: 4.94
# loss_bc1: 5.539e+04
# loss_ics_u: 1.030e+05
# loss_res_val: 1.087e+03
# It: 6600, Loss: 8.590e+03,  loss_bc1: 9.099e-03,  loss_bc2: 4.832e-03, loss_ics_u: 6.594e-02, loss_ics_ut: 6.950e-03,  Loss_res: 2.880e-01 , Time: 4.47
# loss_bc1: 5.539e+04
# loss_ics_u: 1.030e+05
# loss_res_val: 1.087e+03
# It: 6700, Loss: 6.902e+03,  loss_bc1: 7.180e-03,  loss_bc2: 7.259e-03, loss_ics_u: 5.600e-02, loss_ics_ut: 8.094e-04,  Loss_res: 2.317e-01 , Time: 3.95
# loss_bc1: 5.539e+04
# loss_ics_u: 1.030e+05
# loss_res_val: 1.087e+03
# It: 6800, Loss: 7.641e+03,  loss_bc1: 1.016e-02,  loss_bc2: 3.763e-03, loss_ics_u: 6.193e-02, loss_ics_ut: 2.536e-03,  Loss_res: 2.122e-01 , Time: 3.64
# loss_bc1: 5.539e+04
# loss_ics_u: 1.030e+05
# loss_res_val: 1.088e+03
# It: 6900, Loss: 7.805e+03,  loss_bc1: 9.624e-03,  loss_bc2: 6.942e-03, loss_ics_u: 6.032e-02, loss_ics_ut: 2.589e-03,  Loss_res: 3.754e-01 , Time: 3.38
# loss_bc1: 5.540e+04
# loss_ics_u: 1.030e+05
# loss_res_val: 1.088e+03
# It: 7000, Loss: 7.675e+03,  loss_bc1: 7.415e-03,  loss_bc2: 4.125e-03, loss_ics_u: 6.517e-02, loss_ics_ut: 6.327e-04,  Loss_res: 2.373e-01 , Time: 4.03
# loss_bc1: 5.540e+04
# loss_ics_u: 1.030e+05
# loss_res_val: 1.089e+03
# It: 7100, Loss: 7.501e+03,  loss_bc1: 1.128e-02,  loss_bc2: 7.333e-03, loss_ics_u: 5.890e-02, loss_ics_ut: 1.851e-03,  Loss_res: 1.946e-01 , Time: 5.11
# loss_bc1: 5.540e+04
# loss_ics_u: 1.030e+05
# loss_res_val: 1.089e+03
# It: 7200, Loss: 9.463e+03,  loss_bc1: 8.045e-03,  loss_bc2: 6.219e-03, loss_ics_u: 6.614e-02, loss_ics_ut: 1.562e-02,  Loss_res: 2.294e-01 , Time: 5.09
# loss_bc1: 5.540e+04
# loss_ics_u: 1.030e+05
# loss_res_val: 1.089e+03
# It: 7300, Loss: 7.387e+03,  loss_bc1: 9.074e-03,  loss_bc2: 4.445e-03, loss_ics_u: 5.965e-02, loss_ics_ut: 1.760e-03,  Loss_res: 2.855e-01 , Time: 3.83
# loss_bc1: 5.540e+04
# loss_ics_u: 1.030e+05
# loss_res_val: 1.090e+03
# It: 7400, Loss: 7.793e+03,  loss_bc1: 8.682e-03,  loss_bc2: 4.216e-03, loss_ics_u: 6.348e-02, loss_ics_ut: 2.928e-03,  Loss_res: 2.171e-01 , Time: 4.39
# loss_bc1: 5.541e+04
# loss_ics_u: 1.030e+05
# loss_res_val: 1.090e+03
# It: 7500, Loss: 7.555e+03,  loss_bc1: 1.508e-02,  loss_bc2: 3.957e-03, loss_ics_u: 5.786e-02, loss_ics_ut: 2.988e-03,  Loss_res: 2.116e-01 , Time: 4.05
# loss_bc1: 5.541e+04
# loss_ics_u: 1.031e+05
# loss_res_val: 1.090e+03
# It: 7600, Loss: 8.884e+03,  loss_bc1: 1.282e-02,  loss_bc2: 4.397e-03, loss_ics_u: 5.498e-02, loss_ics_ut: 1.708e-02,  Loss_res: 4.617e-01 , Time: 3.66
# loss_bc1: 5.541e+04
# loss_ics_u: 1.031e+05
# loss_res_val: 1.091e+03
# It: 7700, Loss: 7.432e+03,  loss_bc1: 6.384e-03,  loss_bc2: 3.736e-03, loss_ics_u: 6.227e-02, loss_ics_ut: 2.020e-03,  Loss_res: 2.251e-01 , Time: 5.77
# loss_bc1: 5.541e+04
# loss_ics_u: 1.031e+05
# loss_res_val: 1.091e+03
# It: 7800, Loss: 8.166e+03,  loss_bc1: 1.187e-02,  loss_bc2: 4.786e-03, loss_ics_u: 6.377e-02, loss_ics_ut: 4.295e-03,  Loss_res: 2.081e-01 , Time: 3.72
# loss_bc1: 5.541e+04
# loss_ics_u: 1.031e+05
# loss_res_val: 1.091e+03
# It: 7900, Loss: 6.765e+03,  loss_bc1: 9.635e-03,  loss_bc2: 5.142e-03, loss_ics_u: 5.127e-02, loss_ics_ut: 3.730e-03,  Loss_res: 2.533e-01 , Time: 3.66
# loss_bc1: 5.542e+04
# loss_ics_u: 1.031e+05
# loss_res_val: 1.092e+03
# It: 8000, Loss: 6.911e+03,  loss_bc1: 7.815e-03,  loss_bc2: 4.403e-03, loss_ics_u: 5.439e-02, loss_ics_ut: 3.349e-03,  Loss_res: 2.585e-01 , Time: 3.56
# loss_bc1: 5.542e+04
# loss_ics_u: 1.031e+05
# loss_res_val: 1.092e+03
# It: 8100, Loss: 5.868e+03,  loss_bc1: 6.420e-03,  loss_bc2: 7.246e-03, loss_ics_u: 4.696e-02, loss_ics_ut: 6.550e-04,  Loss_res: 1.843e-01 , Time: 3.53
# loss_bc1: 5.542e+04
# loss_ics_u: 1.031e+05
# loss_res_val: 1.092e+03
# It: 8200, Loss: 6.253e+03,  loss_bc1: 1.096e-02,  loss_bc2: 5.302e-03, loss_ics_u: 4.911e-02, loss_ics_ut: 6.997e-04,  Loss_res: 1.981e-01 , Time: 3.53
# loss_bc1: 5.542e+04
# loss_ics_u: 1.031e+05
# loss_res_val: 1.092e+03
# It: 8300, Loss: 7.364e+03,  loss_bc1: 1.353e-02,  loss_bc2: 5.627e-03, loss_ics_u: 4.819e-02, loss_ics_ut: 1.116e-02,  Loss_res: 1.680e-01 , Time: 3.47
# loss_bc1: 5.542e+04
# loss_ics_u: 1.031e+05
# loss_res_val: 1.093e+03
# It: 8400, Loss: 5.173e+03,  loss_bc1: 8.433e-03,  loss_bc2: 6.851e-03, loss_ics_u: 3.880e-02, loss_ics_ut: 9.238e-04,  Loss_res: 2.104e-01 , Time: 3.59
# loss_bc1: 5.543e+04
# loss_ics_u: 1.031e+05
# loss_res_val: 1.093e+03
# It: 8500, Loss: 6.042e+03,  loss_bc1: 1.034e-02,  loss_bc2: 5.109e-03, loss_ics_u: 4.633e-02, loss_ics_ut: 2.940e-03,  Loss_res: 9.610e-02 , Time: 3.55
# loss_bc1: 5.543e+04
# loss_ics_u: 1.031e+05
# loss_res_val: 1.093e+03
# It: 8600, Loss: 5.176e+03,  loss_bc1: 5.499e-03,  loss_bc2: 4.498e-03, loss_ics_u: 3.841e-02, loss_ics_ut: 4.068e-03,  Loss_res: 2.207e-01 , Time: 3.53
# loss_bc1: 5.543e+04
# loss_ics_u: 1.031e+05
# loss_res_val: 1.093e+03
# It: 8700, Loss: 5.268e+03,  loss_bc1: 8.008e-03,  loss_bc2: 5.338e-03, loss_ics_u: 3.728e-02, loss_ics_ut: 3.970e-03,  Loss_res: 2.508e-01 , Time: 3.58
# loss_bc1: 5.543e+04
# loss_ics_u: 1.031e+05
# loss_res_val: 1.094e+03
# It: 8800, Loss: 9.109e+03,  loss_bc1: 8.067e-03,  loss_bc2: 4.843e-03, loss_ics_u: 4.108e-02, loss_ics_ut: 3.857e-02,  Loss_res: 1.629e-01 , Time: 3.52
# loss_bc1: 5.543e+04
# loss_ics_u: 1.031e+05
# loss_res_val: 1.094e+03
# It: 8900, Loss: 5.141e+03,  loss_bc1: 4.654e-03,  loss_bc2: 5.771e-03, loss_ics_u: 4.000e-02, loss_ics_ut: 2.741e-03,  Loss_res: 1.409e-01 , Time: 3.51
# loss_bc1: 5.543e+04
# loss_ics_u: 1.031e+05
# loss_res_val: 1.094e+03
# It: 9000, Loss: 5.023e+03,  loss_bc1: 1.029e-02,  loss_bc2: 4.719e-03, loss_ics_u: 3.716e-02, loss_ics_ut: 2.188e-03,  Loss_res: 1.218e-01 , Time: 3.61
# loss_bc1: 5.543e+04
# loss_ics_u: 1.032e+05
# loss_res_val: 1.094e+03
# It: 9100, Loss: 6.114e+03,  loss_bc1: 7.423e-03,  loss_bc2: 4.642e-03, loss_ics_u: 4.397e-02, loss_ics_ut: 6.463e-03,  Loss_res: 2.227e-01 , Time: 3.45
# loss_bc1: 5.544e+04
# loss_ics_u: 1.032e+05
# loss_res_val: 1.094e+03
# It: 9200, Loss: 5.733e+03,  loss_bc1: 5.674e-03,  loss_bc2: 5.039e-03, loss_ics_u: 3.921e-02, loss_ics_ut: 6.430e-03,  Loss_res: 3.934e-01 , Time: 5.51
# loss_bc1: 5.544e+04
# loss_ics_u: 1.032e+05
# loss_res_val: 1.095e+03
# It: 9300, Loss: 6.028e+03,  loss_bc1: 9.538e-03,  loss_bc2: 4.270e-03, loss_ics_u: 3.523e-02, loss_ics_ut: 1.399e-02,  Loss_res: 1.686e-01 , Time: 5.29
# loss_bc1: 5.544e+04
# loss_ics_u: 1.032e+05
# loss_res_val: 1.095e+03
# It: 9400, Loss: 4.908e+03,  loss_bc1: 1.006e-02,  loss_bc2: 3.088e-03, loss_ics_u: 3.636e-02, loss_ics_ut: 3.000e-03,  Loss_res: 1.081e-01 , Time: 4.61
# loss_bc1: 5.544e+04
# loss_ics_u: 1.032e+05
# loss_res_val: 1.095e+03
# It: 9500, Loss: 4.871e+03,  loss_bc1: 4.645e-03,  loss_bc2: 5.057e-03, loss_ics_u: 3.421e-02, loss_ics_ut: 5.840e-03,  Loss_res: 1.831e-01 , Time: 4.46
# loss_bc1: 5.544e+04
# loss_ics_u: 1.032e+05
# loss_res_val: 1.095e+03
# It: 9600, Loss: 4.183e+03,  loss_bc1: 4.766e-03,  loss_bc2: 4.454e-03, loss_ics_u: 3.123e-02, loss_ics_ut: 2.758e-03,  Loss_res: 1.509e-01 , Time: 3.60
# loss_bc1: 5.544e+04
# loss_ics_u: 1.032e+05
# loss_res_val: 1.095e+03
# It: 9700, Loss: 5.130e+03,  loss_bc1: 6.215e-03,  loss_bc2: 4.217e-03, loss_ics_u: 3.536e-02, loss_ics_ut: 6.559e-03,  Loss_res: 2.062e-01 , Time: 3.55
# loss_bc1: 5.544e+04
# loss_ics_u: 1.032e+05
# loss_res_val: 1.096e+03
# It: 9800, Loss: 4.407e+03,  loss_bc1: 7.862e-03,  loss_bc2: 5.908e-03, loss_ics_u: 3.046e-02, loss_ics_ut: 3.447e-03,  Loss_res: 1.323e-01 , Time: 3.71
# loss_bc1: 5.544e+04
# loss_ics_u: 1.032e+05
# loss_res_val: 1.096e+03
# It: 9900, Loss: 8.677e+03,  loss_bc1: 1.101e-02,  loss_bc2: 5.754e-03, loss_ics_u: 3.046e-02, loss_ics_ut: 3.930e-02,  Loss_res: 5.019e-01 , Time: 4.26
# loss_bc1: 5.545e+04
# loss_ics_u: 1.032e+05
# loss_res_val: 1.096e+03
# It: 10000, Loss: 4.195e+03,  loss_bc1: 6.009e-03,  loss_bc2: 5.433e-03, loss_ics_u: 3.192e-02, loss_ics_ut: 1.419e-03,  Loss_res: 1.099e-01 , Time: 3.83
# loss_bc1: 5.545e+04
# loss_ics_u: 1.032e+05
# loss_res_val: 1.096e+03
# It: 10100, Loss: 3.973e+03,  loss_bc1: 7.323e-03,  loss_bc2: 6.014e-03, loss_ics_u: 2.731e-02, loss_ics_ut: 2.308e-03,  Loss_res: 1.617e-01 , Time: 3.69
# loss_bc1: 5.545e+04
# loss_ics_u: 1.032e+05
# loss_res_val: 1.096e+03
# It: 10200, Loss: 4.247e+03,  loss_bc1: 7.118e-03,  loss_bc2: 5.508e-03, loss_ics_u: 2.904e-02, loss_ics_ut: 3.718e-03,  Loss_res: 1.515e-01 , Time: 3.69
# loss_bc1: 5.545e+04
# loss_ics_u: 1.032e+05
# loss_res_val: 1.097e+03
# It: 10300, Loss: 5.601e+03,  loss_bc1: 7.155e-03,  loss_bc2: 5.379e-03, loss_ics_u: 3.109e-02, loss_ics_ut: 1.464e-02,  Loss_res: 1.708e-01 , Time: 3.74
# loss_bc1: 5.545e+04
# loss_ics_u: 1.032e+05
# loss_res_val: 1.097e+03
# It: 10400, Loss: 6.977e+03,  loss_bc1: 8.458e-03,  loss_bc2: 8.012e-03, loss_ics_u: 2.954e-02, loss_ics_ut: 2.535e-02,  Loss_res: 3.634e-01 , Time: 3.71
# loss_bc1: 5.545e+04
# loss_ics_u: 1.032e+05
# loss_res_val: 1.097e+03
# It: 10500, Loss: 3.627e+03,  loss_bc1: 8.464e-03,  loss_bc2: 3.076e-03, loss_ics_u: 2.157e-02, loss_ics_ut: 5.990e-03,  Loss_res: 1.298e-01 , Time: 4.69
# loss_bc1: 5.545e+04
# loss_ics_u: 1.032e+05
# loss_res_val: 1.097e+03
# It: 10600, Loss: 4.788e+03,  loss_bc1: 7.807e-03,  loss_bc2: 4.540e-03, loss_ics_u: 2.785e-02, loss_ics_ut: 6.598e-03,  Loss_res: 4.991e-01 , Time: 4.93
# loss_bc1: 5.545e+04
# loss_ics_u: 1.032e+05
# loss_res_val: 1.098e+03
# It: 10700, Loss: 4.186e+03,  loss_bc1: 8.667e-03,  loss_bc2: 3.626e-03, loss_ics_u: 2.668e-02, loss_ics_ut: 5.560e-03,  Loss_res: 1.603e-01 , Time: 6.59
# loss_bc1: 5.546e+04
# loss_ics_u: 1.032e+05
# loss_res_val: 1.098e+03
# It: 10800, Loss: 5.746e+03,  loss_bc1: 9.820e-03,  loss_bc2: 4.246e-03, loss_ics_u: 2.953e-02, loss_ics_ut: 1.680e-02,  Loss_res: 1.664e-01 , Time: 3.64
# loss_bc1: 5.546e+04
# loss_ics_u: 1.032e+05
# loss_res_val: 1.098e+03
# It: 10900, Loss: 4.506e+03,  loss_bc1: 1.309e-02,  loss_bc2: 5.016e-03, loss_ics_u: 2.929e-02, loss_ics_ut: 3.376e-03,  Loss_res: 1.185e-01 , Time: 3.75
# loss_bc1: 5.546e+04
# loss_ics_u: 1.032e+05
# loss_res_val: 1.098e+03
# It: 11000, Loss: 3.199e+03,  loss_bc1: 8.144e-03,  loss_bc2: 4.778e-03, loss_ics_u: 2.092e-02, loss_ics_ut: 1.649e-03,  Loss_res: 1.394e-01 , Time: 4.51
# loss_bc1: 5.546e+04
# loss_ics_u: 1.032e+05
# loss_res_val: 1.098e+03
# It: 11100, Loss: 3.646e+03,  loss_bc1: 7.305e-03,  loss_bc2: 4.425e-03, loss_ics_u: 2.511e-02, loss_ics_ut: 2.623e-03,  Loss_res: 1.201e-01 , Time: 3.41
# loss_bc1: 5.546e+04
# loss_ics_u: 1.032e+05
# loss_res_val: 1.098e+03
# It: 11200, Loss: 5.039e+03,  loss_bc1: 6.627e-03,  loss_bc2: 6.604e-03, loss_ics_u: 3.085e-02, loss_ics_ut: 7.602e-03,  Loss_res: 3.061e-01 , Time: 3.51
# loss_bc1: 5.546e+04
# loss_ics_u: 1.032e+05
# loss_res_val: 1.099e+03
# It: 11300, Loss: 3.596e+03,  loss_bc1: 7.013e-03,  loss_bc2: 4.838e-03, loss_ics_u: 2.604e-02, loss_ics_ut: 1.343e-03,  Loss_res: 1.014e-01 , Time: 4.14
# loss_bc1: 5.546e+04
# loss_ics_u: 1.032e+05
# loss_res_val: 1.099e+03
# It: 11400, Loss: 3.257e+03,  loss_bc1: 5.785e-03,  loss_bc2: 6.547e-03, loss_ics_u: 2.183e-02, loss_ics_ut: 1.716e-03,  Loss_res: 1.296e-01 , Time: 3.54
# loss_bc1: 5.546e+04
# loss_ics_u: 1.032e+05
# loss_res_val: 1.099e+03
# It: 11500, Loss: 3.412e+03,  loss_bc1: 9.589e-03,  loss_bc2: 4.717e-03, loss_ics_u: 2.279e-02, loss_ics_ut: 1.367e-03,  Loss_res: 1.132e-01 , Time: 3.37
# loss_bc1: 5.547e+04
# loss_ics_u: 1.032e+05
# loss_res_val: 1.099e+03
# It: 11600, Loss: 2.977e+03,  loss_bc1: 5.568e-03,  loss_bc2: 5.033e-03, loss_ics_u: 2.082e-02, loss_ics_ut: 1.185e-03,  Loss_res: 1.068e-01 , Time: 3.39
# loss_bc1: 5.547e+04
# loss_ics_u: 1.032e+05
# loss_res_val: 1.099e+03
# It: 11700, Loss: 3.357e+03,  loss_bc1: 6.492e-03,  loss_bc2: 4.409e-03, loss_ics_u: 2.200e-02, loss_ics_ut: 3.228e-03,  Loss_res: 1.346e-01 , Time: 3.35
# loss_bc1: 5.547e+04
# loss_ics_u: 1.032e+05
# loss_res_val: 1.099e+03
# It: 11800, Loss: 2.902e+03,  loss_bc1: 7.516e-03,  loss_bc2: 4.640e-03, loss_ics_u: 1.867e-02, loss_ics_ut: 9.583e-04,  Loss_res: 1.829e-01 , Time: 3.34
# loss_bc1: 5.547e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.099e+03
# It: 11900, Loss: 3.538e+03,  loss_bc1: 6.812e-03,  loss_bc2: 4.820e-03, loss_ics_u: 1.753e-02, loss_ics_ut: 7.917e-03,  Loss_res: 2.409e-01 , Time: 3.34
# loss_bc1: 5.547e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.099e+03
# It: 12000, Loss: 2.998e+03,  loss_bc1: 8.996e-03,  loss_bc2: 4.800e-03, loss_ics_u: 1.902e-02, loss_ics_ut: 9.827e-04,  Loss_res: 1.526e-01 , Time: 3.42
# loss_bc1: 5.547e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.100e+03
# It: 12100, Loss: 2.828e+03,  loss_bc1: 7.843e-03,  loss_bc2: 5.154e-03, loss_ics_u: 1.637e-02, loss_ics_ut: 3.072e-03,  Loss_res: 9.090e-02 , Time: 3.37
# loss_bc1: 5.547e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.100e+03
# It: 12200, Loss: 3.364e+03,  loss_bc1: 9.666e-03,  loss_bc2: 4.952e-03, loss_ics_u: 1.820e-02, loss_ics_ut: 5.346e-03,  Loss_res: 1.108e-01 , Time: 3.47
# loss_bc1: 5.547e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.100e+03
# It: 12300, Loss: 3.067e+03,  loss_bc1: 7.760e-03,  loss_bc2: 4.854e-03, loss_ics_u: 1.990e-02, loss_ics_ut: 1.404e-03,  Loss_res: 1.523e-01 , Time: 3.38
# loss_bc1: 5.547e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.100e+03
# It: 12400, Loss: 2.790e+03,  loss_bc1: 8.433e-03,  loss_bc2: 4.725e-03, loss_ics_u: 1.533e-02, loss_ics_ut: 3.559e-03,  Loss_res: 1.004e-01 , Time: 3.36
# loss_bc1: 5.547e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.100e+03
# It: 12500, Loss: 2.643e+03,  loss_bc1: 5.971e-03,  loss_bc2: 5.887e-03, loss_ics_u: 1.600e-02, loss_ics_ut: 1.651e-03,  Loss_res: 1.479e-01 , Time: 3.37
# loss_bc1: 5.548e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.100e+03
# It: 12600, Loss: 2.997e+03,  loss_bc1: 8.548e-03,  loss_bc2: 5.673e-03, loss_ics_u: 1.638e-02, loss_ics_ut: 2.753e-03,  Loss_res: 2.116e-01 , Time: 3.41
# loss_bc1: 5.548e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.100e+03
# It: 12700, Loss: 8.922e+03,  loss_bc1: 9.419e-03,  loss_bc2: 6.848e-03, loss_ics_u: 1.430e-02, loss_ics_ut: 6.038e-02,  Loss_res: 2.796e-01 , Time: 3.33
# loss_bc1: 5.548e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.100e+03
# It: 12800, Loss: 2.601e+03,  loss_bc1: 7.514e-03,  loss_bc2: 4.747e-03, loss_ics_u: 1.629e-02, loss_ics_ut: 1.253e-03,  Loss_res: 1.000e-01 , Time: 3.43
# loss_bc1: 5.548e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.101e+03
# It: 12900, Loss: 2.418e+03,  loss_bc1: 8.819e-03,  loss_bc2: 4.382e-03, loss_ics_u: 1.432e-02, loss_ics_ut: 5.189e-04,  Loss_res: 1.394e-01 , Time: 3.52
# loss_bc1: 5.548e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.101e+03
# It: 13000, Loss: 2.099e+03,  loss_bc1: 6.900e-03,  loss_bc2: 4.247e-03, loss_ics_u: 1.235e-02, loss_ics_ut: 3.587e-04,  Loss_res: 1.524e-01 , Time: 3.62
# loss_bc1: 5.548e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.101e+03
# It: 13100, Loss: 2.037e+03,  loss_bc1: 4.562e-03,  loss_bc2: 4.881e-03, loss_ics_u: 1.164e-02, loss_ics_ut: 1.097e-03,  Loss_res: 1.795e-01 , Time: 3.96
# loss_bc1: 5.548e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.101e+03
# It: 13200, Loss: 2.228e+03,  loss_bc1: 7.267e-03,  loss_bc2: 5.963e-03, loss_ics_u: 1.278e-02, loss_ics_ut: 6.262e-04,  Loss_res: 9.945e-02 , Time: 3.45
# loss_bc1: 5.548e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.101e+03
# It: 13300, Loss: 2.081e+03,  loss_bc1: 7.398e-03,  loss_bc2: 4.510e-03, loss_ics_u: 1.204e-02, loss_ics_ut: 5.512e-04,  Loss_res: 1.086e-01 , Time: 3.48
# loss_bc1: 5.548e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.101e+03
# It: 13400, Loss: 2.538e+03,  loss_bc1: 9.862e-03,  loss_bc2: 6.462e-03, loss_ics_u: 1.203e-02, loss_ics_ut: 2.540e-03,  Loss_res: 1.153e-01 , Time: 3.61
# loss_bc1: 5.548e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.101e+03
# It: 13500, Loss: 2.997e+03,  loss_bc1: 8.282e-03,  loss_bc2: 5.155e-03, loss_ics_u: 1.315e-02, loss_ics_ut: 6.658e-03,  Loss_res: 1.868e-01 , Time: 3.80
# loss_bc1: 5.549e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.101e+03
# It: 13600, Loss: 2.034e+03,  loss_bc1: 5.866e-03,  loss_bc2: 5.497e-03, loss_ics_u: 1.246e-02, loss_ics_ut: 3.043e-04,  Loss_res: 7.735e-02 , Time: 3.47
# loss_bc1: 5.549e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.101e+03
# It: 13700, Loss: 2.359e+03,  loss_bc1: 7.299e-03,  loss_bc2: 5.073e-03, loss_ics_u: 1.357e-02, loss_ics_ut: 1.586e-03,  Loss_res: 9.685e-02 , Time: 3.43
# loss_bc1: 5.549e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.101e+03
# It: 13800, Loss: 1.956e+03,  loss_bc1: 9.588e-03,  loss_bc2: 4.338e-03, loss_ics_u: 9.958e-03, loss_ics_ut: 2.757e-04,  Loss_res: 1.144e-01 , Time: 3.48
# loss_bc1: 5.549e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.101e+03
# It: 13900, Loss: 1.833e+03,  loss_bc1: 5.037e-03,  loss_bc2: 6.224e-03, loss_ics_u: 1.043e-02, loss_ics_ut: 1.972e-04,  Loss_res: 1.002e-01 , Time: 3.23
# loss_bc1: 5.549e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.102e+03
# It: 14000, Loss: 1.819e+03,  loss_bc1: 8.321e-03,  loss_bc2: 5.893e-03, loss_ics_u: 8.343e-03, loss_ics_ut: 5.524e-04,  Loss_res: 1.017e-01 , Time: 3.72
# loss_bc1: 5.549e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.102e+03
# It: 14100, Loss: 1.682e+03,  loss_bc1: 8.524e-03,  loss_bc2: 4.259e-03, loss_ics_u: 7.184e-03, loss_ics_ut: 9.608e-04,  Loss_res: 1.195e-01 , Time: 3.47
# loss_bc1: 5.549e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.102e+03
# It: 14200, Loss: 1.888e+03,  loss_bc1: 7.575e-03,  loss_bc2: 5.062e-03, loss_ics_u: 8.983e-03, loss_ics_ut: 9.921e-04,  Loss_res: 1.419e-01 , Time: 3.64
# loss_bc1: 5.549e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.102e+03
# It: 14300, Loss: 3.062e+03,  loss_bc1: 7.104e-03,  loss_bc2: 5.710e-03, loss_ics_u: 9.084e-03, loss_ics_ut: 1.170e-02,  Loss_res: 1.856e-01 , Time: 3.61
# loss_bc1: 5.549e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.102e+03
# It: 14400, Loss: 2.114e+03,  loss_bc1: 9.389e-03,  loss_bc2: 5.246e-03, loss_ics_u: 9.027e-03, loss_ics_ut: 2.358e-03,  Loss_res: 1.148e-01 , Time: 3.37
# loss_bc1: 5.549e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.102e+03
# It: 14500, Loss: 2.329e+03,  loss_bc1: 7.447e-03,  loss_bc2: 5.913e-03, loss_ics_u: 7.270e-03, loss_ics_ut: 6.880e-03,  Loss_res: 1.145e-01 , Time: 3.66
# loss_bc1: 5.549e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.102e+03
# It: 14600, Loss: 2.766e+03,  loss_bc1: 9.287e-03,  loss_bc2: 5.482e-03, loss_ics_u: 1.227e-02, loss_ics_ut: 3.828e-03,  Loss_res: 2.579e-01 , Time: 4.12
# loss_bc1: 5.550e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.102e+03
# It: 14700, Loss: 1.846e+03,  loss_bc1: 7.152e-03,  loss_bc2: 4.937e-03, loss_ics_u: 1.013e-02, loss_ics_ut: 3.266e-04,  Loss_res: 8.699e-02 , Time: 3.59
# loss_bc1: 5.550e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.102e+03
# It: 14800, Loss: 1.895e+03,  loss_bc1: 7.286e-03,  loss_bc2: 6.032e-03, loss_ics_u: 9.866e-03, loss_ics_ut: 3.567e-04,  Loss_res: 9.098e-02 , Time: 3.56
# loss_bc1: 5.550e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.102e+03
# It: 14900, Loss: 1.579e+03,  loss_bc1: 8.118e-03,  loss_bc2: 5.049e-03, loss_ics_u: 6.724e-03, loss_ics_ut: 3.394e-04,  Loss_res: 1.073e-01 , Time: 3.37
# loss_bc1: 5.550e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.102e+03
# It: 15000, Loss: 1.847e+03,  loss_bc1: 6.840e-03,  loss_bc2: 5.016e-03, loss_ics_u: 7.825e-03, loss_ics_ut: 2.906e-03,  Loss_res: 7.336e-02 , Time: 3.39
# loss_bc1: 5.550e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.102e+03
# It: 15100, Loss: 1.542e+03,  loss_bc1: 7.474e-03,  loss_bc2: 5.222e-03, loss_ics_u: 7.051e-03, loss_ics_ut: 3.371e-04,  Loss_res: 6.696e-02 , Time: 3.27
# loss_bc1: 5.550e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.103e+03
# It: 15200, Loss: 1.622e+03,  loss_bc1: 5.982e-03,  loss_bc2: 4.456e-03, loss_ics_u: 8.518e-03, loss_ics_ut: 7.188e-04,  Loss_res: 8.053e-02 , Time: 3.58
# loss_bc1: 5.550e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.103e+03
# It: 15300, Loss: 1.945e+03,  loss_bc1: 8.236e-03,  loss_bc2: 5.308e-03, loss_ics_u: 6.976e-03, loss_ics_ut: 3.237e-03,  Loss_res: 1.253e-01 , Time: 3.54
# loss_bc1: 5.550e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.103e+03
# It: 15400, Loss: 1.732e+03,  loss_bc1: 7.839e-03,  loss_bc2: 5.893e-03, loss_ics_u: 7.010e-03, loss_ics_ut: 7.919e-04,  Loss_res: 1.486e-01 , Time: 3.78
# loss_bc1: 5.550e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.103e+03
# It: 15500, Loss: 1.546e+03,  loss_bc1: 7.513e-03,  loss_bc2: 6.647e-03, loss_ics_u: 5.837e-03, loss_ics_ut: 4.460e-04,  Loss_res: 1.003e-01 , Time: 3.34
# loss_bc1: 5.550e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.103e+03
# It: 15600, Loss: 1.571e+03,  loss_bc1: 6.502e-03,  loss_bc2: 5.175e-03, loss_ics_u: 6.657e-03, loss_ics_ut: 1.145e-03,  Loss_res: 1.057e-01 , Time: 3.45
# loss_bc1: 5.550e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.103e+03
# It: 15700, Loss: 1.893e+03,  loss_bc1: 6.646e-03,  loss_bc2: 5.841e-03, loss_ics_u: 5.881e-03, loss_ics_ut: 3.968e-03,  Loss_res: 1.658e-01 , Time: 3.43
# loss_bc1: 5.550e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.103e+03
# It: 15800, Loss: 1.564e+03,  loss_bc1: 5.986e-03,  loss_bc2: 5.301e-03, loss_ics_u: 7.157e-03, loss_ics_ut: 8.068e-04,  Loss_res: 1.042e-01 , Time: 3.39
# loss_bc1: 5.551e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.103e+03
# It: 15900, Loss: 4.605e+03,  loss_bc1: 7.118e-03,  loss_bc2: 5.880e-03, loss_ics_u: 7.602e-03, loss_ics_ut: 2.329e-02,  Loss_res: 6.273e-01 , Time: 3.60
# loss_bc1: 5.551e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.103e+03
# It: 16000, Loss: 1.613e+03,  loss_bc1: 6.404e-03,  loss_bc2: 5.701e-03, loss_ics_u: 7.498e-03, loss_ics_ut: 6.853e-04,  Loss_res: 8.678e-02 , Time: 3.59
# loss_bc1: 5.551e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.104e+03
# It: 16100, Loss: 1.497e+03,  loss_bc1: 8.074e-03,  loss_bc2: 4.309e-03, loss_ics_u: 6.181e-03, loss_ics_ut: 4.574e-04,  Loss_res: 1.122e-01 , Time: 3.43
# loss_bc1: 5.551e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.104e+03
# It: 16200, Loss: 1.660e+03,  loss_bc1: 7.059e-03,  loss_bc2: 6.064e-03, loss_ics_u: 6.987e-03, loss_ics_ut: 9.735e-04,  Loss_res: 9.944e-02 , Time: 3.40
# loss_bc1: 5.551e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.104e+03
# It: 16300, Loss: 1.521e+03,  loss_bc1: 8.641e-03,  loss_bc2: 5.844e-03, loss_ics_u: 5.293e-03, loss_ics_ut: 4.988e-04,  Loss_res: 1.075e-01 , Time: 3.67
# loss_bc1: 5.551e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.104e+03
# It: 16400, Loss: 1.700e+03,  loss_bc1: 7.729e-03,  loss_bc2: 4.799e-03, loss_ics_u: 5.125e-03, loss_ics_ut: 3.574e-03,  Loss_res: 9.639e-02 , Time: 3.53
# loss_bc1: 5.551e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.104e+03
# It: 16500, Loss: 1.554e+03,  loss_bc1: 7.306e-03,  loss_bc2: 5.551e-03, loss_ics_u: 6.385e-03, loss_ics_ut: 9.214e-04,  Loss_res: 7.757e-02 , Time: 3.64
# loss_bc1: 5.551e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.104e+03
# It: 16600, Loss: 1.697e+03,  loss_bc1: 6.770e-03,  loss_bc2: 6.520e-03, loss_ics_u: 5.847e-03, loss_ics_ut: 2.487e-03,  Loss_res: 8.898e-02 , Time: 3.63
# loss_bc1: 5.551e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.104e+03
# It: 16700, Loss: 2.119e+03,  loss_bc1: 5.863e-03,  loss_bc2: 4.582e-03, loss_ics_u: 5.676e-03, loss_ics_ut: 3.928e-03,  Loss_res: 4.952e-01 , Time: 3.37
# loss_bc1: 5.551e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.104e+03
# It: 16800, Loss: 1.542e+03,  loss_bc1: 8.126e-03,  loss_bc2: 5.397e-03, loss_ics_u: 5.639e-03, loss_ics_ut: 9.479e-04,  Loss_res: 1.003e-01 , Time: 3.65
# loss_bc1: 5.551e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.104e+03
# It: 16900, Loss: 1.626e+03,  loss_bc1: 7.964e-03,  loss_bc2: 5.656e-03, loss_ics_u: 4.876e-03, loss_ics_ut: 2.390e-03,  Loss_res: 1.082e-01 , Time: 3.54
# loss_bc1: 5.551e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.104e+03
# It: 17000, Loss: 1.429e+03,  loss_bc1: 8.412e-03,  loss_bc2: 4.510e-03, loss_ics_u: 5.103e-03, loss_ics_ut: 8.112e-04,  Loss_res: 9.092e-02 , Time: 3.66
# loss_bc1: 5.551e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.104e+03
# It: 17100, Loss: 1.573e+03,  loss_bc1: 8.265e-03,  loss_bc2: 5.837e-03, loss_ics_u: 4.395e-03, loss_ics_ut: 2.112e-03,  Loss_res: 1.071e-01 , Time: 3.63
# loss_bc1: 5.552e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.104e+03
# It: 17200, Loss: 6.474e+03,  loss_bc1: 8.185e-03,  loss_bc2: 5.681e-03, loss_ics_u: 4.850e-03, loss_ics_ut: 4.656e-02,  Loss_res: 3.558e-01 , Time: 3.41
# loss_bc1: 5.552e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.105e+03
# It: 17300, Loss: 1.490e+03,  loss_bc1: 7.573e-03,  loss_bc2: 5.135e-03, loss_ics_u: 5.838e-03, loss_ics_ut: 5.733e-04,  Loss_res: 1.105e-01 , Time: 3.26
# loss_bc1: 5.552e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.105e+03
# It: 17400, Loss: 1.423e+03,  loss_bc1: 5.669e-03,  loss_bc2: 4.449e-03, loss_ics_u: 5.838e-03, loss_ics_ut: 1.260e-03,  Loss_res: 1.157e-01 , Time: 3.39
# loss_bc1: 5.552e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.105e+03
# It: 17500, Loss: 1.450e+03,  loss_bc1: 6.138e-03,  loss_bc2: 6.214e-03, loss_ics_u: 4.452e-03, loss_ics_ut: 1.941e-03,  Loss_res: 9.365e-02 , Time: 3.26
# loss_bc1: 5.552e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.105e+03
# It: 17600, Loss: 1.243e+03,  loss_bc1: 6.974e-03,  loss_bc2: 4.573e-03, loss_ics_u: 3.796e-03, loss_ics_ut: 7.809e-04,  Loss_res: 1.164e-01 , Time: 3.40
# loss_bc1: 5.552e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.105e+03
# It: 17700, Loss: 1.297e+03,  loss_bc1: 6.584e-03,  loss_bc2: 4.790e-03, loss_ics_u: 4.757e-03, loss_ics_ut: 6.027e-04,  Loss_res: 1.010e-01 , Time: 3.71
# loss_bc1: 5.552e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.105e+03
# It: 17800, Loss: 5.406e+03,  loss_bc1: 7.247e-03,  loss_bc2: 6.647e-03, loss_ics_u: 4.213e-03, loss_ics_ut: 3.506e-02,  Loss_res: 5.225e-01 , Time: 3.72
# loss_bc1: 5.552e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.105e+03
# It: 17900, Loss: 1.244e+03,  loss_bc1: 7.021e-03,  loss_bc2: 4.677e-03, loss_ics_u: 4.289e-03, loss_ics_ut: 5.674e-04,  Loss_res: 8.373e-02 , Time: 3.14
# loss_bc1: 5.552e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.105e+03
# It: 18000, Loss: 1.305e+03,  loss_bc1: 6.505e-03,  loss_bc2: 5.378e-03, loss_ics_u: 4.461e-03, loss_ics_ut: 3.292e-04,  Loss_res: 1.359e-01 , Time: 3.26
# loss_bc1: 5.552e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.105e+03
# It: 18100, Loss: 1.321e+03,  loss_bc1: 7.215e-03,  loss_bc2: 5.138e-03, loss_ics_u: 4.231e-03, loss_ics_ut: 7.487e-04,  Loss_res: 1.089e-01 , Time: 3.53
# loss_bc1: 5.552e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.105e+03
# It: 18200, Loss: 1.344e+03,  loss_bc1: 6.664e-03,  loss_bc2: 5.202e-03, loss_ics_u: 3.902e-03, loss_ics_ut: 1.568e-03,  Loss_res: 1.085e-01 , Time: 3.45
# loss_bc1: 5.552e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.105e+03
# It: 18300, Loss: 3.976e+03,  loss_bc1: 5.957e-03,  loss_bc2: 5.142e-03, loss_ics_u: 3.837e-03, loss_ics_ut: 2.624e-02,  Loss_res: 2.289e-01 , Time: 3.23
# loss_bc1: 5.552e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.106e+03
# It: 18400, Loss: 1.588e+03,  loss_bc1: 6.203e-03,  loss_bc2: 5.783e-03, loss_ics_u: 3.567e-03, loss_ics_ut: 4.427e-03,  Loss_res: 8.735e-02 , Time: 3.37
# loss_bc1: 5.552e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.106e+03
# It: 18500, Loss: 1.164e+03,  loss_bc1: 5.802e-03,  loss_bc2: 6.286e-03, loss_ics_u: 3.545e-03, loss_ics_ut: 3.132e-04,  Loss_res: 8.479e-02 , Time: 3.24
# loss_bc1: 5.553e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.106e+03
# It: 18600, Loss: 1.194e+03,  loss_bc1: 6.970e-03,  loss_bc2: 4.515e-03, loss_ics_u: 4.311e-03, loss_ics_ut: 3.514e-04,  Loss_res: 6.758e-02 , Time: 3.27
# loss_bc1: 5.553e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.106e+03
# It: 18700, Loss: 1.382e+03,  loss_bc1: 7.052e-03,  loss_bc2: 5.702e-03, loss_ics_u: 4.323e-03, loss_ics_ut: 8.343e-04,  Loss_res: 1.279e-01 , Time: 3.16
# loss_bc1: 5.553e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.106e+03
# It: 18800, Loss: 1.128e+03,  loss_bc1: 5.771e-03,  loss_bc2: 4.592e-03, loss_ics_u: 3.554e-03, loss_ics_ut: 8.130e-04,  Loss_res: 9.209e-02 , Time: 3.39
# loss_bc1: 5.553e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.106e+03
# It: 18900, Loss: 1.176e+03,  loss_bc1: 6.081e-03,  loss_bc2: 4.774e-03, loss_ics_u: 4.071e-03, loss_ics_ut: 5.024e-04,  Loss_res: 9.133e-02 , Time: 3.41
# loss_bc1: 5.553e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.106e+03
# It: 19000, Loss: 1.479e+03,  loss_bc1: 6.550e-03,  loss_bc2: 4.925e-03, loss_ics_u: 4.606e-03, loss_ics_ut: 2.514e-03,  Loss_res: 9.613e-02 , Time: 3.32
# loss_bc1: 5.553e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.106e+03
# It: 19100, Loss: 1.162e+03,  loss_bc1: 7.001e-03,  loss_bc2: 4.847e-03, loss_ics_u: 3.475e-03, loss_ics_ut: 4.605e-04,  Loss_res: 8.794e-02 , Time: 3.21
# loss_bc1: 5.553e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.106e+03
# It: 19200, Loss: 1.133e+03,  loss_bc1: 6.082e-03,  loss_bc2: 5.141e-03, loss_ics_u: 3.244e-03, loss_ics_ut: 5.713e-04,  Loss_res: 1.046e-01 , Time: 3.36
# loss_bc1: 5.553e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.106e+03
# It: 19300, Loss: 2.218e+03,  loss_bc1: 6.144e-03,  loss_bc2: 5.196e-03, loss_ics_u: 3.345e-03, loss_ics_ut: 1.043e-02,  Loss_res: 1.493e-01 , Time: 3.60
# loss_bc1: 5.553e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.106e+03
# It: 19400, Loss: 2.185e+03,  loss_bc1: 7.123e-03,  loss_bc2: 6.201e-03, loss_ics_u: 3.510e-03, loss_ics_ut: 9.238e-03,  Loss_res: 1.161e-01 , Time: 3.40
# loss_bc1: 5.553e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.106e+03
# It: 19500, Loss: 1.579e+03,  loss_bc1: 6.511e-03,  loss_bc2: 5.009e-03, loss_ics_u: 3.253e-03, loss_ics_ut: 4.197e-03,  Loss_res: 1.536e-01 , Time: 3.55
# loss_bc1: 5.553e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.106e+03
# It: 19600, Loss: 1.059e+03,  loss_bc1: 6.248e-03,  loss_bc2: 4.831e-03, loss_ics_u: 2.718e-03, loss_ics_ut: 3.577e-04,  Loss_res: 1.141e-01 , Time: 3.40
# loss_bc1: 5.553e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.106e+03
# It: 19700, Loss: 1.128e+03,  loss_bc1: 6.529e-03,  loss_bc2: 4.766e-03, loss_ics_u: 3.081e-03, loss_ics_ut: 7.922e-04,  Loss_res: 9.102e-02 , Time: 3.57
# loss_bc1: 5.553e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.106e+03
# It: 19800, Loss: 1.134e+03,  loss_bc1: 5.402e-03,  loss_bc2: 4.854e-03, loss_ics_u: 3.830e-03, loss_ics_ut: 4.550e-04,  Loss_res: 1.105e-01 , Time: 3.57
# loss_bc1: 5.553e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.106e+03
# It: 19900, Loss: 1.280e+03,  loss_bc1: 6.340e-03,  loss_bc2: 4.907e-03, loss_ics_u: 3.085e-03, loss_ics_ut: 1.451e-03,  Loss_res: 1.689e-01 , Time: 3.52
# loss_bc1: 5.553e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.106e+03
# It: 20000, Loss: 1.081e+03,  loss_bc1: 6.864e-03,  loss_bc2: 3.980e-03, loss_ics_u: 2.164e-03, loss_ics_ut: 1.696e-03,  Loss_res: 7.215e-02 , Time: 3.70
# loss_bc1: 5.553e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.106e+03
# It: 20100, Loss: 1.139e+03,  loss_bc1: 7.229e-03,  loss_bc2: 4.260e-03, loss_ics_u: 3.029e-03, loss_ics_ut: 1.161e-03,  Loss_res: 6.192e-02 , Time: 3.40
# loss_bc1: 5.553e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.107e+03
# It: 20200, Loss: 1.234e+03,  loss_bc1: 6.590e-03,  loss_bc2: 4.929e-03, loss_ics_u: 3.260e-03, loss_ics_ut: 1.647e-03,  Loss_res: 7.849e-02 , Time: 3.48
# loss_bc1: 5.554e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.107e+03
# It: 20300, Loss: 1.253e+03,  loss_bc1: 7.045e-03,  loss_bc2: 5.246e-03, loss_ics_u: 2.551e-03, loss_ics_ut: 9.954e-04,  Loss_res: 1.847e-01 , Time: 3.52
# loss_bc1: 5.554e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.107e+03
# It: 20400, Loss: 1.085e+03,  loss_bc1: 6.251e-03,  loss_bc2: 5.245e-03, loss_ics_u: 2.580e-03, loss_ics_ut: 9.360e-04,  Loss_res: 7.570e-02 , Time: 3.51
# loss_bc1: 5.554e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.107e+03
# It: 20500, Loss: 1.176e+03,  loss_bc1: 7.254e-03,  loss_bc2: 3.890e-03, loss_ics_u: 3.092e-03, loss_ics_ut: 1.271e-03,  Loss_res: 9.597e-02 , Time: 3.46
# loss_bc1: 5.554e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.107e+03
# It: 20600, Loss: 1.071e+03,  loss_bc1: 5.912e-03,  loss_bc2: 3.930e-03, loss_ics_u: 2.750e-03, loss_ics_ut: 1.139e-03,  Loss_res: 1.102e-01 , Time: 3.49
# loss_bc1: 5.554e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.107e+03
# It: 20700, Loss: 2.782e+03,  loss_bc1: 6.216e-03,  loss_bc2: 4.559e-03, loss_ics_u: 3.362e-03, loss_ics_ut: 1.497e-02,  Loss_res: 2.613e-01 , Time: 3.50
# loss_bc1: 5.554e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.107e+03
# It: 20800, Loss: 1.248e+03,  loss_bc1: 6.562e-03,  loss_bc2: 4.300e-03, loss_ics_u: 2.786e-03, loss_ics_ut: 2.391e-03,  Loss_res: 9.905e-02 , Time: 3.44
# loss_bc1: 5.554e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.107e+03
# ...
# loss_res_val: 1.110e+03
# It: 32800, Loss: 4.897e+02,  loss_bc1: 2.976e-03,  loss_bc2: 2.400e-03, loss_ics_u: 1.056e-03, loss_ics_ut: 1.344e-04,  Loss_res: 6.117e-02 , Time: 3.58
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.110e+03
# It: 32900, Loss: 5.170e+02,  loss_bc1: 3.170e-03,  loss_bc2: 3.098e-03, loss_ics_u: 9.286e-04, loss_ics_ut: 1.917e-04,  Loss_res: 4.760e-02 , Time: 3.50
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.110e+03
# It: 33000, Loss: 4.707e+02,  loss_bc1: 3.757e-03,  loss_bc2: 1.674e-03, loss_ics_u: 9.988e-04, loss_ics_ut: 1.307e-04,  Loss_res: 4.695e-02 , Time: 3.45
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.110e+03
# It: 33100, Loss: 4.768e+02,  loss_bc1: 3.288e-03,  loss_bc2: 2.476e-03, loss_ics_u: 8.775e-04, loss_ics_ut: 1.394e-04,  Loss_res: 4.625e-02 , Time: 3.48
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.110e+03
# It: 33200, Loss: 5.419e+02,  loss_bc1: 3.070e-03,  loss_bc2: 1.978e-03, loss_ics_u: 1.021e-03, loss_ics_ut: 8.101e-04,  Loss_res: 6.502e-02 , Time: 3.44
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.110e+03
# It: 33300, Loss: 4.897e+02,  loss_bc1: 3.085e-03,  loss_bc2: 2.483e-03, loss_ics_u: 1.010e-03, loss_ics_ut: 1.942e-04,  Loss_res: 5.026e-02 , Time: 3.50
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.110e+03
# It: 33400, Loss: 5.072e+02,  loss_bc1: 3.541e-03,  loss_bc2: 2.131e-03, loss_ics_u: 9.956e-04, loss_ics_ut: 1.284e-04,  Loss_res: 6.828e-02 , Time: 3.46
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.110e+03
# It: 33500, Loss: 5.003e+02,  loss_bc1: 3.192e-03,  loss_bc2: 2.390e-03, loss_ics_u: 1.025e-03, loss_ics_ut: 1.754e-04,  Loss_res: 5.949e-02 , Time: 3.66
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.110e+03
# It: 33600, Loss: 4.554e+02,  loss_bc1: 2.792e-03,  loss_bc2: 2.648e-03, loss_ics_u: 7.749e-04, loss_ics_ut: 1.311e-04,  Loss_res: 5.350e-02 , Time: 6.70
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.110e+03
# It: 33700, Loss: 4.498e+02,  loss_bc1: 2.977e-03,  loss_bc2: 2.302e-03, loss_ics_u: 9.209e-04, loss_ics_ut: 1.877e-04,  Loss_res: 3.771e-02 , Time: 4.25
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.110e+03
# It: 33800, Loss: 4.799e+02,  loss_bc1: 3.668e-03,  loss_bc2: 2.092e-03, loss_ics_u: 9.032e-04, loss_ics_ut: 1.541e-04,  Loss_res: 4.550e-02 , Time: 3.88
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.110e+03
# It: 33900, Loss: 4.355e+02,  loss_bc1: 2.926e-03,  loss_bc2: 2.361e-03, loss_ics_u: 6.895e-04, loss_ics_ut: 1.654e-04,  Loss_res: 4.803e-02 , Time: 3.70
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 34000, Loss: 4.522e+02,  loss_bc1: 2.950e-03,  loss_bc2: 2.411e-03, loss_ics_u: 8.239e-04, loss_ics_ut: 1.480e-04,  Loss_res: 4.846e-02 , Time: 3.53
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 34100, Loss: 4.763e+02,  loss_bc1: 3.218e-03,  loss_bc2: 2.322e-03, loss_ics_u: 9.324e-04, loss_ics_ut: 1.867e-04,  Loss_res: 4.755e-02 , Time: 4.23
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 34200, Loss: 5.601e+02,  loss_bc1: 3.346e-03,  loss_bc2: 1.972e-03, loss_ics_u: 9.001e-04, loss_ics_ut: 7.610e-04,  Loss_res: 8.364e-02 , Time: 5.50
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 34300, Loss: 5.466e+02,  loss_bc1: 3.608e-03,  loss_bc2: 2.859e-03, loss_ics_u: 7.586e-04, loss_ics_ut: 4.020e-04,  Loss_res: 6.052e-02 , Time: 5.42
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 34400, Loss: 4.901e+02,  loss_bc1: 3.185e-03,  loss_bc2: 2.438e-03, loss_ics_u: 9.684e-04, loss_ics_ut: 1.891e-04,  Loss_res: 5.219e-02 , Time: 3.62
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 34500, Loss: 4.438e+02,  loss_bc1: 3.065e-03,  loss_bc2: 1.961e-03, loss_ics_u: 8.326e-04, loss_ics_ut: 2.093e-04,  Loss_res: 5.115e-02 , Time: 3.52
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 34600, Loss: 4.426e+02,  loss_bc1: 2.733e-03,  loss_bc2: 2.383e-03, loss_ics_u: 9.264e-04, loss_ics_ut: 1.607e-04,  Loss_res: 4.134e-02 , Time: 3.47
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 34700, Loss: 4.632e+02,  loss_bc1: 2.883e-03,  loss_bc2: 2.257e-03, loss_ics_u: 9.638e-04, loss_ics_ut: 2.209e-04,  Loss_res: 4.956e-02 , Time: 3.54
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 34800, Loss: 4.264e+02,  loss_bc1: 3.070e-03,  loss_bc2: 1.926e-03, loss_ics_u: 7.220e-04, loss_ics_ut: 1.474e-04,  Loss_res: 5.304e-02 , Time: 3.52
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 34900, Loss: 5.689e+02,  loss_bc1: 2.140e-03,  loss_bc2: 2.325e-03, loss_ics_u: 8.873e-04, loss_ics_ut: 1.430e-03,  Loss_res: 7.317e-02 , Time: 3.78
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 35000, Loss: 4.623e+02,  loss_bc1: 3.027e-03,  loss_bc2: 1.888e-03, loss_ics_u: 1.012e-03, loss_ics_ut: 2.380e-04,  Loss_res: 5.397e-02 , Time: 4.07
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 35100, Loss: 5.069e+02,  loss_bc1: 3.469e-03,  loss_bc2: 1.649e-03, loss_ics_u: 7.642e-04, loss_ics_ut: 7.964e-04,  Loss_res: 5.503e-02 , Time: 3.76
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 35200, Loss: 4.392e+02,  loss_bc1: 2.578e-03,  loss_bc2: 2.067e-03, loss_ics_u: 7.654e-04, loss_ics_ut: 5.129e-04,  Loss_res: 4.405e-02 , Time: 3.66
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 35300, Loss: 4.460e+02,  loss_bc1: 3.175e-03,  loss_bc2: 1.921e-03, loss_ics_u: 9.125e-04, loss_ics_ut: 1.348e-04,  Loss_res: 4.913e-02 , Time: 3.66
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 35400, Loss: 4.741e+02,  loss_bc1: 3.052e-03,  loss_bc2: 2.553e-03, loss_ics_u: 8.567e-04, loss_ics_ut: 1.175e-04,  Loss_res: 5.570e-02 , Time: 3.50
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 35500, Loss: 4.311e+02,  loss_bc1: 2.771e-03,  loss_bc2: 2.079e-03, loss_ics_u: 9.043e-04, loss_ics_ut: 1.520e-04,  Loss_res: 4.716e-02 , Time: 3.55
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 35600, Loss: 4.586e+02,  loss_bc1: 3.330e-03,  loss_bc2: 1.797e-03, loss_ics_u: 8.543e-04, loss_ics_ut: 2.572e-04,  Loss_res: 5.293e-02 , Time: 3.71
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 35700, Loss: 4.423e+02,  loss_bc1: 2.848e-03,  loss_bc2: 2.022e-03, loss_ics_u: 9.314e-04, loss_ics_ut: 2.074e-04,  Loss_res: 4.858e-02 , Time: 3.90
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 35800, Loss: 4.406e+02,  loss_bc1: 3.261e-03,  loss_bc2: 2.075e-03, loss_ics_u: 7.112e-04, loss_ics_ut: 1.619e-04,  Loss_res: 4.839e-02 , Time: 3.60
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 35900, Loss: 4.628e+02,  loss_bc1: 2.974e-03,  loss_bc2: 2.165e-03, loss_ics_u: 8.654e-04, loss_ics_ut: 2.602e-04,  Loss_res: 5.476e-02 , Time: 3.56
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 36000, Loss: 5.008e+02,  loss_bc1: 3.771e-03,  loss_bc2: 2.392e-03, loss_ics_u: 8.845e-04, loss_ics_ut: 2.128e-04,  Loss_res: 4.038e-02 , Time: 3.50
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 36100, Loss: 4.682e+02,  loss_bc1: 3.412e-03,  loss_bc2: 2.029e-03, loss_ics_u: 8.523e-04, loss_ics_ut: 2.269e-04,  Loss_res: 4.889e-02 , Time: 3.52
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 36200, Loss: 4.577e+02,  loss_bc1: 2.926e-03,  loss_bc2: 2.343e-03, loss_ics_u: 7.871e-04, loss_ics_ut: 2.494e-04,  Loss_res: 5.201e-02 , Time: 3.63
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 36300, Loss: 4.725e+02,  loss_bc1: 3.323e-03,  loss_bc2: 1.695e-03, loss_ics_u: 8.756e-04, loss_ics_ut: 4.749e-04,  Loss_res: 4.869e-02 , Time: 3.49
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 36400, Loss: 4.089e+02,  loss_bc1: 2.906e-03,  loss_bc2: 1.741e-03, loss_ics_u: 6.966e-04, loss_ics_ut: 1.656e-04,  Loss_res: 5.534e-02 , Time: 3.48
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 36500, Loss: 4.087e+02,  loss_bc1: 3.023e-03,  loss_bc2: 1.635e-03, loss_ics_u: 9.181e-04, loss_ics_ut: 1.301e-04,  Loss_res: 3.735e-02 , Time: 3.70
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 36600, Loss: 3.959e+02,  loss_bc1: 2.801e-03,  loss_bc2: 1.689e-03, loss_ics_u: 8.215e-04, loss_ics_ut: 9.234e-05,  Loss_res: 4.670e-02 , Time: 4.18
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 36700, Loss: 3.945e+02,  loss_bc1: 2.686e-03,  loss_bc2: 1.639e-03, loss_ics_u: 7.596e-04, loss_ics_ut: 1.221e-04,  Loss_res: 5.677e-02 , Time: 4.73
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 36800, Loss: 3.676e+02,  loss_bc1: 2.637e-03,  loss_bc2: 1.290e-03, loss_ics_u: 8.532e-04, loss_ics_ut: 1.298e-04,  Loss_res: 4.300e-02 , Time: 4.23
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 36900, Loss: 4.142e+02,  loss_bc1: 2.920e-03,  loss_bc2: 1.965e-03, loss_ics_u: 6.865e-04, loss_ics_ut: 1.540e-04,  Loss_res: 5.025e-02 , Time: 4.23
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 37000, Loss: 4.337e+02,  loss_bc1: 3.067e-03,  loss_bc2: 1.853e-03, loss_ics_u: 9.618e-04, loss_ics_ut: 2.307e-04,  Loss_res: 3.330e-02 , Time: 3.46
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 37100, Loss: 5.588e+02,  loss_bc1: 3.006e-03,  loss_bc2: 1.748e-03, loss_ics_u: 8.641e-04, loss_ics_ut: 1.339e-03,  Loss_res: 6.024e-02 , Time: 3.50
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 37200, Loss: 4.202e+02,  loss_bc1: 3.195e-03,  loss_bc2: 1.804e-03, loss_ics_u: 7.050e-04, loss_ics_ut: 1.883e-04,  Loss_res: 4.508e-02 , Time: 3.70
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 37300, Loss: 3.937e+02,  loss_bc1: 2.595e-03,  loss_bc2: 1.996e-03, loss_ics_u: 7.595e-04, loss_ics_ut: 1.137e-04,  Loss_res: 4.345e-02 , Time: 3.52
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 37400, Loss: 4.258e+02,  loss_bc1: 2.977e-03,  loss_bc2: 2.268e-03, loss_ics_u: 8.280e-04, loss_ics_ut: 1.279e-04,  Loss_res: 3.194e-02 , Time: 3.50
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 37500, Loss: 4.071e+02,  loss_bc1: 2.493e-03,  loss_bc2: 2.005e-03, loss_ics_u: 8.275e-04, loss_ics_ut: 1.697e-04,  Loss_res: 4.868e-02 , Time: 4.33
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 37600, Loss: 4.147e+02,  loss_bc1: 2.755e-03,  loss_bc2: 1.637e-03, loss_ics_u: 9.521e-04, loss_ics_ut: 1.280e-04,  Loss_res: 5.307e-02 , Time: 3.70
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 37700, Loss: 3.745e+02,  loss_bc1: 2.635e-03,  loss_bc2: 1.618e-03, loss_ics_u: 8.026e-04, loss_ics_ut: 1.141e-04,  Loss_res: 3.910e-02 , Time: 3.45
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 37800, Loss: 4.158e+02,  loss_bc1: 2.819e-03,  loss_bc2: 1.929e-03, loss_ics_u: 7.679e-04, loss_ics_ut: 1.225e-04,  Loss_res: 5.392e-02 , Time: 3.48
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 37900, Loss: 3.981e+02,  loss_bc1: 2.725e-03,  loss_bc2: 2.010e-03, loss_ics_u: 7.260e-04, loss_ics_ut: 1.116e-04,  Loss_res: 4.352e-02 , Time: 3.64
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 38000, Loss: 4.517e+02,  loss_bc1: 2.954e-03,  loss_bc2: 1.960e-03, loss_ics_u: 9.564e-04, loss_ics_ut: 2.922e-04,  Loss_res: 4.463e-02 , Time: 3.53
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 38100, Loss: 4.236e+02,  loss_bc1: 3.122e-03,  loss_bc2: 2.027e-03, loss_ics_u: 6.361e-04, loss_ics_ut: 9.782e-05,  Loss_res: 5.543e-02 , Time: 3.56
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 38200, Loss: 4.050e+02,  loss_bc1: 2.832e-03,  loss_bc2: 2.224e-03, loss_ics_u: 6.880e-04, loss_ics_ut: 8.810e-05,  Loss_res: 3.943e-02 , Time: 3.50
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 38300, Loss: 4.605e+02,  loss_bc1: 2.991e-03,  loss_bc2: 2.119e-03, loss_ics_u: 1.049e-03, loss_ics_ut: 1.592e-04,  Loss_res: 4.646e-02 , Time: 3.51
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 38400, Loss: 3.768e+02,  loss_bc1: 2.567e-03,  loss_bc2: 1.650e-03, loss_ics_u: 7.744e-04, loss_ics_ut: 1.519e-04,  Loss_res: 4.203e-02 , Time: 3.51
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 38500, Loss: 4.127e+02,  loss_bc1: 2.697e-03,  loss_bc2: 1.948e-03, loss_ics_u: 8.092e-04, loss_ics_ut: 1.350e-04,  Loss_res: 5.126e-02 , Time: 3.45
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 38600, Loss: 4.255e+02,  loss_bc1: 3.370e-03,  loss_bc2: 1.621e-03, loss_ics_u: 7.875e-04, loss_ics_ut: 2.141e-04,  Loss_res: 4.014e-02 , Time: 3.52
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 38700, Loss: 3.581e+02,  loss_bc1: 2.544e-03,  loss_bc2: 1.423e-03, loss_ics_u: 6.879e-04, loss_ics_ut: 1.170e-04,  Loss_res: 4.894e-02 , Time: 3.48
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 38800, Loss: 4.121e+02,  loss_bc1: 2.606e-03,  loss_bc2: 1.975e-03, loss_ics_u: 6.905e-04, loss_ics_ut: 1.181e-04,  Loss_res: 6.655e-02 , Time: 3.54
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 38900, Loss: 4.009e+02,  loss_bc1: 2.249e-03,  loss_bc2: 2.243e-03, loss_ics_u: 6.868e-04, loss_ics_ut: 1.822e-04,  Loss_res: 5.527e-02 , Time: 3.53
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 39000, Loss: 3.929e+02,  loss_bc1: 2.349e-03,  loss_bc2: 2.200e-03, loss_ics_u: 6.799e-04, loss_ics_ut: 1.736e-04,  Loss_res: 4.668e-02 , Time: 3.57
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 39100, Loss: 3.892e+02,  loss_bc1: 2.683e-03,  loss_bc2: 1.752e-03, loss_ics_u: 7.265e-04, loss_ics_ut: 1.557e-04,  Loss_res: 4.641e-02 , Time: 3.63
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 39200, Loss: 3.725e+02,  loss_bc1: 2.380e-03,  loss_bc2: 1.773e-03, loss_ics_u: 7.951e-04, loss_ics_ut: 1.119e-04,  Loss_res: 4.313e-02 , Time: 4.03
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 39300, Loss: 4.202e+02,  loss_bc1: 2.760e-03,  loss_bc2: 2.060e-03, loss_ics_u: 9.259e-04, loss_ics_ut: 1.335e-04,  Loss_res: 3.851e-02 , Time: 3.51
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 39400, Loss: 3.879e+02,  loss_bc1: 2.385e-03,  loss_bc2: 2.319e-03, loss_ics_u: 6.405e-04, loss_ics_ut: 1.234e-04,  Loss_res: 4.276e-02 , Time: 3.47
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 39500, Loss: 3.882e+02,  loss_bc1: 2.756e-03,  loss_bc2: 2.217e-03, loss_ics_u: 5.153e-04, loss_ics_ut: 1.521e-04,  Loss_res: 3.847e-02 , Time: 3.52
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 39600, Loss: 4.435e+02,  loss_bc1: 3.351e-03,  loss_bc2: 2.147e-03, loss_ics_u: 6.140e-04, loss_ics_ut: 2.065e-04,  Loss_res: 4.775e-02 , Time: 3.48
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 39700, Loss: 4.278e+02,  loss_bc1: 3.034e-03,  loss_bc2: 1.997e-03, loss_ics_u: 7.023e-04, loss_ics_ut: 1.757e-04,  Loss_res: 5.170e-02 , Time: 3.83
# loss_bc1: 5.558e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 39800, Loss: 3.848e+02,  loss_bc1: 2.484e-03,  loss_bc2: 1.825e-03, loss_ics_u: 7.104e-04, loss_ics_ut: 2.803e-04,  Loss_res: 3.862e-02 , Time: 3.57
# loss_bc1: 5.559e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# It: 39900, Loss: 3.698e+02,  loss_bc1: 2.563e-03,  loss_bc2: 1.621e-03, loss_ics_u: 7.179e-04, loss_ics_ut: 8.429e-05,  Loss_res: 4.891e-02 , Time: 3.52
# loss_bc1: 5.559e+04
# loss_ics_u: 1.033e+05
# loss_res_val: 1.111e+03
# elapsed: 1.47e+03
# Relative L2 error_u: 1.64e-01
# elapsed: 1.47e+03
# Relative L2 error_u: 1.64e-01
#
#
# Method:  mini_batch
#
# average of time_list: 1468.4173350334167
# average of error_u_list: 0.1641606562534568

# %%
# Define PINN model
a = 0.5
c = 2

kernel_size = 300

# Domain boundaries
ics_coords = np.array([[0.0, 0.0],  [0.0, 1.0]])
bc1_coords = np.array([[0.0, 0.0],  [1.0, 0.0]])
bc2_coords = np.array([[0.0, 1.0],  [1.0, 1.0]])
dom_coords = np.array([[0.0, 0.0],  [1.0, 1.0]])

# Create initial conditions samplers
ics_sampler = Sampler(2, ics_coords, lambda x: u(x, a, c), name='Initial Condition 1')

# Create boundary conditions samplers
bc1 = Sampler(2, bc1_coords, lambda x: u(x, a, c), name='Dirichlet BC1')
bc2 = Sampler(2, bc2_coords, lambda x: u(x, a, c), name='Dirichlet BC2')
bcs_sampler = [bc1, bc2]

# Create residual sampler
res_sampler = Sampler(2, dom_coords, lambda x: r(x, a, c), name='Forcing')



nIter =40000
bcbatch_size = 500
ubatch_size = 5000
mbbatch_size = 300



# Define model
mode = 'M4'
layers = [2, 500, 500, 500, 1]


nn = 200
t = np.linspace(dom_coords[0, 0], dom_coords[1, 0], nn)[:, None]
x = np.linspace(dom_coords[0, 1], dom_coords[1, 1], nn)[:, None]
t, x = np.meshgrid(t, x)
X_star = np.hstack((t.flatten()[:, None], x.flatten()[:, None]))

u_star = u(X_star, a,c)
r_star = r(X_star, a, c)

iterations = 1
methods = [  "mini_batch"]

result_dict =  dict((mtd, []) for mtd in methods)

for mtd in methods:
    print("Method: ", mtd)
    time_list = []
    error_u_list = []
    
    for index in range(iterations):

        print("Epoch: ", str(index+1))

        # Create residual sampler

        [elapsed, error_u] = test_method(mtd , layers,  ics_sampler, bcs_sampler, res_sampler, c ,kernel_size , X_star , u_star , r_star , nIter ,mbbatch_size , bcbatch_size , ubatch_size )


        print('elapsed: {:.2e}'.format(elapsed))
        print('Relative L2 error_u: {:.2e}'.format(error_u))

        time_list.append(elapsed)
        error_u_list.append(error_u)

    print("\n\nMethod: ", mtd)
    print("\naverage of time_list:" , sum(time_list) / len(time_list) )
    print("average of error_u_list:" , sum(error_u_list) / len(error_u_list) )
    # print("average of error_r_list:" , sum(error_r_list) / len(error_r_list) )

    result_dict[mtd] = [time_list ,error_u_list]
    # scipy.io.savemat("M2_result_"+str(iterations)+"_"+mtd+".mat" , {'time_list':np.array(time_list),'error_u_list':np.array(error_u_list),'error_f_list':np.array(error_f_list)})

    scipy.io.savemat("./1DWave_database/"+mtd+"_1Dwave_"+mode+"_result_mb"+str(mbbatch_size)+"_fb"+str(ubatch_size)+"_bc"+str(mbbatch_size)+"_"+str(iterations)+".mat" , result_dict)

###############################################################################################################################################
# Out:
# Method:  mini_batch
# Epoch:  1
# mini_batch method is used
# It: 100, Loss: 9.238e-01,  loss_bc1: 6.848e-02, loss_ics_u: 3.931e-01,  Loss_res: 6.576e-04 , Time: 4.89
# It: 200, Loss: 6.458e-01,  loss_bc1: 7.923e-02, loss_ics_u: 2.403e-01,  Loss_res: 6.826e-03 , Time: 3.53
# It: 300, Loss: 6.600e-01,  loss_bc1: 8.652e-02, loss_ics_u: 2.341e-01,  Loss_res: 1.875e-02 , Time: 3.44
# It: 400, Loss: 5.494e-01,  loss_bc1: 6.093e-02, loss_ics_u: 2.009e-01,  Loss_res: 2.586e-02 , Time: 3.43
# It: 500, Loss: 5.235e-01,  loss_bc1: 4.314e-02, loss_ics_u: 2.099e-01,  Loss_res: 1.742e-02 , Time: 3.35
# It: 600, Loss: 4.532e-01,  loss_bc1: 4.553e-02, loss_ics_u: 1.763e-01,  Loss_res: 9.461e-03 , Time: 3.27
# It: 700, Loss: 4.660e-01,  loss_bc1: 4.488e-02, loss_ics_u: 1.662e-01,  Loss_res: 4.375e-02 , Time: 3.38
# It: 800, Loss: 4.010e-01,  loss_bc1: 5.502e-02, loss_ics_u: 1.294e-01,  Loss_res: 3.213e-02 , Time: 3.22
# It: 900, Loss: 3.889e-01,  loss_bc1: 4.886e-02, loss_ics_u: 1.423e-01,  Loss_res: 6.523e-03 , Time: 3.26
# It: 1000, Loss: 4.760e-01,  loss_bc1: 3.239e-02, loss_ics_u: 1.614e-01,  Loss_res: 8.841e-02 , Time: 3.23
# loss_bc1: 3.239e+00
# loss_ics_u: 1.614e+01
# It: 1100, Loss: 4.028e+00,  loss_bc1: 2.087e-01, loss_ics_u: 2.050e-01,  Loss_res: 4.341e-02 , Time: 3.24
# It: 1200, Loss: 4.036e+00,  loss_bc1: 2.012e-01, loss_ics_u: 2.079e-01,  Loss_res: 2.821e-02 , Time: 3.24
# It: 1300, Loss: 3.089e+00,  loss_bc1: 1.975e-01, loss_ics_u: 1.486e-01,  Loss_res: 5.050e-02 , Time: 3.29
# It: 1400, Loss: 3.631e+00,  loss_bc1: 9.093e-02, loss_ics_u: 2.015e-01,  Loss_res: 8.446e-02 , Time: 3.25
# It: 1500, Loss: 3.205e+00,  loss_bc1: 1.203e-01, loss_ics_u: 1.708e-01,  Loss_res: 5.864e-02 , Time: 3.28
# It: 1600, Loss: 2.442e+00,  loss_bc1: 6.459e-02, loss_ics_u: 1.321e-01,  Loss_res: 1.004e-01 , Time: 3.25
# It: 1700, Loss: 1.988e+00,  loss_bc1: 5.784e-02, loss_ics_u: 1.060e-01,  Loss_res: 9.038e-02 , Time: 3.28
# It: 1800, Loss: 2.086e+00,  loss_bc1: 6.114e-02, loss_ics_u: 1.096e-01,  Loss_res: 1.187e-01 , Time: 3.30
# It: 1900, Loss: 1.798e+00,  loss_bc1: 5.601e-02, loss_ics_u: 9.710e-02,  Loss_res: 4.957e-02 , Time: 3.27
# It: 2000, Loss: 2.066e+00,  loss_bc1: 5.252e-02, loss_ics_u: 1.144e-01,  Loss_res: 4.957e-02 , Time: 3.29
# loss_bc1: 5.252e+00
# loss_ics_u: 1.144e+01
# It: 2100, Loss: 1.550e+00,  loss_bc1: 4.679e-02, loss_ics_u: 1.096e-01,  Loss_res: 5.031e-02 , Time: 3.31
# It: 2200, Loss: 1.371e+00,  loss_bc1: 4.520e-02, loss_ics_u: 9.635e-02,  Loss_res: 3.133e-02 , Time: 3.24
# It: 2300, Loss: 1.521e+00,  loss_bc1: 4.606e-02, loss_ics_u: 1.102e-01,  Loss_res: 1.778e-02 , Time: 3.20
# It: 2400, Loss: 1.439e+00,  loss_bc1: 4.217e-02, loss_ics_u: 1.018e-01,  Loss_res: 5.311e-02 , Time: 3.22
# It: 2500, Loss: 1.371e+00,  loss_bc1: 4.292e-02, loss_ics_u: 9.668e-02,  Loss_res: 3.920e-02 , Time: 3.22
# It: 2600, Loss: 1.398e+00,  loss_bc1: 4.434e-02, loss_ics_u: 1.003e-01,  Loss_res: 1.732e-02 , Time: 3.33
# It: 2700, Loss: 1.422e+00,  loss_bc1: 5.076e-02, loss_ics_u: 9.485e-02,  Loss_res: 6.997e-02 , Time: 3.22
# It: 2800, Loss: 1.420e+00,  loss_bc1: 4.226e-02, loss_ics_u: 1.026e-01,  Loss_res: 2.447e-02 , Time: 3.22
# It: 2900, Loss: 1.382e+00,  loss_bc1: 4.252e-02, loss_ics_u: 9.909e-02,  Loss_res: 2.485e-02 , Time: 3.21
# It: 3000, Loss: 1.566e+00,  loss_bc1: 3.510e-02, loss_ics_u: 1.161e-01,  Loss_res: 5.379e-02 , Time: 3.23
# loss_bc1: 3.510e+00
# loss_ics_u: 1.161e+01
# It: 3100, Loss: 1.250e+00,  loss_bc1: 4.534e-02, loss_ics_u: 9.202e-02,  Loss_res: 2.217e-02 , Time: 3.25
# It: 3200, Loss: 1.463e+00,  loss_bc1: 4.408e-02, loss_ics_u: 1.112e-01,  Loss_res: 1.781e-02 , Time: 3.22
# It: 3300, Loss: 1.234e+00,  loss_bc1: 4.673e-02, loss_ics_u: 9.008e-02,  Loss_res: 2.384e-02 , Time: 3.23
# It: 3400, Loss: 1.296e+00,  loss_bc1: 4.818e-02, loss_ics_u: 9.465e-02,  Loss_res: 2.827e-02 , Time: 3.19
# It: 3500, Loss: 1.202e+00,  loss_bc1: 4.031e-02, loss_ics_u: 8.907e-02,  Loss_res: 2.603e-02 , Time: 3.22
# It: 3600, Loss: 1.318e+00,  loss_bc1: 3.901e-02, loss_ics_u: 9.679e-02,  Loss_res: 5.757e-02 , Time: 3.22
# It: 3700, Loss: 1.339e+00,  loss_bc1: 4.521e-02, loss_ics_u: 9.347e-02,  Loss_res: 9.490e-02 , Time: 3.23
# It: 3800, Loss: 1.117e+00,  loss_bc1: 3.642e-02, loss_ics_u: 8.242e-02,  Loss_res: 3.266e-02 , Time: 3.23
# It: 3900, Loss: 1.193e+00,  loss_bc1: 3.797e-02, loss_ics_u: 8.865e-02,  Loss_res: 3.007e-02 , Time: 3.21
# It: 4000, Loss: 1.234e+00,  loss_bc1: 4.410e-02, loss_ics_u: 8.808e-02,  Loss_res: 5.626e-02 , Time: 3.26
# loss_bc1: 4.410e+00
# loss_ics_u: 8.808e+00
# It: 4100, Loss: 9.802e-01,  loss_bc1: 4.087e-02, loss_ics_u: 8.796e-02,  Loss_res: 2.525e-02 , Time: 3.23
# It: 4200, Loss: 7.871e-01,  loss_bc1: 3.142e-02, loss_ics_u: 7.091e-02,  Loss_res: 2.396e-02 , Time: 3.22
# It: 4300, Loss: 9.718e-01,  loss_bc1: 3.682e-02, loss_ics_u: 8.874e-02,  Loss_res: 2.785e-02 , Time: 3.20
# It: 4400, Loss: 9.642e-01,  loss_bc1: 3.058e-02, loss_ics_u: 9.060e-02,  Loss_res: 3.125e-02 , Time: 3.26
# It: 4500, Loss: 8.799e-01,  loss_bc1: 2.439e-02, loss_ics_u: 8.445e-02,  Loss_res: 2.850e-02 , Time: 3.32
# It: 4600, Loss: 9.538e-01,  loss_bc1: 2.985e-02, loss_ics_u: 9.104e-02,  Loss_res: 2.028e-02 , Time: 3.49
# It: 4700, Loss: 9.735e-01,  loss_bc1: 2.568e-02, loss_ics_u: 8.460e-02,  Loss_res: 1.151e-01 , Time: 3.21
# It: 4800, Loss: 1.139e+00,  loss_bc1: 3.047e-02, loss_ics_u: 8.349e-02,  Loss_res: 2.688e-01 , Time: 3.23
# It: 4900, Loss: 8.897e-01,  loss_bc1: 2.511e-02, loss_ics_u: 8.457e-02,  Loss_res: 3.410e-02 , Time: 3.27
# It: 5000, Loss: 8.940e-01,  loss_bc1: 2.638e-02, loss_ics_u: 8.533e-02,  Loss_res: 2.602e-02 , Time: 3.57
# loss_bc1: 2.638e+00
# loss_ics_u: 8.533e+00
# It: 5100, Loss: 7.650e-01,  loss_bc1: 2.841e-02, loss_ics_u: 7.593e-02,  Loss_res: 4.203e-02 , Time: 3.42
# It: 5200, Loss: 7.556e-01,  loss_bc1: 2.848e-02, loss_ics_u: 7.732e-02,  Loss_res: 2.066e-02 , Time: 3.46
# It: 5300, Loss: 8.372e-01,  loss_bc1: 2.470e-02, loss_ics_u: 8.721e-02,  Loss_res: 2.776e-02 , Time: 3.27
# It: 5400, Loss: 8.250e-01,  loss_bc1: 3.508e-02, loss_ics_u: 7.640e-02,  Loss_res: 8.048e-02 , Time: 3.37
# It: 5500, Loss: 7.433e-01,  loss_bc1: 3.176e-02, loss_ics_u: 7.389e-02,  Loss_res: 2.904e-02 , Time: 3.84
# It: 5600, Loss: 8.500e-01,  loss_bc1: 2.148e-02, loss_ics_u: 8.489e-02,  Loss_res: 6.889e-02 , Time: 3.76
# It: 5700, Loss: 8.856e-01,  loss_bc1: 2.965e-02, loss_ics_u: 8.233e-02,  Loss_res: 1.047e-01 , Time: 3.84
# It: 5800, Loss: 7.934e-01,  loss_bc1: 3.199e-02, loss_ics_u: 8.170e-02,  Loss_res: 1.185e-02 , Time: 4.21
# It: 5900, Loss: 6.295e-01,  loss_bc1: 2.616e-02, loss_ics_u: 6.469e-02,  Loss_res: 8.447e-03 , Time: 3.81
# It: 6000, Loss: 7.770e-01,  loss_bc1: 2.826e-02, loss_ics_u: 7.285e-02,  Loss_res: 8.075e-02 , Time: 3.30
# loss_bc1: 2.826e+00
# loss_ics_u: 7.285e+00
# It: 6100, Loss: 7.395e-01,  loss_bc1: 2.725e-02, loss_ics_u: 8.498e-02,  Loss_res: 4.339e-02 , Time: 3.26
# It: 6200, Loss: 6.320e-01,  loss_bc1: 2.240e-02, loss_ics_u: 7.337e-02,  Loss_res: 3.422e-02 , Time: 3.26
# It: 6300, Loss: 7.214e-01,  loss_bc1: 2.809e-02, loss_ics_u: 7.978e-02,  Loss_res: 6.084e-02 , Time: 3.37
# It: 6400, Loss: 6.903e-01,  loss_bc1: 2.062e-02, loss_ics_u: 8.453e-02,  Loss_res: 1.630e-02 , Time: 3.31
# It: 6500, Loss: 5.729e-01,  loss_bc1: 2.227e-02, loss_ics_u: 6.528e-02,  Loss_res: 3.439e-02 , Time: 3.25
# It: 6600, Loss: 6.427e-01,  loss_bc1: 2.084e-02, loss_ics_u: 7.847e-02,  Loss_res: 1.215e-02 , Time: 3.28
# It: 6700, Loss: 6.382e-01,  loss_bc1: 2.782e-02, loss_ics_u: 6.780e-02,  Loss_res: 6.566e-02 , Time: 3.34
# It: 6800, Loss: 7.090e-01,  loss_bc1: 3.071e-02, loss_ics_u: 8.264e-02,  Loss_res: 2.019e-02 , Time: 3.31
# It: 6900, Loss: 6.630e-01,  loss_bc1: 3.743e-02, loss_ics_u: 7.378e-02,  Loss_res: 1.977e-02 , Time: 3.27
# It: 7000, Loss: 5.993e-01,  loss_bc1: 2.533e-02, loss_ics_u: 7.067e-02,  Loss_res: 1.288e-02 , Time: 3.26
# loss_bc1: 2.533e+00
# loss_ics_u: 7.067e+00
# It: 7100, Loss: 5.544e-01,  loss_bc1: 1.875e-02, loss_ics_u: 7.023e-02,  Loss_res: 1.061e-02 , Time: 3.27
# It: 7200, Loss: 5.860e-01,  loss_bc1: 2.289e-02, loss_ics_u: 7.186e-02,  Loss_res: 2.016e-02 , Time: 3.29
# It: 7300, Loss: 5.804e-01,  loss_bc1: 2.950e-02, loss_ics_u: 6.364e-02,  Loss_res: 5.588e-02 , Time: 3.28
# It: 7400, Loss: 5.462e-01,  loss_bc1: 2.331e-02, loss_ics_u: 6.764e-02,  Loss_res: 9.172e-03 , Time: 3.27
# It: 7500, Loss: 8.304e-01,  loss_bc1: 3.285e-02, loss_ics_u: 7.115e-02,  Loss_res: 2.443e-01 , Time: 3.27
# It: 7600, Loss: 6.820e-01,  loss_bc1: 2.153e-02, loss_ics_u: 7.428e-02,  Loss_res: 1.026e-01 , Time: 3.29
# It: 7700, Loss: 7.606e-01,  loss_bc1: 4.626e-02, loss_ics_u: 7.817e-02,  Loss_res: 9.092e-02 , Time: 3.27
# It: 7800, Loss: 5.466e-01,  loss_bc1: 2.056e-02, loss_ics_u: 6.840e-02,  Loss_res: 1.107e-02 , Time: 3.27
# It: 7900, Loss: 5.074e-01,  loss_bc1: 2.721e-02, loss_ics_u: 6.056e-02,  Loss_res: 1.047e-02 , Time: 3.27
# It: 8000, Loss: 5.273e-01,  loss_bc1: 2.016e-02, loss_ics_u: 6.464e-02,  Loss_res: 1.944e-02 , Time: 3.29
# loss_bc1: 2.016e+00
# loss_ics_u: 6.464e+00
# It: 8100, Loss: 5.165e-01,  loss_bc1: 2.897e-02, loss_ics_u: 6.732e-02,  Loss_res: 2.294e-02 , Time: 3.25
# It: 8200, Loss: 5.093e-01,  loss_bc1: 2.612e-02, loss_ics_u: 6.808e-02,  Loss_res: 1.660e-02 , Time: 3.39
# It: 8300, Loss: 4.938e-01,  loss_bc1: 2.461e-02, loss_ics_u: 6.506e-02,  Loss_res: 2.366e-02 , Time: 3.26
# It: 8400, Loss: 4.566e-01,  loss_bc1: 2.211e-02, loss_ics_u: 6.029e-02,  Loss_res: 2.233e-02 , Time: 3.28
# It: 8500, Loss: 5.714e-01,  loss_bc1: 2.626e-02, loss_ics_u: 7.673e-02,  Loss_res: 2.248e-02 , Time: 3.28
# It: 8600, Loss: 5.056e-01,  loss_bc1: 1.853e-02, loss_ics_u: 7.116e-02,  Loss_res: 8.203e-03 , Time: 3.30
# It: 8700, Loss: 4.594e-01,  loss_bc1: 2.381e-02, loss_ics_u: 6.117e-02,  Loss_res: 1.599e-02 , Time: 3.26
# It: 8800, Loss: 5.830e-01,  loss_bc1: 3.105e-02, loss_ics_u: 6.247e-02,  Loss_res: 1.166e-01 , Time: 3.31
# It: 8900, Loss: 4.775e-01,  loss_bc1: 2.004e-02, loss_ics_u: 6.605e-02,  Loss_res: 1.014e-02 , Time: 3.55

# %%
# Define PINN model
a = 0.5
c = 2

kernel_size = 300

# Domain boundaries
ics_coords = np.array([[0.0, 0.0],  [0.0, 1.0]])
bc1_coords = np.array([[0.0, 0.0],  [1.0, 0.0]])
bc2_coords = np.array([[0.0, 1.0],  [1.0, 1.0]])
dom_coords = np.array([[0.0, 0.0],  [1.0, 1.0]])

# Create initial conditions samplers
ics_sampler = Sampler(2, ics_coords, lambda x: u(x, a, c), name='Initial Condition 1')

# Create boundary conditions samplers
bc1 = Sampler(2, bc1_coords, lambda x: u(x, a, c), name='Dirichlet BC1')
bc2 = Sampler(2, bc2_coords, lambda x: u(x, a, c), name='Dirichlet BC2')
bcs_sampler = [bc1, bc2]

# Create residual sampler
res_sampler = Sampler(2, dom_coords, lambda x: r(x, a, c), name='Forcing')



nIter =40000
bcbatch_size = 500
ubatch_size = 5000
mbbatch_size = 300



# Define model
mode = 'M4'
layers = [2, 500, 500, 500, 1]


nn = 200
t = np.linspace(dom_coords[0, 0], dom_coords[1, 0], nn)[:, None]
x = np.linspace(dom_coords[0, 1], dom_coords[1, 1], nn)[:, None]
t, x = np.meshgrid(t, x)
X_star = np.hstack((t.flatten()[:, None], x.flatten()[:, None]))

u_star = u(X_star, a,c)
r_star = r(X_star, a, c)

iterations = 1
methods = [  "mini_batch"]

result_dict =  dict((mtd, []) for mtd in methods)

for mtd in methods:
    print("Method: ", mtd)
    time_list = []
    error_u_list = []
    
    for index in range(iterations):

        print("Epoch: ", str(index+1))

        # Create residual sampler

        [elapsed, error_u] = test_method(mtd , layers,  ics_sampler, bcs_sampler, res_sampler, c ,kernel_size , X_star , u_star , r_star , nIter ,mbbatch_size , bcbatch_size , ubatch_size )


        print('elapsed: {:.2e}'.format(elapsed))
        print('Relative L2 error_u: {:.2e}'.format(error_u))

        time_list.append(elapsed)
        error_u_list.append(error_u)

    print("\n\nMethod: ", mtd)
    print("\naverage of time_list:" , sum(time_list) / len(time_list) )
    print("average of error_u_list:" , sum(error_u_list) / len(error_u_list) )
    # print("average of error_r_list:" , sum(error_r_list) / len(error_r_list) )

    result_dict[mtd] = [time_list ,error_u_list]
    # scipy.io.savemat("M2_result_"+str(iterations)+"_"+mtd+".mat" , {'time_list':np.array(time_list),'error_u_list':np.array(error_u_list),'error_f_list':np.array(error_f_list)})

    scipy.io.savemat("./1DWave_database/"+mtd+"_1Dwave_"+mode+"_result_mb"+str(mbbatch_size)+"_fb"+str(ubatch_size)+"_bc"+str(mbbatch_size)+"_"+str(iterations)+".mat" , result_dict)

###############################################################################################################################################

# %%
import scipy.io

mode = 'M4'
mbbatch_size = 128
ubatch_size = 5000
bcbatch_size = 500
iterations = 40000

time_list = []
error_u_list = []
error_v_list = []
error_p_list = []
    
methods = ["mini_batch" , "full_batch"]
result_dict =  dict((mtd, []) for mtd in methods)

##Mini Batch
time_list = []
error_u_list = [ ]


result_dict["mini_batch"] = [time_list ,error_u_list]

print("\n\nMethod: ", mtd)
print("\naverage of time_list:" , sum(time_list) / len(time_list) )
print("average of error_u_list:" , sum(error_u_list) / len(error_u_list) )

##Full Batch
time_list = []
error_u_list = [ ]
error_v_list = []
error_p_list = []

result_dict["full_batch"] = [time_list ,error_u_list ,error_v_list ,  error_p_list]

print("\n\nMethod: ", mtd)
print("\naverage of time_list:" , sum(time_list) / len(time_list) )
print("average of error_u_list:" , sum(error_u_list) / len(error_u_list) )
print("average of error_v_list:" , sum(error_v_list) / len(error_v_list) )
print("average of error_p_list:" , sum(error_p_list) / len(error_p_list) )


scipy.io.savemat("./dataset/1DWave_database_"+mode+"_result_mb"+str(mbbatch_size)+"_fb"+str(ubatch_size)+"_"+str(bcbatch_size)+"_"+str(iterations)+".mat" , result_dict)

# %%
# Train model
itertaions = 80001
log_NTK = True # Compute and store NTK matrix during training
update_lam = True # Compute and update the loss weights using the NTK

# %% [markdown]
# **Training Loss**

# %%
loss_res = model.loss_res_log
loss_bcs = model.loss_bcs_log
loss_u_t_ics = model.loss_ut_ics_log

fig = plt.figure(figsize=(6, 5))
plt.plot(loss_res, label='$\mathcal{L}_{r}$')
plt.plot(loss_bcs, label='$\mathcal{L}_{u}$')
plt.plot(loss_u_t_ics, label='$\mathcal{L}_{u_t}$')
plt.yscale('log')
plt.xlabel('iterations')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# **Model Prediction**

# %%
# Predictions
u_pred = model.predict_u(X_star)
r_pred = model.predict_r(X_star)
error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)

print('Relative L2 error_u: %e' % (error_u))

# %%
U_star = griddata(X_star, u_star.flatten(), (t, x), method='cubic')
r_star = griddata(X_star, r_star.flatten(), (t, x), method='cubic')
U_pred = griddata(X_star, u_pred.flatten(), (t, x), method='cubic')
# R_pred = griddata(X_star, r_pred.flatten(), (t, x), method='cubic')


plt.figure(figsize=(18, 9))
plt.subplot(2, 3, 1)
plt.pcolor(t, x, U_star, cmap='jet')
plt.colorbar()
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.title('Exact u(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 2)
plt.pcolor(t, x, U_pred, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Predicted u(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 3)
plt.pcolor(t, x, np.abs(U_star - U_pred), cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Absolute error')
plt.tight_layout()

plt.subplot(2, 3, 4)
plt.pcolor(t, x, r_star, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Exact r(t, x)')
plt.tight_layout()

# plt.subplot(2, 3, 5)
# plt.pcolor(t, x, R_pred, cmap='jet')
# plt.colorbar()
# plt.xlabel('$t$')
# plt.ylabel('$x$')
# plt.title('Predicted r(t, x)')
# plt.tight_layout()

# plt.subplot(2, 3, 6)
# plt.pcolor(t, x, np.abs(r_star - R_pred), cmap='jet')
# plt.colorbar()
# plt.xlabel('$t$')
# plt.ylabel('$x$')
# plt.title('Absolute error')
# plt.tight_layout()
# plt.show()

# %% [markdown]
# **NTK Eigenvalues**

# %%
# Create empty lists for storing the eigenvalues of NTK
lam_K_u_log = []
lam_K_ut_log = []
lam_K_r_log = []

# Restore the NTK
K_u_list = model.K_u_log
K_ut_list = model.K_ut_log
K_r_list = model.K_r_log

K_list = []
    
for k in range(len(K_u_list)):
    K_u = K_u_list[k]
    K_ut = K_ut_list[k]
    K_r = K_r_list[k]
    
    # Compute eigenvalues
    lam_K_u, _ = np.linalg.eig(K_u)
    lam_K_ut, _ = np.linalg.eig(K_ut)
    lam_K_r, _ = np.linalg.eig(K_r)
    # Sort in descresing order
    lam_K_u = np.sort(np.real(lam_K_u))[::-1]
    lam_K_ut = np.sort(np.real(lam_K_ut))[::-1]
    lam_K_r = np.sort(np.real(lam_K_r))[::-1]
    
    # Store eigenvalues
    lam_K_u_log.append(lam_K_u)
    lam_K_ut_log.append(lam_K_ut)
    lam_K_r_log.append(lam_K_r)

# %%
#  Eigenvalues of NTK
fig = plt.figure(figsize=(18, 5))
plt.subplot(1,3,1)

plt.plot(lam_K_u_log[0], label = '$n=0$')
plt.plot(lam_K_u_log[1], '--', label = '$n=10,000$')
plt.plot(lam_K_u_log[4], '--', label = '$n=40,000$')
plt.plot(lam_K_u_log[-1], '--', label = '$n=80,000$')
plt.xscale('log')
plt.yscale('log')

plt.title(r'Eigenvalues of ${K}_u$')

plt.subplot(1,3,2)
plt.plot(lam_K_ut_log[0], label = '$n=0$')
plt.plot(lam_K_ut_log[1], '--',label = '$n=10,000$')
plt.plot(lam_K_ut_log[4], '--', label = '$n=40,000$')
plt.plot(lam_K_ut_log[-1], '--', label = '$n=80,000$')
plt.xscale('log')
plt.yscale('log')
plt.title(r'Eigenvalues of ${K}_{u_t}$')

ax =plt.subplot(1,3,3)
plt.plot(lam_K_r_log[0], label = '$n=0$')
plt.plot(lam_K_r_log[1], '--', label = '$n=10,000$')
plt.plot(lam_K_r_log[4], '--', label = '$n=40,000$')
plt.plot(lam_K_r_log[-1], '--', label = '$n=80,000$')
plt.xscale('log')
plt.yscale('log')
plt.title(r'Eigenvalues of ${K}_{r}$')
handles, labels = ax.get_legend_handles_labels()
fig.legend(handles, labels, loc="upper left", bbox_to_anchor=(0.35, -0.02),
            borderaxespad=0, bbox_transform=fig.transFigure, ncol=4)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Evolution of NTK Weights**

# %%
if update_lam == True:

  lam_u_log = model.lam_u_log
  lam_ut_log = model.lam_ut_log
  lam_r_log = model.lam_r_log

# %%
fig = plt.figure(figsize=(6, 5))
plt.plot(lam_u_log, label='$\lambda_u$')
plt.plot(lam_ut_log, label='$\lambda_{u_t}$')
plt.plot(lam_r_log, label='$\lambda_{r}$')
plt.xlabel('iterations')
plt.ylabel('$\lambda$')
plt.yscale('log')
plt.legend( )
plt.tight_layout()
plt.show()
