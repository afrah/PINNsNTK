# %%
import tensorflow as tf
from Compute_Jacobian import jacobian # Please download 'Compute_Jacobian.py' in the repository 
import numpy as np
import timeit
from scipy.interpolate import griddata
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import os



os.environ["KMP_WARNINGS"] = "FALSE" 
import timeit

import sys

import scipy
import scipy.io
import time
class Sampler:
    # Initialize the class
    def __init__(self, dim, coords, func, name = None):
        self.dim = dim
        self.coords = coords
        self.func = func
        self.name = name
    def sample(self, N):
        x = self.coords[0:1,:] + (self.coords[1:2,:]-self.coords[0:1,:])*np.random.rand(N, self.dim)
        y = self.func(x)
        return x, y

# Define the exact solution and its derivatives
def u(x, a, c):
    """
    :param x: x = (t, x)
    """
    t = x[:,0:1]
    x = x[:,1:2]
    return np.sin(np.pi * x) * np.cos(c * np.pi * t) + a * np.sin(2 * c * np.pi* x) * np.cos(4 * c  * np.pi * t)

def u_t(x,a, c):
    t = x[:,0:1]
    x = x[:,1:2]
    u_t = -  c * np.pi * np.sin(np.pi * x) * np.sin(c * np.pi * t) -  a * 4 * c * np.pi * np.sin(2 * c * np.pi* x) * np.sin(4 * c * np.pi * t)
    return u_t

def u_tt(x, a, c):
    t = x[:,0:1]
    x = x[:,1:2]
    u_tt = -(c * np.pi)**2 * np.sin( np.pi * x) * np.cos(c * np.pi * t) - a * (4 * c * np.pi)**2 *  np.sin(2 * c * np.pi* x) * np.cos(4 * c * np.pi * t)
    return u_tt

def u_xx(x, a, c):
    t = x[:,0:1]
    x = x[:,1:2]
    u_xx = - np.pi**2 * np.sin( np.pi * x) * np.cos(c * np.pi * t) -  a * (2 * c * np.pi)** 2 * np.sin(2 * c * np.pi* x) * np.cos(4 * c * np.pi * t)
    return  u_xx


def r(x, a, c):
    return u_tt(x, a, c) - c**2 * u_xx(x, a, c)

def operator(u, t, x, c, sigma_t=1.0, sigma_x=1.0):
    u_t = tf.gradients(u, t)[0] / sigma_t
    u_x = tf.gradients(u, x)[0] / sigma_x
    u_tt = tf.gradients(u_t, t)[0] / sigma_t
    u_xx = tf.gradients(u_x, x)[0] / sigma_x
    residual = u_tt - c**2 * u_xx
    return residual

# %%
class PINN:
    # Initialize the class
    def __init__(self, layers, operator, ics_sampler, bcs_sampler, res_sampler, c, kernel_size , sess):
        # Normalization 
        X, _ = res_sampler.sample(np.int32(1e5))
        self.mu_X, self.sigma_X = X.mean(0), X.std(0)
        self.mu_t, self.sigma_t = self.mu_X[0], self.sigma_X[0]
        self.mu_x, self.sigma_x = self.mu_X[1], self.sigma_X[1]

        self.activFun = 'xsig'
        # Samplers
        self.operator = operator
        self.ics_sampler = ics_sampler
        self.bcs_sampler = bcs_sampler
        self.res_sampler = res_sampler

        self.sess = sess
        # Initialize network weights and biases
        self.layers = layers
        self.weights, self.biases = self.initialize_NN(layers)
        
        # weights
        self.lam_u_val = np.array(2.0)
        self.lam_ut_val = np.array(2.0)
        self.lam_res_val = np.array(1.0)
        self.lam_bc1_val = np.array(2.0)
        self.lam_bc2_val = np.array(2.0)
      
        # Wave constant
        self.c = tf.constant(c, dtype=tf.float32)
        
        self.kernel_size = kernel_size # Size of the NTK matrix

        # Define Tensorflow session
        self.sess = tf.Session(config=tf.ConfigProto(log_device_placement=False))

        # Define placeholders and computational graph
        self.t_u_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_u_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_ics_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_ics_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.u_ics_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_r_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_r_tf = tf.placeholder(tf.float32, shape=(None, 1))
        
        self.lam_u_tf = tf.placeholder(tf.float32, shape=self.lam_u_val.shape)
        self.lam_ut_tf = tf.placeholder(tf.float32, shape=self.lam_u_val.shape)
        # self.lam_r_tf = tf.placeholder(tf.float32, shape=self.lam_u_val.shape)
        self.lam_bc_tf = tf.placeholder(tf.float32, shape=self.lam_bc1_val.shape)
        # self.lam_bc2_tf = tf.placeholder(tf.float32, shape=self.lam_bc2_val.shape)
        self.lam_res_tf = tf.placeholder(tf.float32, shape=self.lam_res_val.shape)


        self.u_pred = self.net_u(self.t_u_tf, self.x_u_tf)


        # Evaluate predictions
        self.u_ics_pred = self.net_u(self.t_ics_tf, self.x_ics_tf)
        self.u_bc1_pred = self.net_u(self.t_bc1_tf, self.x_bc1_tf)
        self.u_bc2_pred = self.net_u(self.t_bc2_tf, self.x_bc2_tf)

        self.r_pred = self.net_r(self.t_r_tf, self.x_r_tf)
        

        
        # Boundary loss and Initial loss
        self.loss_ics_u = tf.reduce_mean(tf.square(self.u_ics_tf - self.u_ics_pred))
        self.loss_ics_ut = tf.reduce_mean(tf.square( tf.gradients(self.u_ics_pred, self.t_ics_tf)[0] / self.sigma_t) )
        self.loss_bc1 = tf.reduce_mean(tf.square(self.u_bc1_pred)) #+ tf.reduce_mean(tf.square(self.u_bc2_pred))
        self.loss_bc2 = tf.reduce_mean(tf.square(self.u_bc2_pred))

        # Residual loss
        self.loss_res = tf.reduce_mean(tf.square(self.r_pred))

        # Total loss
        self.loss =  self.lam_res_tf *self.loss_res + self.lam_bc_tf *( self.loss_bc1 + self.loss_bc2 )+ self.lam_u_tf * (self.loss_ics_u + self.loss_ics_ut )

        # Define optimizer with learning rate schedule
        self.global_step = tf.Variable(0, trainable=False)
        starter_learning_rate = 1e-3
        self.learning_rate = tf.train.exponential_decay(starter_learning_rate, self.global_step,  1000, 0.9, staircase=False)
        # Passing global_step to minimize() will increment it at each step.
        self.train_op = tf.train.AdamOptimizer(self.learning_rate).minimize(self.loss, global_step=self.global_step)
        

         # Initialize Tensorflow variables
        init = tf.global_variables_initializer()
        self.sess.run(init)

    # Initialize network weights and biases using Xavier initialization
    def initialize_NN(self, layers):
        # Xavier initialization
        def xavier_init(size):
            in_dim = size[0]
            out_dim = size[1]
            xavier_stddev = 1. / np.sqrt((in_dim + out_dim) / 2.)
            return tf.Variable(tf.random.normal([in_dim, out_dim], dtype=tf.float32) * xavier_stddev,  dtype=tf.float32)

        weights = []
        biases = []
        num_layers = len(layers)
        for l in range(0, num_layers - 1):
            W = xavier_init(size=[layers[l], layers[l + 1]])
            b = tf.Variable(tf.zeros([1, layers[l + 1]], dtype=tf.float32), dtype=tf.float32)
            weights.append(W)
            biases.append(b)
        return weights, biases

    # Evaluates the forward pass
    def forward_pass(self, H, layers, weights, biases):
        # num_layers = len(layers)
        # for l in range(0, num_layers - 2):
        #     W = weights[l]
        #     b = biases[l]
        #     # H = tf.tanh(tf.add(tf.matmul(H, W), b))
        #     H =  H*tf.sigmoid(tf.add(tf.matmul(H, W), b))
        # W = weights[-1]
        # b = biases[-1]
        # H = tf.add(tf.matmul(H, W), b)
        # H = (tf.concat(inputs, 1) - self.X_mean)/self.X_std
        num_layers = len(layers)
        for l in range(0,num_layers-1):
            W = weights[l]
            b = biases[l]
            V = W/tf.norm(W, axis = 0, keepdims=True)
            H = tf.matmul(H, V)
            H = H + b
            if l < num_layers-2:
                    if(self.activFun == 'xsig'):
                        # print("xsig is used")
                        H = H*tf.sigmoid(H)
                    elif self.activFun == 'hard_swish':
                        H = H * tf.nn.relu6(H+3) * 0.16666667
                    else:
                        H = tf.tanh(H)
                
        Y = tf.split(H, num_or_size_splits=H.shape[1], axis=1)
        return H
################################################################################################
    # Forward pass for u
    def net_u(self, t, x):
        u = self.forward_pass(tf.concat([t, x], 1),  self.layers, self.weights, self.biases)
        return u

    # Forward pass for du/dt
    def net_u_t(self, t, x):
        u_t = tf.gradients(self.net_u(t, x), t)[0] / self.sigma_t
        return u_t

    # Forward pass for the residual
    def net_r(self, t, x):
        u = self.net_u(t, x)
        residual = self.operator(u, t, x, self.c, self.sigma_t,  self.sigma_x)
        return residual
    
    

    def fetch_minibatch(self, sampler, N):
        X, Y = sampler.sample(N)
        X = (X - self.mu_X) / self.sigma_X
        return X, Y

        # Trains the model by minimizing the MSE loss

    def trainmb(self, nIter=10000, batch_size=128, log_NTK=False, update_lam=False):

        start_time = timeit.default_timer()
        for it in range(nIter):
            # Fetch boundary mini-batches
            X_ics_batch, u_ics_batch = self.fetch_minibatch(self.ics_sampler, batch_size // 3)
            X_bc1_batch, _ = self.fetch_minibatch(self.bcs_sampler[0], batch_size // 3)
            X_bc2_batch, _ = self.fetch_minibatch(self.bcs_sampler[1], batch_size // 3)
            
            # Fetch residual mini-batch
            X_res_batch, _ = self.fetch_minibatch(self.res_sampler, batch_size)
            # Define a dictionary for associating placeholders with data
            tf_dict = {self.t_ics_tf: X_ics_batch[:, 0:1], self.x_ics_tf: X_ics_batch[:, 1:2],
                       self.u_ics_tf: u_ics_batch,
                       self.t_bc1_tf: X_bc1_batch[:, 0:1], self.x_bc1_tf: X_bc1_batch[:, 1:2],
                       self.t_bc2_tf: X_bc2_batch[:, 0:1], self.x_bc2_tf: X_bc2_batch[:, 1:2],
                       self.t_r_tf: X_res_batch[:, 0:1], self.x_r_tf: X_res_batch[:, 1:2],
                       self.lam_u_tf: self.lam_u_val,
                       self.lam_bc_tf: self.lam_bc1_val,
                    self.lam_res_tf: self.lam_res_val,
                       }

            # Run the Tensorflow session to minimize the loss
            self.sess.run(self.train_op, tf_dict)

            # Print
            if it % 100 == 0:
            
                elapsed = timeit.default_timer() - start_time

                loss , loss_bc1 , loss_bc2 , loss_ics_u , loss_ics_ut , loss_res = self.sess.run( [self.loss  , self.loss_bc1 ,self.loss_bc2 , self.loss_ics_u, self.loss_ics_ut, self.loss_res ] , tf_dict)

                print('It: %d, Loss: %.3e,  loss_bc1: %.3e,  loss_bc2: %.3e, loss_ics_u: %.3e, loss_ics_ut: %.3e,  Loss_res: %.3e , Time: %.2f' %(it, loss, loss_bc1 , loss_bc2 , loss_ics_u, loss_ics_ut , loss_res , elapsed))
                

                # start_time = timeit.default_timer()

                self.loss_bc_avg += (loss_bc1 + loss_bc2 ) /self.count
                self.loss_ics_u_avg += (loss_ics_u + loss_ics_ut )  /self.count
                self.loss_res_avg += loss_res  /self.count
                self.count +=1
        
                if it % 100== 0: 
                        alpha   = 100
                        self.lam_bc_val = alpha *  self.loss_bc_avg# (loss_bc1 + loss_bc2 )
                        # self.lam_bc2_val = alpha * loss_bc2
                        self.lam_u_val = alpha * self.loss_ics_u_avg # (loss_ics_u + loss_ics_ut )
                        self.lam_res_val = 100 * self.loss_res_avg #loss_res
                        
                        print('loss_bc1: {:.3e}'.format(self.lam_bc_val))
                        # print('loss_bc2: {:.3e}'.format(self.lam_bc2_val))
                        print('loss_ics_u: {:.3e}'.format(self.lam_u_val))
                        print('loss_res_val: {:.3e}'.format(self.lam_res_val))

            sys.stdout.flush()

#########################################################################################################################

    def train(self, nIter , bcbatch_size , ubatch_size):

        start_time = timeit.default_timer()

        # Fetch boundary mini-batches
        X_ics_batch, u_ics_batch = self.fetch_minibatch(self.ics_sampler, bcbatch_size)
        X_bc1_batch, _ = self.fetch_minibatch(self.bcs_sampler[0], bcbatch_size )
        X_bc2_batch, _ = self.fetch_minibatch(self.bcs_sampler[1], bcbatch_size )
        
        # Fetch residual mini-batch
        X_res_batch, _ = self.fetch_minibatch(self.res_sampler, ubatch_size)
        # print("inside trainmb: " , X_res_batch.shape)
        # Define a dictionary for associating placeholders with data
        tf_dict = {self.t_ics_tf: X_ics_batch[:, 0:1], self.x_ics_tf: X_ics_batch[:, 1:2],
                    self.u_ics_tf: u_ics_batch,
                    self.t_bc1_tf: X_bc1_batch[:, 0:1], self.x_bc1_tf: X_bc1_batch[:, 1:2],
                    self.t_bc2_tf: X_bc2_batch[:, 0:1], self.x_bc2_tf: X_bc2_batch[:, 1:2],
                    self.t_r_tf: X_res_batch[:, 0:1], self.x_r_tf: X_res_batch[:, 1:2],
                    self.lam_u_tf: self.lam_u_val,
                       self.lam_bc_tf: self.lam_bc1_val,
                    self.lam_res_tf: self.lam_res_val,
                    }
        
   
  
        for it in range(1 , nIter):

            # Run the Tensorflow session to minimize the loss
            self.sess.run(self.train_op, tf_dict)

            # Print
            if it % 100 == 0:
                elapsed = timeit.default_timer() - start_time

                loss = self.sess.run(self.loss, tf_dict)
                loss_bc1 = self.sess.run(self.loss_bc1, tf_dict)
                # loss_bc2 = self.sess.run(self.loss_bc2, tf_dict)
                loss_ics_u = self.sess.run(self.loss_ics_u, tf_dict)
                loss_res = self.sess.run(self.loss_res, tf_dict)

                if it % 100 == 0:
                    elapsed = timeit.default_timer() - start_time

                    loss , loss_bc1 , loss_bc2 , loss_ics_u , loss_ics_ut , loss_res = self.sess.run( [self.loss  , self.loss_bc1 ,self.loss_bc2 , self.loss_ics_u, self.loss_ics_ut, self.loss_res ] , tf_dict)

                    print('It: %d, Loss: %.3e,  loss_bc1: %.3e,  loss_bc2: %.3e, loss_ics_u: %.3e, loss_ics_ut: %.3e,  Loss_res: %.3e , Time: %.2f' %(it, loss, loss_bc1 , loss_bc2 , loss_ics_u, loss_ics_ut , loss_res , elapsed))
                    
    
                    # start_time = timeit.default_timer()

                    # self.loss_bc_avg += (loss_bc1 + loss_bc2 ) /self.count
                    # self.loss_ics_u_avg += (loss_ics_u + loss_ics_ut )  /self.count
                    # self.loss_res_avg += loss_res  /self.count
                    # self.count +=1
            
                    if it % 1000== 0: 
                            alpha   = 1
                            self.lam_bc_val = alpha *  (loss_bc1 + loss_bc2 )
                            # self.lam_bc2_val = alpha * loss_bc2
                            self.lam_u_val = alpha * (loss_ics_u + loss_ics_ut )
                            self.lam_res_val = 1 *loss_res
                            
                            print('loss_bc1: {:.3e}'.format(self.lam_bc_val))
                            # print('loss_bc2: {:.3e}'.format(self.lam_bc2_val))
                            print('loss_ics_u: {:.3e}'.format(self.lam_u_val))
                            print('loss_res_val: {:.3e}'.format(self.lam_res_val))

                sys.stdout.flush()


    # Evaluates predictions at test points
    def predict_u(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.t_u_tf: X_star[:, 0:1], self.x_u_tf: X_star[:, 1:2]}
        u_star = self.sess.run(self.u_pred, tf_dict)
        return u_star

        # Evaluates predictions at test points

    def predict_r(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.t_r_tf: X_star[:, 0:1], self.x_r_tf: X_star[:, 1:2]}
        r_star = self.sess.run(self.r_pred, tf_dict)
        return r_star
    
   ###############################################################################################################################################
   # 
   # ###############################################################################################################################################
   # 
   # ###############################################################################################################################################
   # 
   #

# %%
#test_method(mtd , layers,  X_u, Y_u, X_r, Y_r ,  X_star , u_star , r_star  , nIter ,batch_size , bcbatch_size , ubatch_size)
def test_method(method , layers,  ics_sampler, bcs_sampler, res_sampler, c ,kernel_size , X_star , u_star , r_star , nIter ,mbbatch_size , bcbatch_size , ubatch_size ):

    tf.reset_default_graph()
    gpu_options = tf.GPUOptions(visible_device_list="0")
    with tf.Session(config=tf.ConfigProto(gpu_options=gpu_options,allow_soft_placement=False, log_device_placement=False)) as sess:
        # sess.run(init)

        model = PINN(layers, operator, ics_sampler, bcs_sampler, res_sampler, c, kernel_size , sess)
        # Train model
        start_time = time.time()

        if method =="full_batch":
            print("full_batch method is used")
            model.train(nIter  , bcbatch_size , ubatch_size  )
        elif method =="mini_batch":
            print("mini_batch method is used")
            model.trainmb(nIter, mbbatch_size)
        else:
            print("unknown method!")
        elapsed = time.time() - start_time

        # Predictions
        u_pred = model.predict_u(X_star)
        r_pred = model.predict_r(X_star)
        # Predictions

        sess.close()   

    error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)
    error_r = np.linalg.norm(r_star - r_pred, 2) #/ np.linalg.norm(u_star, 2)

    print('elapsed: {:.2e}'.format(elapsed))

    print('Relative L2 error_u: {:.2e}'.format(error_u))
    print('Relative L2 error_r: {:.2e}'.format(error_r))


    return [elapsed, error_u , error_r , model]

###############################################################################################################################################

# %%
# Define PINN model
a = 0.5
c = 2

kernel_size = 300

# Domain boundaries
ics_coords = np.array([[0.0, 0.0],  [0.0, 1.0]])
bc1_coords = np.array([[0.0, 0.0],  [1.0, 0.0]])
bc2_coords = np.array([[0.0, 1.0],  [1.0, 1.0]])
dom_coords = np.array([[0.0, 0.0],  [1.0, 1.0]])

# Create initial conditions samplers
ics_sampler = Sampler(2, ics_coords, lambda x: u(x, a, c), name='Initial Condition 1')

# Create boundary conditions samplers
bc1 = Sampler(2, bc1_coords, lambda x: u(x, a, c), name='Dirichlet BC1')
bc2 = Sampler(2, bc2_coords, lambda x: u(x, a, c), name='Dirichlet BC2')
bcs_sampler = [bc1, bc2]

# Create residual sampler
res_sampler = Sampler(2, dom_coords, lambda x: r(x, a, c), name='Forcing')



nIter =40000
bcbatch_size = 500
ubatch_size = 5000
mbbatch_size = 300



# Define model
mode = 'M4'
layers = [2, 500, 500, 500, 1]


nn = 200
t = np.linspace(dom_coords[0, 0], dom_coords[1, 0], nn)[:, None]
x = np.linspace(dom_coords[0, 1], dom_coords[1, 1], nn)[:, None]
t, x = np.meshgrid(t, x)
X_star = np.hstack((t.flatten()[:, None], x.flatten()[:, None]))

u_star = u(X_star, a,c)
r_star = r(X_star, a, c)

iterations = 1
methods = [  "mini_batch"]

result_dict =  dict((mtd, []) for mtd in methods)

for mtd in methods:
    print("Method: ", mtd)
    time_list = []
    error_u_list = []
    
    for index in range(iterations):

        print("Epoch: ", str(index+1))

        # Create residual sampler

        tf.reset_default_graph()
        gpu_options = tf.GPUOptions(visible_device_list="0")
        with tf.Session(config=tf.ConfigProto(gpu_options=gpu_options,allow_soft_placement=False, log_device_placement=False)) as sess:
            # sess.run(init)

            model = PINN(layers, operator, ics_sampler, bcs_sampler, res_sampler, c, kernel_size , sess)
            # Train model
            start_time = time.time()

            if mtd =="full_batch":
                print("full_batch method is used")
                model.train(nIter  , bcbatch_size , ubatch_size  )
            elif mtd =="mini_batch":
                print("mini_batch method is used")
                model.trainmb(nIter, mbbatch_size)
            else:
                print("unknown method!")
            elapsed = time.time() - start_time

            # Predictions
            u_pred = model.predict_u(X_star)
            r_pred = model.predict_r(X_star)
            # Predictions

            sess.close()   

        error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)
        error_r = np.linalg.norm(r_star - r_pred, 2) #/ np.linalg.norm(u_star, 2)

        print('elapsed: {:.2e}'.format(elapsed))

        print('Relative L2 error_u: {:.2e}'.format(error_u))
        print('Relative L2 error_r: {:.2e}'.format(error_r))


        # print('elapsed: {:.2e}'.format(elapsed))
        # print('Relative L2 error_u: {:.2e}'.format(error_u))

        time_list.append(elapsed)
        error_u_list.append(error_u)

    print("\n\nMethod: ", mtd)
    print("\naverage of time_list:" , sum(time_list) / len(time_list) )
    print("average of error_u_list:" , sum(error_u_list) / len(error_u_list) )
    # print("average of error_r_list:" , sum(error_r_list) / len(error_r_list) )

    result_dict[mtd] = [time_list ,error_u_list]
    # scipy.io.savemat("M2_result_"+str(iterations)+"_"+mtd+".mat" , {'time_list':np.array(time_list),'error_u_list':np.array(error_u_list),'error_f_list':np.array(error_f_list)})

    scipy.io.savemat("./1DWave_database/"+mtd+"_1Dwave_"+mode+"_result_mb"+str(mbbatch_size)+"_fb"+str(ubatch_size)+"_bc"+str(mbbatch_size)+"_"+str(iterations)+".mat" , result_dict)

###############################################################################################################################################
# Out:
# Method:  mini_batch
# Epoch:  1
# WARNING:tensorflow:From /tmp/ipykernel_12919/2509204241.py:63: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_12919/2509204241.py:64: The name tf.GPUOptions is deprecated. Please use tf.compat.v1.GPUOptions instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_12919/2509204241.py:65: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_12919/2509204241.py:65: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_12919/3500675666.py:38: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# 2023-11-27 17:51:41.229323: I tensorflow/core/platform/cpu_feature_guard.cc:145] This TensorFlow binary is optimized with Intel(R) MKL-DNN to use the following CPU instructions in performance critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in non-MKL-DNN operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-27 17:51:41.249079: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2899885000 Hz
# 2023-11-27 17:51:41.249595: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x558b672c1aa0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-11-27 17:51:41.249608: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2023-11-27 17:51:41.254293: I tensorflow/core/common_runtime/process_util.cc:115] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# WARNING:tensorflow:From /tmp/ipykernel_12919/3500675666.py:89: The name tf.train.exponential_decay is deprecated. Please use tf.compat.v1.train.exponential_decay instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_12919/3500675666.py:91: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_12919/3500675666.py:95: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# mini_batch method is used
# It: 0, Loss: 2.220e+03,  loss_bc1: 1.163e+00,  loss_bc2: 2.046e+00, loss_ics_u: 7.293e-01, loss_ics_ut: 2.883e+00,  Loss_res: 2.206e+03 , Time: 4.07
# loss_bc1: 3.209e+02
# loss_ics_u: 3.613e+02
# loss_res_val: 2.206e+05
# It: 100, Loss: 1.578e+03,  loss_bc1: 6.754e-03,  loss_bc2: 1.059e-02, loss_ics_u: 4.850e-01, loss_ics_ut: 6.510e-02,  Loss_res: 6.252e-03 , Time: 9.88
# loss_bc1: 1.735e+00
# loss_ics_u: 5.501e+01
# loss_res_val: 6.252e-01
# It: 200, Loss: 2.808e+01,  loss_bc1: 1.477e-02,  loss_bc2: 1.602e-02, loss_ics_u: 4.505e-01, loss_ics_ut: 5.852e-02,  Loss_res: 2.596e-02 , Time: 15.02
# loss_bc1: 3.079e+00
# loss_ics_u: 5.090e+01
# loss_res_val: 2.596e+00
# It: 300, Loss: 2.529e+01,  loss_bc1: 1.763e-02,  loss_bc2: 2.116e-02, loss_ics_u: 4.371e-01, loss_ics_ut: 5.716e-02,  Loss_res: 2.062e-02 , Time: 20.17
# loss_bc1: 3.879e+00
# loss_ics_u: 4.943e+01
# loss_res_val: 2.062e+00
# It: 400, Loss: 2.378e+01,  loss_bc1: 2.291e-02,  loss_bc2: 2.804e-02, loss_ics_u: 4.245e-01, loss_ics_ut: 5.345e-02,  Loss_res: 2.580e-02 , Time: 25.22
# loss_bc1: 5.095e+00
# loss_ics_u: 4.779e+01
# loss_res_val: 2.580e+00
# It: 500, Loss: 2.042e+01,  loss_bc1: 2.947e-02,  loss_bc2: 3.515e-02, loss_ics_u: 3.674e-01, loss_ics_ut: 5.567e-02,  Loss_res: 2.709e-02 , Time: 30.49
# loss_bc1: 6.462e+00
# loss_ics_u: 4.231e+01
# loss_res_val: 2.709e+00
# It: 600, Loss: 1.737e+01,  loss_bc1: 3.511e-02,  loss_bc2: 4.413e-02, loss_ics_u: 3.529e-01, loss_ics_ut: 5.198e-02,  Loss_res: 2.896e-02 , Time: 36.06
# loss_bc1: 7.923e+00
# loss_ics_u: 4.049e+01
# loss_res_val: 2.896e+00
# It: 700, Loss: 1.633e+01,  loss_bc1: 4.646e-02,  loss_bc2: 4.904e-02, loss_ics_u: 3.454e-01, loss_ics_ut: 5.124e-02,  Loss_res: 2.629e-02 , Time: 41.59
# loss_bc1: 9.550e+00
# loss_ics_u: 3.966e+01
# loss_res_val: 2.629e+00
# It: 800, Loss: 1.660e+01,  loss_bc1: 5.120e-02,  loss_bc2: 5.420e-02, loss_ics_u: 3.605e-01, loss_ics_ut: 5.088e-02,  Loss_res: 2.657e-02 , Time: 47.07
# loss_bc1: 1.054e+01
# loss_ics_u: 4.114e+01
# loss_res_val: 2.657e+00
# It: 900, Loss: 1.848e+01,  loss_bc1: 6.308e-02,  loss_bc2: 7.030e-02, loss_ics_u: 3.964e-01, loss_ics_ut: 4.463e-02,  Loss_res: 2.664e-02 , Time: 52.48
# loss_bc1: 1.334e+01
# loss_ics_u: 4.410e+01
# loss_res_val: 2.664e+00
# It: 1000, Loss: 1.884e+01,  loss_bc1: 7.200e-02,  loss_bc2: 8.369e-02, loss_ics_u: 3.736e-01, loss_ics_ut: 4.472e-02,  Loss_res: 2.991e-02 , Time: 57.78
# loss_bc1: 1.557e+01
# loss_ics_u: 4.184e+01
# loss_res_val: 2.991e+00
# It: 1100, Loss: 1.633e+01,  loss_bc1: 8.108e-02,  loss_bc2: 8.978e-02, loss_ics_u: 3.360e-01, loss_ics_ut: 4.424e-02,  Loss_res: 2.602e-02 , Time: 63.10
# loss_bc1: 1.709e+01
# loss_ics_u: 3.803e+01
# loss_res_val: 2.602e+00
# It: 1200, Loss: 1.524e+01,  loss_bc1: 9.653e-02,  loss_bc2: 1.045e-01, loss_ics_u: 3.444e-01, loss_ics_ut: 4.356e-02,  Loss_res: 3.045e-02 , Time: 68.46
# loss_bc1: 2.011e+01
# loss_ics_u: 3.880e+01
# loss_res_val: 3.045e+00
# It: 1300, Loss: 1.325e+01,  loss_bc1: 1.040e-01,  loss_bc2: 1.140e-01, loss_ics_u: 2.852e-01, loss_ics_ut: 4.232e-02,  Loss_res: 3.361e-02 , Time: 73.75
# loss_bc1: 2.181e+01
# loss_ics_u: 3.275e+01
# loss_res_val: 3.361e+00
# It: 1400, Loss: 1.082e+01,  loss_bc1: 1.186e-01,  loss_bc2: 1.211e-01, loss_ics_u: 2.705e-01, loss_ics_ut: 4.166e-02,  Loss_res: 3.322e-02 , Time: 79.19
# loss_bc1: 2.397e+01
# loss_ics_u: 3.122e+01
# loss_res_val: 3.322e+00
# It: 1500, Loss: 1.055e+01,  loss_bc1: 1.262e-01,  loss_bc2: 1.305e-01, loss_ics_u: 2.763e-01, loss_ics_ut: 4.139e-02,  Loss_res: 3.430e-02 , Time: 84.52
# loss_bc1: 2.566e+01
# loss_ics_u: 3.177e+01
# loss_res_val: 3.430e+00
# It: 1600, Loss: 1.136e+01,  loss_bc1: 1.309e-01,  loss_bc2: 1.439e-01, loss_ics_u: 3.003e-01, loss_ics_ut: 3.643e-02,  Loss_res: 3.316e-02 , Time: 89.91
# loss_bc1: 2.748e+01
# loss_ics_u: 3.367e+01
# loss_res_val: 3.316e+00
# It: 1700, Loss: 9.723e+00,  loss_bc1: 1.459e-01,  loss_bc2: 1.544e-01, loss_ics_u: 2.294e-01, loss_ics_ut: 3.806e-02,  Loss_res: 3.605e-02 , Time: 95.25
# loss_bc1: 3.003e+01
# loss_ics_u: 2.674e+01
# loss_res_val: 3.605e+00
# It: 1800, Loss: 8.637e+00,  loss_bc1: 1.476e-01,  loss_bc2: 1.609e-01, loss_ics_u: 2.623e-01, loss_ics_ut: 3.354e-02,  Loss_res: 3.061e-02 , Time: 100.59
# loss_bc1: 3.084e+01
# loss_ics_u: 2.958e+01
# loss_res_val: 3.061e+00
# It: 1900, Loss: 1.051e+01,  loss_bc1: 1.531e-01,  loss_bc2: 1.729e-01, loss_ics_u: 2.956e-01, loss_ics_ut: 3.397e-02,  Loss_res: 3.434e-02 , Time: 105.95
# loss_bc1: 3.261e+01
# loss_ics_u: 3.296e+01
# loss_res_val: 3.434e+00
# It: 2000, Loss: 1.108e+01,  loss_bc1: 1.718e-01,  loss_bc2: 1.773e-01, loss_ics_u: 2.754e-01, loss_ics_ut: 3.554e-02,  Loss_res: 3.865e-02 , Time: 111.33
# loss_bc1: 3.491e+01
# loss_ics_u: 3.110e+01
# loss_res_val: 3.865e+00
# It: 2100, Loss: 9.403e+00,  loss_bc1: 1.749e-01,  loss_bc2: 1.820e-01, loss_ics_u: 2.455e-01, loss_ics_ut: 2.951e-02,  Loss_res: 3.559e-02 , Time: 116.66
# loss_bc1: 3.569e+01
# loss_ics_u: 2.750e+01
# loss_res_val: 3.559e+00
# It: 2200, Loss: 9.290e+00,  loss_bc1: 1.830e-01,  loss_bc2: 1.948e-01, loss_ics_u: 2.754e-01, loss_ics_ut: 3.051e-02,  Loss_res: 3.435e-02 , Time: 121.99
# loss_bc1: 3.777e+01
# loss_ics_u: 3.059e+01
# loss_res_val: 3.435e+00
# It: 2300, Loss: 9.354e+00,  loss_bc1: 1.796e-01,  loss_bc2: 2.049e-01, loss_ics_u: 2.463e-01, loss_ics_ut: 2.999e-02,  Loss_res: 3.854e-02 , Time: 127.28
# loss_bc1: 3.845e+01
# loss_ics_u: 2.763e+01
# loss_res_val: 3.854e+00
# It: 2400, Loss: 8.366e+00,  loss_bc1: 2.009e-01,  loss_bc2: 2.107e-01, loss_ics_u: 2.366e-01, loss_ics_ut: 3.069e-02,  Loss_res: 4.065e-02 , Time: 132.59
# loss_bc1: 4.116e+01
# loss_ics_u: 2.673e+01
# loss_res_val: 4.065e+00
# It: 2500, Loss: 6.994e+00,  loss_bc1: 1.969e-01,  loss_bc2: 2.126e-01, loss_ics_u: 1.966e-01, loss_ics_ut: 2.897e-02,  Loss_res: 3.554e-02 , Time: 138.00
# loss_bc1: 4.095e+01
# loss_ics_u: 2.256e+01
# loss_res_val: 3.554e+00
# It: 2600, Loss: 6.968e+00,  loss_bc1: 2.043e-01,  loss_bc2: 2.115e-01, loss_ics_u: 2.390e-01, loss_ics_ut: 2.715e-02,  Loss_res: 3.747e-02 , Time: 143.46
# loss_bc1: 4.158e+01
# loss_ics_u: 2.661e+01
# loss_res_val: 3.747e+00
# It: 2700, Loss: 9.339e+00,  loss_bc1: 2.062e-01,  loss_bc2: 2.210e-01, loss_ics_u: 2.875e-01, loss_ics_ut: 2.565e-02,  Loss_res: 4.031e-02 , Time: 148.78
# loss_bc1: 4.273e+01
# loss_ics_u: 3.132e+01
# loss_res_val: 4.031e+00
# It: 2800, Loss: 8.869e+00,  loss_bc1: 2.131e-01,  loss_bc2: 2.274e-01, loss_ics_u: 2.247e-01, loss_ics_ut: 2.552e-02,  Loss_res: 3.746e-02 , Time: 154.13
# loss_bc1: 4.405e+01
# loss_ics_u: 2.503e+01
# loss_res_val: 3.746e+00
# It: 2900, Loss: 7.305e+00,  loss_bc1: 2.195e-01,  loss_bc2: 2.294e-01, loss_ics_u: 2.250e-01, loss_ics_ut: 2.535e-02,  Loss_res: 3.786e-02 , Time: 159.62
# loss_bc1: 4.488e+01
# loss_ics_u: 2.504e+01
# loss_res_val: 3.786e+00
# It: 3000, Loss: 7.365e+00,  loss_bc1: 2.165e-01,  loss_bc2: 2.391e-01, loss_ics_u: 2.303e-01, loss_ics_ut: 2.184e-02,  Loss_res: 3.708e-02 , Time: 165.31
# loss_bc1: 4.556e+01
# loss_ics_u: 2.522e+01
# loss_res_val: 3.708e+00
# It: 3100, Loss: 8.713e+00,  loss_bc1: 2.220e-01,  loss_bc2: 2.385e-01, loss_ics_u: 2.790e-01, loss_ics_ut: 2.470e-02,  Loss_res: 3.595e-02 , Time: 170.75
# loss_bc1: 4.605e+01
# loss_ics_u: 3.037e+01
# loss_res_val: 3.595e+00
# It: 3200, Loss: 7.861e+00,  loss_bc1: 2.237e-01,  loss_bc2: 2.395e-01, loss_ics_u: 2.021e-01, loss_ics_ut: 2.183e-02,  Loss_res: 3.710e-02 , Time: 176.13
# loss_bc1: 4.633e+01
# loss_ics_u: 2.239e+01
# loss_res_val: 3.710e+00
# It: 3300, Loss: 7.741e+00,  loss_bc1: 2.298e-01,  loss_bc2: 2.403e-01, loss_ics_u: 2.771e-01, loss_ics_ut: 2.029e-02,  Loss_res: 3.824e-02 , Time: 181.44
# loss_bc1: 4.701e+01
# loss_ics_u: 2.974e+01
# loss_res_val: 3.824e+00
# It: 3400, Loss: 7.367e+00,  loss_bc1: 2.364e-01,  loss_bc2: 2.446e-01, loss_ics_u: 1.951e-01, loss_ics_ut: 1.521e-02,  Loss_res: 3.907e-02 , Time: 186.89
# loss_bc1: 4.809e+01
# loss_ics_u: 2.104e+01
# loss_res_val: 3.907e+00
# It: 3500, Loss: 6.264e+00,  loss_bc1: 2.388e-01,  loss_bc2: 2.469e-01, loss_ics_u: 2.263e-01, loss_ics_ut: 1.768e-02,  Loss_res: 4.099e-02 , Time: 192.34
# loss_bc1: 4.858e+01
# loss_ics_u: 2.440e+01
# loss_res_val: 4.099e+00
# It: 3600, Loss: 6.986e+00,  loss_bc1: 2.364e-01,  loss_bc2: 2.552e-01, loss_ics_u: 2.228e-01, loss_ics_ut: 1.734e-02,  Loss_res: 3.534e-02 , Time: 197.77
# loss_bc1: 4.916e+01
# loss_ics_u: 2.401e+01
# loss_res_val: 3.534e+00
# It: 3700, Loss: 8.122e+00,  loss_bc1: 2.357e-01,  loss_bc2: 2.546e-01, loss_ics_u: 2.771e-01, loss_ics_ut: 1.536e-02,  Loss_res: 3.414e-02 , Time: 203.09
# loss_bc1: 4.902e+01
# loss_ics_u: 2.924e+01
# loss_res_val: 3.414e+00
# It: 3800, Loss: 9.359e+00,  loss_bc1: 2.330e-01,  loss_bc2: 2.529e-01, loss_ics_u: 2.643e-01, loss_ics_ut: 1.819e-02,  Loss_res: 3.690e-02 , Time: 208.46
# loss_bc1: 4.859e+01
# loss_ics_u: 2.825e+01
# loss_res_val: 3.690e+00
# It: 3900, Loss: 7.191e+00,  loss_bc1: 2.449e-01,  loss_bc2: 2.610e-01, loss_ics_u: 2.018e-01, loss_ics_ut: 1.226e-02,  Loss_res: 3.544e-02 , Time: 213.80
# loss_bc1: 5.059e+01
# loss_ics_u: 2.141e+01
# loss_res_val: 3.544e+00
# It: 4000, Loss: 7.154e+00,  loss_bc1: 2.431e-01,  loss_bc2: 2.556e-01, loss_ics_u: 2.651e-01, loss_ics_ut: 1.659e-02,  Loss_res: 3.544e-02 , Time: 219.17
# loss_bc1: 4.987e+01
# loss_ics_u: 2.817e+01
# loss_res_val: 3.544e+00
# It: 4100, Loss: 9.071e+00,  loss_bc1: 2.412e-01,  loss_bc2: 2.604e-01, loss_ics_u: 2.692e-01, loss_ics_ut: 1.312e-02,  Loss_res: 3.272e-02 , Time: 224.61
# loss_bc1: 5.016e+01
# loss_ics_u: 2.823e+01
# loss_res_val: 3.272e+00
# It: 4200, Loss: 7.050e+00,  loss_bc1: 2.464e-01,  loss_bc2: 2.682e-01, loss_ics_u: 1.983e-01, loss_ics_ut: 1.101e-02,  Loss_res: 3.441e-02 , Time: 229.88
# loss_bc1: 5.147e+01
# loss_ics_u: 2.093e+01
# loss_res_val: 3.441e+00
# It: 4300, Loss: 5.824e+00,  loss_bc1: 2.520e-01,  loss_bc2: 2.567e-01, loss_ics_u: 2.139e-01, loss_ics_ut: 1.043e-02,  Loss_res: 3.247e-02 , Time: 235.13
# loss_bc1: 5.087e+01
# loss_ics_u: 2.243e+01
# loss_res_val: 3.247e+00
# It: 4400, Loss: 6.637e+00,  loss_bc1: 2.475e-01,  loss_bc2: 2.584e-01, loss_ics_u: 2.351e-01, loss_ics_ut: 1.132e-02,  Loss_res: 3.038e-02 , Time: 240.44
# loss_bc1: 5.059e+01
# loss_ics_u: 2.464e+01
# loss_res_val: 3.038e+00
# It: 4500, Loss: 6.903e+00,  loss_bc1: 2.460e-01,  loss_bc2: 2.573e-01, loss_ics_u: 2.271e-01, loss_ics_ut: 8.088e-03,  Loss_res: 3.369e-02 , Time: 245.75
# loss_bc1: 5.033e+01
# loss_ics_u: 2.352e+01
# loss_res_val: 3.369e+00
# It: 4600, Loss: 6.128e+00,  loss_bc1: 2.440e-01,  loss_bc2: 2.613e-01, loss_ics_u: 2.037e-01, loss_ics_ut: 9.608e-03,  Loss_res: 3.012e-02 , Time: 251.03
# loss_bc1: 5.053e+01
# loss_ics_u: 2.133e+01
# loss_res_val: 3.012e+00
# It: 4700, Loss: 6.138e+00,  loss_bc1: 2.456e-01,  loss_bc2: 2.600e-01, loss_ics_u: 2.273e-01, loss_ics_ut: 8.518e-03,  Loss_res: 3.204e-02 , Time: 256.40
# loss_bc1: 5.056e+01
# loss_ics_u: 2.358e+01
# loss_res_val: 3.204e+00
# It: 4800, Loss: 6.726e+00,  loss_bc1: 2.418e-01,  loss_bc2: 2.567e-01, loss_ics_u: 2.310e-01, loss_ics_ut: 7.794e-03,  Loss_res: 3.046e-02 , Time: 261.82
# loss_bc1: 4.984e+01
# loss_ics_u: 2.388e+01
# loss_res_val: 3.046e+00
# It: 4900, Loss: 7.876e+00,  loss_bc1: 2.525e-01,  loss_bc2: 2.680e-01, loss_ics_u: 2.748e-01, loss_ics_ut: 7.865e-03,  Loss_res: 2.831e-02 , Time: 267.89
# loss_bc1: 5.205e+01
# loss_ics_u: 2.826e+01
# loss_res_val: 2.831e+00
# It: 5000, Loss: 7.773e+00,  loss_bc1: 2.505e-01,  loss_bc2: 2.628e-01, loss_ics_u: 2.292e-01, loss_ics_ut: 6.463e-03,  Loss_res: 3.020e-02 , Time: 273.49
# loss_bc1: 5.133e+01
# loss_ics_u: 2.357e+01
# loss_res_val: 3.020e+00
# It: 5100, Loss: 6.676e+00,  loss_bc1: 2.510e-01,  loss_bc2: 2.617e-01, loss_ics_u: 2.304e-01, loss_ics_ut: 5.612e-03,  Loss_res: 2.907e-02 , Time: 278.81
# loss_bc1: 5.127e+01
# loss_ics_u: 2.360e+01
# loss_res_val: 2.907e+00
# It: 5200, Loss: 6.857e+00,  loss_bc1: 2.484e-01,  loss_bc2: 2.611e-01, loss_ics_u: 2.375e-01, loss_ics_ut: 6.553e-03,  Loss_res: 2.640e-02 , Time: 284.22
# loss_bc1: 5.095e+01
# loss_ics_u: 2.441e+01
# loss_res_val: 2.640e+00
# It: 5300, Loss: 7.410e+00,  loss_bc1: 2.549e-01,  loss_bc2: 2.623e-01, loss_ics_u: 2.514e-01, loss_ics_ut: 6.806e-03,  Loss_res: 2.805e-02 , Time: 289.80
# loss_bc1: 5.172e+01
# loss_ics_u: 2.582e+01
# loss_res_val: 2.805e+00
# It: 5400, Loss: 8.561e+00,  loss_bc1: 2.443e-01,  loss_bc2: 2.649e-01, loss_ics_u: 2.822e-01, loss_ics_ut: 6.834e-03,  Loss_res: 2.853e-02 , Time: 295.11
# loss_bc1: 5.092e+01
# loss_ics_u: 2.890e+01
# loss_res_val: 2.853e+00
# It: 5500, Loss: 7.904e+00,  loss_bc1: 2.582e-01,  loss_bc2: 2.693e-01, loss_ics_u: 2.297e-01, loss_ics_ut: 4.754e-03,  Loss_res: 2.574e-02 , Time: 300.37
# loss_bc1: 5.275e+01
# loss_ics_u: 2.344e+01
# loss_res_val: 2.574e+00
# It: 5600, Loss: 6.678e+00,  loss_bc1: 2.513e-01,  loss_bc2: 2.640e-01, loss_ics_u: 2.336e-01, loss_ics_ut: 4.123e-03,  Loss_res: 2.900e-02 , Time: 305.94
# loss_bc1: 5.154e+01
# loss_ics_u: 2.377e+01
# loss_res_val: 2.900e+00
# It: 5700, Loss: 6.088e+00,  loss_bc1: 2.591e-01,  loss_bc2: 2.667e-01, loss_ics_u: 2.038e-01, loss_ics_ut: 4.999e-03,  Loss_res: 2.562e-02 , Time: 311.31
# loss_bc1: 5.258e+01
# loss_ics_u: 2.088e+01
# loss_res_val: 2.562e+00
# It: 5800, Loss: 6.570e+00,  loss_bc1: 2.522e-01,  loss_bc2: 2.659e-01, loss_ics_u: 2.575e-01, loss_ics_ut: 4.638e-03,  Loss_res: 2.446e-02 , Time: 316.64
# loss_bc1: 5.181e+01
# loss_ics_u: 2.621e+01
# loss_res_val: 2.446e+00
# It: 5900, Loss: 7.277e+00,  loss_bc1: 2.631e-01,  loss_bc2: 2.617e-01, loss_ics_u: 2.309e-01, loss_ics_ut: 4.279e-03,  Loss_res: 2.635e-02 , Time: 321.95
# loss_bc1: 5.248e+01
# loss_ics_u: 2.352e+01
# loss_res_val: 2.635e+00
# It: 6000, Loss: 6.105e+00,  loss_bc1: 2.534e-01,  loss_bc2: 2.622e-01, loss_ics_u: 2.079e-01, loss_ics_ut: 5.210e-03,  Loss_res: 2.343e-02 , Time: 327.24
# loss_bc1: 5.156e+01
# loss_ics_u: 2.131e+01
# loss_res_val: 2.343e+00
# It: 6100, Loss: 5.926e+00,  loss_bc1: 2.487e-01,  loss_bc2: 2.592e-01, loss_ics_u: 2.249e-01, loss_ics_ut: 2.966e-03,  Loss_res: 2.308e-02 , Time: 332.72
# loss_bc1: 5.079e+01
# loss_ics_u: 2.278e+01
# loss_res_val: 2.308e+00
# It: 6200, Loss: 5.704e+00,  loss_bc1: 2.479e-01,  loss_bc2: 2.621e-01, loss_ics_u: 2.006e-01, loss_ics_ut: 2.871e-03,  Loss_res: 2.041e-02 , Time: 338.01
# loss_bc1: 5.099e+01
# loss_ics_u: 2.035e+01
# loss_res_val: 2.041e+00
# It: 6300, Loss: 6.026e+00,  loss_bc1: 2.500e-01,  loss_bc2: 2.572e-01, loss_ics_u: 2.406e-01, loss_ics_ut: 3.424e-03,  Loss_res: 2.238e-02 , Time: 343.34
# loss_bc1: 5.071e+01
# loss_ics_u: 2.440e+01
# loss_res_val: 2.238e+00
# It: 6400, Loss: 6.899e+00,  loss_bc1: 2.539e-01,  loss_bc2: 2.635e-01, loss_ics_u: 2.353e-01, loss_ics_ut: 3.057e-03,  Loss_res: 2.149e-02 , Time: 348.66
# loss_bc1: 5.174e+01
# loss_ics_u: 2.383e+01
# loss_res_val: 2.149e+00
# It: 6500, Loss: 5.913e+00,  loss_bc1: 2.480e-01,  loss_bc2: 2.672e-01, loss_ics_u: 1.994e-01, loss_ics_ut: 3.348e-03,  Loss_res: 2.367e-02 , Time: 353.92
# loss_bc1: 5.153e+01
# loss_ics_u: 2.027e+01
# loss_res_val: 2.367e+00
# It: 6600, Loss: 6.973e+00,  loss_bc1: 2.461e-01,  loss_bc2: 2.607e-01, loss_ics_u: 2.881e-01, loss_ics_ut: 3.365e-03,  Loss_res: 2.097e-02 , Time: 359.18
# loss_bc1: 5.069e+01
# loss_ics_u: 2.915e+01
# loss_res_val: 2.097e+00
# It: 6700, Loss: 8.645e+00,  loss_bc1: 2.596e-01,  loss_bc2: 2.650e-01, loss_ics_u: 2.552e-01, loss_ics_ut: 3.889e-03,  Loss_res: 2.062e-02 , Time: 364.47
# loss_bc1: 5.246e+01
# loss_ics_u: 2.591e+01
# loss_res_val: 2.062e+00
# It: 6800, Loss: 7.366e+00,  loss_bc1: 2.622e-01,  loss_bc2: 2.720e-01, loss_ics_u: 2.393e-01, loss_ics_ut: 2.142e-03,  Loss_res: 2.052e-02 , Time: 369.75
# loss_bc1: 5.342e+01
# loss_ics_u: 2.414e+01
# loss_res_val: 2.052e+00
# It: 6900, Loss: 6.589e+00,  loss_bc1: 2.588e-01,  loss_bc2: 2.704e-01, loss_ics_u: 2.241e-01, loss_ics_ut: 3.249e-03,  Loss_res: 2.051e-02 , Time: 375.04
# loss_bc1: 5.292e+01
# loss_ics_u: 2.273e+01
# loss_res_val: 2.051e+00
# It: 7000, Loss: 5.657e+00,  loss_bc1: 2.502e-01,  loss_bc2: 2.624e-01, loss_ics_u: 1.995e-01, loss_ics_ut: 2.506e-03,  Loss_res: 1.911e-02 , Time: 380.34
# loss_bc1: 5.126e+01
# loss_ics_u: 2.020e+01
# loss_res_val: 1.911e+00
# It: 7100, Loss: 5.374e+00,  loss_bc1: 2.429e-01,  loss_bc2: 2.534e-01, loss_ics_u: 2.130e-01, loss_ics_ut: 2.225e-03,  Loss_res: 1.710e-02 , Time: 385.60
# loss_bc1: 4.963e+01
# loss_ics_u: 2.152e+01
# loss_res_val: 1.710e+00
# It: 7200, Loss: 6.399e+00,  loss_bc1: 2.536e-01,  loss_bc2: 2.563e-01, loss_ics_u: 2.468e-01, loss_ics_ut: 1.789e-03,  Loss_res: 1.733e-02 , Time: 390.89
# loss_bc1: 5.099e+01
# loss_ics_u: 2.486e+01
# loss_res_val: 1.733e+00
# It: 7300, Loss: 6.516e+00,  loss_bc1: 2.504e-01,  loss_bc2: 2.619e-01, loss_ics_u: 2.174e-01, loss_ics_ut: 2.321e-03,  Loss_res: 1.768e-02 , Time: 396.28
# loss_bc1: 5.123e+01
# loss_ics_u: 2.197e+01
# loss_res_val: 1.768e+00
# It: 7400, Loss: 6.465e+00,  loss_bc1: 2.532e-01,  loss_bc2: 2.596e-01, loss_ics_u: 2.440e-01, loss_ics_ut: 2.242e-03,  Loss_res: 1.725e-02 , Time: 401.61
# loss_bc1: 5.128e+01
# loss_ics_u: 2.462e+01
# loss_res_val: 1.725e+00
# It: 7500, Loss: 7.189e+00,  loss_bc1: 2.531e-01,  loss_bc2: 2.645e-01, loss_ics_u: 2.473e-01, loss_ics_ut: 1.344e-03,  Loss_res: 1.886e-02 , Time: 406.88
# loss_bc1: 5.176e+01
# loss_ics_u: 2.486e+01
# loss_res_val: 1.886e+00
# It: 7600, Loss: 7.108e+00,  loss_bc1: 2.670e-01,  loss_bc2: 2.667e-01, loss_ics_u: 2.392e-01, loss_ics_ut: 2.452e-03,  Loss_res: 1.768e-02 , Time: 412.12
# loss_bc1: 5.337e+01
# loss_ics_u: 2.416e+01
# loss_res_val: 1.768e+00
# It: 7700, Loss: 6.518e+00,  loss_bc1: 2.532e-01,  loss_bc2: 2.591e-01, loss_ics_u: 2.243e-01, loss_ics_ut: 1.910e-03,  Loss_res: 1.520e-02 , Time: 417.43
# loss_bc1: 5.123e+01
# loss_ics_u: 2.262e+01
# loss_res_val: 1.520e+00
# It: 7800, Loss: 6.108e+00,  loss_bc1: 2.558e-01,  loss_bc2: 2.599e-01, loss_ics_u: 2.211e-01, loss_ics_ut: 2.213e-03,  Loss_res: 1.566e-02 , Time: 422.72
# loss_bc1: 5.158e+01
# loss_ics_u: 2.233e+01
# loss_res_val: 1.566e+00
# It: 7900, Loss: 5.822e+00,  loss_bc1: 2.605e-01,  loss_bc2: 2.583e-01, loss_ics_u: 2.111e-01, loss_ics_ut: 2.143e-03,  Loss_res: 1.443e-02 , Time: 428.03
# loss_bc1: 5.189e+01
# loss_ics_u: 2.132e+01
# loss_res_val: 1.443e+00
# It: 8000, Loss: 5.563e+00,  loss_bc1: 2.610e-01,  loss_bc2: 2.539e-01, loss_ics_u: 2.101e-01, loss_ics_ut: 1.608e-03,  Loss_res: 1.389e-02 , Time: 433.66
# loss_bc1: 5.149e+01
# loss_ics_u: 2.117e+01
# loss_res_val: 1.389e+00
# It: 8100, Loss: 5.813e+00,  loss_bc1: 2.483e-01,  loss_bc2: 2.508e-01, loss_ics_u: 2.249e-01, loss_ics_ut: 1.642e-03,  Loss_res: 1.417e-02 , Time: 438.95
# loss_bc1: 4.991e+01
# loss_ics_u: 2.265e+01
# loss_res_val: 1.417e+00
# It: 8200, Loss: 5.298e+00,  loss_bc1: 2.523e-01,  loss_bc2: 2.534e-01, loss_ics_u: 1.863e-01, loss_ics_ut: 1.846e-03,  Loss_res: 1.815e-02 , Time: 444.22
# loss_bc1: 5.057e+01
# loss_ics_u: 1.881e+01
# loss_res_val: 1.815e+00
# It: 8300, Loss: 5.250e+00,  loss_bc1: 2.453e-01,  loss_bc2: 2.486e-01, loss_ics_u: 2.236e-01, loss_ics_ut: 1.296e-03,  Loss_res: 1.732e-02 , Time: 449.58
# loss_bc1: 4.939e+01
# loss_ics_u: 2.249e+01
# loss_res_val: 1.732e+00
# It: 8400, Loss: 5.667e+00,  loss_bc1: 2.483e-01,  loss_bc2: 2.477e-01, loss_ics_u: 2.054e-01, loss_ics_ut: 1.240e-03,  Loss_res: 1.571e-02 , Time: 454.95
# loss_bc1: 4.960e+01
# loss_ics_u: 2.067e+01
# loss_res_val: 1.571e+00
# It: 8500, Loss: 5.128e+00,  loss_bc1: 2.474e-01,  loss_bc2: 2.417e-01, loss_ics_u: 1.981e-01, loss_ics_ut: 1.566e-03,  Loss_res: 1.549e-02 , Time: 460.31
# loss_bc1: 4.891e+01
# loss_ics_u: 1.996e+01
# loss_res_val: 1.549e+00
# It: 8600, Loss: 5.412e+00,  loss_bc1: 2.505e-01,  loss_bc2: 2.458e-01, loss_ics_u: 2.184e-01, loss_ics_ut: 1.734e-03,  Loss_res: 1.561e-02 , Time: 465.59
# loss_bc1: 4.963e+01
# loss_ics_u: 2.201e+01
# loss_res_val: 1.561e+00
# It: 8700, Loss: 6.328e+00,  loss_bc1: 2.551e-01,  loss_bc2: 2.464e-01, loss_ics_u: 2.392e-01, loss_ics_ut: 1.525e-03,  Loss_res: 1.692e-02 , Time: 470.92
# loss_bc1: 5.015e+01
# loss_ics_u: 2.407e+01
# loss_res_val: 1.692e+00
# It: 8800, Loss: 6.044e+00,  loss_bc1: 2.545e-01,  loss_bc2: 2.508e-01, loss_ics_u: 2.061e-01, loss_ics_ut: 1.949e-03,  Loss_res: 1.559e-02 , Time: 476.24
# loss_bc1: 5.052e+01
# loss_ics_u: 2.080e+01
# loss_res_val: 1.559e+00
# It: 8900, Loss: 6.096e+00,  loss_bc1: 2.552e-01,  loss_bc2: 2.500e-01, loss_ics_u: 2.420e-01, loss_ics_ut: 1.557e-03,  Loss_res: 1.257e-02 , Time: 481.57
# loss_bc1: 5.052e+01
# loss_ics_u: 2.436e+01
# loss_res_val: 1.257e+00
# It: 9000, Loss: 6.363e+00,  loss_bc1: 2.536e-01,  loss_bc2: 2.490e-01, loss_ics_u: 2.178e-01, loss_ics_ut: 1.392e-03,  Loss_res: 1.496e-02 , Time: 486.86
# loss_bc1: 5.026e+01
# loss_ics_u: 2.192e+01
# loss_res_val: 1.496e+00
# It: 9100, Loss: 6.283e+00,  loss_bc1: 2.530e-01,  loss_bc2: 2.471e-01, loss_ics_u: 2.387e-01, loss_ics_ut: 1.313e-03,  Loss_res: 1.360e-02 , Time: 492.14
# loss_bc1: 5.001e+01
# loss_ics_u: 2.400e+01
# loss_res_val: 1.360e+00
# It: 9200, Loss: 6.252e+00,  loss_bc1: 2.543e-01,  loss_bc2: 2.514e-01, loss_ics_u: 2.154e-01, loss_ics_ut: 2.075e-03,  Loss_res: 1.609e-02 , Time: 497.45
# loss_bc1: 5.057e+01
# loss_ics_u: 2.174e+01
# loss_res_val: 1.609e+00
# It: 9300, Loss: 5.587e+00,  loss_bc1: 2.580e-01,  loss_bc2: 2.457e-01, loss_ics_u: 2.083e-01, loss_ics_ut: 1.166e-03,  Loss_res: 1.593e-02 , Time: 502.74
# loss_bc1: 5.037e+01
# loss_ics_u: 2.095e+01
# loss_res_val: 1.593e+00
# It: 9400, Loss: 6.481e+00,  loss_bc1: 2.474e-01,  loss_bc2: 2.415e-01, loss_ics_u: 2.602e-01, loss_ics_ut: 1.335e-03,  Loss_res: 1.524e-02 , Time: 507.99
# loss_bc1: 4.889e+01
# loss_ics_u: 2.616e+01
# loss_res_val: 1.524e+00
# It: 9500, Loss: 6.196e+00,  loss_bc1: 2.694e-01,  loss_bc2: 2.472e-01, loss_ics_u: 1.947e-01, loss_ics_ut: 1.515e-03,  Loss_res: 1.942e-02 , Time: 513.33
# loss_bc1: 5.166e+01
# loss_ics_u: 1.963e+01
# loss_res_val: 1.942e+00
# It: 9600, Loss: 5.135e+00,  loss_bc1: 2.469e-01,  loss_bc2: 2.352e-01, loss_ics_u: 2.093e-01, loss_ics_ut: 1.586e-03,  Loss_res: 1.625e-02 , Time: 518.73
# loss_bc1: 4.821e+01
# loss_ics_u: 2.109e+01
# loss_res_val: 1.625e+00
# It: 9700, Loss: 5.440e+00,  loss_bc1: 2.407e-01,  loss_bc2: 2.348e-01, loss_ics_u: 2.105e-01, loss_ics_ut: 1.200e-03,  Loss_res: 1.517e-02 , Time: 524.05
# loss_bc1: 4.755e+01
# loss_ics_u: 2.117e+01
# loss_res_val: 1.517e+00
# It: 9800, Loss: 5.957e+00,  loss_bc1: 2.486e-01,  loss_bc2: 2.326e-01, loss_ics_u: 2.337e-01, loss_ics_ut: 1.104e-03,  Loss_res: 1.609e-02 , Time: 529.37
# loss_bc1: 4.812e+01
# loss_ics_u: 2.348e+01
# loss_res_val: 1.609e+00
# It: 9900, Loss: 5.352e+00,  loss_bc1: 2.386e-01,  loss_bc2: 2.343e-01, loss_ics_u: 1.849e-01, loss_ics_ut: 1.663e-03,  Loss_res: 1.646e-02 , Time: 534.67
# loss_bc1: 4.729e+01
# loss_ics_u: 1.865e+01
# loss_res_val: 1.646e+00
# It: 10000, Loss: 4.805e+00,  loss_bc1: 2.553e-01,  loss_bc2: 2.275e-01, loss_ics_u: 2.028e-01, loss_ics_ut: 1.419e-03,  Loss_res: 1.796e-02 , Time: 539.99
# loss_bc1: 4.828e+01
# loss_ics_u: 2.042e+01
# loss_res_val: 1.796e+00
# It: 10100, Loss: 5.681e+00,  loss_bc1: 2.384e-01,  loss_bc2: 2.253e-01, loss_ics_u: 2.304e-01, loss_ics_ut: 1.046e-03,  Loss_res: 1.534e-02 , Time: 545.33
# loss_bc1: 4.637e+01
# loss_ics_u: 2.314e+01
# loss_res_val: 1.534e+00
# It: 10200, Loss: 6.590e+00,  loss_bc1: 2.538e-01,  loss_bc2: 2.254e-01, loss_ics_u: 2.411e-01, loss_ics_ut: 1.362e-03,  Loss_res: 1.333e-02 , Time: 550.59
# loss_bc1: 4.792e+01
# loss_ics_u: 2.425e+01
# loss_res_val: 1.333e+00
# It: 10300, Loss: 6.938e+00,  loss_bc1: 2.400e-01,  loss_bc2: 2.303e-01, loss_ics_u: 2.452e-01, loss_ics_ut: 1.101e-03,  Loss_res: 1.861e-02 , Time: 555.93
# loss_bc1: 4.704e+01
# loss_ics_u: 2.463e+01
# loss_res_val: 1.861e+00
# It: 10400, Loss: 5.900e+00,  loss_bc1: 2.419e-01,  loss_bc2: 2.275e-01, loss_ics_u: 1.989e-01, loss_ics_ut: 9.590e-04,  Loss_res: 2.033e-02 , Time: 561.21
# loss_bc1: 4.694e+01
# loss_ics_u: 1.999e+01
# loss_res_val: 2.033e+00
# It: 10500, Loss: 4.528e+00,  loss_bc1: 2.428e-01,  loss_bc2: 2.244e-01, loss_ics_u: 1.769e-01, loss_ics_ut: 1.019e-03,  Loss_res: 1.815e-02 , Time: 566.48
# loss_bc1: 4.672e+01
# loss_ics_u: 1.779e+01
# loss_res_val: 1.815e+00
# It: 10600, Loss: 5.384e+00,  loss_bc1: 2.322e-01,  loss_bc2: 2.158e-01, loss_ics_u: 2.490e-01, loss_ics_ut: 1.266e-03,  Loss_res: 1.874e-02 , Time: 571.74
# loss_bc1: 4.481e+01
# loss_ics_u: 2.503e+01
# loss_res_val: 1.874e+00
# It: 10700, Loss: 7.019e+00,  loss_bc1: 2.489e-01,  loss_bc2: 2.175e-01, loss_ics_u: 2.407e-01, loss_ics_ut: 1.277e-03,  Loss_res: 1.528e-02 , Time: 577.05
# loss_bc1: 4.664e+01
# loss_ics_u: 2.420e+01
# loss_res_val: 1.528e+00
# It: 10800, Loss: 6.698e+00,  loss_bc1: 2.355e-01,  loss_bc2: 2.187e-01, loss_ics_u: 2.370e-01, loss_ics_ut: 9.944e-04,  Loss_res: 1.954e-02 , Time: 582.45
# loss_bc1: 4.542e+01
# loss_ics_u: 2.380e+01
# loss_res_val: 1.954e+00
# It: 10900, Loss: 6.215e+00,  loss_bc1: 2.475e-01,  loss_bc2: 2.195e-01, loss_ics_u: 2.191e-01, loss_ics_ut: 1.358e-03,  Loss_res: 1.747e-02 , Time: 587.75
# loss_bc1: 4.669e+01
# loss_ics_u: 2.205e+01
# loss_res_val: 1.747e+00
# It: 11000, Loss: 5.447e+00,  loss_bc1: 2.304e-01,  loss_bc2: 2.176e-01, loss_ics_u: 2.039e-01, loss_ics_ut: 1.009e-03,  Loss_res: 1.954e-02 , Time: 593.02
# loss_bc1: 4.480e+01
# loss_ics_u: 2.049e+01
# loss_res_val: 1.954e+00
# It: 11100, Loss: 5.340e+00,  loss_bc1: 2.344e-01,  loss_bc2: 2.102e-01, loss_ics_u: 2.142e-01, loss_ics_ut: 1.130e-03,  Loss_res: 2.034e-02 , Time: 598.31
# loss_bc1: 4.446e+01
# loss_ics_u: 2.153e+01
# loss_res_val: 2.034e+00
# It: 11200, Loss: 5.712e+00,  loss_bc1: 2.395e-01,  loss_bc2: 2.100e-01, loss_ics_u: 2.210e-01, loss_ics_ut: 9.824e-04,  Loss_res: 1.639e-02 , Time: 603.64
# loss_bc1: 4.495e+01
# loss_ics_u: 2.220e+01
# loss_res_val: 1.639e+00
# It: 11300, Loss: 5.684e+00,  loss_bc1: 2.414e-01,  loss_bc2: 2.071e-01, loss_ics_u: 2.133e-01, loss_ics_ut: 1.007e-03,  Loss_res: 1.812e-02 , Time: 608.93
# loss_bc1: 4.484e+01
# loss_ics_u: 2.143e+01
# loss_res_val: 1.812e+00
# It: 11400, Loss: 5.628e+00,  loss_bc1: 2.344e-01,  loss_bc2: 2.073e-01, loss_ics_u: 2.186e-01, loss_ics_ut: 1.097e-03,  Loss_res: 2.037e-02 , Time: 614.24
# loss_bc1: 4.418e+01
# loss_ics_u: 2.197e+01
# loss_res_val: 2.037e+00
# It: 11500, Loss: 5.896e+00,  loss_bc1: 2.409e-01,  loss_bc2: 2.014e-01, loss_ics_u: 2.253e-01, loss_ics_ut: 1.042e-03,  Loss_res: 1.869e-02 , Time: 619.54
# loss_bc1: 4.423e+01
# loss_ics_u: 2.264e+01
# loss_res_val: 1.869e+00
# It: 11600, Loss: 6.005e+00,  loss_bc1: 2.567e-01,  loss_bc2: 2.008e-01, loss_ics_u: 2.226e-01, loss_ics_ut: 8.585e-04,  Loss_res: 1.681e-02 , Time: 624.80
# loss_bc1: 4.575e+01
# loss_ics_u: 2.234e+01
# loss_res_val: 1.681e+00
# It: 11700, Loss: 5.253e+00,  loss_bc1: 2.239e-01,  loss_bc2: 1.977e-01, loss_ics_u: 1.950e-01, loss_ics_ut: 8.951e-04,  Loss_res: 1.919e-02 , Time: 630.14
# loss_bc1: 4.217e+01
# loss_ics_u: 1.959e+01
# loss_res_val: 1.919e+00
# It: 11800, Loss: 4.748e+00,  loss_bc1: 2.322e-01,  loss_bc2: 1.946e-01, loss_ics_u: 1.962e-01, loss_ics_ut: 8.105e-04,  Loss_res: 1.878e-02 , Time: 635.39
# loss_bc1: 4.268e+01
# loss_ics_u: 1.970e+01
# loss_res_val: 1.878e+00
# It: 11900, Loss: 5.335e+00,  loss_bc1: 2.324e-01,  loss_bc2: 1.881e-01, loss_ics_u: 2.254e-01, loss_ics_ut: 9.040e-04,  Loss_res: 1.923e-02 , Time: 640.69
# loss_bc1: 4.205e+01
# loss_ics_u: 2.263e+01
# loss_res_val: 1.923e+00
# It: 12000, Loss: 5.670e+00,  loss_bc1: 2.451e-01,  loss_bc2: 1.916e-01, loss_ics_u: 2.095e-01, loss_ics_ut: 7.578e-04,  Loss_res: 1.922e-02 , Time: 646.12
# loss_bc1: 4.367e+01
# loss_ics_u: 2.103e+01
# loss_res_val: 1.922e+00
# It: 12100, Loss: 5.051e+00,  loss_bc1: 2.392e-01,  loss_bc2: 1.912e-01, loss_ics_u: 1.967e-01, loss_ics_ut: 7.792e-04,  Loss_res: 1.986e-02 , Time: 651.45
# loss_bc1: 4.304e+01
# loss_ics_u: 1.974e+01
# loss_res_val: 1.986e+00
# It: 12200, Loss: 5.646e+00,  loss_bc1: 2.160e-01,  loss_bc2: 1.840e-01, loss_ics_u: 2.430e-01, loss_ics_ut: 6.562e-04,  Loss_res: 1.753e-02 , Time: 656.72
# loss_bc1: 3.999e+01
# loss_ics_u: 2.437e+01
# loss_res_val: 1.753e+00
# It: 12300, Loss: 5.075e+00,  loss_bc1: 2.458e-01,  loss_bc2: 1.881e-01, loss_ics_u: 1.706e-01, loss_ics_ut: 6.556e-04,  Loss_res: 1.950e-02 , Time: 662.04
# loss_bc1: 4.339e+01
# loss_ics_u: 1.713e+01
# loss_res_val: 1.950e+00
# It: 12400, Loss: 4.921e+00,  loss_bc1: 2.235e-01,  loss_bc2: 1.837e-01, loss_ics_u: 2.365e-01, loss_ics_ut: 6.464e-04,  Loss_res: 2.273e-02 , Time: 667.29
# loss_bc1: 4.072e+01
# loss_ics_u: 2.372e+01
# loss_res_val: 2.273e+00
# It: 12500, Loss: 5.906e+00,  loss_bc1: 2.288e-01,  loss_bc2: 1.822e-01, loss_ics_u: 2.122e-01, loss_ics_ut: 6.141e-04,  Loss_res: 1.650e-02 , Time: 672.60
# loss_bc1: 4.109e+01
# loss_ics_u: 2.128e+01
# loss_res_val: 1.650e+00
# It: 12600, Loss: 4.560e+00,  loss_bc1: 2.310e-01,  loss_bc2: 1.778e-01, loss_ics_u: 1.736e-01, loss_ics_ut: 8.955e-04,  Loss_res: 1.812e-02 , Time: 680.86
# loss_bc1: 4.088e+01
# loss_ics_u: 1.745e+01
# loss_res_val: 1.812e+00
# It: 12700, Loss: 4.672e+00,  loss_bc1: 2.314e-01,  loss_bc2: 1.689e-01, loss_ics_u: 2.197e-01, loss_ics_ut: 4.328e-04,  Loss_res: 1.751e-02 , Time: 689.12
# loss_bc1: 4.003e+01
# loss_ics_u: 2.201e+01
# loss_res_val: 1.751e+00
# It: 12800, Loss: 4.592e+00,  loss_bc1: 2.232e-01,  loss_bc2: 1.703e-01, loss_ics_u: 1.709e-01, loss_ics_ut: 5.801e-04,  Loss_res: 1.717e-02 , Time: 695.45
# loss_bc1: 3.935e+01
# loss_ics_u: 1.715e+01
# loss_res_val: 1.717e+00
# It: 12900, Loss: 4.519e+00,  loss_bc1: 2.028e-01,  loss_bc2: 1.633e-01, loss_ics_u: 2.185e-01, loss_ics_ut: 6.076e-04,  Loss_res: 1.746e-02 , Time: 701.06
# loss_bc1: 3.661e+01
# loss_ics_u: 2.191e+01
# loss_res_val: 1.746e+00
# It: 13000, Loss: 5.273e+00,  loss_bc1: 2.251e-01,  loss_bc2: 1.634e-01, loss_ics_u: 2.034e-01, loss_ics_ut: 3.808e-04,  Loss_res: 1.808e-02 , Time: 706.68
# loss_bc1: 3.885e+01
# loss_ics_u: 2.038e+01
# loss_res_val: 1.808e+00
# It: 13100, Loss: 5.347e+00,  loss_bc1: 2.161e-01,  loss_bc2: 1.585e-01, loss_ics_u: 2.232e-01, loss_ics_ut: 4.667e-04,  Loss_res: 2.187e-02 , Time: 712.48
# loss_bc1: 3.746e+01
# loss_ics_u: 2.236e+01
# loss_res_val: 2.187e+00
# It: 13200, Loss: 5.510e+00,  loss_bc1: 2.081e-01,  loss_bc2: 1.583e-01, loss_ics_u: 2.111e-01, loss_ics_ut: 3.773e-04,  Loss_res: 2.219e-02 , Time: 718.32
# loss_bc1: 3.663e+01
# loss_ics_u: 2.115e+01
# loss_res_val: 2.219e+00
# It: 13300, Loss: 4.554e+00,  loss_bc1: 2.257e-01,  loss_bc2: 1.591e-01, loss_ics_u: 1.765e-01, loss_ics_ut: 4.377e-04,  Loss_res: 1.979e-02 , Time: 723.99
# loss_bc1: 3.847e+01
# loss_ics_u: 1.769e+01
# loss_res_val: 1.979e+00
# It: 13400, Loss: 3.714e+00,  loss_bc1: 2.259e-01,  loss_bc2: 1.492e-01, loss_ics_u: 1.653e-01, loss_ics_ut: 3.350e-04,  Loss_res: 1.666e-02 , Time: 734.93
# loss_bc1: 3.751e+01
# loss_ics_u: 1.657e+01
# loss_res_val: 1.666e+00
# It: 13500, Loss: 5.041e+00,  loss_bc1: 2.136e-01,  loss_bc2: 1.445e-01, loss_ics_u: 2.590e-01, loss_ics_ut: 3.582e-04,  Loss_res: 1.673e-02 , Time: 748.46
# loss_bc1: 3.580e+01
# loss_ics_u: 2.594e+01
# loss_res_val: 1.673e+00
# It: 13600, Loss: 5.711e+00,  loss_bc1: 2.370e-01,  loss_bc2: 1.423e-01, loss_ics_u: 1.891e-01, loss_ics_ut: 3.588e-04,  Loss_res: 2.315e-02 , Time: 756.71
# loss_bc1: 3.793e+01
# loss_ics_u: 1.894e+01
# loss_res_val: 2.315e+00
# It: 13700, Loss: 4.311e+00,  loss_bc1: 2.107e-01,  loss_bc2: 1.373e-01, loss_ics_u: 1.885e-01, loss_ics_ut: 3.752e-04,  Loss_res: 1.642e-02 , Time: 763.40
# loss_bc1: 3.480e+01
# loss_ics_u: 1.888e+01
# loss_res_val: 1.642e+00
# It: 13800, Loss: 4.513e+00,  loss_bc1: 2.122e-01,  loss_bc2: 1.304e-01, loss_ics_u: 2.008e-01, loss_ics_ut: 2.908e-04,  Loss_res: 1.841e-02 , Time: 770.40
# loss_bc1: 3.426e+01
# loss_ics_u: 2.011e+01
# loss_res_val: 1.841e+00
# It: 13900, Loss: 4.144e+00,  loss_bc1: 2.150e-01,  loss_bc2: 1.306e-01, loss_ics_u: 1.695e-01, loss_ics_ut: 2.511e-04,  Loss_res: 2.130e-02 , Time: 776.20
# loss_bc1: 3.456e+01
# loss_ics_u: 1.697e+01
# loss_res_val: 2.130e+00
# It: 14000, Loss: 4.643e+00,  loss_bc1: 2.173e-01,  loss_bc2: 1.279e-01, loss_ics_u: 2.306e-01, loss_ics_ut: 1.597e-04,  Loss_res: 1.665e-02 , Time: 782.45
# loss_bc1: 3.452e+01
# loss_ics_u: 2.308e+01
# loss_res_val: 1.665e+00
# It: 14100, Loss: 5.976e+00,  loss_bc1: 1.816e-01,  loss_bc2: 1.299e-01, loss_ics_u: 2.297e-01, loss_ics_ut: 3.453e-04,  Loss_res: 2.593e-02 , Time: 793.22
# loss_bc1: 3.115e+01
# loss_ics_u: 2.301e+01
# loss_res_val: 2.593e+00
# It: 14200, Loss: 4.535e+00,  loss_bc1: 2.092e-01,  loss_bc2: 1.253e-01, loss_ics_u: 1.649e-01, loss_ics_ut: 2.571e-04,  Loss_res: 2.560e-02 , Time: 798.78
# loss_bc1: 3.345e+01
# loss_ics_u: 1.652e+01
# loss_res_val: 2.560e+00
# It: 14300, Loss: 3.326e+00,  loss_bc1: 2.026e-01,  loss_bc2: 1.160e-01, loss_ics_u: 1.596e-01, loss_ics_ut: 1.488e-04,  Loss_res: 1.954e-02 , Time: 804.32
# loss_bc1: 3.185e+01
# loss_ics_u: 1.598e+01
# loss_res_val: 1.954e+00
# It: 14400, Loss: 3.847e+00,  loss_bc1: 2.158e-01,  loss_bc2: 1.130e-01, loss_ics_u: 1.978e-01, loss_ics_ut: 1.649e-04,  Loss_res: 1.388e-02 , Time: 809.84
# loss_bc1: 3.289e+01
# loss_ics_u: 1.979e+01
# loss_res_val: 1.388e+00
# It: 14500, Loss: 4.213e+00,  loss_bc1: 2.135e-01,  loss_bc2: 1.016e-01, loss_ics_u: 1.793e-01, loss_ics_ut: 1.757e-04,  Loss_res: 2.202e-02 , Time: 815.30
# loss_bc1: 3.151e+01
# loss_ics_u: 1.795e+01
# loss_res_val: 2.202e+00
# It: 14600, Loss: 4.739e+00,  loss_bc1: 2.002e-01,  loss_bc2: 1.089e-01, loss_ics_u: 2.271e-01, loss_ics_ut: 2.101e-04,  Loss_res: 1.903e-02 , Time: 821.08
# loss_bc1: 3.092e+01
# loss_ics_u: 2.273e+01
# loss_res_val: 1.903e+00
# It: 14700, Loss: 4.955e+00,  loss_bc1: 1.979e-01,  loss_bc2: 1.073e-01, loss_ics_u: 1.891e-01, loss_ics_ut: 1.618e-04,  Loss_res: 2.298e-02 , Time: 826.71
# loss_bc1: 3.053e+01
# loss_ics_u: 1.893e+01
# loss_res_val: 2.298e+00
# It: 14800, Loss: 4.243e+00,  loss_bc1: 2.200e-01,  loss_bc2: 1.069e-01, loss_ics_u: 1.875e-01, loss_ics_ut: 1.454e-04,  Loss_res: 1.611e-02 , Time: 832.23
# loss_bc1: 3.269e+01
# loss_ics_u: 1.877e+01
# loss_res_val: 1.611e+00
# It: 14900, Loss: 4.258e+00,  loss_bc1: 2.026e-01,  loss_bc2: 9.618e-02, loss_ics_u: 1.934e-01, loss_ics_ut: 1.774e-04,  Loss_res: 1.757e-02 , Time: 837.90
# loss_bc1: 2.988e+01
# loss_ics_u: 1.936e+01
# loss_res_val: 1.757e+00
# It: 15000, Loss: 4.504e+00,  loss_bc1: 1.871e-01,  loss_bc2: 1.011e-01, loss_ics_u: 2.008e-01, loss_ics_ut: 1.311e-04,  Loss_res: 2.184e-02 , Time: 843.42
# loss_bc1: 2.882e+01
# loss_ics_u: 2.010e+01
# loss_res_val: 2.184e+00
# It: 15100, Loss: 4.600e+00,  loss_bc1: 2.121e-01,  loss_bc2: 1.058e-01, loss_ics_u: 1.946e-01, loss_ics_ut: 1.837e-04,  Loss_res: 2.269e-02 , Time: 849.01
# loss_bc1: 3.178e+01
# loss_ics_u: 1.948e+01
# loss_res_val: 2.269e+00
# It: 15200, Loss: 4.163e+00,  loss_bc1: 1.851e-01,  loss_bc2: 9.219e-02, loss_ics_u: 1.829e-01, loss_ics_ut: 1.524e-04,  Loss_res: 1.889e-02 , Time: 854.57
# loss_bc1: 2.773e+01
# loss_ics_u: 1.830e+01
# loss_res_val: 1.889e+00
# It: 15300, Loss: 3.436e+00,  loss_bc1: 1.951e-01,  loss_bc2: 9.352e-02, loss_ics_u: 1.544e-01, loss_ics_ut: 1.495e-04,  Loss_res: 1.634e-02 , Time: 860.24
# loss_bc1: 2.886e+01
# loss_ics_u: 1.545e+01
# loss_res_val: 1.634e+00
# It: 15400, Loss: 4.114e+00,  loss_bc1: 1.958e-01,  loss_bc2: 8.161e-02, loss_ics_u: 2.285e-01, loss_ics_ut: 1.361e-04,  Loss_res: 1.556e-02 , Time: 865.76
# loss_bc1: 2.774e+01
# loss_ics_u: 2.287e+01
# loss_res_val: 1.556e+00
# It: 15500, Loss: 4.705e+00,  loss_bc1: 2.183e-01,  loss_bc2: 8.701e-02, loss_ics_u: 1.774e-01, loss_ics_ut: 2.257e-04,  Loss_res: 2.076e-02 , Time: 873.08
# loss_bc1: 3.053e+01
# loss_ics_u: 1.776e+01
# loss_res_val: 2.076e+00
# It: 15600, Loss: 3.485e+00,  loss_bc1: 1.999e-01,  loss_bc2: 7.885e-02, loss_ics_u: 1.622e-01, loss_ics_ut: 1.429e-04,  Loss_res: 2.125e-02 , Time: 878.76
# loss_bc1: 2.787e+01
# loss_ics_u: 1.623e+01
# loss_res_val: 2.125e+00
# It: 15700, Loss: 2.895e+00,  loss_bc1: 1.721e-01,  loss_bc2: 7.164e-02, loss_ics_u: 1.461e-01, loss_ics_ut: 1.770e-04,  Loss_res: 1.550e-02 , Time: 884.39
# loss_bc1: 2.437e+01
# loss_ics_u: 1.463e+01
# loss_res_val: 1.550e+00
# It: 15800, Loss: 3.511e+00,  loss_bc1: 1.587e-01,  loss_bc2: 6.787e-02, loss_ics_u: 2.064e-01, loss_ics_ut: 1.677e-04,  Loss_res: 2.307e-02 , Time: 890.08
# loss_bc1: 2.265e+01
# loss_ics_u: 2.066e+01
# loss_res_val: 2.307e+00
# It: 15900, Loss: 4.331e+00,  loss_bc1: 1.969e-01,  loss_bc2: 6.830e-02, loss_ics_u: 1.812e-01, loss_ics_ut: 1.820e-04,  Loss_res: 2.265e-02 , Time: 895.83
# loss_bc1: 2.652e+01
# loss_ics_u: 1.814e+01
# loss_res_val: 2.265e+00
# It: 16000, Loss: 3.295e+00,  loss_bc1: 1.748e-01,  loss_bc2: 6.519e-02, loss_ics_u: 1.529e-01, loss_ics_ut: 1.930e-04,  Loss_res: 1.676e-02 , Time: 901.56
# loss_bc1: 2.400e+01
# loss_ics_u: 1.531e+01
# loss_res_val: 1.676e+00
# It: 16100, Loss: 3.352e+00,  loss_bc1: 1.869e-01,  loss_bc2: 6.784e-02, loss_ics_u: 1.834e-01, loss_ics_ut: 2.027e-04,  Loss_res: 1.877e-02 , Time: 907.22
# loss_bc1: 2.548e+01
# loss_ics_u: 1.836e+01
# loss_res_val: 1.877e+00
# It: 16200, Loss: 3.778e+00,  loss_bc1: 1.671e-01,  loss_bc2: 6.340e-02, loss_ics_u: 1.784e-01, loss_ics_ut: 2.605e-04,  Loss_res: 1.880e-02 , Time: 912.86
# loss_bc1: 2.304e+01
# loss_ics_u: 1.787e+01
# loss_res_val: 1.880e+00
# It: 16300, Loss: 4.337e+00,  loss_bc1: 2.104e-01,  loss_bc2: 6.605e-02, loss_ics_u: 2.094e-01, loss_ics_ut: 2.650e-04,  Loss_res: 1.986e-02 , Time: 918.42
# loss_bc1: 2.764e+01
# loss_ics_u: 2.097e+01
# loss_res_val: 1.986e+00
# It: 16400, Loss: 4.383e+00,  loss_bc1: 2.164e-01,  loss_bc2: 5.648e-02, loss_ics_u: 1.809e-01, loss_ics_ut: 2.611e-04,  Loss_res: 1.903e-02 , Time: 924.02
# loss_bc1: 2.729e+01
# loss_ics_u: 1.812e+01
# loss_res_val: 1.903e+00
# It: 16500, Loss: 3.597e+00,  loss_bc1: 1.918e-01,  loss_bc2: 5.724e-02, loss_ics_u: 1.688e-01, loss_ics_ut: 2.420e-04,  Loss_res: 1.878e-02 , Time: 929.78
# loss_bc1: 2.490e+01
# loss_ics_u: 1.691e+01
# loss_res_val: 1.878e+00
# It: 16600, Loss: 3.349e+00,  loss_bc1: 2.087e-01,  loss_bc2: 5.854e-02, loss_ics_u: 1.642e-01, loss_ics_ut: 2.316e-04,  Loss_res: 1.884e-02 , Time: 935.62
# loss_bc1: 2.673e+01
# loss_ics_u: 1.644e+01
# loss_res_val: 1.884e+00
# It: 16700, Loss: 3.837e+00,  loss_bc1: 1.823e-01,  loss_bc2: 4.593e-02, loss_ics_u: 2.033e-01, loss_ics_ut: 2.167e-04,  Loss_res: 1.862e-02 , Time: 942.57
# loss_bc1: 2.283e+01
# loss_ics_u: 2.035e+01
# loss_res_val: 1.862e+00
# It: 16800, Loss: 3.934e+00,  loss_bc1: 1.867e-01,  loss_bc2: 5.509e-02, loss_ics_u: 1.677e-01, loss_ics_ut: 3.329e-04,  Loss_res: 1.649e-02 , Time: 948.57
# loss_bc1: 2.418e+01
# loss_ics_u: 1.681e+01
# loss_res_val: 1.649e+00
# It: 16900, Loss: 3.398e+00,  loss_bc1: 2.102e-01,  loss_bc2: 4.806e-02, loss_ics_u: 1.694e-01, loss_ics_ut: 2.716e-04,  Loss_res: 1.819e-02 , Time: 954.57
# loss_bc1: 2.583e+01
# loss_ics_u: 1.697e+01
# loss_res_val: 1.819e+00
# It: 17000, Loss: 3.647e+00,  loss_bc1: 1.688e-01,  loss_bc2: 3.964e-02, loss_ics_u: 1.884e-01, loss_ics_ut: 2.752e-04,  Loss_res: 1.518e-02 , Time: 960.32
# loss_bc1: 2.084e+01
# loss_ics_u: 1.887e+01
# loss_res_val: 1.518e+00
# It: 17100, Loss: 4.079e+00,  loss_bc1: 1.832e-01,  loss_bc2: 4.875e-02, loss_ics_u: 1.896e-01, loss_ics_ut: 3.778e-04,  Loss_res: 1.947e-02 , Time: 967.19
# loss_bc1: 2.320e+01
# loss_ics_u: 1.900e+01
# loss_res_val: 1.947e+00
# It: 17200, Loss: 3.646e+00,  loss_bc1: 1.229e-01,  loss_bc2: 4.382e-02, loss_ics_u: 1.720e-01, loss_ics_ut: 4.454e-04,  Loss_res: 1.853e-02 , Time: 972.81
# loss_bc1: 1.667e+01
# loss_ics_u: 1.724e+01
# loss_res_val: 1.853e+00
# It: 17300, Loss: 3.584e+00,  loss_bc1: 1.826e-01,  loss_bc2: 4.390e-02, loss_ics_u: 1.789e-01, loss_ics_ut: 3.277e-04,  Loss_res: 2.233e-02 , Time: 978.91
# loss_bc1: 2.265e+01
# loss_ics_u: 1.792e+01
# loss_res_val: 2.233e+00
# It: 17400, Loss: 3.660e+00,  loss_bc1: 1.822e-01,  loss_bc2: 4.024e-02, loss_ics_u: 1.774e-01, loss_ics_ut: 4.305e-04,  Loss_res: 1.313e-02 , Time: 984.42
# loss_bc1: 2.224e+01
# loss_ics_u: 1.778e+01
# loss_res_val: 1.313e+00
# It: 17500, Loss: 3.734e+00,  loss_bc1: 1.864e-01,  loss_bc2: 4.393e-02, loss_ics_u: 1.824e-01, loss_ics_ut: 4.345e-04,  Loss_res: 1.643e-02 , Time: 990.03
# loss_bc1: 2.303e+01
# loss_ics_u: 1.829e+01
# loss_res_val: 1.643e+00
# It: 17600, Loss: 4.098e+00,  loss_bc1: 1.811e-01,  loss_bc2: 4.508e-02, loss_ics_u: 1.973e-01, loss_ics_ut: 3.819e-04,  Loss_res: 1.818e-02 , Time: 995.64
# loss_bc1: 2.262e+01
# loss_ics_u: 1.977e+01
# loss_res_val: 1.818e+00
# It: 17700, Loss: 4.165e+00,  loss_bc1: 1.821e-01,  loss_bc2: 4.147e-02, loss_ics_u: 1.859e-01, loss_ics_ut: 4.759e-04,  Loss_res: 1.814e-02 , Time: 1001.41
# loss_bc1: 2.236e+01
# loss_ics_u: 1.864e+01
# loss_res_val: 1.814e+00
# It: 17800, Loss: 3.799e+00,  loss_bc1: 1.751e-01,  loss_bc2: 3.731e-02, loss_ics_u: 1.785e-01, loss_ics_ut: 5.082e-04,  Loss_res: 2.073e-02 , Time: 1007.05
# loss_bc1: 2.124e+01
# loss_ics_u: 1.790e+01
# loss_res_val: 2.073e+00
# It: 17900, Loss: 3.625e+00,  loss_bc1: 1.910e-01,  loss_bc2: 4.009e-02, loss_ics_u: 1.740e-01, loss_ics_ut: 4.980e-04,  Loss_res: 1.895e-02 , Time: 1012.69
# loss_bc1: 2.311e+01
# loss_ics_u: 1.745e+01
# loss_res_val: 1.895e+00
# It: 18000, Loss: 4.009e+00,  loss_bc1: 1.854e-01,  loss_bc2: 3.847e-02, loss_ics_u: 2.018e-01, loss_ics_ut: 5.027e-04,  Loss_res: 1.705e-02 , Time: 1018.47
# loss_bc1: 2.239e+01
# loss_ics_u: 2.023e+01
# loss_res_val: 1.705e+00
# It: 18100, Loss: 4.198e+00,  loss_bc1: 1.741e-01,  loss_bc2: 3.813e-02, loss_ics_u: 1.842e-01, loss_ics_ut: 5.589e-04,  Loss_res: 2.187e-02 , Time: 1024.30
# loss_bc1: 2.123e+01
# loss_ics_u: 1.847e+01
# loss_res_val: 2.187e+00
# It: 18200, Loss: 3.530e+00,  loss_bc1: 1.747e-01,  loss_bc2: 4.130e-02, loss_ics_u: 1.650e-01, loss_ics_ut: 4.419e-04,  Loss_res: 1.898e-02 , Time: 1030.06
# loss_bc1: 2.160e+01
# loss_ics_u: 1.655e+01
# loss_res_val: 1.898e+00
# It: 18300, Loss: 3.497e+00,  loss_bc1: 1.960e-01,  loss_bc2: 3.276e-02, loss_ics_u: 1.819e-01, loss_ics_ut: 5.411e-04,  Loss_res: 1.066e-02 , Time: 1035.77
# loss_bc1: 2.288e+01
# loss_ics_u: 1.824e+01
# loss_res_val: 1.066e+00
# It: 18400, Loss: 3.594e+00,  loss_bc1: 1.483e-01,  loss_bc2: 3.917e-02, loss_ics_u: 1.744e-01, loss_ics_ut: 4.896e-04,  Loss_res: 2.593e-02 , Time: 1041.61
# loss_bc1: 1.874e+01
# loss_ics_u: 1.749e+01
# loss_res_val: 2.593e+00
# It: 18500, Loss: 3.303e+00,  loss_bc1: 1.755e-01,  loss_bc2: 3.249e-02, loss_ics_u: 1.625e-01, loss_ics_ut: 5.954e-04,  Loss_res: 1.323e-02 , Time: 1047.34
# loss_bc1: 2.080e+01
# loss_ics_u: 1.631e+01
# loss_res_val: 1.323e+00
# It: 18600, Loss: 3.031e+00,  loss_bc1: 1.674e-01,  loss_bc2: 3.588e-02, loss_ics_u: 1.590e-01, loss_ics_ut: 4.278e-04,  Loss_res: 1.878e-02 , Time: 1053.04
# loss_bc1: 2.033e+01
# loss_ics_u: 1.594e+01
# loss_res_val: 1.878e+00
# It: 18700, Loss: 3.051e+00,  loss_bc1: 1.808e-01,  loss_bc2: 3.626e-02, loss_ics_u: 1.616e-01, loss_ics_ut: 6.089e-04,  Loss_res: 1.711e-02 , Time: 1058.73
# loss_bc1: 2.170e+01
# loss_ics_u: 1.622e+01
# loss_res_val: 1.711e+00
# It: 18800, Loss: 3.509e+00,  loss_bc1: 1.949e-01,  loss_bc2: 3.685e-02, loss_ics_u: 1.855e-01, loss_ics_ut: 7.330e-04,  Loss_res: 1.472e-02 , Time: 1064.48
# loss_bc1: 2.317e+01
# loss_ics_u: 1.863e+01
# loss_res_val: 1.472e+00
# It: 18900, Loss: 3.712e+00,  loss_bc1: 1.869e-01,  loss_bc2: 2.543e-02, loss_ics_u: 1.746e-01, loss_ics_ut: 6.461e-04,  Loss_res: 1.529e-02 , Time: 1070.04
# loss_bc1: 2.123e+01
# loss_ics_u: 1.753e+01
# loss_res_val: 1.529e+00
# It: 19000, Loss: 3.243e+00,  loss_bc1: 1.411e-01,  loss_bc2: 3.592e-02, loss_ics_u: 1.627e-01, loss_ics_ut: 5.529e-04,  Loss_res: 1.795e-02 , Time: 1075.61
# loss_bc1: 1.770e+01
# loss_ics_u: 1.632e+01
# loss_res_val: 1.795e+00
# It: 19100, Loss: 3.795e+00,  loss_bc1: 1.678e-01,  loss_bc2: 3.922e-02, loss_ics_u: 2.045e-01, loss_ics_ut: 7.149e-04,  Loss_res: 1.714e-02 , Time: 1081.25
# loss_bc1: 2.071e+01
# loss_ics_u: 2.052e+01
# loss_res_val: 1.714e+00
# It: 19200, Loss: 4.010e+00,  loss_bc1: 1.847e-01,  loss_bc2: 3.265e-02, loss_ics_u: 1.725e-01, loss_ics_ut: 5.634e-04,  Loss_res: 1.348e-02 , Time: 1086.89
# loss_bc1: 2.173e+01
# loss_ics_u: 1.731e+01
# loss_res_val: 1.348e+00
# It: 19300, Loss: 2.558e+00,  loss_bc1: 1.895e-01,  loss_bc2: 2.758e-02, loss_ics_u: 1.208e-01, loss_ics_ut: 5.655e-04,  Loss_res: 1.710e-02 , Time: 1092.47
# loss_bc1: 2.171e+01
# loss_ics_u: 1.214e+01
# loss_res_val: 1.710e+00
# It: 19400, Loss: 2.830e+00,  loss_bc1: 1.802e-01,  loss_bc2: 3.558e-02, loss_ics_u: 1.950e-01, loss_ics_ut: 7.085e-04,  Loss_res: 1.366e-02 , Time: 1098.06
# loss_bc1: 2.157e+01
# loss_ics_u: 1.957e+01
# loss_res_val: 1.366e+00
# It: 19500, Loss: 3.139e+00,  loss_bc1: 1.700e-01,  loss_bc2: 2.972e-02, loss_ics_u: 1.385e-01, loss_ics_ut: 6.319e-04,  Loss_res: 1.272e-02 , Time: 1103.61
# loss_bc1: 1.997e+01
# loss_ics_u: 1.391e+01
# loss_res_val: 1.272e+00
# It: 19600, Loss: 2.476e+00,  loss_bc1: 1.382e-01,  loss_bc2: 3.103e-02, loss_ics_u: 1.515e-01, loss_ics_ut: 7.633e-04,  Loss_res: 1.486e-02 , Time: 1109.21
# loss_bc1: 1.692e+01
# loss_ics_u: 1.523e+01
# loss_res_val: 1.486e+00
# It: 19700, Loss: 3.763e+00,  loss_bc1: 1.842e-01,  loss_bc2: 2.911e-02, loss_ics_u: 2.168e-01, loss_ics_ut: 6.361e-04,  Loss_res: 1.630e-02 , Time: 1114.70
# loss_bc1: 2.133e+01
# loss_ics_u: 2.175e+01
# loss_res_val: 1.630e+00
# It: 19800, Loss: 4.121e+00,  loss_bc1: 1.521e-01,  loss_bc2: 2.571e-02, loss_ics_u: 1.710e-01, loss_ics_ut: 8.031e-04,  Loss_res: 1.836e-02 , Time: 1120.31
# loss_bc1: 1.778e+01
# loss_ics_u: 1.718e+01
# loss_res_val: 1.836e+00
# It: 19900, Loss: 3.448e+00,  loss_bc1: 2.109e-01,  loss_bc2: 3.269e-02, loss_ics_u: 1.705e-01, loss_ics_ut: 4.939e-04,  Loss_res: 1.299e-02 , Time: 1125.93
# loss_bc1: 2.436e+01
# loss_ics_u: 1.710e+01
# loss_res_val: 1.299e+00
# It: 20000, Loss: 3.212e+00,  loss_bc1: 1.689e-01,  loss_bc2: 2.747e-02, loss_ics_u: 1.627e-01, loss_ics_ut: 1.062e-03,  Loss_res: 1.504e-02 , Time: 1131.47
# loss_bc1: 1.964e+01
# loss_ics_u: 1.637e+01
# loss_res_val: 1.504e+00
# It: 20100, Loss: 3.094e+00,  loss_bc1: 1.828e-01,  loss_bc2: 2.683e-02, loss_ics_u: 1.614e-01, loss_ics_ut: 5.979e-04,  Loss_res: 1.541e-02 , Time: 1137.11
# loss_bc1: 2.096e+01
# loss_ics_u: 1.620e+01
# loss_res_val: 1.541e+00
# It: 20200, Loss: 3.004e+00,  loss_bc1: 1.295e-01,  loss_bc2: 2.569e-02, loss_ics_u: 1.639e-01, loss_ics_ut: 8.639e-04,  Loss_res: 1.638e-02 , Time: 1142.84
# loss_bc1: 1.552e+01
# loss_ics_u: 1.647e+01
# loss_res_val: 1.638e+00
# It: 20300, Loss: 2.852e+00,  loss_bc1: 1.639e-01,  loss_bc2: 2.805e-02, loss_ics_u: 1.475e-01, loss_ics_ut: 6.804e-04,  Loss_res: 1.637e-02 , Time: 1148.54
# loss_bc1: 1.919e+01
# loss_ics_u: 1.482e+01
# loss_res_val: 1.637e+00
# It: 20400, Loss: 3.015e+00,  loss_bc1: 1.524e-01,  loss_bc2: 2.781e-02, loss_ics_u: 1.768e-01, loss_ics_ut: 7.476e-04,  Loss_res: 1.369e-02 , Time: 1154.79
# loss_bc1: 1.802e+01
# loss_ics_u: 1.776e+01
# loss_res_val: 1.369e+00
# It: 20500, Loss: 3.432e+00,  loss_bc1: 1.635e-01,  loss_bc2: 2.787e-02, loss_ics_u: 1.703e-01, loss_ics_ut: 5.509e-04,  Loss_res: 1.070e-02 , Time: 1160.91
# loss_bc1: 1.913e+01
# loss_ics_u: 1.709e+01
# loss_res_val: 1.070e+00
# It: 20600, Loss: 2.969e+00,  loss_bc1: 1.056e-01,  loss_bc2: 3.048e-02, loss_ics_u: 1.559e-01, loss_ics_ut: 7.428e-04,  Loss_res: 1.826e-02 , Time: 1167.75
# loss_bc1: 1.361e+01
# loss_ics_u: 1.567e+01
# loss_res_val: 1.826e+00
# ...
# loss_ics_u: 1.058e+01
# loss_res_val: 6.469e-01
# It: 32900, Loss: 1.224e+00,  loss_bc1: 1.451e-02,  loss_bc2: 9.672e-03, loss_ics_u: 1.102e-01, loss_ics_ut: 4.833e-04,  Loss_res: 6.835e-03 , Time: 1889.50
# loss_bc1: 2.418e+00
# loss_ics_u: 1.107e+01
# loss_res_val: 6.835e-01
# It: 33000, Loss: 1.171e+00,  loss_bc1: 2.403e-02,  loss_bc2: 8.266e-03, loss_ics_u: 9.899e-02, loss_ics_ut: 3.810e-04,  Loss_res: 9.893e-03 , Time: 1895.12
# loss_bc1: 3.230e+00
# loss_ics_u: 9.937e+00
# loss_res_val: 9.893e-01
# It: 33100, Loss: 1.095e+00,  loss_bc1: 2.624e-02,  loss_bc2: 6.299e-03, loss_ics_u: 1.024e-01, loss_ics_ut: 2.016e-04,  Loss_res: 1.041e-02 , Time: 1900.86
# loss_bc1: 3.254e+00
# loss_ics_u: 1.026e+01
# loss_res_val: 1.041e+00
# It: 33200, Loss: 1.015e+00,  loss_bc1: 1.696e-02,  loss_bc2: 9.180e-03, loss_ics_u: 9.283e-02, loss_ics_ut: 2.560e-04,  Loss_res: 7.317e-03 , Time: 1908.55
# loss_bc1: 2.614e+00
# loss_ics_u: 9.308e+00
# loss_res_val: 7.317e-01
# It: 33300, Loss: 9.322e-01,  loss_bc1: 1.997e-02,  loss_bc2: 7.930e-03, loss_ics_u: 9.318e-02, loss_ics_ut: 4.561e-04,  Loss_res: 6.543e-03 , Time: 1914.35
# loss_bc1: 2.790e+00
# loss_ics_u: 9.364e+00
# loss_res_val: 6.543e-01
# It: 33400, Loss: 1.020e+00,  loss_bc1: 1.651e-02,  loss_bc2: 6.701e-03, loss_ics_u: 1.028e-01, loss_ics_ut: 1.704e-04,  Loss_res: 1.493e-02 , Time: 1920.01
# loss_bc1: 2.321e+00
# loss_ics_u: 1.030e+01
# loss_res_val: 1.493e+00
# It: 33500, Loss: 1.008e+00,  loss_bc1: 1.917e-02,  loss_bc2: 5.943e-03, loss_ics_u: 9.123e-02, loss_ics_ut: 6.586e-04,  Loss_res: 8.039e-03 , Time: 1925.62
# loss_bc1: 2.511e+00
# loss_ics_u: 9.189e+00
# loss_res_val: 8.039e-01
# It: 33600, Loss: 8.862e-01,  loss_bc1: 2.361e-02,  loss_bc2: 8.203e-03, loss_ics_u: 8.845e-02, loss_ics_ut: 3.627e-04,  Loss_res: 8.015e-03 , Time: 1931.35
# loss_bc1: 3.181e+00
# loss_ics_u: 8.881e+00
# loss_res_val: 8.015e-01
# It: 33700, Loss: 1.077e+00,  loss_bc1: 1.897e-02,  loss_bc2: 6.965e-03, loss_ics_u: 1.147e-01, loss_ics_ut: 1.841e-04,  Loss_res: 6.355e-03 , Time: 1936.93
# loss_bc1: 2.593e+00
# loss_ics_u: 1.149e+01
# loss_res_val: 6.355e-01
# It: 33800, Loss: 1.329e+00,  loss_bc1: 1.374e-02,  loss_bc2: 8.550e-03, loss_ics_u: 1.105e-01, loss_ics_ut: 3.484e-04,  Loss_res: 1.778e-02 , Time: 1942.58
# loss_bc1: 2.229e+00
# loss_ics_u: 1.108e+01
# loss_res_val: 1.778e+00
# It: 33900, Loss: 1.197e+00,  loss_bc1: 2.032e-02,  loss_bc2: 6.579e-03, loss_ics_u: 1.017e-01, loss_ics_ut: 1.150e-04,  Loss_res: 8.048e-03 , Time: 1948.10
# loss_bc1: 2.690e+00
# loss_ics_u: 1.018e+01
# loss_res_val: 8.048e-01
# It: 34000, Loss: 1.040e+00,  loss_bc1: 1.915e-02,  loss_bc2: 8.914e-03, loss_ics_u: 9.570e-02, loss_ics_ut: 1.987e-04,  Loss_res: 9.257e-03 , Time: 1953.64
# loss_bc1: 2.806e+00
# loss_ics_u: 9.590e+00
# loss_res_val: 9.257e-01
# It: 34100, Loss: 1.072e+00,  loss_bc1: 1.472e-02,  loss_bc2: 5.043e-03, loss_ics_u: 1.070e-01, loss_ics_ut: 2.312e-04,  Loss_res: 4.564e-03 , Time: 1959.26
# loss_bc1: 1.976e+00
# loss_ics_u: 1.072e+01
# loss_res_val: 4.564e-01
# It: 34200, Loss: 1.071e+00,  loss_bc1: 1.667e-02,  loss_bc2: 7.415e-03, loss_ics_u: 9.485e-02, loss_ics_ut: 2.815e-04,  Loss_res: 7.736e-03 , Time: 1964.80
# loss_bc1: 2.408e+00
# loss_ics_u: 9.513e+00
# loss_res_val: 7.736e-01
# It: 34300, Loss: 9.571e-01,  loss_bc1: 1.579e-02,  loss_bc2: 1.003e-02, loss_ics_u: 9.432e-02, loss_ics_ut: 3.117e-04,  Loss_res: 6.748e-03 , Time: 1970.75
# loss_bc1: 2.582e+00
# loss_ics_u: 9.463e+00
# loss_res_val: 6.748e-01
# It: 34400, Loss: 1.006e+00,  loss_bc1: 1.889e-02,  loss_bc2: 9.270e-03, loss_ics_u: 9.930e-02, loss_ics_ut: 1.594e-04,  Loss_res: 1.269e-02 , Time: 1976.37
# loss_bc1: 2.816e+00
# loss_ics_u: 9.946e+00
# loss_res_val: 1.269e+00
# It: 34500, Loss: 8.833e-01,  loss_bc1: 2.195e-02,  loss_bc2: 1.020e-02, loss_ics_u: 8.112e-02, loss_ics_ut: 4.332e-04,  Loss_res: 6.172e-03 , Time: 1982.02
# loss_bc1: 3.215e+00
# loss_ics_u: 8.155e+00
# loss_res_val: 6.172e-01
# It: 34600, Loss: 7.919e-01,  loss_bc1: 1.651e-02,  loss_bc2: 9.797e-03, loss_ics_u: 8.994e-02, loss_ics_ut: 2.745e-04,  Loss_res: 5.668e-03 , Time: 1987.67
# loss_bc1: 2.631e+00
# loss_ics_u: 9.022e+00
# loss_res_val: 5.668e-01
# It: 34700, Loss: 9.079e-01,  loss_bc1: 1.716e-02,  loss_bc2: 1.066e-02, loss_ics_u: 9.346e-02, loss_ics_ut: 2.963e-04,  Loss_res: 1.142e-02 , Time: 1993.61
# loss_bc1: 2.782e+00
# loss_ics_u: 9.375e+00
# loss_res_val: 1.142e+00
# It: 34800, Loss: 9.815e-01,  loss_bc1: 1.425e-02,  loss_bc2: 8.688e-03, loss_ics_u: 9.812e-02, loss_ics_ut: 7.541e-04,  Loss_res: 7.609e-03 , Time: 1999.50
# loss_bc1: 2.293e+00
# loss_ics_u: 9.887e+00
# loss_res_val: 7.609e-01
# It: 34900, Loss: 8.991e-01,  loss_bc1: 1.720e-02,  loss_bc2: 8.235e-03, loss_ics_u: 8.497e-02, loss_ics_ut: 2.347e-04,  Loss_res: 7.603e-03 , Time: 2005.56
# loss_bc1: 2.543e+00
# loss_ics_u: 8.521e+00
# loss_res_val: 7.603e-01
# It: 35000, Loss: 9.137e-01,  loss_bc1: 1.409e-02,  loss_bc2: 6.811e-03, loss_ics_u: 1.011e-01, loss_ics_ut: 2.152e-04,  Loss_res: 1.149e-02 , Time: 2011.05
# loss_bc1: 2.090e+00
# loss_ics_u: 1.013e+01
# loss_res_val: 1.149e+00
# It: 35100, Loss: 1.149e+00,  loss_bc1: 1.623e-02,  loss_bc2: 8.139e-03, loss_ics_u: 1.065e-01, loss_ics_ut: 6.687e-04,  Loss_res: 1.327e-02 , Time: 2016.47
# loss_bc1: 2.437e+00
# loss_ics_u: 1.071e+01
# loss_res_val: 1.327e+00
# It: 35200, Loss: 9.692e-01,  loss_bc1: 1.724e-02,  loss_bc2: 9.607e-03, loss_ics_u: 8.361e-02, loss_ics_ut: 5.592e-04,  Loss_res: 1.030e-02 , Time: 2021.72
# loss_bc1: 2.685e+00
# loss_ics_u: 8.417e+00
# loss_res_val: 1.030e+00
# It: 35300, Loss: 8.728e-01,  loss_bc1: 1.789e-02,  loss_bc2: 7.578e-03, loss_ics_u: 9.658e-02, loss_ics_ut: 2.519e-04,  Loss_res: 6.688e-03 , Time: 2027.02
# loss_bc1: 2.546e+00
# loss_ics_u: 9.683e+00
# loss_res_val: 6.688e-01
# It: 35400, Loss: 9.216e-01,  loss_bc1: 1.486e-02,  loss_bc2: 1.062e-02, loss_ics_u: 8.905e-02, loss_ics_ut: 2.784e-04,  Loss_res: 8.441e-03 , Time: 2032.48
# loss_bc1: 2.548e+00
# loss_ics_u: 8.933e+00
# loss_res_val: 8.441e-01
# It: 35500, Loss: 9.142e-01,  loss_bc1: 1.985e-02,  loss_bc2: 1.021e-02, loss_ics_u: 9.415e-02, loss_ics_ut: 2.685e-04,  Loss_res: 1.257e-02 , Time: 2037.78
# loss_bc1: 3.006e+00
# loss_ics_u: 9.442e+00
# loss_res_val: 1.257e+00
# It: 35600, Loss: 9.286e-01,  loss_bc1: 1.829e-02,  loss_bc2: 8.951e-03, loss_ics_u: 9.137e-02, loss_ics_ut: 1.796e-04,  Loss_res: 7.760e-03 , Time: 2043.05
# loss_bc1: 2.724e+00
# loss_ics_u: 9.155e+00
# loss_res_val: 7.760e-01
# It: 35700, Loss: 9.911e-01,  loss_bc1: 1.142e-02,  loss_bc2: 7.933e-03, loss_ics_u: 1.025e-01, loss_ics_ut: 3.676e-04,  Loss_res: 1.409e-02 , Time: 2048.42
# loss_bc1: 1.935e+00
# loss_ics_u: 1.028e+01
# loss_res_val: 1.409e+00
# It: 35800, Loss: 1.196e+00,  loss_bc1: 1.290e-02,  loss_bc2: 1.275e-02, loss_ics_u: 1.100e-01, loss_ics_ut: 4.287e-04,  Loss_res: 6.490e-03 , Time: 2053.70
# loss_bc1: 2.565e+00
# loss_ics_u: 1.104e+01
# loss_res_val: 6.490e-01
# It: 35900, Loss: 1.264e+00,  loss_bc1: 1.252e-02,  loss_bc2: 1.693e-02, loss_ics_u: 1.080e-01, loss_ics_ut: 4.268e-04,  Loss_res: 1.256e-02 , Time: 2058.98
# loss_bc1: 2.945e+00
# loss_ics_u: 1.084e+01
# loss_res_val: 1.256e+00
# It: 36000, Loss: 1.190e+00,  loss_bc1: 1.446e-02,  loss_bc2: 1.038e-02, loss_ics_u: 1.033e-01, loss_ics_ut: 8.596e-04,  Loss_res: 9.244e-03 , Time: 2064.33
# loss_bc1: 2.484e+00
# loss_ics_u: 1.041e+01
# loss_res_val: 9.244e-01
# It: 36100, Loss: 1.115e+00,  loss_bc1: 1.246e-02,  loss_bc2: 1.192e-02, loss_ics_u: 1.017e-01, loss_ics_ut: 3.191e-04,  Loss_res: 4.686e-03 , Time: 2069.61
# loss_bc1: 2.437e+00
# loss_ics_u: 1.020e+01
# loss_res_val: 4.686e-01
# It: 36200, Loss: 1.079e+00,  loss_bc1: 1.747e-02,  loss_bc2: 2.053e-02, loss_ics_u: 9.707e-02, loss_ics_ut: 2.631e-04,  Loss_res: 2.081e-02 , Time: 2074.92
# loss_bc1: 3.799e+00
# loss_ics_u: 9.734e+00
# loss_res_val: 2.081e+00
# It: 36300, Loss: 9.401e-01,  loss_bc1: 2.642e-02,  loss_bc2: 1.209e-02, loss_ics_u: 8.670e-02, loss_ics_ut: 6.305e-04,  Loss_res: 6.271e-03 , Time: 2080.22
# loss_bc1: 3.850e+00
# loss_ics_u: 8.733e+00
# loss_res_val: 6.271e-01
# It: 36400, Loss: 9.892e-01,  loss_bc1: 1.431e-02,  loss_bc2: 1.278e-02, loss_ics_u: 1.061e-01, loss_ics_ut: 4.528e-04,  Loss_res: 6.593e-03 , Time: 2085.55
# loss_bc1: 2.710e+00
# loss_ics_u: 1.066e+01
# loss_res_val: 6.593e-01
# It: 36500, Loss: 1.197e+00,  loss_bc1: 1.324e-02,  loss_bc2: 1.306e-02, loss_ics_u: 1.067e-01, loss_ics_ut: 2.765e-04,  Loss_res: 5.915e-03 , Time: 2090.86
# loss_bc1: 2.630e+00
# loss_ics_u: 1.070e+01
# loss_res_val: 5.915e-01
# It: 36600, Loss: 1.171e+00,  loss_bc1: 1.767e-02,  loss_bc2: 9.212e-03, loss_ics_u: 1.037e-01, loss_ics_ut: 1.562e-04,  Loss_res: 1.095e-02 , Time: 2096.23
# loss_bc1: 2.688e+00
# loss_ics_u: 1.039e+01
# loss_res_val: 1.095e+00
# It: 36700, Loss: 9.902e-01,  loss_bc1: 1.481e-02,  loss_bc2: 1.483e-02, loss_ics_u: 8.852e-02, loss_ics_ut: 4.781e-04,  Loss_res: 5.737e-03 , Time: 2101.55
# loss_bc1: 2.964e+00
# loss_ics_u: 8.900e+00
# loss_res_val: 5.737e-01
# It: 36800, Loss: 9.752e-01,  loss_bc1: 1.350e-02,  loss_bc2: 1.102e-02, loss_ics_u: 1.031e-01, loss_ics_ut: 2.604e-04,  Loss_res: 1.056e-02 , Time: 2106.83
# loss_bc1: 2.452e+00
# loss_ics_u: 1.034e+01
# loss_res_val: 1.056e+00
# It: 36900, Loss: 9.757e-01,  loss_bc1: 2.410e-02,  loss_bc2: 1.552e-02, loss_ics_u: 8.594e-02, loss_ics_ut: 2.194e-04,  Loss_res: 5.393e-03 , Time: 2112.15
# loss_bc1: 3.962e+00
# loss_ics_u: 8.616e+00
# loss_res_val: 5.393e-01
# It: 37000, Loss: 9.915e-01,  loss_bc1: 1.750e-02,  loss_bc2: 1.235e-02, loss_ics_u: 1.075e-01, loss_ics_ut: 1.265e-04,  Loss_res: 8.312e-03 , Time: 2117.45
# loss_bc1: 2.985e+00
# loss_ics_u: 1.076e+01
# loss_res_val: 8.312e-01
# It: 37100, Loss: 1.047e+00,  loss_bc1: 1.541e-02,  loss_bc2: 1.584e-02, loss_ics_u: 9.050e-02, loss_ics_ut: 3.817e-04,  Loss_res: 7.494e-03 , Time: 2122.75
# loss_bc1: 3.125e+00
# loss_ics_u: 9.088e+00
# loss_res_val: 7.494e-01
# It: 37200, Loss: 9.739e-01,  loss_bc1: 1.376e-02,  loss_bc2: 1.353e-02, loss_ics_u: 9.999e-02, loss_ics_ut: 2.774e-04,  Loss_res: 1.075e-02 , Time: 2128.09
# loss_bc1: 2.729e+00
# loss_ics_u: 1.003e+01
# loss_res_val: 1.075e+00
# It: 37300, Loss: 1.002e+00,  loss_bc1: 1.838e-02,  loss_bc2: 1.388e-02, loss_ics_u: 9.251e-02, loss_ics_ut: 3.540e-04,  Loss_res: 6.302e-03 , Time: 2133.41
# loss_bc1: 3.226e+00
# loss_ics_u: 9.287e+00
# loss_res_val: 6.302e-01
# It: 37400, Loss: 8.636e-01,  loss_bc1: 1.642e-02,  loss_bc2: 1.203e-02, loss_ics_u: 8.609e-02, loss_ics_ut: 2.905e-04,  Loss_res: 7.164e-03 , Time: 2138.70
# loss_bc1: 2.845e+00
# loss_ics_u: 8.638e+00
# loss_res_val: 7.164e-01
# It: 37500, Loss: 9.762e-01,  loss_bc1: 1.327e-02,  loss_bc2: 1.152e-02, loss_ics_u: 1.063e-01, loss_ics_ut: 2.666e-04,  Loss_res: 8.276e-03 , Time: 2143.97
# loss_bc1: 2.479e+00
# loss_ics_u: 1.066e+01
# loss_res_val: 8.276e-01
# It: 37600, Loss: 9.296e-01,  loss_bc1: 2.074e-02,  loss_bc2: 1.269e-02, loss_ics_u: 7.980e-02, loss_ics_ut: 3.250e-04,  Loss_res: 1.050e-02 , Time: 2149.29
# loss_bc1: 3.342e+00
# loss_ics_u: 8.013e+00
# loss_res_val: 1.050e+00
# It: 37700, Loss: 8.113e-01,  loss_bc1: 9.859e-03,  loss_bc2: 1.314e-02, loss_ics_u: 9.447e-02, loss_ics_ut: 3.158e-04,  Loss_res: 5.529e-03 , Time: 2154.57
# loss_bc1: 2.300e+00
# loss_ics_u: 9.478e+00
# loss_res_val: 5.529e-01
# It: 37800, Loss: 8.772e-01,  loss_bc1: 1.490e-02,  loss_bc2: 1.139e-02, loss_ics_u: 8.517e-02, loss_ics_ut: 1.107e-03,  Loss_res: 1.236e-02 , Time: 2159.95
# loss_bc1: 2.629e+00
# loss_ics_u: 8.628e+00
# loss_res_val: 1.236e+00
# It: 37900, Loss: 9.234e-01,  loss_bc1: 1.393e-02,  loss_bc2: 1.378e-02, loss_ics_u: 9.918e-02, loss_ics_ut: 6.098e-04,  Loss_res: 5.631e-03 , Time: 2165.26
# loss_bc1: 2.771e+00
# loss_ics_u: 9.979e+00
# loss_res_val: 5.631e-01
# It: 38000, Loss: 1.068e+00,  loss_bc1: 2.332e-02,  loss_bc2: 1.165e-02, loss_ics_u: 9.918e-02, loss_ics_ut: 2.954e-04,  Loss_res: 9.373e-03 , Time: 2170.57
# loss_bc1: 3.497e+00
# loss_ics_u: 9.948e+00
# loss_res_val: 9.373e-01
# It: 38100, Loss: 1.039e+00,  loss_bc1: 1.822e-02,  loss_bc2: 1.125e-02, loss_ics_u: 9.752e-02, loss_ics_ut: 2.082e-04,  Loss_res: 8.563e-03 , Time: 2175.90
# loss_bc1: 2.947e+00
# loss_ics_u: 9.773e+00
# loss_res_val: 8.563e-01
# It: 38200, Loss: 9.933e-01,  loss_bc1: 2.541e-02,  loss_bc2: 1.455e-02, loss_ics_u: 9.221e-02, loss_ics_ut: 4.533e-04,  Loss_res: 9.129e-03 , Time: 2181.23
# loss_bc1: 3.996e+00
# loss_ics_u: 9.266e+00
# loss_res_val: 9.129e-01
# It: 38300, Loss: 9.667e-01,  loss_bc1: 1.518e-02,  loss_bc2: 1.351e-02, loss_ics_u: 9.705e-02, loss_ics_ut: 1.656e-04,  Loss_res: 9.261e-03 , Time: 2186.54
# loss_bc1: 2.869e+00
# loss_ics_u: 9.722e+00
# loss_res_val: 9.261e-01
# It: 38400, Loss: 1.122e+00,  loss_bc1: 1.669e-02,  loss_bc2: 1.596e-02, loss_ics_u: 1.074e-01, loss_ics_ut: 2.601e-04,  Loss_res: 1.055e-02 , Time: 2191.85
# loss_bc1: 3.265e+00
# loss_ics_u: 1.077e+01
# loss_res_val: 1.055e+00
# It: 38500, Loss: 1.099e+00,  loss_bc1: 1.209e-02,  loss_bc2: 1.336e-02, loss_ics_u: 9.653e-02, loss_ics_ut: 3.289e-04,  Loss_res: 4.675e-03 , Time: 2197.14
# loss_bc1: 2.545e+00
# loss_ics_u: 9.686e+00
# loss_res_val: 4.675e-01
# It: 38600, Loss: 9.421e-01,  loss_bc1: 1.296e-02,  loss_bc2: 9.013e-03, loss_ics_u: 9.198e-02, loss_ics_ut: 3.540e-04,  Loss_res: 8.171e-03 , Time: 2202.45
# loss_bc1: 2.197e+00
# loss_ics_u: 9.234e+00
# loss_res_val: 8.171e-01
# It: 38700, Loss: 8.678e-01,  loss_bc1: 1.464e-02,  loss_bc2: 1.382e-02, loss_ics_u: 8.676e-02, loss_ics_ut: 2.999e-04,  Loss_res: 8.604e-03 , Time: 2207.76
# loss_bc1: 2.846e+00
# loss_ics_u: 8.706e+00
# loss_res_val: 8.604e-01
# It: 38800, Loss: 8.574e-01,  loss_bc1: 1.529e-02,  loss_bc2: 1.577e-02, loss_ics_u: 9.045e-02, loss_ics_ut: 3.033e-04,  Loss_res: 6.062e-03 , Time: 2213.15
# loss_bc1: 3.106e+00
# loss_ics_u: 9.075e+00
# loss_res_val: 6.062e-01
# It: 38900, Loss: 7.635e-01,  loss_bc1: 1.385e-02,  loss_bc2: 1.323e-02, loss_ics_u: 7.764e-02, loss_ics_ut: 2.066e-04,  Loss_res: 4.701e-03 , Time: 2218.75
# loss_bc1: 2.708e+00
# loss_ics_u: 7.784e+00
# loss_res_val: 4.701e-01
# It: 39000, Loss: 7.939e-01,  loss_bc1: 1.014e-02,  loss_bc2: 1.146e-02, loss_ics_u: 9.581e-02, loss_ics_ut: 2.441e-04,  Loss_res: 6.348e-03 , Time: 2224.16
# loss_bc1: 2.160e+00
# loss_ics_u: 9.606e+00
# loss_res_val: 6.348e-01
# It: 39100, Loss: 9.338e-01,  loss_bc1: 1.594e-02,  loss_bc2: 1.450e-02, loss_ics_u: 9.007e-02, loss_ics_ut: 2.778e-04,  Loss_res: 8.064e-03 , Time: 2229.46
# loss_bc1: 3.044e+00
# loss_ics_u: 9.035e+00
# loss_res_val: 8.064e-01
# It: 39200, Loss: 8.542e-01,  loss_bc1: 1.517e-02,  loss_bc2: 1.278e-02, loss_ics_u: 8.747e-02, loss_ics_ut: 3.635e-04,  Loss_res: 5.884e-03 , Time: 2234.84
# loss_bc1: 2.796e+00
# loss_ics_u: 8.784e+00
# loss_res_val: 5.884e-01
# It: 39300, Loss: 8.394e-01,  loss_bc1: 1.016e-02,  loss_bc2: 1.323e-02, loss_ics_u: 8.889e-02, loss_ics_ut: 5.023e-04,  Loss_res: 1.257e-02 , Time: 2240.18
# loss_bc1: 2.339e+00
# loss_ics_u: 8.939e+00
# loss_res_val: 1.257e+00
# It: 39400, Loss: 8.408e-01,  loss_bc1: 1.775e-02,  loss_bc2: 9.560e-03, loss_ics_u: 8.693e-02, loss_ics_ut: 2.415e-04,  Loss_res: 5.515e-03 , Time: 2245.47
# loss_bc1: 2.731e+00
# loss_ics_u: 8.717e+00
# loss_res_val: 5.515e-01
# It: 39500, Loss: 8.284e-01,  loss_bc1: 1.702e-02,  loss_bc2: 1.448e-02, loss_ics_u: 8.654e-02, loss_ics_ut: 3.007e-04,  Loss_res: 1.522e-02 , Time: 2250.76
# loss_bc1: 3.150e+00
# loss_ics_u: 8.684e+00
# loss_res_val: 1.522e+00
# It: 39600, Loss: 9.255e-01,  loss_bc1: 1.398e-02,  loss_bc2: 1.527e-02, loss_ics_u: 9.810e-02, loss_ics_ut: 6.686e-04,  Loss_res: 6.052e-03 , Time: 2256.16
# loss_bc1: 2.925e+00
# loss_ics_u: 9.877e+00
# loss_res_val: 6.052e-01
# It: 39700, Loss: 9.381e-01,  loss_bc1: 1.344e-02,  loss_bc2: 2.260e-02, loss_ics_u: 8.686e-02, loss_ics_ut: 2.253e-04,  Loss_res: 9.541e-03 , Time: 2261.51
# loss_bc1: 3.604e+00
# loss_ics_u: 8.709e+00
# loss_res_val: 9.541e-01
# It: 39800, Loss: 1.002e+00,  loss_bc1: 1.239e-02,  loss_bc2: 1.320e-02, loss_ics_u: 1.083e-01, loss_ics_ut: 2.651e-04,  Loss_res: 5.974e-03 , Time: 2266.80
# loss_bc1: 2.559e+00
# loss_ics_u: 1.085e+01
# loss_res_val: 5.974e-01
# It: 39900, Loss: 9.716e-01,  loss_bc1: 1.318e-02,  loss_bc2: 1.826e-02, loss_ics_u: 8.284e-02, loss_ics_ut: 2.784e-04,  Loss_res: 1.077e-02 , Time: 2272.19
# loss_bc1: 3.144e+00
# loss_ics_u: 8.312e+00
# loss_res_val: 1.077e+00
# elapsed: 2.28e+03
# Relative L2 error_u: 4.93e-01
# Relative L2 error_r: 1.59e+01
#
#
# Method:  mini_batch
#
# average of time_list: 2278.1474964618683
# average of error_u_list: 0.49294808478093666

# %%
# Predictions
u_pred = model.predict_u(X_star)
r_pred = model.predict_r(X_star)
# Predictions

error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)
error_r= np.linalg.norm(r_star - r_pred, 2)# / np.linalg.norm(r_star, 2)

# print('elapsed: {:.2e}'.format(elapsed))

print('Relative L2 error_u: {:.2e}'.format(error_u))
print('Relative L2 error_r: {:.2e}'.format(error_r))

r_pred = r_pred.reshape(200, 200)

U_star = griddata(X_star, u_star.flatten(), (t, x), method='cubic')
r_star = griddata(X_star, r_star.flatten(), (t, x), method='cubic')
U_pred = griddata(X_star, u_pred.flatten(), (t, x), method='cubic')
# R_pred = griddata(X_star, r_pred.flatten(), (t, x), method='cubic')


plt.figure(figsize=(18, 9))
plt.subplot(2, 3, 1)
plt.pcolor(t, x, U_star, cmap='jet')
plt.colorbar()
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.title('Exact u(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 2)
plt.pcolor(t, x, U_pred, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Predicted u(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 3)
plt.pcolor(t, x, np.abs(U_star - U_pred), cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Absolute error')
plt.tight_layout()

plt.subplot(2, 3, 4)
plt.pcolor(t, x, r_star, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Exact r(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 5)
plt.pcolor(t, x, r_pred.reshape(200, 200), cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Predicted r(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 6)
plt.pcolor(t, x, np.abs(r_star - r_pred.reshape(200, 200)), cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Absolute error')
plt.tight_layout()
plt.show()
# Out:
# Relative L2 error_u: 4.93e-01
# Relative L2 error_r: 1.59e+01

# %%
# Define PINN model
a = 0.5
c = 2

kernel_size = 300

# Domain boundaries
ics_coords = np.array([[0.0, 0.0],  [0.0, 1.0]])
bc1_coords = np.array([[0.0, 0.0],  [1.0, 0.0]])
bc2_coords = np.array([[0.0, 1.0],  [1.0, 1.0]])
dom_coords = np.array([[0.0, 0.0],  [1.0, 1.0]])

# Create initial conditions samplers
ics_sampler = Sampler(2, ics_coords, lambda x: u(x, a, c), name='Initial Condition 1')

# Create boundary conditions samplers
bc1 = Sampler(2, bc1_coords, lambda x: u(x, a, c), name='Dirichlet BC1')
bc2 = Sampler(2, bc2_coords, lambda x: u(x, a, c), name='Dirichlet BC2')
bcs_sampler = [bc1, bc2]

# Create residual sampler
res_sampler = Sampler(2, dom_coords, lambda x: r(x, a, c), name='Forcing')



nIter =40000
bcbatch_size = 500
ubatch_size = 5000
mbbatch_size = 300



# Define model
mode = 'M4'
layers = [2, 500, 500, 500, 1]


nn = 200
t = np.linspace(dom_coords[0, 0], dom_coords[1, 0], nn)[:, None]
x = np.linspace(dom_coords[0, 1], dom_coords[1, 1], nn)[:, None]
t, x = np.meshgrid(t, x)
X_star = np.hstack((t.flatten()[:, None], x.flatten()[:, None]))

u_star = u(X_star, a,c)
r_star = r(X_star, a, c)

iterations = 1
methods = [  "mini_batch"]

result_dict =  dict((mtd, []) for mtd in methods)

for mtd in methods:
    print("Method: ", mtd)
    time_list = []
    error_u_list = []
    
    for index in range(iterations):

        print("Epoch: ", str(index+1))

        # Create residual sampler

        [elapsed, error_u] = test_method(mtd , layers,  ics_sampler, bcs_sampler, res_sampler, c ,kernel_size , X_star , u_star , r_star , nIter ,mbbatch_size , bcbatch_size , ubatch_size )


        print('elapsed: {:.2e}'.format(elapsed))
        print('Relative L2 error_u: {:.2e}'.format(error_u))

        time_list.append(elapsed)
        error_u_list.append(error_u)

    print("\n\nMethod: ", mtd)
    print("\naverage of time_list:" , sum(time_list) / len(time_list) )
    print("average of error_u_list:" , sum(error_u_list) / len(error_u_list) )
    # print("average of error_r_list:" , sum(error_r_list) / len(error_r_list) )

    result_dict[mtd] = [time_list ,error_u_list]
    # scipy.io.savemat("M2_result_"+str(iterations)+"_"+mtd+".mat" , {'time_list':np.array(time_list),'error_u_list':np.array(error_u_list),'error_f_list':np.array(error_f_list)})

    scipy.io.savemat("./1DWave_database/"+mtd+"_1Dwave_"+mode+"_result_mb"+str(mbbatch_size)+"_fb"+str(ubatch_size)+"_bc"+str(mbbatch_size)+"_"+str(iterations)+".mat" , result_dict)

###############################################################################################################################################
# Out:
# Method:  mini_batch
# Epoch:  1
# mini_batch method is used
# It: 100, Loss: 9.238e-01,  loss_bc1: 6.848e-02, loss_ics_u: 3.931e-01,  Loss_res: 6.576e-04 , Time: 4.89
# It: 200, Loss: 6.458e-01,  loss_bc1: 7.923e-02, loss_ics_u: 2.403e-01,  Loss_res: 6.826e-03 , Time: 3.53
# It: 300, Loss: 6.600e-01,  loss_bc1: 8.652e-02, loss_ics_u: 2.341e-01,  Loss_res: 1.875e-02 , Time: 3.44
# It: 400, Loss: 5.494e-01,  loss_bc1: 6.093e-02, loss_ics_u: 2.009e-01,  Loss_res: 2.586e-02 , Time: 3.43
# It: 500, Loss: 5.235e-01,  loss_bc1: 4.314e-02, loss_ics_u: 2.099e-01,  Loss_res: 1.742e-02 , Time: 3.35
# It: 600, Loss: 4.532e-01,  loss_bc1: 4.553e-02, loss_ics_u: 1.763e-01,  Loss_res: 9.461e-03 , Time: 3.27
# It: 700, Loss: 4.660e-01,  loss_bc1: 4.488e-02, loss_ics_u: 1.662e-01,  Loss_res: 4.375e-02 , Time: 3.38
# It: 800, Loss: 4.010e-01,  loss_bc1: 5.502e-02, loss_ics_u: 1.294e-01,  Loss_res: 3.213e-02 , Time: 3.22
# It: 900, Loss: 3.889e-01,  loss_bc1: 4.886e-02, loss_ics_u: 1.423e-01,  Loss_res: 6.523e-03 , Time: 3.26
# It: 1000, Loss: 4.760e-01,  loss_bc1: 3.239e-02, loss_ics_u: 1.614e-01,  Loss_res: 8.841e-02 , Time: 3.23
# loss_bc1: 3.239e+00
# loss_ics_u: 1.614e+01
# It: 1100, Loss: 4.028e+00,  loss_bc1: 2.087e-01, loss_ics_u: 2.050e-01,  Loss_res: 4.341e-02 , Time: 3.24
# It: 1200, Loss: 4.036e+00,  loss_bc1: 2.012e-01, loss_ics_u: 2.079e-01,  Loss_res: 2.821e-02 , Time: 3.24
# It: 1300, Loss: 3.089e+00,  loss_bc1: 1.975e-01, loss_ics_u: 1.486e-01,  Loss_res: 5.050e-02 , Time: 3.29
# It: 1400, Loss: 3.631e+00,  loss_bc1: 9.093e-02, loss_ics_u: 2.015e-01,  Loss_res: 8.446e-02 , Time: 3.25
# It: 1500, Loss: 3.205e+00,  loss_bc1: 1.203e-01, loss_ics_u: 1.708e-01,  Loss_res: 5.864e-02 , Time: 3.28
# It: 1600, Loss: 2.442e+00,  loss_bc1: 6.459e-02, loss_ics_u: 1.321e-01,  Loss_res: 1.004e-01 , Time: 3.25
# It: 1700, Loss: 1.988e+00,  loss_bc1: 5.784e-02, loss_ics_u: 1.060e-01,  Loss_res: 9.038e-02 , Time: 3.28
# It: 1800, Loss: 2.086e+00,  loss_bc1: 6.114e-02, loss_ics_u: 1.096e-01,  Loss_res: 1.187e-01 , Time: 3.30
# It: 1900, Loss: 1.798e+00,  loss_bc1: 5.601e-02, loss_ics_u: 9.710e-02,  Loss_res: 4.957e-02 , Time: 3.27
# It: 2000, Loss: 2.066e+00,  loss_bc1: 5.252e-02, loss_ics_u: 1.144e-01,  Loss_res: 4.957e-02 , Time: 3.29
# loss_bc1: 5.252e+00
# loss_ics_u: 1.144e+01
# It: 2100, Loss: 1.550e+00,  loss_bc1: 4.679e-02, loss_ics_u: 1.096e-01,  Loss_res: 5.031e-02 , Time: 3.31
# It: 2200, Loss: 1.371e+00,  loss_bc1: 4.520e-02, loss_ics_u: 9.635e-02,  Loss_res: 3.133e-02 , Time: 3.24
# It: 2300, Loss: 1.521e+00,  loss_bc1: 4.606e-02, loss_ics_u: 1.102e-01,  Loss_res: 1.778e-02 , Time: 3.20
# It: 2400, Loss: 1.439e+00,  loss_bc1: 4.217e-02, loss_ics_u: 1.018e-01,  Loss_res: 5.311e-02 , Time: 3.22
# It: 2500, Loss: 1.371e+00,  loss_bc1: 4.292e-02, loss_ics_u: 9.668e-02,  Loss_res: 3.920e-02 , Time: 3.22
# It: 2600, Loss: 1.398e+00,  loss_bc1: 4.434e-02, loss_ics_u: 1.003e-01,  Loss_res: 1.732e-02 , Time: 3.33
# It: 2700, Loss: 1.422e+00,  loss_bc1: 5.076e-02, loss_ics_u: 9.485e-02,  Loss_res: 6.997e-02 , Time: 3.22
# It: 2800, Loss: 1.420e+00,  loss_bc1: 4.226e-02, loss_ics_u: 1.026e-01,  Loss_res: 2.447e-02 , Time: 3.22
# It: 2900, Loss: 1.382e+00,  loss_bc1: 4.252e-02, loss_ics_u: 9.909e-02,  Loss_res: 2.485e-02 , Time: 3.21
# It: 3000, Loss: 1.566e+00,  loss_bc1: 3.510e-02, loss_ics_u: 1.161e-01,  Loss_res: 5.379e-02 , Time: 3.23
# loss_bc1: 3.510e+00
# loss_ics_u: 1.161e+01
# It: 3100, Loss: 1.250e+00,  loss_bc1: 4.534e-02, loss_ics_u: 9.202e-02,  Loss_res: 2.217e-02 , Time: 3.25
# It: 3200, Loss: 1.463e+00,  loss_bc1: 4.408e-02, loss_ics_u: 1.112e-01,  Loss_res: 1.781e-02 , Time: 3.22
# It: 3300, Loss: 1.234e+00,  loss_bc1: 4.673e-02, loss_ics_u: 9.008e-02,  Loss_res: 2.384e-02 , Time: 3.23
# It: 3400, Loss: 1.296e+00,  loss_bc1: 4.818e-02, loss_ics_u: 9.465e-02,  Loss_res: 2.827e-02 , Time: 3.19
# It: 3500, Loss: 1.202e+00,  loss_bc1: 4.031e-02, loss_ics_u: 8.907e-02,  Loss_res: 2.603e-02 , Time: 3.22
# It: 3600, Loss: 1.318e+00,  loss_bc1: 3.901e-02, loss_ics_u: 9.679e-02,  Loss_res: 5.757e-02 , Time: 3.22
# It: 3700, Loss: 1.339e+00,  loss_bc1: 4.521e-02, loss_ics_u: 9.347e-02,  Loss_res: 9.490e-02 , Time: 3.23
# It: 3800, Loss: 1.117e+00,  loss_bc1: 3.642e-02, loss_ics_u: 8.242e-02,  Loss_res: 3.266e-02 , Time: 3.23
# It: 3900, Loss: 1.193e+00,  loss_bc1: 3.797e-02, loss_ics_u: 8.865e-02,  Loss_res: 3.007e-02 , Time: 3.21
# It: 4000, Loss: 1.234e+00,  loss_bc1: 4.410e-02, loss_ics_u: 8.808e-02,  Loss_res: 5.626e-02 , Time: 3.26
# loss_bc1: 4.410e+00
# loss_ics_u: 8.808e+00
# It: 4100, Loss: 9.802e-01,  loss_bc1: 4.087e-02, loss_ics_u: 8.796e-02,  Loss_res: 2.525e-02 , Time: 3.23
# It: 4200, Loss: 7.871e-01,  loss_bc1: 3.142e-02, loss_ics_u: 7.091e-02,  Loss_res: 2.396e-02 , Time: 3.22
# It: 4300, Loss: 9.718e-01,  loss_bc1: 3.682e-02, loss_ics_u: 8.874e-02,  Loss_res: 2.785e-02 , Time: 3.20
# It: 4400, Loss: 9.642e-01,  loss_bc1: 3.058e-02, loss_ics_u: 9.060e-02,  Loss_res: 3.125e-02 , Time: 3.26
# It: 4500, Loss: 8.799e-01,  loss_bc1: 2.439e-02, loss_ics_u: 8.445e-02,  Loss_res: 2.850e-02 , Time: 3.32
# It: 4600, Loss: 9.538e-01,  loss_bc1: 2.985e-02, loss_ics_u: 9.104e-02,  Loss_res: 2.028e-02 , Time: 3.49
# It: 4700, Loss: 9.735e-01,  loss_bc1: 2.568e-02, loss_ics_u: 8.460e-02,  Loss_res: 1.151e-01 , Time: 3.21
# It: 4800, Loss: 1.139e+00,  loss_bc1: 3.047e-02, loss_ics_u: 8.349e-02,  Loss_res: 2.688e-01 , Time: 3.23
# It: 4900, Loss: 8.897e-01,  loss_bc1: 2.511e-02, loss_ics_u: 8.457e-02,  Loss_res: 3.410e-02 , Time: 3.27
# It: 5000, Loss: 8.940e-01,  loss_bc1: 2.638e-02, loss_ics_u: 8.533e-02,  Loss_res: 2.602e-02 , Time: 3.57
# loss_bc1: 2.638e+00
# loss_ics_u: 8.533e+00
# It: 5100, Loss: 7.650e-01,  loss_bc1: 2.841e-02, loss_ics_u: 7.593e-02,  Loss_res: 4.203e-02 , Time: 3.42
# It: 5200, Loss: 7.556e-01,  loss_bc1: 2.848e-02, loss_ics_u: 7.732e-02,  Loss_res: 2.066e-02 , Time: 3.46
# It: 5300, Loss: 8.372e-01,  loss_bc1: 2.470e-02, loss_ics_u: 8.721e-02,  Loss_res: 2.776e-02 , Time: 3.27
# It: 5400, Loss: 8.250e-01,  loss_bc1: 3.508e-02, loss_ics_u: 7.640e-02,  Loss_res: 8.048e-02 , Time: 3.37
# It: 5500, Loss: 7.433e-01,  loss_bc1: 3.176e-02, loss_ics_u: 7.389e-02,  Loss_res: 2.904e-02 , Time: 3.84
# It: 5600, Loss: 8.500e-01,  loss_bc1: 2.148e-02, loss_ics_u: 8.489e-02,  Loss_res: 6.889e-02 , Time: 3.76
# It: 5700, Loss: 8.856e-01,  loss_bc1: 2.965e-02, loss_ics_u: 8.233e-02,  Loss_res: 1.047e-01 , Time: 3.84
# It: 5800, Loss: 7.934e-01,  loss_bc1: 3.199e-02, loss_ics_u: 8.170e-02,  Loss_res: 1.185e-02 , Time: 4.21
# It: 5900, Loss: 6.295e-01,  loss_bc1: 2.616e-02, loss_ics_u: 6.469e-02,  Loss_res: 8.447e-03 , Time: 3.81
# It: 6000, Loss: 7.770e-01,  loss_bc1: 2.826e-02, loss_ics_u: 7.285e-02,  Loss_res: 8.075e-02 , Time: 3.30
# loss_bc1: 2.826e+00
# loss_ics_u: 7.285e+00
# It: 6100, Loss: 7.395e-01,  loss_bc1: 2.725e-02, loss_ics_u: 8.498e-02,  Loss_res: 4.339e-02 , Time: 3.26
# It: 6200, Loss: 6.320e-01,  loss_bc1: 2.240e-02, loss_ics_u: 7.337e-02,  Loss_res: 3.422e-02 , Time: 3.26
# It: 6300, Loss: 7.214e-01,  loss_bc1: 2.809e-02, loss_ics_u: 7.978e-02,  Loss_res: 6.084e-02 , Time: 3.37
# It: 6400, Loss: 6.903e-01,  loss_bc1: 2.062e-02, loss_ics_u: 8.453e-02,  Loss_res: 1.630e-02 , Time: 3.31
# It: 6500, Loss: 5.729e-01,  loss_bc1: 2.227e-02, loss_ics_u: 6.528e-02,  Loss_res: 3.439e-02 , Time: 3.25
# It: 6600, Loss: 6.427e-01,  loss_bc1: 2.084e-02, loss_ics_u: 7.847e-02,  Loss_res: 1.215e-02 , Time: 3.28
# It: 6700, Loss: 6.382e-01,  loss_bc1: 2.782e-02, loss_ics_u: 6.780e-02,  Loss_res: 6.566e-02 , Time: 3.34
# It: 6800, Loss: 7.090e-01,  loss_bc1: 3.071e-02, loss_ics_u: 8.264e-02,  Loss_res: 2.019e-02 , Time: 3.31
# It: 6900, Loss: 6.630e-01,  loss_bc1: 3.743e-02, loss_ics_u: 7.378e-02,  Loss_res: 1.977e-02 , Time: 3.27
# It: 7000, Loss: 5.993e-01,  loss_bc1: 2.533e-02, loss_ics_u: 7.067e-02,  Loss_res: 1.288e-02 , Time: 3.26
# loss_bc1: 2.533e+00
# loss_ics_u: 7.067e+00
# It: 7100, Loss: 5.544e-01,  loss_bc1: 1.875e-02, loss_ics_u: 7.023e-02,  Loss_res: 1.061e-02 , Time: 3.27
# It: 7200, Loss: 5.860e-01,  loss_bc1: 2.289e-02, loss_ics_u: 7.186e-02,  Loss_res: 2.016e-02 , Time: 3.29
# It: 7300, Loss: 5.804e-01,  loss_bc1: 2.950e-02, loss_ics_u: 6.364e-02,  Loss_res: 5.588e-02 , Time: 3.28
# It: 7400, Loss: 5.462e-01,  loss_bc1: 2.331e-02, loss_ics_u: 6.764e-02,  Loss_res: 9.172e-03 , Time: 3.27
# It: 7500, Loss: 8.304e-01,  loss_bc1: 3.285e-02, loss_ics_u: 7.115e-02,  Loss_res: 2.443e-01 , Time: 3.27
# It: 7600, Loss: 6.820e-01,  loss_bc1: 2.153e-02, loss_ics_u: 7.428e-02,  Loss_res: 1.026e-01 , Time: 3.29
# It: 7700, Loss: 7.606e-01,  loss_bc1: 4.626e-02, loss_ics_u: 7.817e-02,  Loss_res: 9.092e-02 , Time: 3.27
# It: 7800, Loss: 5.466e-01,  loss_bc1: 2.056e-02, loss_ics_u: 6.840e-02,  Loss_res: 1.107e-02 , Time: 3.27
# It: 7900, Loss: 5.074e-01,  loss_bc1: 2.721e-02, loss_ics_u: 6.056e-02,  Loss_res: 1.047e-02 , Time: 3.27
# It: 8000, Loss: 5.273e-01,  loss_bc1: 2.016e-02, loss_ics_u: 6.464e-02,  Loss_res: 1.944e-02 , Time: 3.29
# loss_bc1: 2.016e+00
# loss_ics_u: 6.464e+00
# It: 8100, Loss: 5.165e-01,  loss_bc1: 2.897e-02, loss_ics_u: 6.732e-02,  Loss_res: 2.294e-02 , Time: 3.25
# It: 8200, Loss: 5.093e-01,  loss_bc1: 2.612e-02, loss_ics_u: 6.808e-02,  Loss_res: 1.660e-02 , Time: 3.39
# It: 8300, Loss: 4.938e-01,  loss_bc1: 2.461e-02, loss_ics_u: 6.506e-02,  Loss_res: 2.366e-02 , Time: 3.26
# It: 8400, Loss: 4.566e-01,  loss_bc1: 2.211e-02, loss_ics_u: 6.029e-02,  Loss_res: 2.233e-02 , Time: 3.28
# It: 8500, Loss: 5.714e-01,  loss_bc1: 2.626e-02, loss_ics_u: 7.673e-02,  Loss_res: 2.248e-02 , Time: 3.28
# It: 8600, Loss: 5.056e-01,  loss_bc1: 1.853e-02, loss_ics_u: 7.116e-02,  Loss_res: 8.203e-03 , Time: 3.30
# It: 8700, Loss: 4.594e-01,  loss_bc1: 2.381e-02, loss_ics_u: 6.117e-02,  Loss_res: 1.599e-02 , Time: 3.26
# It: 8800, Loss: 5.830e-01,  loss_bc1: 3.105e-02, loss_ics_u: 6.247e-02,  Loss_res: 1.166e-01 , Time: 3.31
# It: 8900, Loss: 4.775e-01,  loss_bc1: 2.004e-02, loss_ics_u: 6.605e-02,  Loss_res: 1.014e-02 , Time: 3.55

# %%
# Define PINN model
a = 0.5
c = 2

kernel_size = 300

# Domain boundaries
ics_coords = np.array([[0.0, 0.0],  [0.0, 1.0]])
bc1_coords = np.array([[0.0, 0.0],  [1.0, 0.0]])
bc2_coords = np.array([[0.0, 1.0],  [1.0, 1.0]])
dom_coords = np.array([[0.0, 0.0],  [1.0, 1.0]])

# Create initial conditions samplers
ics_sampler = Sampler(2, ics_coords, lambda x: u(x, a, c), name='Initial Condition 1')

# Create boundary conditions samplers
bc1 = Sampler(2, bc1_coords, lambda x: u(x, a, c), name='Dirichlet BC1')
bc2 = Sampler(2, bc2_coords, lambda x: u(x, a, c), name='Dirichlet BC2')
bcs_sampler = [bc1, bc2]

# Create residual sampler
res_sampler = Sampler(2, dom_coords, lambda x: r(x, a, c), name='Forcing')



nIter =40000
bcbatch_size = 500
ubatch_size = 5000
mbbatch_size = 300



# Define model
mode = 'M4'
layers = [2, 500, 500, 500, 1]


nn = 200
t = np.linspace(dom_coords[0, 0], dom_coords[1, 0], nn)[:, None]
x = np.linspace(dom_coords[0, 1], dom_coords[1, 1], nn)[:, None]
t, x = np.meshgrid(t, x)
X_star = np.hstack((t.flatten()[:, None], x.flatten()[:, None]))

u_star = u(X_star, a,c)
r_star = r(X_star, a, c)

iterations = 1
methods = [  "mini_batch"]

result_dict =  dict((mtd, []) for mtd in methods)

for mtd in methods:
    print("Method: ", mtd)
    time_list = []
    error_u_list = []
    
    for index in range(iterations):

        print("Epoch: ", str(index+1))

        # Create residual sampler

        [elapsed, error_u] = test_method(mtd , layers,  ics_sampler, bcs_sampler, res_sampler, c ,kernel_size , X_star , u_star , r_star , nIter ,mbbatch_size , bcbatch_size , ubatch_size )


        print('elapsed: {:.2e}'.format(elapsed))
        print('Relative L2 error_u: {:.2e}'.format(error_u))

        time_list.append(elapsed)
        error_u_list.append(error_u)

    print("\n\nMethod: ", mtd)
    print("\naverage of time_list:" , sum(time_list) / len(time_list) )
    print("average of error_u_list:" , sum(error_u_list) / len(error_u_list) )
    # print("average of error_r_list:" , sum(error_r_list) / len(error_r_list) )

    result_dict[mtd] = [time_list ,error_u_list]
    # scipy.io.savemat("M2_result_"+str(iterations)+"_"+mtd+".mat" , {'time_list':np.array(time_list),'error_u_list':np.array(error_u_list),'error_f_list':np.array(error_f_list)})

    scipy.io.savemat("./1DWave_database/"+mtd+"_1Dwave_"+mode+"_result_mb"+str(mbbatch_size)+"_fb"+str(ubatch_size)+"_bc"+str(mbbatch_size)+"_"+str(iterations)+".mat" , result_dict)

###############################################################################################################################################

# %%
import scipy.io

mode = 'M4'
mbbatch_size = 128
ubatch_size = 5000
bcbatch_size = 500
iterations = 40000

time_list = []
error_u_list = []
error_v_list = []
error_p_list = []
    
methods = ["mini_batch" , "full_batch"]
result_dict =  dict((mtd, []) for mtd in methods)

##Mini Batch
time_list = []
error_u_list = [ ]


result_dict["mini_batch"] = [time_list ,error_u_list]

print("\n\nMethod: ", mtd)
print("\naverage of time_list:" , sum(time_list) / len(time_list) )
print("average of error_u_list:" , sum(error_u_list) / len(error_u_list) )

##Full Batch
time_list = []
error_u_list = [ ]
error_v_list = []
error_p_list = []

result_dict["full_batch"] = [time_list ,error_u_list ,error_v_list ,  error_p_list]

print("\n\nMethod: ", mtd)
print("\naverage of time_list:" , sum(time_list) / len(time_list) )
print("average of error_u_list:" , sum(error_u_list) / len(error_u_list) )
print("average of error_v_list:" , sum(error_v_list) / len(error_v_list) )
print("average of error_p_list:" , sum(error_p_list) / len(error_p_list) )


scipy.io.savemat("./dataset/1DWave_database_"+mode+"_result_mb"+str(mbbatch_size)+"_fb"+str(ubatch_size)+"_"+str(bcbatch_size)+"_"+str(iterations)+".mat" , result_dict)

# %%
# Train model
itertaions = 80001
log_NTK = True # Compute and store NTK matrix during training
update_lam = True # Compute and update the loss weights using the NTK

# %% [markdown]
# **Training Loss**

# %%
loss_res = model.loss_res_log
loss_bcs = model.loss_bcs_log
loss_u_t_ics = model.loss_ut_ics_log

fig = plt.figure(figsize=(6, 5))
plt.plot(loss_res, label='$\mathcal{L}_{r}$')
plt.plot(loss_bcs, label='$\mathcal{L}_{u}$')
plt.plot(loss_u_t_ics, label='$\mathcal{L}_{u_t}$')
plt.yscale('log')
plt.xlabel('iterations')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# **Model Prediction**

# %%
# Predictions
u_pred = model.predict_u(X_star)
r_pred = model.predict_r(X_star)
error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)

print('Relative L2 error_u: %e' % (error_u))

# %%
U_star = griddata(X_star, u_star.flatten(), (t, x), method='cubic')
r_star = griddata(X_star, r_star.flatten(), (t, x), method='cubic')
U_pred = griddata(X_star, u_pred.flatten(), (t, x), method='cubic')
R_pred = griddata(X_star, r_pred.flatten(), (t, x), method='cubic')


plt.figure(figsize=(18, 9))
plt.subplot(2, 3, 1)
plt.pcolor(t, x, U_star, cmap='jet')
plt.colorbar()
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.title('Exact u(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 2)
plt.pcolor(t, x, U_pred, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Predicted u(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 3)
plt.pcolor(t, x, np.abs(U_star - U_pred), cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Absolute error')
plt.tight_layout()

plt.subplot(2, 3, 4)
plt.pcolor(t, x, r_star, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Exact r(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 5)
plt.pcolor(t, x, R_pred, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Predicted r(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 6)
plt.pcolor(t, x, np.abs(r_star - R_pred), cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Absolute error')
plt.tight_layout()
plt.show()

# %% [markdown]
# **NTK Eigenvalues**

# %%
# Create empty lists for storing the eigenvalues of NTK
lam_K_u_log = []
lam_K_ut_log = []
lam_K_r_log = []

# Restore the NTK
K_u_list = model.K_u_log
K_ut_list = model.K_ut_log
K_r_list = model.K_r_log

K_list = []
    
for k in range(len(K_u_list)):
    K_u = K_u_list[k]
    K_ut = K_ut_list[k]
    K_r = K_r_list[k]
    
    # Compute eigenvalues
    lam_K_u, _ = np.linalg.eig(K_u)
    lam_K_ut, _ = np.linalg.eig(K_ut)
    lam_K_r, _ = np.linalg.eig(K_r)
    # Sort in descresing order
    lam_K_u = np.sort(np.real(lam_K_u))[::-1]
    lam_K_ut = np.sort(np.real(lam_K_ut))[::-1]
    lam_K_r = np.sort(np.real(lam_K_r))[::-1]
    
    # Store eigenvalues
    lam_K_u_log.append(lam_K_u)
    lam_K_ut_log.append(lam_K_ut)
    lam_K_r_log.append(lam_K_r)

# %%
#  Eigenvalues of NTK
fig = plt.figure(figsize=(18, 5))
plt.subplot(1,3,1)

plt.plot(lam_K_u_log[0], label = '$n=0$')
plt.plot(lam_K_u_log[1], '--', label = '$n=10,000$')
plt.plot(lam_K_u_log[4], '--', label = '$n=40,000$')
plt.plot(lam_K_u_log[-1], '--', label = '$n=80,000$')
plt.xscale('log')
plt.yscale('log')

plt.title(r'Eigenvalues of ${K}_u$')

plt.subplot(1,3,2)
plt.plot(lam_K_ut_log[0], label = '$n=0$')
plt.plot(lam_K_ut_log[1], '--',label = '$n=10,000$')
plt.plot(lam_K_ut_log[4], '--', label = '$n=40,000$')
plt.plot(lam_K_ut_log[-1], '--', label = '$n=80,000$')
plt.xscale('log')
plt.yscale('log')
plt.title(r'Eigenvalues of ${K}_{u_t}$')

ax =plt.subplot(1,3,3)
plt.plot(lam_K_r_log[0], label = '$n=0$')
plt.plot(lam_K_r_log[1], '--', label = '$n=10,000$')
plt.plot(lam_K_r_log[4], '--', label = '$n=40,000$')
plt.plot(lam_K_r_log[-1], '--', label = '$n=80,000$')
plt.xscale('log')
plt.yscale('log')
plt.title(r'Eigenvalues of ${K}_{r}$')
handles, labels = ax.get_legend_handles_labels()
fig.legend(handles, labels, loc="upper left", bbox_to_anchor=(0.35, -0.02),
            borderaxespad=0, bbox_transform=fig.transFigure, ncol=4)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Evolution of NTK Weights**

# %%
if update_lam == True:

  lam_u_log = model.lam_u_log
  lam_ut_log = model.lam_ut_log
  lam_r_log = model.lam_r_log

# %%
fig = plt.figure(figsize=(6, 5))
plt.plot(lam_u_log, label='$\lambda_u$')
plt.plot(lam_ut_log, label='$\lambda_{u_t}$')
plt.plot(lam_r_log, label='$\lambda_{r}$')
plt.xlabel('iterations')
plt.ylabel('$\lambda$')
plt.yscale('log')
plt.legend( )
plt.tight_layout()
plt.show()
