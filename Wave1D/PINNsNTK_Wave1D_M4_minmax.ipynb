# %%
import tensorflow as tf
from Compute_Jacobian import jacobian # Please download 'Compute_Jacobian.py' in the repository 
import numpy as np
import timeit
from scipy.interpolate import griddata
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import os



os.environ["KMP_WARNINGS"] = "FALSE" 
import timeit

import sys

import scipy
import scipy.io
import time

class Sampler:
    # Initialize the class
    def __init__(self, dim, coords, func, name = None):
        self.dim = dim
        self.coords = coords
        self.func = func
        self.name = name
    def sample(self, N):
        x = self.coords[0:1,:] + (self.coords[1:2,:]-self.coords[0:1,:])*np.random.rand(N, self.dim)
        y = self.func(x)
        return x, y

# Define the exact solution and its derivatives
def u(x, a, c):
    """
    :param x: x = (t, x)
    """
    t = x[:,0:1]
    x = x[:,1:2]
    return np.sin(np.pi * x) * np.cos(c * np.pi * t) + a * np.sin(2 * c * np.pi* x) * np.cos(4 * c  * np.pi * t)

def u_t(x,a, c):
    t = x[:,0:1]
    x = x[:,1:2]
    u_t = -  c * np.pi * np.sin(np.pi * x) * np.sin(c * np.pi * t) -  a * 4 * c * np.pi * np.sin(2 * c * np.pi* x) * np.sin(4 * c * np.pi * t)
    return u_t

def u_tt(x, a, c):
    t = x[:,0:1]
    x = x[:,1:2]
    u_tt = -(c * np.pi)**2 * np.sin( np.pi * x) * np.cos(c * np.pi * t) - a * (4 * c * np.pi)**2 *  np.sin(2 * c * np.pi* x) * np.cos(4 * c * np.pi * t)
    return u_tt

def u_xx(x, a, c):
    t = x[:,0:1]
    x = x[:,1:2]
    u_xx = - np.pi**2 * np.sin( np.pi * x) * np.cos(c * np.pi * t) -  a * (2 * c * np.pi)** 2 * np.sin(2 * c * np.pi* x) * np.cos(4 * c * np.pi * t)
    return  u_xx


def r(x, a, c):
    return u_tt(x, a, c) - c**2 * u_xx(x, a, c)

def operator(u, t, x, c, sigma_t=1.0, sigma_x=1.0):
    u_t = tf.gradients(u, t)[0] / sigma_t
    u_x = tf.gradients(u, x)[0] / sigma_x
    u_tt = tf.gradients(u_t, t)[0] / sigma_t
    u_xx = tf.gradients(u_x, x)[0] / sigma_x
    residual = u_tt - c**2 * u_xx
    return residual

# %%
class PINN:
    # Initialize the class
    def __init__(self, layers, operator, ics_sampler, bcs_sampler, res_sampler, c, kernel_size , sess):
        # Normalization 
        X, _ = res_sampler.sample(np.int32(1e5))
        self.mu_X, self.sigma_X = X.mean(0), X.std(0)
        self.mu_t, self.sigma_t = self.mu_X[0], self.sigma_X[0]
        self.mu_x, self.sigma_x = self.mu_X[1], self.sigma_X[1]

        self.activFun = 'xsig'
        # Samplers
        self.operator = operator
        self.ics_sampler = ics_sampler
        self.bcs_sampler = bcs_sampler
        self.res_sampler = res_sampler

        self.sess = sess
        # Initialize network weights and biases
        self.layers = layers
        self.weights, self.biases = self.initialize_NN(layers)
        
        # weights
        self.lam_u_val = np.array(2.0)
        self.lam_ut_val = np.array(2.0)

        self.lam_r_val = np.array(1.0)
        self.lam_bc1_val = np.array(2.0)
        self.lam_bc2_val = np.array(2.0)
      
        # Wave constant
        self.c = tf.constant(c, dtype=tf.float32)
        
        self.kernel_size = kernel_size # Size of the NTK matrix

        # Define Tensorflow session
        self.sess = tf.Session(config=tf.ConfigProto(log_device_placement=False))

        # Define placeholders and computational graph
        self.t_u_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_u_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_ics_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_ics_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.u_ics_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_r_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_r_tf = tf.placeholder(tf.float32, shape=(None, 1))
        
        self.lam_u_tf = tf.placeholder(tf.float32, shape=self.lam_u_val.shape)
        self.lam_ut_tf = tf.placeholder(tf.float32, shape=self.lam_u_val.shape)
        # self.lam_r_tf = tf.placeholder(tf.float32, shape=self.lam_u_val.shape)
        self.lam_bc_tf = tf.placeholder(tf.float32, shape=self.lam_bc1_val.shape)
        self.lam_res_tf = tf.placeholder(tf.float32, shape=self.lam_r_val.shape)
        

        self.u_pred = self.net_u(self.t_u_tf, self.x_u_tf)


        # Evaluate predictions
        self.u_ics_pred = self.net_u(self.t_ics_tf, self.x_ics_tf)
        self.u_bc1_pred = self.net_u(self.t_bc1_tf, self.x_bc1_tf)
        self.u_bc2_pred = self.net_u(self.t_bc2_tf, self.x_bc2_tf)

        self.r_pred = self.net_r(self.t_r_tf, self.x_r_tf)
        
        
        # Boundary loss and Initial loss
        self.loss_ics_u = tf.reduce_mean(tf.square(self.u_ics_tf - self.u_ics_pred)  +  tf.square( tf.gradients(self.u_ics_pred, self.t_ics_tf)[0] / self.sigma_t) )
        self.loss_bc1 = tf.reduce_mean(tf.square(self.u_bc1_pred)) + tf.reduce_mean(tf.square(self.u_bc2_pred))
        # self.loss_bc2 = tf.reduce_mean(tf.square(self.u_bc2_pred))

        # Residual loss
        self.loss_res = tf.reduce_mean(tf.square(self.r_pred))

        # Total loss
        self.loss =  self.lam_res_tf * self.loss_res + self.lam_bc_tf *( self.loss_bc1  )+ self.lam_u_tf * self.loss_ics_u # + self.lam_ut_tf * self.loss_ics_u_t 

        self.prev_lam_bc1_val = 10000000
        self.prev_lam_u_val = 10000000
        self.prev_lam_res_val = 10000000

        # Define optimizer with learning rate schedule
        self.global_step = tf.Variable(0, trainable=False)
        starter_learning_rate = 1e-3
        self.learning_rate = tf.train.exponential_decay(starter_learning_rate, self.global_step,  1000, 0.9, staircase=False)
        # Passing global_step to minimize() will increment it at each step.
        self.train_op = tf.train.AdamOptimizer(self.learning_rate).minimize(self.loss, global_step=self.global_step)
        
         # Initialize Tensorflow variables
        init = tf.global_variables_initializer()
        self.sess.run(init)

    # Initialize network weights and biases using Xavier initialization
    def initialize_NN(self, layers):
        # Xavier initialization
        def xavier_init(size):
            in_dim = size[0]
            out_dim = size[1]
            xavier_stddev = 1. / np.sqrt((in_dim + out_dim) / 2.)
            return tf.Variable(tf.random.normal([in_dim, out_dim], dtype=tf.float32) * xavier_stddev,  dtype=tf.float32)

        weights = []
        biases = []
        num_layers = len(layers)
        for l in range(0, num_layers - 1):
            W = xavier_init(size=[layers[l], layers[l + 1]])
            b = tf.Variable(tf.zeros([1, layers[l + 1]], dtype=tf.float32), dtype=tf.float32)
            weights.append(W)
            biases.append(b)
        return weights, biases

    # Evaluates the forward pass
    def forward_pass(self, H, layers, weights, biases):
        num_layers = len(layers)
        for l in range(0, num_layers - 2):
            W = weights[l]
            b = biases[l]
            H = tf.tanh(tf.add(tf.matmul(H, W), b))
            # H =  H*tf.sigmoid(tf.add(tf.matmul(H, W), b))
        W = weights[-1]
        b = biases[-1]
        H = tf.add(tf.matmul(H, W), b)
              
        return H
################################################################################################
    # Forward pass for u
    def net_u(self, t, x):
        u = self.forward_pass(tf.concat([t, x], 1),  self.layers, self.weights, self.biases)
        return u

    # Forward pass for du/dt
    def net_u_t(self, t, x):
        u_t = tf.gradients(self.net_u(t, x), t)[0] / self.sigma_t
        return u_t

    # Forward pass for the residual
    def net_r(self, t, x):
        u = self.net_u(t, x)
        residual = self.operator(u, t, x, self.c, self.sigma_t,  self.sigma_x)
        return residual
    
    

    def fetch_minibatch(self, sampler, N):
        X, Y = sampler.sample(N)
        X = (X - self.mu_X) / self.sigma_X
        return X, Y

        # Trains the model by minimizing the MSE loss

    def trainmb(self, nIter=10000, batch_size=128, log_NTK=False, update_lam=False):

        start_time = timeit.default_timer()
        for it in range(nIter):
            # Fetch boundary mini-batches
            X_ics_batch, u_ics_batch = self.fetch_minibatch(self.ics_sampler, batch_size // 3)
            X_bc1_batch, _ = self.fetch_minibatch(self.bcs_sampler[0], batch_size // 3)
            X_bc2_batch, _ = self.fetch_minibatch(self.bcs_sampler[1], batch_size // 3)
            
            # Fetch residual mini-batch
            X_res_batch, _ = self.fetch_minibatch(self.res_sampler, batch_size)
            # Define a dictionary for associating placeholders with data
            tf_dict = {self.t_ics_tf: X_ics_batch[:, 0:1], self.x_ics_tf: X_ics_batch[:, 1:2],
                       self.u_ics_tf: u_ics_batch,
                       self.t_bc1_tf: X_bc1_batch[:, 0:1], self.x_bc1_tf: X_bc1_batch[:, 1:2],
                       self.t_bc2_tf: X_bc2_batch[:, 0:1], self.x_bc2_tf: X_bc2_batch[:, 1:2],
                       self.t_r_tf: X_res_batch[:, 0:1], self.x_r_tf: X_res_batch[:, 1:2],
                       self.lam_u_tf: self.lam_u_val,
                       self.lam_bc_tf: self.lam_bc1_val,
                    self.lam_res_tf: self.lam_r_val,
                       }

            # Run the Tensorflow session to minimize the loss
            self.sess.run(self.train_op, tf_dict)

            # Print
            if it % 100 == 0:
                elapsed = timeit.default_timer() - start_time

                loss = self.sess.run(self.loss, tf_dict)
                loss_bc1 = self.sess.run(self.loss_bc1, tf_dict)
                # loss_bc2 = self.sess.run(self.loss_bc2, tf_dict)
                loss_ics_u = self.sess.run(self.loss_ics_u, tf_dict)
                loss_res = self.sess.run(self.loss_res, tf_dict)


                print('It: %d, Loss: %.3e,  loss_bc1: %.3e, loss_ics_u: %.3e,  Loss_res: %.3e , Time: %.2f' %(it, loss, loss_bc1 ,loss_ics_u , loss_res , elapsed))
                
 
                start_time = timeit.default_timer()
            
          
                alpha   = 10000
                if loss_bc1 < self.prev_lam_bc1_val:
                    self.lam_bc1_val = alpha * loss_bc1
                    self.prev_lam_bc1_val = loss_bc1

                if loss_ics_u < self.prev_lam_u_val:
                    self.lam_u_val = alpha * loss_ics_u
                    self.prev_lam_u_val = loss_ics_u

                if loss_res < self.prev_lam_res_val:
                    self.prev_lam_res_val = loss_res
                    self.lam_res_val = 100 * loss_res

                print('loss_bc1: {:.3e}'.format(self.lam_bc1_val))
                # print('loss_bc2: {:.3e}'.format(self.lam_bc2_val))
                print('loss_ics_u: {:.3e}'.format(self.lam_u_val))
                print('loss_res: {:.3e}'.format(self.lam_res_val))
                sys.stdout.flush()
                
##################################################################################################
    def train(self, nIter , bcbatch_size , ubatch_size):

        start_time = timeit.default_timer()

        # Fetch boundary mini-batches
        X_ics_batch, u_ics_batch = self.fetch_minibatch(self.ics_sampler, bcbatch_size)
        X_bc1_batch, _ = self.fetch_minibatch(self.bcs_sampler[0], bcbatch_size )
        X_bc2_batch, _ = self.fetch_minibatch(self.bcs_sampler[1], bcbatch_size )
        
        # Fetch residual mini-batch
        X_res_batch, _ = self.fetch_minibatch(self.res_sampler, ubatch_size)
        # print("inside trainmb: " , X_res_batch.shape)
        # Define a dictionary for associating placeholders with data
        tf_dict = {self.t_ics_tf: X_ics_batch[:, 0:1],
                    self.x_ics_tf: X_ics_batch[:, 1:2],
                    self.u_ics_tf: u_ics_batch,
                    self.t_bc1_tf: X_bc1_batch[:, 0:1],
                    self.x_bc1_tf: X_bc1_batch[:, 1:2],
                    self.t_bc2_tf: X_bc2_batch[:, 0:1],
                    self.x_bc2_tf: X_bc2_batch[:, 1:2],
                    self.t_r_tf: X_res_batch[:, 0:1],
                    self.x_r_tf: X_res_batch[:, 1:2],
                    self.lam_u_tf: self.lam_u_val,
                    self.lam_bc_tf: self.lam_bc1_val,
                    self.lam_res_tf: self.lam_r_val,
                       }
  
        for it in range(nIter):

            # Run the Tensorflow session to minimize the loss
            self.sess.run(self.train_op, tf_dict)

             # Print
            if it % 100 == 0:
                elapsed = timeit.default_timer() - start_time

                loss = self.sess.run(self.loss, tf_dict)
                loss_bc1 = self.sess.run(self.loss_bc1, tf_dict)
                # loss_bc2 = self.sess.run(self.loss_bc2, tf_dict)
                loss_ics_u = self.sess.run(self.loss_ics_u, tf_dict)
                loss_res = self.sess.run(self.loss_res, tf_dict)


                print('It: %d, Loss: %.3e,  loss_bc1: %.3e, loss_ics_u: %.3e,  Loss_res: %.3e , Time: %.2f' %(it, loss, loss_bc1 ,loss_ics_u , loss_res , elapsed))
                
 
                start_time = timeit.default_timer()
            
          
                alpha   = 10000
                if loss_bc1 < self.prev_lam_bc1_val:
                    self.lam_bc1_val = alpha * loss_bc1
                    self.prev_lam_bc1_val = loss_bc1

                if loss_ics_u < self.prev_lam_u_val:
                    self.lam_u_val = alpha * loss_ics_u
                    self.prev_lam_u_val = loss_ics_u

                if loss_res < self.prev_lam_res_val:
                    self.prev_lam_res_val = loss_res
                    self.lam_res_val = 100 * loss_res

                print('loss_bc1: {:.3e}'.format(self.lam_bc1_val))
                # print('loss_bc2: {:.3e}'.format(self.lam_bc2_val))
                print('loss_ics_u: {:.3e}'.format(self.lam_u_val))
                print('loss_res: {:.3e}'.format(self.lam_res_val))
                sys.stdout.flush()

                #########################################################################################################################
    # Evaluates predictions at test points
    def predict_u(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.t_u_tf: X_star[:, 0:1], self.x_u_tf: X_star[:, 1:2]}
        u_star = self.sess.run(self.u_pred, tf_dict)
        return u_star

        # Evaluates predictions at test points

    def predict_r(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.t_r_tf: X_star[:, 0:1], self.x_r_tf: X_star[:, 1:2]}
        r_star = self.sess.run(self.r_pred, tf_dict)
        return r_star
    
   ###############################################################################################################################################
   # 
   # ###############################################################################################################################################
   # 
   # ###############################################################################################################################################
   # 
   #

# %%
#test_method(mtd , layers,  X_u, Y_u, X_r, Y_r ,  X_star , u_star , r_star  , nIter ,batch_size , bcbatch_size , ubatch_size)
def test_method(method , layers,  ics_sampler, bcs_sampler, res_sampler, c ,kernel_size , X_star , u_star , r_star , nIter ,mbbatch_size , bcbatch_size , ubatch_size ):

    tf.reset_default_graph()
    gpu_options = tf.GPUOptions(visible_device_list="0")
    with tf.Session(config=tf.ConfigProto(gpu_options=gpu_options,allow_soft_placement=False, log_device_placement=False)) as sess:
        # sess.run(init)

        model = PINN(layers, operator, ics_sampler, bcs_sampler, res_sampler, c, kernel_size , sess)
        # Train model
        start_time = time.time()

        if method =="full_batch":
            print("full_batch method is used")
            model.train(nIter  , bcbatch_size , ubatch_size  )
        elif method =="mini_batch":
            print("mini_batch method is used")
            model.trainmb(nIter, mbbatch_size)
        else:
            print("unknown method!")
        elapsed = time.time() - start_time

        # Predictions
        u_pred = model.predict_u(X_star)
        # Predictions

        sess.close()   

    error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)

    print('elapsed: {:.2e}'.format(elapsed))

    print('Relative L2 error_u: {:.2e}'.format(error_u))


    return [elapsed, error_u  ]

###############################################################################################################################################

# %%
# Define PINN model
a = 0.5
c = 2

kernel_size = 300

# Domain boundaries
ics_coords = np.array([[0.0, 0.0],  [0.0, 1.0]])
bc1_coords = np.array([[0.0, 0.0],  [1.0, 0.0]])
bc2_coords = np.array([[0.0, 1.0],  [1.0, 1.0]])
dom_coords = np.array([[0.0, 0.0],  [1.0, 1.0]])

# Create initial conditions samplers
ics_sampler = Sampler(2, ics_coords, lambda x: u(x, a, c), name='Initial Condition 1')

# Create boundary conditions samplers
bc1 = Sampler(2, bc1_coords, lambda x: u(x, a, c), name='Dirichlet BC1')
bc2 = Sampler(2, bc2_coords, lambda x: u(x, a, c), name='Dirichlet BC2')
bcs_sampler = [bc1, bc2]

# Create residual sampler
res_sampler = Sampler(2, dom_coords, lambda x: r(x, a, c), name='Forcing')



nIter =40000
bcbatch_size = 500
ubatch_size = 5000
mbbatch_size = 300



# Define model
mode = 'M4'
layers = [2, 500, 500, 500, 1]


nn = 200
t = np.linspace(dom_coords[0, 0], dom_coords[1, 0], nn)[:, None]
x = np.linspace(dom_coords[0, 1], dom_coords[1, 1], nn)[:, None]
t, x = np.meshgrid(t, x)
X_star = np.hstack((t.flatten()[:, None], x.flatten()[:, None]))

u_star = u(X_star, a,c)
r_star = r(X_star, a, c)

iterations = 1
methods = [  "full_batch"]

result_dict =  dict((mtd, []) for mtd in methods)

for mtd in methods:
    print("Method: ", mtd)
    time_list = []
    error_u_list = []
    
    for index in range(iterations):

        print("Epoch: ", str(index+1))

        # Create residual sampler

        tf.reset_default_graph()
        gpu_options = tf.GPUOptions(visible_device_list="0")
        with tf.Session(config=tf.ConfigProto(gpu_options=gpu_options,allow_soft_placement=False, log_device_placement=False)) as sess:
            # sess.run(init)

            model = PINN(layers, operator, ics_sampler, bcs_sampler, res_sampler, c, kernel_size , sess)
            # Train model
            start_time = time.time()

            if mtd =="full_batch":
                print("full_batch method is used")
                model.train(nIter  , bcbatch_size , ubatch_size  )
            elif mtd =="mini_batch":
                print("mini_batch method is used")
                model.trainmb(nIter, mbbatch_size)
            else:
                print("unknown method!")
            elapsed = time.time() - start_time

            # Predictions
            u_pred = model.predict_u(X_star)
            r_pred = model.predict_r(X_star)
            # Predictions

            sess.close()   

            error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)
            error_r = np.linalg.norm(r_star - r_pred, 2)# / np.linalg.norm(r_star, 2)

            print('elapsed: {:.2e}'.format(elapsed))

            print('Relative L2 error_u: {:.2e}'.format(error_u))
            print('Relative L2 error_r: {:.2e}'.format(error_r))

        # print('elapsed: {:.2e}'.format(elapsed))
        # print('Relative L2 error_u: {:.2e}'.format(error_u))

        time_list.append(elapsed)
        error_u_list.append(error_u)

    print("\n\nMethod: ", mtd)
    print("\naverage of time_list:" , sum(time_list) / len(time_list) )
    print("average of error_u_list:" , sum(error_u_list) / len(error_u_list) )
    # print("average of error_r_list:" , sum(error_r_list) / len(error_r_list) )

    result_dict[mtd] = [time_list ,error_u_list]
    # scipy.io.savemat("M2_result_"+str(iterations)+"_"+mtd+".mat" , {'time_list':np.array(time_list),'error_u_list':np.array(error_u_list),'error_f_list':np.array(error_f_list)})

    scipy.io.savemat("./1DWave_database/"+mtd+"_1Dwave_"+mode+"_result_mb"+str(mbbatch_size)+"_fb"+str(ubatch_size)+"_bc"+str(mbbatch_size)+"_"+str(iterations)+".mat" , result_dict)

###############################################################################################################################################
# Out:
# Method:  full_batch
# Epoch:  1
# WARNING:tensorflow:From /tmp/ipykernel_17878/497367041.py:63: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_17878/497367041.py:64: The name tf.GPUOptions is deprecated. Please use tf.compat.v1.GPUOptions instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_17878/497367041.py:65: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_17878/497367041.py:65: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
# WARNING:tensorflow:From /tmp/ipykernel_17878/77731530.py:39: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# 2023-11-27 20:55:02.655740: I tensorflow/core/platform/cpu_feature_guard.cc:145] This TensorFlow binary is optimized with Intel(R) MKL-DNN to use the following CPU instructions in performance critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in non-MKL-DNN operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-27 20:55:02.681024: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2899885000 Hz
# 2023-11-27 20:55:02.681481: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55ece63bd980 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-11-27 20:55:02.681499: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2023-11-27 20:55:02.682586: I tensorflow/core/common_runtime/process_util.cc:115] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# WARNING:tensorflow:From /tmp/ipykernel_17878/77731530.py:91: The name tf.train.exponential_decay is deprecated. Please use tf.compat.v1.train.exponential_decay instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_17878/77731530.py:93: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_17878/77731530.py:96: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# full_batch method is used
# It: 0, Loss: 4.765e+01,  loss_bc1: 3.807e+00, loss_ics_u: 1.904e+01,  Loss_res: 1.952e+00 , Time: 1.90
# loss_bc1: 3.807e+04
# loss_ics_u: 1.904e+05
# loss_res: 1.952e+02
# It: 100, Loss: 8.469e-01,  loss_bc1: 7.225e-02, loss_ics_u: 3.510e-01,  Loss_res: 3.667e-04 , Time: 33.47
# loss_bc1: 7.225e+02
# loss_ics_u: 3.510e+03
# loss_res: 3.667e-02
# It: 200, Loss: 7.400e-01,  loss_bc1: 7.447e-02, loss_ics_u: 2.919e-01,  Loss_res: 7.253e-03 , Time: 35.03
# loss_bc1: 7.225e+02
# loss_ics_u: 2.919e+03
# loss_res: 3.667e-02
# It: 300, Loss: 6.221e-01,  loss_bc1: 7.022e-02, loss_ics_u: 2.331e-01,  Loss_res: 1.550e-02 , Time: 35.02
# loss_bc1: 7.022e+02
# loss_ics_u: 2.331e+03
# loss_res: 3.667e-02
# It: 400, Loss: 5.926e-01,  loss_bc1: 7.270e-02, loss_ics_u: 2.138e-01,  Loss_res: 1.957e-02 , Time: 34.95
# loss_bc1: 7.022e+02
# loss_ics_u: 2.138e+03
# loss_res: 3.667e-02
# It: 500, Loss: 4.453e-01,  loss_bc1: 4.601e-02, loss_ics_u: 1.700e-01,  Loss_res: 1.324e-02 , Time: 35.38
# loss_bc1: 4.601e+02
# loss_ics_u: 1.700e+03
# loss_res: 3.667e-02
# It: 600, Loss: 4.083e-01,  loss_bc1: 4.544e-02, loss_ics_u: 1.566e-01,  Loss_res: 4.170e-03 , Time: 35.30
# loss_bc1: 4.544e+02
# loss_ics_u: 1.566e+03
# loss_res: 3.667e-02
# It: 700, Loss: 3.807e-01,  loss_bc1: 4.698e-02, loss_ics_u: 1.410e-01,  Loss_res: 4.689e-03 , Time: 35.03
# loss_bc1: 4.544e+02
# loss_ics_u: 1.410e+03
# loss_res: 3.667e-02
# It: 800, Loss: 3.622e-01,  loss_bc1: 4.646e-02, loss_ics_u: 1.330e-01,  Loss_res: 3.223e-03 , Time: 35.07
# loss_bc1: 4.544e+02
# loss_ics_u: 1.330e+03
# loss_res: 3.667e-02
# It: 900, Loss: 3.467e-01,  loss_bc1: 4.441e-02, loss_ics_u: 1.276e-01,  Loss_res: 2.696e-03 , Time: 35.09
# loss_bc1: 4.441e+02
# loss_ics_u: 1.276e+03
# loss_res: 3.667e-02
# It: 1000, Loss: 3.324e-01,  loss_bc1: 4.296e-02, loss_ics_u: 1.223e-01,  Loss_res: 1.926e-03 , Time: 35.17
# loss_bc1: 4.296e+02
# loss_ics_u: 1.223e+03
# loss_res: 3.667e-02
# It: 1100, Loss: 3.328e-01,  loss_bc1: 4.092e-02, loss_ics_u: 1.237e-01,  Loss_res: 3.556e-03 , Time: 37.52
# loss_bc1: 4.092e+02
# loss_ics_u: 1.223e+03
# loss_res: 3.667e-02
# It: 1200, Loss: 3.189e-01,  loss_bc1: 3.950e-02, loss_ics_u: 1.184e-01,  Loss_res: 3.091e-03 , Time: 35.56
# It: 2500, Loss: 2.668e-01,  loss_bc1: 3.114e-02, loss_ics_u: 1.014e-01,  Loss_res: 1.799e-03 , Time: 36.57
# loss_bc1: 2.855e+02
# loss_ics_u: 1.014e+03
# loss_res: 3.667e-02
# It: 2600, Loss: 2.649e-01,  loss_bc1: 3.058e-02, loss_ics_u: 1.010e-01,  Loss_res: 1.708e-03 , Time: 37.79
# loss_bc1: 2.855e+02
# loss_ics_u: 1.010e+03
# loss_res: 3.667e-02
# It: 2700, Loss: 2.648e-01,  loss_bc1: 3.014e-02, loss_ics_u: 1.013e-01,  Loss_res: 1.836e-03 , Time: 38.15
# loss_bc1: 2.855e+02
# loss_ics_u: 1.010e+03
# loss_res: 3.667e-02
# It: 2800, Loss: 2.688e-01,  loss_bc1: 3.039e-02, loss_ics_u: 1.026e-01,  Loss_res: 2.843e-03 , Time: 38.83
# loss_bc1: 2.855e+02
# loss_ics_u: 1.010e+03
# loss_res: 3.667e-02
# It: 2900, Loss: 2.606e-01,  loss_bc1: 2.804e-02, loss_ics_u: 9.999e-02,  Loss_res: 4.519e-03 , Time: 39.40
# loss_bc1: 2.804e+02
# loss_ics_u: 9.999e+02
# loss_res: 3.667e-02
# It: 3000, Loss: 2.691e-01,  loss_bc1: 2.842e-02, loss_ics_u: 9.725e-02,  Loss_res: 1.773e-02 , Time: 36.88
# loss_bc1: 2.804e+02
# loss_ics_u: 9.725e+02
# loss_res: 3.667e-02
# It: 3100, Loss: 2.627e-01,  loss_bc1: 2.540e-02, loss_ics_u: 1.001e-01,  Loss_res: 1.174e-02 , Time: 36.27
# loss_bc1: 2.540e+02
# loss_ics_u: 9.725e+02
# loss_res: 3.667e-02
# It: 3200, Loss: 2.461e-01,  loss_bc1: 2.579e-02, loss_ics_u: 9.630e-02,  Loss_res: 1.934e-03 , Time: 35.30
# loss_bc1: 2.540e+02
# loss_ics_u: 9.630e+02
# loss_res: 3.667e-02
# It: 3300, Loss: 2.468e-01,  loss_bc1: 2.391e-02, loss_ics_u: 9.721e-02,  Loss_res: 4.609e-03 , Time: 35.19
# loss_bc1: 2.391e+02
# loss_ics_u: 9.630e+02
# loss_res: 3.667e-02
# It: 3400, Loss: 2.537e-01,  loss_bc1: 2.689e-02, loss_ics_u: 9.637e-02,  Loss_res: 7.212e-03 , Time: 35.24
# loss_bc1: 2.391e+02
# loss_ics_u: 9.630e+02
# loss_res: 3.667e-02
# It: 3500, Loss: 2.411e-01,  loss_bc1: 2.286e-02, loss_ics_u: 9.533e-02,  Loss_res: 4.723e-03 , Time: 35.27
# loss_bc1: 2.286e+02
# loss_ics_u: 9.533e+02
# loss_res: 3.667e-02
# It: 3600, Loss: 2.317e-01,  loss_bc1: 2.041e-02, loss_ics_u: 9.455e-02,  Loss_res: 1.817e-03 , Time: 35.27
# loss_bc1: 2.041e+02
# loss_ics_u: 9.455e+02
# loss_res: 3.667e-02
# It: 3700, Loss: 2.313e-01,  loss_bc1: 1.977e-02, loss_ics_u: 9.509e-02,  Loss_res: 1.603e-03 , Time: 35.16
# loss_bc1: 1.977e+02
# loss_ics_u: 9.455e+02
# loss_res: 3.667e-02
# It: 3800, Loss: 3.628e-01,  loss_bc1: 1.724e-02, loss_ics_u: 9.921e-02,  Loss_res: 1.299e-01 , Time: 35.32
# loss_bc1: 1.724e+02
# loss_ics_u: 9.455e+02
# loss_res: 3.667e-02
# It: 3900, Loss: 2.283e-01,  loss_bc1: 1.685e-02, loss_ics_u: 9.532e-02,  Loss_res: 3.916e-03 , Time: 35.17
# loss_bc1: 1.685e+02
# loss_ics_u: 9.455e+02
# loss_res: 3.667e-02
# It: 4000, Loss: 2.263e-01,  loss_bc1: 1.507e-02, loss_ics_u: 9.379e-02,  Loss_res: 8.545e-03 , Time: 35.17
# loss_bc1: 1.507e+02
# loss_ics_u: 9.379e+02
# loss_res: 3.667e-02
# It: 4100, Loss: 2.206e-01,  loss_bc1: 1.556e-02, loss_ics_u: 9.329e-02,  Loss_res: 2.861e-03 , Time: 35.16
# loss_bc1: 1.507e+02
# loss_ics_u: 9.329e+02
# loss_res: 3.667e-02
# It: 4200, Loss: 2.236e-01,  loss_bc1: 1.611e-02, loss_ics_u: 9.490e-02,  Loss_res: 1.616e-03 , Time: 35.48
# loss_bc1: 1.507e+02
# loss_ics_u: 9.329e+02
# loss_res: 3.667e-02
# It: 4300, Loss: 2.162e-01,  loss_bc1: 1.325e-02, loss_ics_u: 9.352e-02,  Loss_res: 2.597e-03 , Time: 35.33
# loss_bc1: 1.325e+02
# loss_ics_u: 9.329e+02
# loss_res: 3.667e-02
# It: 4400, Loss: 2.414e-01,  loss_bc1: 1.478e-02, loss_ics_u: 9.103e-02,  Loss_res: 2.982e-02 , Time: 35.24
# loss_bc1: 1.325e+02
# loss_ics_u: 9.103e+02
# loss_res: 3.667e-02
# It: 4500, Loss: 2.076e-01,  loss_bc1: 1.166e-02, loss_ics_u: 9.074e-02,  Loss_res: 2.813e-03 , Time: 35.31
# loss_bc1: 1.166e+02
# loss_ics_u: 9.074e+02
# loss_res: 3.667e-02
# It: 4600, Loss: 2.080e-01,  loss_bc1: 1.196e-02, loss_ics_u: 9.074e-02,  Loss_res: 2.569e-03 , Time: 35.28
# loss_bc1: 1.166e+02
# loss_ics_u: 9.074e+02
# loss_res: 3.667e-02
# It: 4700, Loss: 2.026e-01,  loss_bc1: 1.050e-02, loss_ics_u: 8.983e-02,  Loss_res: 1.956e-03 , Time: 35.38
# loss_bc1: 1.050e+02
# loss_ics_u: 8.983e+02
# loss_res: 3.667e-02
# It: 4800, Loss: 2.533e-01,  loss_bc1: 1.599e-02, loss_ics_u: 9.944e-02,  Loss_res: 2.241e-02 , Time: 34.77
# loss_bc1: 1.050e+02
# loss_ics_u: 8.983e+02
# loss_res: 3.667e-02
# It: 4900, Loss: 2.018e-01,  loss_bc1: 9.946e-03, loss_ics_u: 8.809e-02,  Loss_res: 5.715e-03 , Time: 36.02
# loss_bc1: 9.946e+01
# loss_ics_u: 8.809e+02
# loss_res: 3.667e-02
# loss_bc1: 6.124e+01
# loss_ics_u: 3.032e+01
# loss_res: 3.667e-02
# It: 32500, Loss: 2.880e-02,  loss_bc1: 1.096e-02, loss_ics_u: 3.022e-03,  Loss_res: 8.401e-04 , Time: 35.23
# loss_bc1: 6.124e+01
# loss_ics_u: 3.022e+01
# loss_res: 3.667e-02
# It: 32600, Loss: 3.209e-02,  loss_bc1: 1.096e-02, loss_ics_u: 3.339e-03,  Loss_res: 3.496e-03 , Time: 35.10
# loss_bc1: 6.124e+01
# loss_ics_u: 3.022e+01
# loss_res: 3.667e-02
# It: 32700, Loss: 2.876e-02,  loss_bc1: 1.092e-02, loss_ics_u: 2.998e-03,  Loss_res: 9.324e-04 , Time: 35.06
# loss_bc1: 6.124e+01
# loss_ics_u: 2.998e+01
# loss_res: 3.667e-02
# It: 32800, Loss: 2.858e-02,  loss_bc1: 1.089e-02, loss_ics_u: 2.988e-03,  Loss_res: 8.153e-04 , Time: 35.02
# loss_bc1: 6.124e+01
# loss_ics_u: 2.988e+01
# loss_res: 3.667e-02
# It: 32900, Loss: 2.877e-02,  loss_bc1: 1.087e-02, loss_ics_u: 3.000e-03,  Loss_res: 1.023e-03 , Time: 35.14
# loss_bc1: 6.124e+01
# loss_ics_u: 2.988e+01
# loss_res: 3.667e-02
# It: 33000, Loss: 2.892e-02,  loss_bc1: 1.085e-02, loss_ics_u: 3.009e-03,  Loss_res: 1.203e-03 , Time: 35.06
# loss_bc1: 6.124e+01
# loss_ics_u: 2.988e+01
# loss_res: 3.667e-02
# It: 33100, Loss: 2.894e-02,  loss_bc1: 1.083e-02, loss_ics_u: 2.958e-03,  Loss_res: 1.367e-03 , Time: 35.22
# loss_bc1: 6.124e+01
# loss_ics_u: 2.958e+01
# loss_res: 3.667e-02
# It: 33200, Loss: 2.874e-02,  loss_bc1: 1.080e-02, loss_ics_u: 2.977e-03,  Loss_res: 1.178e-03 , Time: 35.19
# loss_bc1: 6.124e+01
# loss_ics_u: 2.958e+01
# loss_res: 3.667e-02
# It: 33300, Loss: 2.820e-02,  loss_bc1: 1.078e-02, loss_ics_u: 2.927e-03,  Loss_res: 7.930e-04 , Time: 35.15
# loss_bc1: 6.124e+01
# loss_ics_u: 2.927e+01
# loss_res: 3.667e-02
# It: 33400, Loss: 2.882e-02,  loss_bc1: 1.076e-02, loss_ics_u: 3.039e-03,  Loss_res: 1.224e-03 , Time: 35.09
# loss_bc1: 6.124e+01
# loss_ics_u: 2.927e+01
# loss_res: 3.667e-02
# It: 33500, Loss: 2.905e-02,  loss_bc1: 1.074e-02, loss_ics_u: 3.025e-03,  Loss_res: 1.519e-03 , Time: 35.38
# loss_bc1: 6.124e+01
# loss_ics_u: 2.927e+01
# loss_res: 3.667e-02
# It: 33600, Loss: 3.116e-02,  loss_bc1: 1.071e-02, loss_ics_u: 2.945e-03,  Loss_res: 3.849e-03 , Time: 35.13
# loss_bc1: 6.124e+01
# loss_ics_u: 2.927e+01
# It: 34900, Loss: 2.700e-02,  loss_bc1: 1.038e-02, loss_ics_u: 2.764e-03,  Loss_res: 7.189e-04 , Time: 34.34
# loss_bc1: 6.124e+01
# loss_ics_u: 2.764e+01
# loss_res: 3.667e-02
# It: 35000, Loss: 2.736e-02,  loss_bc1: 1.035e-02, loss_ics_u: 2.772e-03,  Loss_res: 1.115e-03 , Time: 35.04
# loss_bc1: 6.124e+01
# loss_ics_u: 2.764e+01
# loss_res: 3.667e-02
# It: 35100, Loss: 2.686e-02,  loss_bc1: 1.032e-02, loss_ics_u: 2.744e-03,  Loss_res: 7.304e-04 , Time: 35.05
# loss_bc1: 6.124e+01
# loss_ics_u: 2.744e+01
# loss_res: 3.667e-02
# It: 35200, Loss: 2.675e-02,  loss_bc1: 1.030e-02, loss_ics_u: 2.733e-03,  Loss_res: 6.899e-04 , Time: 37.21
# loss_bc1: 6.124e+01
# loss_ics_u: 2.733e+01
# loss_res: 3.667e-02
# It: 35300, Loss: 2.695e-02,  loss_bc1: 1.027e-02, loss_ics_u: 2.758e-03,  Loss_res: 8.940e-04 , Time: 35.87
# loss_bc1: 6.124e+01
# loss_ics_u: 2.733e+01
# loss_res: 3.667e-02
# It: 35400, Loss: 2.665e-02,  loss_bc1: 1.024e-02, loss_ics_u: 2.723e-03,  Loss_res: 7.230e-04 , Time: 36.95
# loss_bc1: 6.124e+01
# loss_ics_u: 2.723e+01
# loss_res: 3.667e-02
# It: 35500, Loss: 2.654e-02,  loss_bc1: 1.021e-02, loss_ics_u: 2.707e-03,  Loss_res: 6.973e-04 , Time: 39.15
# loss_bc1: 6.124e+01
# loss_ics_u: 2.707e+01
# loss_res: 3.667e-02
# It: 35600, Loss: 2.789e-02,  loss_bc1: 1.019e-02, loss_ics_u: 2.830e-03,  Loss_res: 1.844e-03 , Time: 34.87
# loss_bc1: 6.124e+01
# loss_ics_u: 2.707e+01
# loss_res: 3.667e-02
# It: 35700, Loss: 2.644e-02,  loss_bc1: 1.016e-02, loss_ics_u: 2.692e-03,  Loss_res: 7.417e-04 , Time: 33.86
# loss_bc1: 6.124e+01
# loss_ics_u: 2.692e+01
# loss_res: 3.667e-02
# It: 35800, Loss: 2.640e-02,  loss_bc1: 1.013e-02, loss_ics_u: 2.684e-03,  Loss_res: 7.786e-04 , Time: 36.01
# loss_bc1: 6.124e+01
# loss_ics_u: 2.684e+01
# loss_res: 3.667e-02
# It: 35900, Loss: 2.651e-02,  loss_bc1: 1.010e-02, loss_ics_u: 2.710e-03,  Loss_res: 8.819e-04 , Time: 42.53
# loss_bc1: 6.124e+01
# loss_ics_u: 2.684e+01
# loss_res: 3.667e-02
# It: 36000, Loss: 2.724e-02,  loss_bc1: 1.008e-02, loss_ics_u: 2.769e-03,  Loss_res: 1.550e-03 , Time: 49.38
# loss_bc1: 6.124e+01
# loss_ics_u: 2.684e+01
# loss_res: 3.667e-02
# It: 36100, Loss: 2.627e-02,  loss_bc1: 1.004e-02, loss_ics_u: 2.659e-03,  Loss_res: 8.606e-04 , Time: 49.31
# loss_bc1: 6.124e+01
# It: 37400, Loss: 2.520e-02,  loss_bc1: 9.675e-03, loss_ics_u: 2.554e-03,  Loss_res: 7.409e-04 , Time: 49.23
# loss_bc1: 6.124e+01
# loss_ics_u: 2.554e+01
# loss_res: 3.667e-02
# It: 37500, Loss: 2.511e-02,  loss_bc1: 9.646e-03, loss_ics_u: 2.543e-03,  Loss_res: 7.345e-04 , Time: 49.59
# loss_bc1: 6.124e+01
# loss_ics_u: 2.543e+01
# loss_res: 3.667e-02
# It: 37600, Loss: 2.503e-02,  loss_bc1: 9.618e-03, loss_ics_u: 2.535e-03,  Loss_res: 7.245e-04 , Time: 52.32
# loss_bc1: 6.124e+01
# loss_ics_u: 2.535e+01
# loss_res: 3.667e-02
# It: 37700, Loss: 2.608e-02,  loss_bc1: 9.593e-03, loss_ics_u: 2.619e-03,  Loss_res: 1.654e-03 , Time: 51.47
# loss_bc1: 6.124e+01
# loss_ics_u: 2.535e+01
# loss_res: 3.667e-02
# It: 37800, Loss: 2.489e-02,  loss_bc1: 9.561e-03, loss_ics_u: 2.519e-03,  Loss_res: 7.276e-04 , Time: 50.71
# loss_bc1: 6.124e+01
# loss_ics_u: 2.519e+01
# loss_res: 3.667e-02
# It: 37900, Loss: 2.482e-02,  loss_bc1: 9.532e-03, loss_ics_u: 2.512e-03,  Loss_res: 7.300e-04 , Time: 49.05
# loss_bc1: 6.124e+01
# loss_ics_u: 2.512e+01
# loss_res: 3.667e-02
# It: 38000, Loss: 2.481e-02,  loss_bc1: 9.503e-03, loss_ics_u: 2.507e-03,  Loss_res: 7.852e-04 , Time: 49.58
# loss_bc1: 6.124e+01
# loss_ics_u: 2.507e+01
# loss_res: 3.667e-02
# It: 38100, Loss: 2.476e-02,  loss_bc1: 9.475e-03, loss_ics_u: 2.500e-03,  Loss_res: 8.114e-04 , Time: 49.07
# loss_bc1: 6.124e+01
# loss_ics_u: 2.500e+01
# loss_res: 3.667e-02
# It: 38200, Loss: 2.461e-02,  loss_bc1: 9.447e-03, loss_ics_u: 2.489e-03,  Loss_res: 7.362e-04 , Time: 48.96
# loss_bc1: 6.124e+01
# loss_ics_u: 2.489e+01
# loss_res: 3.667e-02
# It: 38300, Loss: 2.455e-02,  loss_bc1: 9.418e-03, loss_ics_u: 2.482e-03,  Loss_res: 7.521e-04 , Time: 50.14
# loss_bc1: 6.124e+01
# loss_ics_u: 2.482e+01
# loss_res: 3.667e-02
# It: 38400, Loss: 2.477e-02,  loss_bc1: 9.393e-03, loss_ics_u: 2.525e-03,  Loss_res: 9.353e-04 , Time: 52.19
# loss_bc1: 6.124e+01
# loss_ics_u: 2.482e+01
# loss_res: 3.667e-02
# It: 38500, Loss: 2.441e-02,  loss_bc1: 9.360e-03, loss_ics_u: 2.467e-03,  Loss_res: 7.539e-04 , Time: 51.47
# loss_bc1: 6.124e+01
# loss_ics_u: 2.467e+01
# loss_res: 3.667e-02
# It: 38600, Loss: 2.432e-02,  loss_bc1: 9.330e-03, loss_ics_u: 2.459e-03,  Loss_res: 7.441e-04 , Time: 52.04
# loss_bc1: 6.124e+01
# loss_ics_u: 2.459e+01
# loss_res: 3.667e-02
# It: 38700, Loss: 2.427e-02,  loss_bc1: 9.300e-03, loss_ics_u: 2.453e-03,  Loss_res: 7.596e-04 , Time: 52.09
# loss_bc1: 6.124e+01
# loss_ics_u: 2.453e+01
# loss_res: 3.667e-02
# It: 38800, Loss: 2.459e-02,  loss_bc1: 9.272e-03, loss_ics_u: 2.470e-03,  Loss_res: 1.106e-03 , Time: 54.42
# loss_bc1: 6.124e+01
# loss_ics_u: 2.453e+01
# loss_res: 3.667e-02
# It: 38900, Loss: 2.424e-02,  loss_bc1: 9.240e-03, loss_ics_u: 2.453e-03,  Loss_res: 8.511e-04 , Time: 50.75
# loss_bc1: 6.124e+01
# loss_ics_u: 2.453e+01
# loss_res: 3.667e-02
# It: 39000, Loss: 2.408e-02,  loss_bc1: 9.210e-03, loss_ics_u: 2.431e-03,  Loss_res: 8.002e-04 , Time: 51.13
# loss_bc1: 6.124e+01
# loss_ics_u: 2.431e+01
# loss_res: 3.667e-02
# It: 39100, Loss: 2.400e-02,  loss_bc1: 9.178e-03, loss_ics_u: 2.427e-03,  Loss_res: 7.938e-04 , Time: 51.30
# loss_bc1: 6.124e+01
# loss_ics_u: 2.427e+01
# loss_res: 3.667e-02
# It: 39200, Loss: 2.391e-02,  loss_bc1: 9.147e-03, loss_ics_u: 2.419e-03,  Loss_res: 7.755e-04 , Time: 51.18
# loss_bc1: 6.124e+01
# loss_ics_u: 2.419e+01
# loss_res: 3.667e-02
# It: 39300, Loss: 2.381e-02,  loss_bc1: 9.115e-03, loss_ics_u: 2.409e-03,  Loss_res: 7.589e-04 , Time: 52.12
# loss_bc1: 6.124e+01
# loss_ics_u: 2.409e+01
# loss_res: 3.667e-02
# It: 39400, Loss: 2.374e-02,  loss_bc1: 9.084e-03, loss_ics_u: 2.401e-03,  Loss_res: 7.667e-04 , Time: 49.79
# loss_bc1: 6.124e+01
# loss_ics_u: 2.401e+01
# loss_res: 3.667e-02
# It: 39500, Loss: 2.365e-02,  loss_bc1: 9.052e-03, loss_ics_u: 2.393e-03,  Loss_res: 7.550e-04 , Time: 50.06
# loss_bc1: 6.124e+01
# loss_ics_u: 2.393e+01
# loss_res: 3.667e-02
# It: 39600, Loss: 2.367e-02,  loss_bc1: 9.020e-03, loss_ics_u: 2.395e-03,  Loss_res: 8.392e-04 , Time: 48.81
# loss_bc1: 6.124e+01
# loss_ics_u: 2.393e+01
# loss_res: 3.667e-02
# It: 39700, Loss: 2.349e-02,  loss_bc1: 8.988e-03, loss_ics_u: 2.379e-03,  Loss_res: 7.540e-04 , Time: 49.26
# loss_bc1: 6.124e+01
# loss_ics_u: 2.379e+01
# loss_res: 3.667e-02
# It: 39800, Loss: 2.341e-02,  loss_bc1: 8.955e-03, loss_ics_u: 2.372e-03,  Loss_res: 7.543e-04 , Time: 49.22
# loss_bc1: 6.124e+01
# loss_ics_u: 2.372e+01
# loss_res: 3.667e-02
# It: 39900, Loss: 2.333e-02,  loss_bc1: 8.923e-03, loss_ics_u: 2.364e-03,  Loss_res: 7.538e-04 , Time: 49.65
# loss_bc1: 6.124e+01
# loss_ics_u: 2.364e+01
# loss_res: 3.667e-02
# elapsed: 1.51e+04
# Relative L2 error_u: 2.70e-01
# Relative L2 error_r: 6.14e+00
#
#
# Method:  full_batch
#
# average of time_list: 15131.348989963531
# average of error_u_list: 0.26967001329865303

# %%
elapsed: 1.31e+03
Relative L2 error_u: 2.99e-01
Relative L2 error_r: 6.20e+01


Method:  mini_batch

average of time_list: 1313.1498460769653
average of error_u_list: 0.29926996990659016
# Out:
#   File "/tmp/ipykernel_16775/951167299.py", line 1
#     average of time_list: 1333.2788634300232
#              ^
# SyntaxError: invalid syntax

# %%
# Predictions
u_pred = model.predict_u(X_star)
r_pred = model.predict_r(X_star)
# Predictions

error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)
error_r = np.linalg.norm(r_star - r_pred, 2)# / np.linalg.norm(r_star, 2)

# print('elapsed: {:.2e}'.format(elapsed))

print('Relative L2 error_u: {:.2e}'.format(error_u))
print('Relative L2 error_r: {:.2e}'.format(error_r))
r_pred =r_pred.reshape(200,200)
# Out:
# Relative L2 error_u: 2.70e-01
# Relative L2 error_r: 6.14e+00

# %%
U_star = griddata(X_star, u_star.flatten(), (t, x), method='cubic')
r_star = griddata(X_star, r_star.flatten(), (t, x), method='cubic')
U_pred = griddata(X_star, u_pred.flatten(), (t, x), method='cubic')
# R_pred = griddata(X_star, r_pred.flatten(), (t, x), method='cubic')


plt.figure(figsize=(18, 9))
plt.subplot(2, 3, 1)
plt.pcolor(t, x, U_star, cmap='jet')
plt.colorbar()
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.title('Exact u(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 2)
plt.pcolor(t, x, U_pred, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Predicted u(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 3)
plt.pcolor(t, x, np.abs(U_star - U_pred), cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Absolute error')
plt.tight_layout()

plt.subplot(2, 3, 4)
plt.pcolor(t, x, r_star, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Exact r(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 5)
plt.pcolor(t, x, r_pred, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Predicted r(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 6)
plt.pcolor(t, x, np.abs(r_star - r_pred), cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Absolute error')
plt.tight_layout()
plt.show()

# %%
# Define PINN model
a = 0.5
c = 2

kernel_size = 300

# Domain boundaries
ics_coords = np.array([[0.0, 0.0],  [0.0, 1.0]])
bc1_coords = np.array([[0.0, 0.0],  [1.0, 0.0]])
bc2_coords = np.array([[0.0, 1.0],  [1.0, 1.0]])
dom_coords = np.array([[0.0, 0.0],  [1.0, 1.0]])

# Create initial conditions samplers
ics_sampler = Sampler(2, ics_coords, lambda x: u(x, a, c), name='Initial Condition 1')

# Create boundary conditions samplers
bc1 = Sampler(2, bc1_coords, lambda x: u(x, a, c), name='Dirichlet BC1')
bc2 = Sampler(2, bc2_coords, lambda x: u(x, a, c), name='Dirichlet BC2')
bcs_sampler = [bc1, bc2]

# Create residual sampler
res_sampler = Sampler(2, dom_coords, lambda x: r(x, a, c), name='Forcing')



nIter =40000
bcbatch_size = 500
ubatch_size = 5000
mbbatch_size = 300



# Define model
mode = 'M4'
layers = [2, 500, 500, 500, 1]


nn = 200
t = np.linspace(dom_coords[0, 0], dom_coords[1, 0], nn)[:, None]
x = np.linspace(dom_coords[0, 1], dom_coords[1, 1], nn)[:, None]
t, x = np.meshgrid(t, x)
X_star = np.hstack((t.flatten()[:, None], x.flatten()[:, None]))

u_star = u(X_star, a,c)
r_star = r(X_star, a, c)

iterations = 1
methods = [  "mini_batch"]

result_dict =  dict((mtd, []) for mtd in methods)

for mtd in methods:
    print("Method: ", mtd)
    time_list = []
    error_u_list = []
    
    for index in range(iterations):

        print("Epoch: ", str(index+1))

        # Create residual sampler

        [elapsed, error_u] = test_method(mtd , layers,  ics_sampler, bcs_sampler, res_sampler, c ,kernel_size , X_star , u_star , r_star , nIter ,mbbatch_size , bcbatch_size , ubatch_size )


        print('elapsed: {:.2e}'.format(elapsed))
        print('Relative L2 error_u: {:.2e}'.format(error_u))

        time_list.append(elapsed)
        error_u_list.append(error_u)

    print("\n\nMethod: ", mtd)
    print("\naverage of time_list:" , sum(time_list) / len(time_list) )
    print("average of error_u_list:" , sum(error_u_list) / len(error_u_list) )
    # print("average of error_r_list:" , sum(error_r_list) / len(error_r_list) )

    result_dict[mtd] = [time_list ,error_u_list]
    # scipy.io.savemat("M2_result_"+str(iterations)+"_"+mtd+".mat" , {'time_list':np.array(time_list),'error_u_list':np.array(error_u_list),'error_f_list':np.array(error_f_list)})

    scipy.io.savemat("./1DWave_database/"+mtd+"_1Dwave_"+mode+"_result_mb"+str(mbbatch_size)+"_fb"+str(ubatch_size)+"_bc"+str(mbbatch_size)+"_"+str(iterations)+".mat" , result_dict)

###############################################################################################################################################
# Out:
# Method:  mini_batch
# Epoch:  1
# mini_batch method is used
# It: 100, Loss: 7.738e-01,  loss_bc1: 6.568e-02, loss_ics_u: 3.210e-01,  Loss_res: 3.158e-04 , Time: 4.42
# loss_bc1: 6.568e+02
# loss_ics_u: 3.210e+03
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_15773/1267976146.py in <module>
#      61         # Create residual sampler
#      62
# ---> 63         [elapsed, error_u] = test_method(mtd , layers,  ics_sampler, bcs_sampler, res_sampler, c ,kernel_size , X_star , u_star , r_star , nIter ,mbbatch_size , bcbatch_size , ubatch_size )
#      64
#      65
#
# /tmp/ipykernel_15773/1247141941.py in test_method(method, layers, ics_sampler, bcs_sampler, res_sampler, c, kernel_size, X_star, u_star, r_star, nIter, mbbatch_size, bcbatch_size, ubatch_size)
#      16         elif method =="mini_batch":
#      17             print("mini_batch method is used")
# ---> 18             model.trainmb(nIter, mbbatch_size)
#      19         else:
#      20             print("unknown method!")
#
# /tmp/ipykernel_15773/1049498559.py in trainmb(self, nIter, batch_size, log_NTK, update_lam)
#     176
#     177             # Run the Tensorflow session to minimize the loss
# --> 178             self.sess.run(self.train_op, tf_dict)
#     179
#     180             # Print
#
# ~/anaconda3/envs/twoPhase/lib/python3.7/site-packages/tensorflow_core/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     954     try:
#     955       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 956                          run_metadata_ptr)
#     957       if run_metadata:
#     958         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/envs/twoPhase/lib/python3.7/site-packages/tensorflow_core/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1178     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1179       results = self._do_run(handle, final_targets, final_fetches,
# -> 1180                              feed_dict_tensor, options, run_metadata)
#    1181     else:
#    1182       results = []
#
# ~/anaconda3/envs/twoPhase/lib/python3.7/site-packages/tensorflow_core/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1357     if handle is None:
#    1358       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1359                            run_metadata)
#    1360     else:
#    1361       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/anaconda3/envs/twoPhase/lib/python3.7/site-packages/tensorflow_core/python/client/session.py in _do_call(self, fn, *args)
#    1363   def _do_call(self, fn, *args):
#    1364     try:
# -> 1365       return fn(*args)
#    1366     except errors.OpError as e:
#    1367       message = compat.as_text(e.message)
#
# ~/anaconda3/envs/twoPhase/lib/python3.7/site-packages/tensorflow_core/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1348       self._extend_graph()
#    1349       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
# -> 1350                                       target_list, run_metadata)
#    1351
#    1352     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~/anaconda3/envs/twoPhase/lib/python3.7/site-packages/tensorflow_core/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1441     return tf_session.TF_SessionRun_wrapper(self._session, options, feed_dict,
#    1442                                             fetch_list, target_list,
# -> 1443                                             run_metadata)
#    1444
#    1445   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
# Define PINN model
a = 0.5
c = 2

kernel_size = 300

# Domain boundaries
ics_coords = np.array([[0.0, 0.0],  [0.0, 1.0]])
bc1_coords = np.array([[0.0, 0.0],  [1.0, 0.0]])
bc2_coords = np.array([[0.0, 1.0],  [1.0, 1.0]])
dom_coords = np.array([[0.0, 0.0],  [1.0, 1.0]])

# Create initial conditions samplers
ics_sampler = Sampler(2, ics_coords, lambda x: u(x, a, c), name='Initial Condition 1')

# Create boundary conditions samplers
bc1 = Sampler(2, bc1_coords, lambda x: u(x, a, c), name='Dirichlet BC1')
bc2 = Sampler(2, bc2_coords, lambda x: u(x, a, c), name='Dirichlet BC2')
bcs_sampler = [bc1, bc2]

# Create residual sampler
res_sampler = Sampler(2, dom_coords, lambda x: r(x, a, c), name='Forcing')



nIter =40000
bcbatch_size = 500
ubatch_size = 5000
mbbatch_size = 300



# Define model
mode = 'M4'
layers = [2, 500, 500, 500, 1]


nn = 200
t = np.linspace(dom_coords[0, 0], dom_coords[1, 0], nn)[:, None]
x = np.linspace(dom_coords[0, 1], dom_coords[1, 1], nn)[:, None]
t, x = np.meshgrid(t, x)
X_star = np.hstack((t.flatten()[:, None], x.flatten()[:, None]))

u_star = u(X_star, a,c)
r_star = r(X_star, a, c)

iterations = 1
methods = [  "mini_batch"]

result_dict =  dict((mtd, []) for mtd in methods)

for mtd in methods:
    print("Method: ", mtd)
    time_list = []
    error_u_list = []
    
    for index in range(iterations):

        print("Epoch: ", str(index+1))

        # Create residual sampler

        [elapsed, error_u] = test_method(mtd , layers,  ics_sampler, bcs_sampler, res_sampler, c ,kernel_size , X_star , u_star , r_star , nIter ,mbbatch_size , bcbatch_size , ubatch_size )


        print('elapsed: {:.2e}'.format(elapsed))
        print('Relative L2 error_u: {:.2e}'.format(error_u))

        time_list.append(elapsed)
        error_u_list.append(error_u)

    print("\n\nMethod: ", mtd)
    print("\naverage of time_list:" , sum(time_list) / len(time_list) )
    print("average of error_u_list:" , sum(error_u_list) / len(error_u_list) )
    # print("average of error_r_list:" , sum(error_r_list) / len(error_r_list) )

    result_dict[mtd] = [time_list ,error_u_list]
    # scipy.io.savemat("M2_result_"+str(iterations)+"_"+mtd+".mat" , {'time_list':np.array(time_list),'error_u_list':np.array(error_u_list),'error_f_list':np.array(error_f_list)})

    scipy.io.savemat("./1DWave_database/"+mtd+"_1Dwave_"+mode+"_result_mb"+str(mbbatch_size)+"_fb"+str(ubatch_size)+"_bc"+str(mbbatch_size)+"_"+str(iterations)+".mat" , result_dict)

###############################################################################################################################################

# %%
import scipy.io

mode = 'M4'
mbbatch_size = 128
ubatch_size = 5000
bcbatch_size = 500
iterations = 40000

time_list = []
error_u_list = []
error_v_list = []
error_p_list = []
    
methods = ["mini_batch" , "full_batch"]
result_dict =  dict((mtd, []) for mtd in methods)

##Mini Batch
time_list = []
error_u_list = [ ]


result_dict["mini_batch"] = [time_list ,error_u_list]

print("\n\nMethod: ", mtd)
print("\naverage of time_list:" , sum(time_list) / len(time_list) )
print("average of error_u_list:" , sum(error_u_list) / len(error_u_list) )

##Full Batch
time_list = []
error_u_list = [ ]
error_v_list = []
error_p_list = []

result_dict["full_batch"] = [time_list ,error_u_list ,error_v_list ,  error_p_list]

print("\n\nMethod: ", mtd)
print("\naverage of time_list:" , sum(time_list) / len(time_list) )
print("average of error_u_list:" , sum(error_u_list) / len(error_u_list) )
print("average of error_v_list:" , sum(error_v_list) / len(error_v_list) )
print("average of error_p_list:" , sum(error_p_list) / len(error_p_list) )


scipy.io.savemat("./dataset/1DWave_database_"+mode+"_result_mb"+str(mbbatch_size)+"_fb"+str(ubatch_size)+"_"+str(bcbatch_size)+"_"+str(iterations)+".mat" , result_dict)

# %%
# Train model
itertaions = 80001
log_NTK = True # Compute and store NTK matrix during training
update_lam = True # Compute and update the loss weights using the NTK

# %% [markdown]
# **Training Loss**

# %%
loss_res = model.loss_res_log
loss_bcs = model.loss_bcs_log
loss_u_t_ics = model.loss_ut_ics_log

fig = plt.figure(figsize=(6, 5))
plt.plot(loss_res, label='$\mathcal{L}_{r}$')
plt.plot(loss_bcs, label='$\mathcal{L}_{u}$')
plt.plot(loss_u_t_ics, label='$\mathcal{L}_{u_t}$')
plt.yscale('log')
plt.xlabel('iterations')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# **Model Prediction**

# %%
# Predictions
u_pred = model.predict_u(X_star)
r_pred = model.predict_r(X_star)
error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)

print('Relative L2 error_u: %e' % (error_u))

# %%
U_star = griddata(X_star, u_star.flatten(), (t, x), method='cubic')
r_star = griddata(X_star, r_star.flatten(), (t, x), method='cubic')
U_pred = griddata(X_star, u_pred.flatten(), (t, x), method='cubic')
R_pred = griddata(X_star, r_pred.flatten(), (t, x), method='cubic')


plt.figure(figsize=(18, 9))
plt.subplot(2, 3, 1)
plt.pcolor(t, x, U_star, cmap='jet')
plt.colorbar()
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.title('Exact u(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 2)
plt.pcolor(t, x, U_pred, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Predicted u(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 3)
plt.pcolor(t, x, np.abs(U_star - U_pred), cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Absolute error')
plt.tight_layout()

plt.subplot(2, 3, 4)
plt.pcolor(t, x, r_star, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Exact r(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 5)
plt.pcolor(t, x, R_pred, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Predicted r(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 6)
plt.pcolor(t, x, np.abs(r_star - R_pred), cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Absolute error')
plt.tight_layout()
plt.show()

# %% [markdown]
# **NTK Eigenvalues**

# %%
# Create empty lists for storing the eigenvalues of NTK
lam_K_u_log = []
lam_K_ut_log = []
lam_K_r_log = []

# Restore the NTK
K_u_list = model.K_u_log
K_ut_list = model.K_ut_log
K_r_list = model.K_r_log

K_list = []
    
for k in range(len(K_u_list)):
    K_u = K_u_list[k]
    K_ut = K_ut_list[k]
    K_r = K_r_list[k]
    
    # Compute eigenvalues
    lam_K_u, _ = np.linalg.eig(K_u)
    lam_K_ut, _ = np.linalg.eig(K_ut)
    lam_K_r, _ = np.linalg.eig(K_r)
    # Sort in descresing order
    lam_K_u = np.sort(np.real(lam_K_u))[::-1]
    lam_K_ut = np.sort(np.real(lam_K_ut))[::-1]
    lam_K_r = np.sort(np.real(lam_K_r))[::-1]
    
    # Store eigenvalues
    lam_K_u_log.append(lam_K_u)
    lam_K_ut_log.append(lam_K_ut)
    lam_K_r_log.append(lam_K_r)

# %%
#  Eigenvalues of NTK
fig = plt.figure(figsize=(18, 5))
plt.subplot(1,3,1)

plt.plot(lam_K_u_log[0], label = '$n=0$')
plt.plot(lam_K_u_log[1], '--', label = '$n=10,000$')
plt.plot(lam_K_u_log[4], '--', label = '$n=40,000$')
plt.plot(lam_K_u_log[-1], '--', label = '$n=80,000$')
plt.xscale('log')
plt.yscale('log')

plt.title(r'Eigenvalues of ${K}_u$')

plt.subplot(1,3,2)
plt.plot(lam_K_ut_log[0], label = '$n=0$')
plt.plot(lam_K_ut_log[1], '--',label = '$n=10,000$')
plt.plot(lam_K_ut_log[4], '--', label = '$n=40,000$')
plt.plot(lam_K_ut_log[-1], '--', label = '$n=80,000$')
plt.xscale('log')
plt.yscale('log')
plt.title(r'Eigenvalues of ${K}_{u_t}$')

ax =plt.subplot(1,3,3)
plt.plot(lam_K_r_log[0], label = '$n=0$')
plt.plot(lam_K_r_log[1], '--', label = '$n=10,000$')
plt.plot(lam_K_r_log[4], '--', label = '$n=40,000$')
plt.plot(lam_K_r_log[-1], '--', label = '$n=80,000$')
plt.xscale('log')
plt.yscale('log')
plt.title(r'Eigenvalues of ${K}_{r}$')
handles, labels = ax.get_legend_handles_labels()
fig.legend(handles, labels, loc="upper left", bbox_to_anchor=(0.35, -0.02),
            borderaxespad=0, bbox_transform=fig.transFigure, ncol=4)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Evolution of NTK Weights**

# %%
if update_lam == True:

  lam_u_log = model.lam_u_log
  lam_ut_log = model.lam_ut_log
  lam_r_log = model.lam_r_log

# %%
fig = plt.figure(figsize=(6, 5))
plt.plot(lam_u_log, label='$\lambda_u$')
plt.plot(lam_ut_log, label='$\lambda_{u_t}$')
plt.plot(lam_r_log, label='$\lambda_{r}$')
plt.xlabel('iterations')
plt.ylabel('$\lambda$')
plt.yscale('log')
plt.legend( )
plt.tight_layout()
plt.show()
