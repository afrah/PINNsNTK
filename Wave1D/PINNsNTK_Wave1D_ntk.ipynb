# %%
import tensorflow as tf
from Compute_Jacobian import jacobian # Please download 'Compute_Jacobian.py' in the repository 
import numpy as np
import timeit
from scipy.interpolate import griddata
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import os



os.environ["KMP_WARNINGS"] = "FALSE" 
import timeit

import sys

import scipy
import scipy.io
import time

# %%
class Sampler:
    # Initialize the class
    def __init__(self, dim, coords, func, name = None):
        self.dim = dim
        self.coords = coords
        self.func = func
        self.name = name
    def sample(self, N):
        x = self.coords[0:1,:] + (self.coords[1:2,:]-self.coords[0:1,:])*np.random.rand(N, self.dim)
        y = self.func(x)
        return x, y

# Define the exact solution and its derivatives
def u(x, a, c):
    """
    :param x: x = (t, x)
    """
    t = x[:,0:1]
    x = x[:,1:2]
    return np.sin(np.pi * x) * np.cos(c * np.pi * t) + a * np.sin(2 * c * np.pi* x) * np.cos(4 * c  * np.pi * t)

def u_t(x,a, c):
    t = x[:,0:1]
    x = x[:,1:2]
    u_t = -  c * np.pi * np.sin(np.pi * x) * np.sin(c * np.pi * t) -  a * 4 * c * np.pi * np.sin(2 * c * np.pi* x) * np.sin(4 * c * np.pi * t)
    return u_t

def u_tt(x, a, c):
    t = x[:,0:1]
    x = x[:,1:2]
    u_tt = -(c * np.pi)**2 * np.sin( np.pi * x) * np.cos(c * np.pi * t) - a * (4 * c * np.pi)**2 *  np.sin(2 * c * np.pi* x) * np.cos(4 * c * np.pi * t)
    return u_tt

def u_xx(x, a, c):
    t = x[:,0:1]
    x = x[:,1:2]
    u_xx = - np.pi**2 * np.sin( np.pi * x) * np.cos(c * np.pi * t) -  a * (2 * c * np.pi)** 2 * np.sin(2 * c * np.pi* x) * np.cos(4 * c * np.pi * t)
    return  u_xx


def r(x, a, c):
    return u_tt(x, a, c) - c**2 * u_xx(x, a, c)

def operator(u, t, x, c, sigma_t=1.0, sigma_x=1.0):
    u_t = tf.gradients(u, t)[0] / sigma_t
    u_x = tf.gradients(u, x)[0] / sigma_x
    u_tt = tf.gradients(u_t, t)[0] / sigma_t
    u_xx = tf.gradients(u_x, x)[0] / sigma_x
    residual = u_tt - c**2 * u_xx
    return residual

# %%
class PINN:
    # Initialize the class
    def __init__(self, layers, operator, coll_sampler , ics_sampler, bcs_sampler, res_sampler, c, kernel_size , sess):
        # Normalization 
        X, _ = res_sampler.sample(np.int32(1e5))
        self.mu_X, self.sigma_X = X.mean(0), X.std(0)
        self.mu_t, self.sigma_t = self.mu_X[0], self.sigma_X[0]
        self.mu_x, self.sigma_x = self.mu_X[1], self.sigma_X[1]

        # Samplers
        self.operator = operator
        self.ics_sampler = ics_sampler
        self.bcs_sampler = bcs_sampler
        self.res_sampler = res_sampler
        self.coll_sampler = coll_sampler

        self.sess = sess
        # Initialize network weights and biases
        self.layers = layers
        self.weights, self.biases = self.initialize_NN(layers)
        

        # weights
        self.lam_coll_val = np.array(2.0)

        self.lam_u_val = np.array(1.0)
        self.lam_ut_val = np.array(1.0)
        self.lam_r_val = np.array(1.0)
      
        # Wave constant
        self.c = tf.constant(c, dtype=tf.float32)
        
        self.kernel_size = kernel_size # Size of the NTK matrix

        # Define Tensorflow session
        self.sess = tf.Session(config=tf.ConfigProto(log_device_placement=False))

        # Define placeholders and computational graph
        self.t_u_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_u_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_ics_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_ics_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.u_ics_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_coll_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_coll_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.u_coll_tf = tf.placeholder(tf.float32, shape=(None, 1))
    
        self.t_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_r_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_r_tf = tf.placeholder(tf.float32, shape=(None, 1))
        
        self.lam_u_tf = tf.placeholder(tf.float32, shape=self.lam_u_val.shape)
        self.lam_ut_tf = tf.placeholder(tf.float32, shape=self.lam_u_val.shape)
        self.lam_r_tf = tf.placeholder(tf.float32, shape=self.lam_u_val.shape)
        self.lam_coll_tf = tf.placeholder(tf.float32, shape=self.lam_coll_val.shape)


        # Define placeholders for NTK computation
        D1 = self.kernel_size    # boundary
        D2 = self.kernel_size    # ut   
        D3 = self.kernel_size    # residual  D1 = D3 = 3D2

        self.t_u_ntk_tf = tf.placeholder(tf.float32, shape=(D1, 1))
        self.x_u_ntk_tf = tf.placeholder(tf.float32, shape=(D1, 1))
        
        self.t_ut_ntk_tf = tf.placeholder(tf.float32, shape=(D2, 1))
        self.x_ut_ntk_tf = tf.placeholder(tf.float32, shape=(D2, 1))
        
        self.t_coll_ntk_tf = tf.placeholder(tf.float32, shape=(D2, 1))
        self.x_coll_ntk_tf = tf.placeholder(tf.float32, shape=(D2, 1))
        
        self.t_r_ntk_tf = tf.placeholder(tf.float32, shape=(D3, 1))
        self.x_r_ntk_tf = tf.placeholder(tf.float32, shape=(D3, 1))

        # Evaluate predictions

        self.u_coll_pred = self.net_u(self.t_coll_tf, self.x_coll_tf)

        self.u_ics_pred = self.net_u(self.t_ics_tf, self.x_ics_tf)
        self.u_t_ics_pred = self.net_u_t(self.t_ics_tf, self.x_ics_tf)
        self.u_bc1_pred = self.net_u(self.t_bc1_tf, self.x_bc1_tf)
        self.u_bc2_pred = self.net_u(self.t_bc2_tf, self.x_bc2_tf)

        self.u_pred = self.net_u(self.t_u_tf, self.x_u_tf)
        self.r_pred = self.net_r(self.t_r_tf, self.x_r_tf)
        
        # Define predictions for NTK computation
        self.u_ntk_pred = self.net_u(self.t_u_ntk_tf, self.x_u_ntk_tf)
        self.ut_ntk_pred = self.net_u_t(self.t_ut_ntk_tf, self.x_ut_ntk_tf)
        self.r_ntk_pred = self.net_r(self.t_r_ntk_tf, self.x_r_ntk_tf)
        self.coll_ntk_pred = self.net_u_t(self.t_coll_ntk_tf, self.x_coll_ntk_tf)

        # Boundary loss and Initial loss
        self.loss_ics_u = tf.reduce_mean(tf.square(self.u_ics_tf - self.u_ics_pred))
        self.loss_ics_u_t = tf.reduce_mean(tf.square(self.u_t_ics_pred))
        self.loss_bc1 = tf.reduce_mean(tf.square(self.u_bc1_pred))
        self.loss_bc2 = tf.reduce_mean(tf.square(self.u_bc2_pred))

        self.loss_coll_u = tf.reduce_mean(tf.square(self.u_coll_tf - self.u_coll_pred))

        self.loss_bcs = self.loss_ics_u + self.loss_bc1 + self.loss_bc2

        # Residual loss
        self.loss_res = tf.reduce_mean(tf.square(self.r_pred))

        # Total loss
        self.loss = self.lam_r_tf * self.loss_res +   self.lam_coll_tf * self.loss_coll_u + self.lam_u_tf * self.loss_bcs + self.lam_ut_tf * self.loss_ics_u_t 

        # Define optimizer with learning rate schedule
        self.global_step = tf.Variable(0, trainable=False)
        starter_learning_rate = 1e-3
        self.learning_rate = tf.train.exponential_decay(starter_learning_rate, self.global_step,
                                                        1000, 0.9, staircase=False)
        # Passing global_step to minimize() will increment it at each step.
        self.train_op = tf.train.AdamOptimizer(self.learning_rate).minimize(self.loss, global_step=self.global_step)

        # Logger
        self.loss_bcs_log = []
        self.loss_ut_ics_log = []
        self.loss_res_log = []
        self.saver = tf.train.Saver()
        
        # Compute the Jacobian for weights and biases in each hidden layer  
        self.J_u = self.compute_jacobian(self.u_ntk_pred)
        self.J_ut = self.compute_jacobian(self.ut_ntk_pred)
        self.J_r = self.compute_jacobian(self.r_ntk_pred)
        self.J_coll = self.compute_jacobian(self.coll_ntk_pred)

        self.K_u = self.compute_ntk(self.J_u, D1, self.J_u, D1)
        self.K_ut = self.compute_ntk(self.J_ut, D2, self.J_ut, D2)
        self.K_r = self.compute_ntk(self.J_r, D3, self.J_r, D3)
        self.K_coll = self.compute_ntk(self.J_coll, D2, self.J_coll, D2)

        # NTK logger 
        self.K_u_log = []
        self.K_ut_log = []
        self.K_r_log = []
        
        # weights logger
        self.lam_u_log = []
        self.lam_ut_log = []
        self.lam_r_log = []
        
         # Initialize Tensorflow variables
        init = tf.global_variables_initializer()
        self.sess.run(init)

    # Initialize network weights and biases using Xavier initialization
    def initialize_NN(self, layers):
        # Xavier initialization
        def xavier_init(size):
            in_dim = size[0]
            out_dim = size[1]
            xavier_stddev = 1. / np.sqrt((in_dim + out_dim) / 2.)
            return tf.Variable(tf.random.normal([in_dim, out_dim], dtype=tf.float32) * xavier_stddev,
                               dtype=tf.float32)

        weights = []
        biases = []
        num_layers = len(layers)
        for l in range(0, num_layers - 1):
            W = xavier_init(size=[layers[l], layers[l + 1]])
            b = tf.Variable(tf.zeros([1, layers[l + 1]], dtype=tf.float32), dtype=tf.float32)
            weights.append(W)
            biases.append(b)
        return weights, biases

    # Evaluates the forward pass
    def forward_pass(self, H, layers, weights, biases):
        num_layers = len(layers)
        for l in range(0, num_layers - 2):
            W = weights[l]
            b = biases[l]
            H = tf.tanh(tf.add(tf.matmul(H, W), b))
        W = weights[-1]
        b = biases[-1]
        H = tf.add(tf.matmul(H, W), b)
        return H

    # Forward pass for u
    def net_u(self, t, x):
        u = self.forward_pass(tf.concat([t, x], 1),
                              self.layers,
                              self.weights,
                              self.biases)
        return u

    # Forward pass for du/dt
    def net_u_t(self, t, x):
        u_t = tf.gradients(self.net_u(t, x), t)[0] / self.sigma_t
        return u_t

    # Forward pass for the residual
    def net_r(self, t, x):
        u = self.net_u(t, x)
        residual = self.operator(u, t, x,
                                 self.c,
                                 self.sigma_t,
                                 self.sigma_x)
        return residual
    
    
    # Compute Jacobian for each weights and biases in each layer and retrun a list 
    def compute_jacobian(self, f):
        J_list =[]
        L = len(self.weights)    
        for i in range(L):
            J_w = jacobian(f, self.weights[i])
            J_list.append(J_w)
     
        for i in range(L):
            J_b = jacobian(f, self.biases[i])
            J_list.append(J_b)
        return J_list
    
    # Compute the empirical NTK = J J^T
    def compute_ntk(self, J1_list, D1, J2_list, D2):

        N = len(J1_list)
        
        Ker = tf.zeros((D1,D2))
        for k in range(N):
            J1 = tf.reshape(J1_list[k], shape=(D1,-1))
            J2 = tf.reshape(J2_list[k], shape=(D2,-1))
            
            K = tf.matmul(J1, tf.transpose(J2))
            Ker = Ker + K
        return Ker

    def fetch_minibatch(self, sampler, N):
        X, Y = sampler.sample(N)
        X = (X - self.mu_X) / self.sigma_X
        return X, Y

        # Trains the model by minimizing the MSE loss

    def trainmb(self, nIter=10000, batch_size=128, log_NTK=False, update_lam=False):

        start_time = timeit.default_timer()
        for it in range(nIter):
            # Fetch boundary mini-batches
            X_ics_batch, u_ics_batch = self.fetch_minibatch(self.ics_sampler, batch_size // 3)
            X_bc1_batch, _ = self.fetch_minibatch(self.bcs_sampler[0], batch_size // 3)
            X_bc2_batch, _ = self.fetch_minibatch(self.bcs_sampler[1], batch_size // 3)
            X_coll_batch, u_coll_batch = self.fetch_minibatch(self.coll_sampler, batch_size )

            # Fetch residual mini-batch
            X_res_batch, _ = self.fetch_minibatch(self.res_sampler, batch_size)
            # Define a dictionary for associating placeholders with data
            tf_dict = {self.t_ics_tf: X_ics_batch[:, 0:1], 
                       self.x_ics_tf: X_ics_batch[:, 1:2],
                       self.u_ics_tf: u_ics_batch,
                        self.t_coll_tf: X_coll_batch[:, 0:1], 
                        self.x_coll_tf: X_coll_batch[:, 1:2],
                        self.u_coll_tf: u_coll_batch,
                       self.t_bc1_tf: X_bc1_batch[:, 0:1],
                         self.x_bc1_tf: X_bc1_batch[:, 1:2],
                       self.t_bc2_tf: X_bc2_batch[:, 0:1], 
                       self.x_bc2_tf: X_bc2_batch[:, 1:2],
                       self.t_r_tf: X_res_batch[:, 0:1], 
                       self.x_r_tf: X_res_batch[:, 1:2],
                       self.lam_u_tf: self.lam_u_val,
                       self.lam_ut_tf: self.lam_ut_val,
                       self.lam_r_tf: self.lam_r_val,
                        self.lam_coll_tf:self.lam_coll_val
                       }

            # Run the Tensorflow session to minimize the loss
            self.sess.run(self.train_op, tf_dict)

            # Print
            if it % 100 == 0:
                elapsed = timeit.default_timer() - start_time

                loss_value = self.sess.run(self.loss, tf_dict)
                loss_bcs_value = self.sess.run(self.loss_bcs, tf_dict)
                loss_ics_ut_value = self.sess.run(self.loss_ics_u_t, tf_dict)
                loss_res_value = self.sess.run(self.loss_res, tf_dict)
                loss_coll_u= self.sess.run(self.loss_coll_u, tf_dict)

                # # Store losses
                # self.loss_bcs_log.append(loss_bcs_value)
                # self.loss_res_log.append(loss_res_value)
                # self.loss_ut_ics_log.append(loss_ics_ut_value)

                print('It: %d, Loss: %.3e, Loss_res: %.3e,  Loss_bcs: %.3e, Loss_ut_ics: %.3e , loss_coll_u: %.3e, Time: %.2f' %(it, loss_value, loss_res_value, loss_bcs_value, loss_ics_ut_value, loss_coll_u , elapsed))
                

            
          
                if it % 100 == 0:
                        print("Compute NTK...")
 
                        X_bc_batch = np.vstack([X_ics_batch, X_bc1_batch, X_bc2_batch])
                        X_ics_batch, u_ics_batch = self.fetch_minibatch(self.ics_sampler, batch_size )
                        X_coll_batch, u_coll_batch = self.fetch_minibatch(self.coll_sampler, batch_size )

                        tf_dict = {self.t_u_ntk_tf: X_bc_batch[:,0:1], 
                                   self.x_u_ntk_tf: X_bc_batch[:, 1:2],
                                   self.t_ut_ntk_tf: X_ics_batch[:,0:1], 
                                   self.x_ut_ntk_tf: X_ics_batch[:, 1:2],
                                   self.t_coll_ntk_tf: X_coll_batch[:,0:1], 
                                   self.x_coll_ntk_tf: X_coll_batch[:, 1:2],
                                   self.t_r_ntk_tf: X_res_batch[:,0:1], 
                                   self.x_r_ntk_tf: X_res_batch[:, 1:2]
                                   }
                        
                        K_u_value, K_ut_value, K_r_value, K_coll_value =  self.sess.run([self.K_u, self.K_ut, self.K_r, self.K_coll], tf_dict)
                        
                        trace_K = np.trace(K_u_value) + np.trace(K_ut_value) +  np.trace(K_r_value) +  np.trace(K_coll_value)

                        # # Store NTK matrices
                        # self.K_u_log.append(K_u_value)
                        # self.K_ut_log.append(K_ut_value)
                        # self.K_r_log.append(K_r_value)
                        
                        # if update_lam:

                        self.lam_u_val = trace_K / np.trace(K_u_value)
                        self.lam_ut_val = trace_K /np.trace(K_ut_value)
                        self.lam_r_val = trace_K / np.trace(K_r_value)
                        self.lam_coll_val = trace_K /np.trace(K_coll_value)

                        print('lambda_u: {:.3e}'.format(self.lam_u_val))
                        print('lambda_ut: {:.3e}'.format(self.lam_ut_val))
                        print('lambda_r: {:.3e}'.format(self.lam_r_val))
                        print('lam_coll_val: {:.3e}'.format(self.lam_coll_val))

                sys.stdout.flush()
                start_time = timeit.default_timer()

                        
    def train(self, nIter , bcbatch_size , ubatch_size):

        start_time = timeit.default_timer()

        # Fetch boundary mini-batches
        X_ics_batch, u_ics_batch = self.fetch_minibatch(self.ics_sampler, bcbatch_size)
        X_bc1_batch, _ = self.fetch_minibatch(self.bcs_sampler[0], bcbatch_size )
        X_bc2_batch, _ = self.fetch_minibatch(self.bcs_sampler[1], bcbatch_size )
        
        # Fetch residual mini-batch
        X_res_batch, _ = self.fetch_minibatch(self.res_sampler, ubatch_size)
        # print("inside trainmb: " , X_res_batch.shape)
        # Define a dictionary for associating placeholders with data
        tf_dict = {self.t_ics_tf: X_ics_batch[:, 0:1], self.x_ics_tf: X_ics_batch[:, 1:2],
                    self.u_ics_tf: u_ics_batch,
                    self.t_bc1_tf: X_bc1_batch[:, 0:1], self.x_bc1_tf: X_bc1_batch[:, 1:2],
                    self.t_bc2_tf: X_bc2_batch[:, 0:1], self.x_bc2_tf: X_bc2_batch[:, 1:2],
                    self.t_r_tf: X_res_batch[:, 0:1], self.x_r_tf: X_res_batch[:, 1:2],
                    self.lam_u_tf: self.lam_u_val,
                    self.lam_ut_tf: self.lam_ut_val,
                    self.lam_r_tf: self.lam_r_val
                    }
        
        # Fetch boundary mini-batches
        X_ics_batch, u_ics_batch = self.fetch_minibatch(self.ics_sampler, self.kernel_size // 3)
        X_bc1_batch, _ = self.fetch_minibatch(self.bcs_sampler[0], self.kernel_size // 3)
        X_bc2_batch, _ = self.fetch_minibatch(self.bcs_sampler[1], self.kernel_size // 3)

        X_bc_batch = np.vstack([X_ics_batch, X_bc1_batch, X_bc2_batch])
        X_res_batch, _ = self.fetch_minibatch(self.res_sampler, self.kernel_size)
        X_ics_batch, u_ics_batch = self.fetch_minibatch(self.ics_sampler, self.kernel_size )

        ntk_dict = {self.t_u_ntk_tf: X_bc_batch[:,0:1], self.x_u_ntk_tf: X_bc_batch[:, 1:2],
                                   self.t_ut_ntk_tf: X_ics_batch[:,0:1], self.x_ut_ntk_tf: X_ics_batch[:, 1:2],
                                   self.t_r_ntk_tf: X_res_batch[:,0:1], self.x_r_ntk_tf: X_res_batch[:, 1:2]}
        for it in range(nIter):

            # Run the Tensorflow session to minimize the loss
            self.sess.run(self.train_op, tf_dict)

            # Print
            if it % 100 == 0:
                elapsed = timeit.default_timer() - start_time

                loss_value = self.sess.run(self.loss, tf_dict)
                loss_bcs_value = self.sess.run(self.loss_bcs, tf_dict)
                loss_ics_ut_value = self.sess.run(self.loss_ics_u_t, tf_dict)
                loss_res_value = self.sess.run(self.loss_res, tf_dict)

                # # Store losses
                # self.loss_bcs_log.append(loss_bcs_value)
                # self.loss_res_log.append(loss_res_value)
                # self.loss_ut_ics_log.append(loss_ics_ut_value)

                print('It: %d, Loss: %.3e, Loss_res: %.3e,  Loss_bcs: %.3e, Loss_ut_ics: %.3e,, Time: %.2f' %(it, loss_value, loss_res_value, loss_bcs_value, loss_ics_ut_value, elapsed))
                
                print('lambda_u: {:.3e}'.format(self.lam_u_val))
                print('lambda_ut: {:.3e}'.format(self.lam_ut_val))
                print('lambda_r: {:.3e}'.format(self.lam_r_val))
                sys.stdout.flush()
                start_time = timeit.default_timer()
            
          
                if it % 100 == 0:
                        print("Compute NTK...")

                    # # Fetch boundary mini-batches
                    #     X_ics_batch, u_ics_batch = self.fetch_minibatch(self.ics_sampler, self.kernel_size // 3)
                    #     X_bc1_batch, _ = self.fetch_minibatch(self.bcs_sampler[0], self.kernel_size // 3)
                    #     X_bc2_batch, _ = self.fetch_minibatch(self.bcs_sampler[1], self.kernel_size // 3)
                        
                        # Fetch residual mini-batch
                
                        
                        K_u_value, K_ut_value, K_r_value =  self.sess.run([self.K_u, self.K_ut, self.K_r], ntk_dict)
                        
                        trace_K = np.trace(K_u_value) + np.trace(K_ut_value) +  np.trace(K_r_value)

                        # # Store NTK matrices
                        # self.K_u_log.append(K_u_value)
                        # self.K_ut_log.append(K_ut_value)
                        # self.K_r_log.append(K_r_value)
                        
                        # if update_lam:

                        self.lam_u_val = trace_K / np.trace(K_u_value)
                        self.lam_ut_val = trace_K /np.trace(K_ut_value)
                        self.lam_r_val = trace_K / np.trace(K_r_value)

                        #   # Store NTK weights
                        #   self.lam_u_log.append(self.lam_u_val)
                        #   self.lam_ut_log.append(self.lam_ut_val)
                        #   self.lam_r_log.append(self.lam_r_val)
                        


    # Evaluates predictions at test points
    def predict_u(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.t_u_tf: X_star[:, 0:1], self.x_u_tf: X_star[:, 1:2]}
        u_star = self.sess.run(self.u_pred, tf_dict)
        return u_star

        # Evaluates predictions at test points

    def predict_r(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.t_r_tf: X_star[:, 0:1], self.x_r_tf: X_star[:, 1:2]}
        r_star = self.sess.run(self.r_pred, tf_dict)
        return r_star
    
   ###############################################################################################################################################
   # 
   # ###############################################################################################################################################
   # 
   # ###############################################################################################################################################
   # 
   #

# %%
#test_method(mtd , layers,  X_u, Y_u, X_r, Y_r ,  X_star , u_star , r_star  , nIter ,batch_size , bcbatch_size , ubatch_size)
def test_method(method , layers, coll_sampler,  ics_sampler, bcs_sampler, res_sampler, c ,kernel_size , X_star , u_star , r_star , nIter ,mbbatch_size , bcbatch_size , ubatch_size ):

    tf.reset_default_graph()
    gpu_options = tf.GPUOptions(visible_device_list="0")
    with tf.Session(config=tf.ConfigProto(gpu_options=gpu_options,allow_soft_placement=False, log_device_placement=False)) as sess:
        # sess.run(init)

        model = PINN(layers, operator, coll_sampler , ics_sampler, bcs_sampler, res_sampler, c, kernel_size , sess)
        # Train model
        start_time = time.time()

        if method =="full_batch":
            print("full_batch method is used")
            model.train(nIter  , bcbatch_size , ubatch_size  )
        elif method =="mini_batch":
            print("mini_batch method is used")
            model.trainmb(nIter, mbbatch_size)
        else:
            print("unknown method!")
        elapsed = time.time() - start_time

        # Predictions
        u_pred = model.predict_u(X_star)
        r_pred = model.predict_r(X_star)
        # Predictions

        sess.close()   

    error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)

    print('elapsed: {:.2e}'.format(elapsed))

    print('Relative L2 error_u: {:.2e}'.format(error_u))


    return [elapsed, error_u  ]

###############################################################################################################################################

# %%
# Define PINN model
a = 0.5
c = 2

kernel_size = 300

# Domain boundaries
ics_coords = np.array([[0.0, 0.0],  [0.0, 1.0]])
bc1_coords = np.array([[0.0, 0.0],  [1.0, 0.0]])
bc2_coords = np.array([[0.0, 1.0],  [1.0, 1.0]])
dom_coords = np.array([[0.0, 0.0],  [1.0, 1.0]])

# Create initial conditions samplers
ics_sampler = Sampler(2, ics_coords, lambda x: u(x, a, c), name='Initial Condition 1')

# Create boundary conditions samplers
bc1 = Sampler(2, bc1_coords, lambda x: u(x, a, c), name='Dirichlet BC1')
bc2 = Sampler(2, bc2_coords, lambda x: u(x, a, c), name='Dirichlet BC2')
bcs_sampler = [bc1, bc2]

# Create residual sampler
res_sampler = Sampler(2, dom_coords, lambda x: r(x, a, c), name='Forcing')
coll_sampler = Sampler(2, dom_coords, lambda x: u(x, a, c), name='coll')



nIter =40000
bcbatch_size = 500
ubatch_size = 5000
mbbatch_size = 300



# Define model
mode = 'M3'
layers = [2, 500, 500, 500, 1]


nn = 200
t = np.linspace(dom_coords[0, 0], dom_coords[1, 0], nn)[:, None]
x = np.linspace(dom_coords[0, 1], dom_coords[1, 1], nn)[:, None]
t, x = np.meshgrid(t, x)
X_star = np.hstack((t.flatten()[:, None], x.flatten()[:, None]))

u_star = u(X_star, a,c)
r_star = r(X_star, a, c)

iterations = 1
methods = [  "mini_batch"]

result_dict =  dict((mtd, []) for mtd in methods)

for mtd in methods:
    print("Method: ", mtd)
    time_list = []
    error_u_list = []
    
    for index in range(iterations):

        print("Epoch: ", str(index+1))

        # Create residual sampler

        [elapsed, error_u] = test_method(mtd , layers, coll_sampler ,  ics_sampler, bcs_sampler, res_sampler, c ,kernel_size , X_star , u_star , r_star , nIter ,mbbatch_size , bcbatch_size , ubatch_size )


        print('elapsed: {:.2e}'.format(elapsed))
        print('Relative L2 error_u: {:.2e}'.format(error_u))

        time_list.append(elapsed)
        error_u_list.append(error_u)

    print("\n\nMethod: ", mtd)
    print("\naverage of time_list:" , sum(time_list) / len(time_list) )
    print("average of error_u_list:" , sum(error_u_list) / len(error_u_list) )
    # print("average of error_r_list:" , sum(error_r_list) / len(error_r_list) )

    result_dict[mtd] = [time_list ,error_u_list]
    # scipy.io.savemat("M2_result_"+str(iterations)+"_"+mtd+".mat" , {'time_list':np.array(time_list),'error_u_list':np.array(error_u_list),'error_f_list':np.array(error_f_list)})

    scipy.io.savemat("./1DWave_database/"+mtd+"_1Dwave_"+mode+"_result_mb"+str(mbbatch_size)+"_fb"+str(ubatch_size)+"_bc"+str(mbbatch_size)+"_"+str(iterations)+".mat" , result_dict)

###############################################################################################################################################
# Out:
# Method:  mini_batch
# Epoch:  1
# WARNING:tensorflow:From /tmp/ipykernel_14634/1828311678.py:4: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_14634/1828311678.py:5: The name tf.GPUOptions is deprecated. Please use tf.compat.v1.GPUOptions instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_14634/1828311678.py:6: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_14634/1828311678.py:6: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_14634/2672418608.py:39: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# 2023-11-28 13:21:09.255770: I tensorflow/core/platform/cpu_feature_guard.cc:145] This TensorFlow binary is optimized with Intel(R) MKL-DNN to use the following CPU instructions in performance critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in non-MKL-DNN operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-28 13:21:09.275682: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2899885000 Hz
# 2023-11-28 13:21:09.276140: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5603259892a0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-11-28 13:21:09.276155: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2023-11-28 13:21:09.276780: I tensorflow/core/common_runtime/process_util.cc:115] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# WARNING:tensorflow:From /tmp/ipykernel_14634/2672418608.py:119: The name tf.train.exponential_decay is deprecated. Please use tf.compat.v1.train.exponential_decay instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_14634/2672418608.py:122: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_14634/2672418608.py:128: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_14634/2672418608.py:152: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# mini_batch method is used
# It: 0, Loss: 2.980e+01, Loss_res: 3.901e+00,  Loss_bcs: 7.133e+00, Loss_ut_ics: 1.461e+01 , loss_coll_u: 2.078e+00, Time: 1.83
# Compute NTK...
# lambda_u: 1.145e+01
# lambda_ut: 5.001e+00
# lambda_r: 2.166e+00
# lam_coll_val: 3.985e+00
# It: 100, Loss: 5.854e+00, Loss_res: 1.935e-03,  Loss_bcs: 3.614e-01, Loss_ut_ics: 3.421e-02 , loss_coll_u: 3.870e-01, Time: 17.00
# Compute NTK...
# lambda_u: 9.759e+00
# lambda_ut: 3.476e+00
# lambda_r: 3.643e+00
# lam_coll_val: 2.982e+00
# It: 200, Loss: 4.339e+00, Loss_res: 4.313e-03,  Loss_bcs: 3.269e-01, Loss_ut_ics: 4.078e-02 , loss_coll_u: 3.322e-01, Time: 10.67
# Compute NTK...
# lambda_u: 1.346e+01
# lambda_ut: 4.045e+00
# lambda_r: 2.554e+00
# lam_coll_val: 3.486e+00
# It: 300, Loss: 5.110e+00, Loss_res: 7.192e-02,  Loss_bcs: 2.807e-01, Loss_ut_ics: 4.941e-02 , loss_coll_u: 2.725e-01, Time: 11.28
# Compute NTK...
# lambda_u: 3.100e+01
# lambda_ut: 7.403e+00
# lambda_r: 1.440e+00
# lam_coll_val: 7.222e+00
# It: 400, Loss: 7.355e+00, Loss_res: 1.255e-01,  Loss_bcs: 1.936e-01, Loss_ut_ics: 2.490e-02 , loss_coll_u: 1.367e-01, Time: 11.14
# Compute NTK...
# lambda_u: 8.469e+01
# lambda_ut: 1.320e+01
# lambda_r: 1.175e+00
# lam_coll_val: 1.632e+01
# It: 500, Loss: 1.746e+01, Loss_res: 3.730e-01,  Loss_bcs: 1.705e-01, Loss_ut_ics: 3.104e-02 , loss_coll_u: 1.327e-01, Time: 11.22
# Compute NTK...
# lambda_u: 1.163e+02
# lambda_ut: 1.407e+01
# lambda_r: 1.148e+00
# lam_coll_val: 2.036e+01
# It: 600, Loss: 2.142e+01, Loss_res: 6.838e-01,  Loss_bcs: 1.578e-01, Loss_ut_ics: 2.026e-02 , loss_coll_u: 9.842e-02, Time: 10.96
# Compute NTK...
# lambda_u: 1.319e+02
# lambda_ut: 1.318e+01
# lambda_r: 1.146e+00
# lam_coll_val: 2.270e+01
# It: 700, Loss: 2.344e+01, Loss_res: 9.169e-01,  Loss_bcs: 1.378e-01, Loss_ut_ics: 1.025e-01 , loss_coll_u: 1.261e-01, Time: 10.98
# Compute NTK...
# lambda_u: 1.458e+02
# lambda_ut: 1.325e+01
# lambda_r: 1.143e+00
# lam_coll_val: 2.330e+01
# It: 800, Loss: 2.382e+01, Loss_res: 5.567e-01,  Loss_bcs: 1.365e-01, Loss_ut_ics: 5.173e-02 , loss_coll_u: 1.115e-01, Time: 11.10
# Compute NTK...
# lambda_u: 1.995e+02
# lambda_ut: 1.402e+01
# lambda_r: 1.046e+00
# lam_coll_val: 6.686e+01
# It: 7500, Loss: 1.539e+01, Loss_res: 4.596e+00,  Loss_bcs: 9.393e-04, Loss_ut_ics: 1.383e-01 , loss_coll_u: 2.300e-03, Time: 10.84
# Compute NTK...
# lambda_u: 5.859e+03
# lambda_ut: 3.506e+01
# lambda_r: 1.046e+00
# lam_coll_val: 6.502e+01
# It: 7600, Loss: 1.046e+01, Loss_res: 3.185e+00,  Loss_bcs: 1.048e-03, Loss_ut_ics: 2.410e-02 , loss_coll_u: 2.127e-03, Time: 11.00
# Compute NTK...
# lambda_u: 5.323e+03
# lambda_ut: 3.105e+01
# lambda_r: 1.051e+00
# lam_coll_val: 6.085e+01
# It: 7700, Loss: 7.347e+00, Loss_res: 2.374e+00,  Loss_bcs: 7.795e-04, Loss_ut_ics: 1.784e-02 , loss_coll_u: 2.440e-03, Time: 11.06
# Compute NTK...
# lambda_u: 5.448e+03
# lambda_ut: 3.337e+01
# lambda_r: 1.048e+00
# lam_coll_val: 6.392e+01
# It: 7800, Loss: 8.962e+00, Loss_res: 2.515e+00,  Loss_bcs: 1.100e-03, Loss_ut_ics: 5.633e-03 , loss_coll_u: 2.283e-03, Time: 14.03
# Compute NTK...
# lambda_u: 5.290e+03
# lambda_ut: 2.834e+01
# lambda_r: 1.055e+00
# lam_coll_val: 6.037e+01
# It: 7900, Loss: 1.033e+01, Loss_res: 2.652e+00,  Loss_bcs: 9.770e-04, Loss_ut_ics: 7.898e-02 , loss_coll_u: 2.096e-03, Time: 10.77
# Compute NTK...
# lambda_u: 5.756e+03
# lambda_ut: 3.239e+01
# lambda_r: 1.050e+00
# lam_coll_val: 6.014e+01
# It: 8000, Loss: 7.890e+00, Loss_res: 2.204e+00,  Loss_bcs: 8.510e-04, Loss_ut_ics: 1.794e-02 , loss_coll_u: 1.607e-03, Time: 12.12
# Compute NTK...
# lambda_u: 5.835e+03
# lambda_ut: 3.277e+01
# lambda_r: 1.049e+00
# lam_coll_val: 6.338e+01
# It: 8100, Loss: 7.559e+00, Loss_res: 2.239e+00,  Loss_bcs: 7.928e-04, Loss_ut_ics: 1.387e-02 , loss_coll_u: 2.053e-03, Time: 11.79
# Compute NTK...
# lambda_u: 5.371e+03
# lambda_ut: 3.210e+01
# lambda_r: 1.049e+00
# lam_coll_val: 6.574e+01
# It: 8200, Loss: 6.056e+00, Loss_res: 1.506e+00,  Loss_bcs: 7.898e-04, Loss_ut_ics: 4.555e-03 , loss_coll_u: 1.350e-03, Time: 11.82
# Compute NTK...
# lambda_u: 5.533e+03
# lambda_ut: 2.957e+01
# lambda_r: 1.052e+00
# lam_coll_val: 6.615e+01
# It: 8300, Loss: 6.789e+00, Loss_res: 1.759e+00,  Loss_bcs: 8.266e-04, Loss_ut_ics: 8.732e-03 , loss_coll_u: 1.621e-03, Time: 11.12
# Compute NTK...
# lambda_u: 5.666e+03
# lambda_ut: 3.309e+01
# lambda_r: 1.049e+00
# lam_coll_val: 6.130e+01
# It: 8400, Loss: 6.940e+00, Loss_res: 1.936e+00,  Loss_bcs: 7.394e-04, Loss_ut_ics: 1.880e-02 , loss_coll_u: 1.593e-03, Time: 12.61
# Compute NTK...
# lambda_u: 5.921e+03
# lambda_ut: 3.224e+01
# lambda_r: 1.048e+00
# lam_coll_val: 6.798e+01
# It: 8500, Loss: 7.643e+00, Loss_res: 1.611e+00,  Loss_bcs: 7.167e-04, Loss_ut_ics: 4.986e-02 , loss_coll_u: 1.516e-03, Time: 10.66
# Compute NTK...
# lambda_u: 5.501e+03
# lambda_ut: 3.016e+01
# lambda_r: 1.052e+00
# lam_coll_val: 6.129e+01
# It: 8600, Loss: 5.421e+00, Loss_res: 1.264e+00,  Loss_bcs: 6.824e-04, Loss_ut_ics: 8.423e-03 , loss_coll_u: 1.355e-03, Time: 10.85
# Compute NTK...
# lambda_u: 5.527e+03
# lambda_ut: 3.325e+01
# lambda_r: 1.049e+00
# lam_coll_val: 5.919e+01
# It: 8700, Loss: 5.529e+00, Loss_res: 1.698e+00,  Loss_bcs: 5.662e-04, Loss_ut_ics: 1.701e-02 , loss_coll_u: 8.898e-04, Time: 10.92
# Compute NTK...
# lambda_u: 5.590e+03
# lambda_ut: 3.185e+01
# lambda_r: 1.049e+00
# lam_coll_val: 6.479e+01
# It: 8800, Loss: 4.918e+00, Loss_res: 1.150e+00,  Loss_bcs: 5.767e-04, Loss_ut_ics: 1.344e-02 , loss_coll_u: 9.191e-04, Time: 10.56
# Compute NTK...
# lambda_u: 5.731e+03
# lambda_ut: 3.216e+01
# lambda_r: 1.050e+00
# lam_coll_val: 6.221e+01
# It: 8900, Loss: 1.342e+01, Loss_res: 2.388e+00,  Loss_bcs: 5.939e-04, Loss_ut_ics: 2.315e-01 , loss_coll_u: 1.001e-03, Time: 12.38
# Compute NTK...
# lambda_u: 6.388e+03
# lambda_ut: 3.540e+01
# lambda_r: 1.046e+00
# lam_coll_val: 6.437e+01
# It: 9000, Loss: 3.831e+00, Loss_res: 1.157e+00,  Loss_bcs: 3.358e-04, Loss_ut_ics: 1.182e-02 , loss_coll_u: 8.823e-04, Time: 10.90
# Compute NTK...
# lambda_u: 5.482e+03
# lambda_ut: 3.126e+01
# lambda_r: 1.052e+00
# lam_coll_val: 5.927e+01
# It: 9100, Loss: 3.986e+00, Loss_res: 7.933e-01,  Loss_bcs: 3.744e-04, Loss_ut_ics: 3.373e-02 , loss_coll_u: 7.700e-04, Time: 11.12
# Compute NTK...
# lambda_u: 5.768e+03
# lambda_ut: 3.364e+01
# lambda_r: 1.049e+00
# lam_coll_val: 5.915e+01
# It: 9200, Loss: 3.580e+00, Loss_res: 8.644e-01,  Loss_bcs: 4.343e-04, Loss_ut_ics: 3.540e-03 , loss_coll_u: 8.317e-04, Time: 10.88
# Compute NTK...
# lambda_u: 5.747e+03
# lambda_ut: 3.167e+01
# lambda_r: 1.050e+00
# lam_coll_val: 6.353e+01
# It: 9300, Loss: 4.023e+00, Loss_res: 1.045e+00,  Loss_bcs: 4.896e-04, Loss_ut_ics: 2.176e-03 , loss_coll_u: 6.776e-04, Time: 10.90
# Compute NTK...
# lambda_u: 5.709e+03
# lambda_ut: 3.209e+01
# lambda_r: 1.050e+00
# lam_coll_val: 6.038e+01
# It: 9400, Loss: 2.756e+00, Loss_res: 8.366e-01,  Loss_bcs: 3.127e-04, Loss_ut_ics: 1.624e-03 , loss_coll_u: 6.690e-04, Time: 12.35
# Compute NTK...
# lambda_u: 5.508e+03
# lambda_ut: 3.107e+01
# lambda_r: 1.053e+00
# lam_coll_val: 5.665e+01
# It: 9500, Loss: 3.138e+00, Loss_res: 7.034e-01,  Loss_bcs: 4.190e-04, Loss_ut_ics: 1.834e-03 , loss_coll_u: 5.704e-04, Time: 13.65
# Compute NTK...
# lambda_u: 5.862e+03
# lambda_ut: 3.351e+01
# lambda_r: 1.048e+00
# lam_coll_val: 6.310e+01
# It: 9600, Loss: 3.095e+00, Loss_res: 6.349e-01,  Loss_bcs: 3.105e-04, Loss_ut_ics: 1.728e-02 , loss_coll_u: 4.764e-04, Time: 13.01
# Compute NTK...
# lambda_u: 5.746e+03
# lambda_ut: 3.286e+01
# lambda_r: 1.049e+00
# lam_coll_val: 6.150e+01
# It: 9700, Loss: 2.504e+00, Loss_res: 7.557e-01,  Loss_bcs: 2.676e-04, Loss_ut_ics: 4.291e-03 , loss_coll_u: 5.232e-04, Time: 13.00
# Compute NTK...
# lambda_u: 5.329e+03
# lambda_ut: 3.070e+01
# lambda_r: 1.053e+00
# lam_coll_val: 5.595e+01
# It: 9800, Loss: 2.318e+00, Loss_res: 5.937e-01,  Loss_bcs: 2.856e-04, Loss_ut_ics: 4.901e-03 , loss_coll_u: 3.712e-04, Time: 12.81
# Compute NTK...
# lambda_u: 6.203e+03
# lambda_ut: 3.563e+01
# lambda_r: 1.045e+00
# lam_coll_val: 6.845e+01
# It: 9900, Loss: 4.059e+00, Loss_res: 8.739e-01,  Loss_bcs: 2.261e-04, Loss_ut_ics: 4.829e-02 , loss_coll_u: 3.306e-04, Time: 12.98
# Compute NTK...
# lambda_u: 5.938e+03
# lambda_ut: 3.394e+01
# lambda_r: 1.048e+00
# lam_coll_val: 6.231e+01
# It: 10000, Loss: 2.361e+00, Loss_res: 8.799e-01,  Loss_bcs: 1.913e-04, Loss_ut_ics: 8.384e-03 , loss_coll_u: 3.021e-04, Time: 11.94
# Compute NTK...
# lambda_u: 6.293e+03
# lambda_ut: 3.536e+01
# lambda_r: 1.046e+00
# lam_coll_val: 6.458e+01
# It: 10100, Loss: 1.594e+00, Loss_res: 4.649e-01,  Loss_bcs: 1.673e-04, Loss_ut_ics: 1.147e-03 , loss_coll_u: 2.336e-04, Time: 12.80
# Compute NTK...
# lambda_u: 5.868e+03
# lambda_ut: 3.315e+01
# lambda_r: 1.049e+00
# lam_coll_val: 6.226e+01
# It: 10200, Loss: 1.373e+00, Loss_res: 3.581e-01,  Loss_bcs: 1.582e-04, Loss_ut_ics: 1.519e-03 , loss_coll_u: 2.975e-04, Time: 11.36
# Compute NTK...
# lambda_u: 5.961e+03
# lambda_ut: 3.378e+01
# lambda_r: 1.047e+00
# lam_coll_val: 6.620e+01
# It: 10300, Loss: 1.889e+00, Loss_res: 5.662e-01,  Loss_bcs: 1.867e-04, Loss_ut_ics: 4.958e-03 , loss_coll_u: 2.461e-04, Time: 10.71
# Compute NTK...
# lambda_u: 6.001e+03
# lambda_ut: 3.628e+01
# lambda_r: 1.045e+00
# lam_coll_val: 6.395e+01
# It: 10400, Loss: 3.309e+00, Loss_res: 1.273e+00,  Loss_bcs: 1.941e-04, Loss_ut_ics: 2.186e-02 , loss_coll_u: 3.155e-04, Time: 10.66
# Compute NTK...
# lambda_u: 5.903e+03
# lambda_ut: 3.348e+01
# lambda_r: 1.049e+00
# lam_coll_val: 5.867e+01
# It: 10500, Loss: 2.013e+00, Loss_res: 4.324e-01,  Loss_bcs: 1.617e-04, Loss_ut_ics: 1.768e-02 , loss_coll_u: 2.229e-04, Time: 11.60
# Compute NTK...
# lambda_u: 6.303e+03
# lambda_ut: 3.687e+01
# lambda_r: 1.046e+00
# lam_coll_val: 6.031e+01
# It: 10600, Loss: 1.617e+00, Loss_res: 4.826e-01,  Loss_bcs: 1.595e-04, Loss_ut_ics: 2.532e-03 , loss_coll_u: 2.245e-04, Time: 11.00
# Compute NTK...
# lambda_u: 5.958e+03
# lambda_ut: 3.262e+01
# lambda_r: 1.048e+00
# lam_coll_val: 6.677e+01
# It: 10700, Loss: 1.647e+00, Loss_res: 4.289e-01,  Loss_bcs: 1.628e-04, Loss_ut_ics: 6.515e-03 , loss_coll_u: 2.255e-04, Time: 10.96
# Compute NTK...
# lambda_u: 6.005e+03
# lambda_ut: 3.292e+01
# lambda_r: 1.048e+00
# lam_coll_val: 6.402e+01
# It: 10800, Loss: 2.227e+00, Loss_res: 5.165e-01,  Loss_bcs: 2.079e-04, Loss_ut_ics: 1.289e-02 , loss_coll_u: 2.010e-04, Time: 11.08
# Compute NTK...
# lambda_u: 5.843e+03
# lambda_ut: 3.223e+01
# lambda_r: 1.051e+00
# lam_coll_val: 5.811e+01
# It: 10900, Loss: 1.186e+00, Loss_res: 3.373e-01,  Loss_bcs: 1.380e-04, Loss_ut_ics: 4.628e-04 , loss_coll_u: 1.827e-04, Time: 11.43
# Compute NTK...
# lambda_u: 6.050e+03
# lambda_ut: 3.456e+01
# lambda_r: 1.047e+00
# lam_coll_val: 6.167e+01
# It: 11000, Loss: 1.769e+00, Loss_res: 6.521e-01,  Loss_bcs: 1.603e-04, Loss_ut_ics: 3.051e-03 , loss_coll_u: 1.767e-04, Time: 11.36
# Compute NTK...
# lambda_u: 6.063e+03
# lambda_ut: 3.493e+01
# lambda_r: 1.047e+00
# lam_coll_val: 6.328e+01
# It: 11100, Loss: 1.356e+00, Loss_res: 3.415e-01,  Loss_bcs: 1.101e-04, Loss_ut_ics: 9.110e-03 , loss_coll_u: 2.078e-04, Time: 11.52
# Compute NTK...
# lambda_u: 6.023e+03
# lambda_ut: 3.537e+01
# lambda_r: 1.046e+00
# lam_coll_val: 6.257e+01
# It: 11200, Loss: 2.253e+00, Loss_res: 7.605e-01,  Loss_bcs: 1.801e-04, Loss_ut_ics: 1.023e-02 , loss_coll_u: 1.723e-04, Time: 11.40
# Compute NTK...
# lambda_u: 6.074e+03
# lambda_ut: 3.420e+01
# lambda_r: 1.047e+00
# lam_coll_val: 6.474e+01
# It: 11300, Loss: 2.331e+00, Loss_res: 5.849e-01,  Loss_bcs: 1.904e-04, Loss_ut_ics: 1.613e-02 , loss_coll_u: 1.529e-04, Time: 10.96
# Compute NTK...
# lambda_u: 5.751e+03
# lambda_ut: 3.256e+01
# lambda_r: 1.051e+00
# lam_coll_val: 5.761e+01
# It: 11400, Loss: 1.551e+00, Loss_res: 3.919e-01,  Loss_bcs: 1.825e-04, Loss_ut_ics: 2.466e-03 , loss_coll_u: 1.684e-04, Time: 11.11
# Compute NTK...
# lambda_u: 5.716e+03
# lambda_ut: 3.359e+01
# lambda_r: 1.049e+00
# lam_coll_val: 6.091e+01
# It: 11500, Loss: 1.005e+00, Loss_res: 2.280e-01,  Loss_bcs: 1.097e-04, Loss_ut_ics: 3.921e-03 , loss_coll_u: 1.183e-04, Time: 11.34
# Compute NTK...
# lambda_u: 6.190e+03
# lambda_ut: 3.389e+01
# lambda_r: 1.047e+00
# lam_coll_val: 6.592e+01
# It: 11600, Loss: 1.363e+00, Loss_res: 2.481e-01,  Loss_bcs: 1.553e-04, Loss_ut_ics: 3.887e-03 , loss_coll_u: 1.511e-04, Time: 11.06
# Compute NTK...
# lambda_u: 5.806e+03
# lambda_ut: 3.579e+01
# lambda_r: 1.046e+00
# lam_coll_val: 6.250e+01
# It: 11700, Loss: 1.319e+00, Loss_res: 3.777e-01,  Loss_bcs: 9.367e-05, Loss_ut_ics: 1.040e-02 , loss_coll_u: 1.237e-04, Time: 11.65
# Compute NTK...
# lambda_u: 5.666e+03
# lambda_ut: 3.258e+01
# lambda_r: 1.050e+00
# lam_coll_val: 5.894e+01
# It: 11800, Loss: 1.037e+00, Loss_res: 2.854e-01,  Loss_bcs: 1.173e-04, Loss_ut_ics: 2.025e-03 , loss_coll_u: 1.122e-04, Time: 11.83
# Compute NTK...
# lambda_u: 6.145e+03
# lambda_ut: 3.400e+01
# lambda_r: 1.047e+00
# lam_coll_val: 6.534e+01
# It: 11900, Loss: 1.518e+00, Loss_res: 3.331e-01,  Loss_bcs: 1.192e-04, Loss_ut_ics: 1.254e-02 , loss_coll_u: 1.639e-04, Time: 16.10
# Compute NTK...
# lambda_u: 5.657e+03
# lambda_ut: 3.117e+01
# lambda_r: 1.052e+00
# lam_coll_val: 5.894e+01
# It: 12000, Loss: 8.984e-01, Loss_res: 2.969e-01,  Loss_bcs: 8.802e-05, Loss_ut_ics: 2.561e-03 , loss_coll_u: 1.409e-04, Time: 18.79
# Compute NTK...
# lambda_u: 6.112e+03
# lambda_ut: 3.333e+01
# lambda_r: 1.048e+00
# lam_coll_val: 6.358e+01
# It: 12100, Loss: 1.027e+00, Loss_res: 3.049e-01,  Loss_bcs: 1.001e-04, Loss_ut_ics: 2.595e-03 , loss_coll_u: 1.416e-04, Time: 19.78
# Compute NTK...
# lambda_u: 6.003e+03
# lambda_ut: 3.419e+01
# lambda_r: 1.048e+00
# lam_coll_val: 6.061e+01
# It: 12200, Loss: 9.978e-01, Loss_res: 1.686e-01,  Loss_bcs: 1.095e-04, Loss_ut_ics: 4.558e-03 , loss_coll_u: 1.313e-04, Time: 19.42
# Compute NTK...
# lambda_u: 6.051e+03
# lambda_ut: 3.325e+01
# lambda_r: 1.050e+00
# lam_coll_val: 5.647e+01
# It: 12300, Loss: 7.775e-01, Loss_res: 1.886e-01,  Loss_bcs: 7.540e-05, Loss_ut_ics: 3.574e-03 , loss_coll_u: 7.657e-05, Time: 19.57
# Compute NTK...
# lambda_u: 5.649e+03
# lambda_ut: 3.181e+01
# lambda_r: 1.052e+00
# lam_coll_val: 5.547e+01
# It: 12400, Loss: 7.160e-01, Loss_res: 1.999e-01,  Loss_bcs: 6.337e-05, Loss_ut_ics: 4.465e-03 , loss_coll_u: 1.013e-04, Time: 19.27
# Compute NTK...
# lambda_u: 5.744e+03
# lambda_ut: 3.249e+01
# lambda_r: 1.050e+00
# lam_coll_val: 6.116e+01
# It: 12500, Loss: 1.334e+00, Loss_res: 5.894e-01,  Loss_bcs: 1.007e-04, Loss_ut_ics: 4.001e-03 , loss_coll_u: 1.176e-04, Time: 19.57
# Compute NTK...
# lambda_u: 5.780e+03
# lambda_ut: 3.079e+01
# lambda_r: 1.052e+00
# lam_coll_val: 6.039e+01
# It: 12600, Loss: 8.649e-01, Loss_res: 3.012e-01,  Loss_bcs: 8.748e-05, Loss_ut_ics: 1.167e-03 , loss_coll_u: 1.103e-04, Time: 19.85
# Compute NTK...
# lambda_u: 6.043e+03
# lambda_ut: 3.287e+01
# lambda_r: 1.048e+00
# lam_coll_val: 6
+01
# lambda_r: 1.047e+00
# lam_coll_val: 6.153e+01
# It: 13600, Loss: 6.000e-01, Loss_res: 1.690e-01,  Loss_bcs: 6.560e-05, Loss_ut_ics: 8.091e-04 , loss_coll_u: 7.697e-05, Time: 18.79
# Compute NTK...
# lambda_u: 5.940e+03
# lambda_ut: 3.564e+01
# lambda_r: 1.046e+00
# lam_coll_val: 6.253e+01
# It: 13700, Loss: 5.870e-01, Loss_res: 1.332e-01,  Loss_bcs: 7.245e-05, Loss_ut_ics: 3.473e-04 , loss_coll_u: 7.784e-05, Time: 18.91
# Compute NTK...
# lambda_u: 5.805e+03
# lambda_ut: 3.210e+01
# lambda_r: 1.051e+00
# lam_coll_val: 5.933e+01
# It: 13800, Loss: 6.967e-01, Loss_res: 2.331e-01,  Loss_bcs: 6.382e-05, Loss_ut_ics: 2.400e-03 , loss_coll_u: 7.205e-05, Time: 18.66
# Compute NTK...
# lambda_u: 5.938e+03
# lambda_ut: 3.278e+01
# lambda_r: 1.049e+00
# lam_coll_val: 6.149e+01
# It: 13900, Loss: 4.774e-01, Loss_res: 1.590e-01,  Loss_bcs: 4.666e-05, Loss_ut_ics: 9.057e-04 , loss_coll_u: 6.305e-05, Time: 18.76
# Compute NTK...
# lambda_u: 5.619e+03
# lambda_ut: 3.249e+01
# lambda_r: 1.051e+00
# lam_coll_val: 5.632e+01
# It: 14000, Loss: 1.025e+00, Loss_res: 3.463e-01,  Loss_bcs: 1.044e-04, Loss_ut_ics: 2.175e-03 , loss_coll_u: 6.913e-05, Time: 18.65
# Compute NTK...
# lambda_u: 6.071e+03
# lambda_ut: 3.386e+01
# lambda_r: 1.049e+00
# lam_coll_val: 5.943e+01
# It: 14100, Loss: 1.239e+00, Loss_res: 3.061e-01,  Loss_bcs: 6.921e-05, Loss_ut_ics: 1.457e-02 , loss_coll_u: 7.073e-05, Time: 18.81
# Compute NTK...
# lambda_u: 6.042e+03
# lambda_ut: 3.373e+01
# lambda_r: 1.048e+00
# lam_coll_val: 6.308e+01
# It: 14200, Loss: 6.836e-01, Loss_res: 2.376e-01,  Loss_bcs: 4.971e-05, Loss_ut_ics: 3.838e-03 , loss_coll_u: 7.594e-05, Time: 18.81
# Compute NTK...
# lambda_u: 5.793e+03
# lambda_ut: 3.251e+01
# lambda_r: 1.049e+00
# lam_coll_val: 6.195e+01
# It: 14300, Loss: 1.176e+00, Loss_res: 2.905e-01,  Loss_bcs: 1.032e-04, Loss_ut_ics: 8.267e-03 , loss_coll_u: 7.710e-05, Time: 18.84
# Compute NTK...
# lambda_u: 5.546e+03
# lambda_ut: 3.076e+01
# lambda_r: 1.053e+00
# lam_coll_val: 5.724e+01
# It: 14400, Loss: 7.487e-01, Loss_res: 1.991e-01,  Loss_bcs: 6.433e-05, Loss_ut_ics: 5.829e-03 , loss_coll_u: 5.250e-05, Time: 18.86
# Compute NTK...
# lambda_u: 5.853e+03
# lambda_ut: 3.390e+01
# lambda_r: 1.048e+00
# lam_coll_val: 6.263e+01
# It: 14500, Loss: 6.242e-01, Loss_res: 2.425e-01,  Loss_bcs: 4.847e-05, Loss_ut_ics: 2.429e-03 , loss_coll_u: 6.580e-05, Time: 18.71
# Compute NTK...
# lambda_u: 6.062e+03
# lambda_ut: 3.567e+01
# lambda_r: 1.045e+00
# lam_coll_val: 6.656e+01
# It: 14600, Loss: 6.411e-01, Loss_res: 1.724e-01,  Loss_bcs: 6.691e-05, Loss_ut_ics: 1.424e-03 , loss_coll_u: 6.804e-05, Time: 18.87
# Compute NTK...
# lambda_u: 5.649e+03
# lambda_ut: 3.521e+01
# lambda_r: 1.047e+00
# lam_coll_val: 6.101e+01
# It: 14700, Loss: 2.307e+00, Loss_res: 2.561e-01,  Loss_bcs: 6.671e-05, Loss_ut_ics: 4.706e-02 , loss_coll_u: 7.780e-05, Time: 18.86
# Compute NTK...
# lambda_u: 5.717e+03
# lambda_ut: 3.226e+01
# lambda_r: 1.050e+00
# lam_coll_val: 6.242e+01
# It: 14800, Loss: 4.292e-01, Loss_res: 1.403e-01,  Loss_bcs: 4.340e-05, Loss_ut_ics: 9.288e-04 , loss_coll_u: 6.255e-05, Time: 18.83
# Compute NTK...
# lambda_u: 5.793e+03
# lambda_ut: 3.552e+01
# lambda_r: 1.047e+00
# lam_coll_val: 5.919e+01
# It: 14900, Loss: 3.382e-01, Loss_res: 9.152e-02,  Loss_bcs: 3.642e-05, Loss_ut_ics: 7.845e-04 , loss_coll_u: 5.865e-05, Time: 19.46
# Compute NTK...
# lambda_u: 5.981e+03
# lambda_ut: 3.404e+01
# lambda_r: 1.048e+00
# lam_coll_val: 5.986e+01
# It: 15000, Loss: 5.384e-01, Loss_res: 1.556e-01,  Loss_bcs: 5.050e-05, Loss_ut_ics: 2.038e-03 , loss_coll_u: 6.249e-05, Time: 19.14
# Compute NTK...
# lambda_u: 5.734e+03
# lambda_ut: 3.275e+01
# lambda_r: 1.050e+00
# lam_coll_val: 5.954e+01
# It: 15100, Loss: 5.007e-01, Loss_res: 1.356e-01,  Loss_bcs: 5.158e-05, Loss_ut_ics: 1.778e-03 , loss_coll_u: 7.473e-05, Time: 19.67
# Compute NTK...
# lambda_u: 5.831e+03
# lambda_ut: 3.258e+01
# lambda_r: 1.050e+00
# lam_coll_val: 5.938e+01
# It: 15200, Loss: 9.483e-01, Loss_res: 2.360e-01,  Loss_bcs: 6.111e-05, Loss_ut_ics: 1.046e-02 , loss_coll_u: 5.753e-05, Time: 23.81
# Compute NTK...
# lambda_u: 5.966e+03
# lambda_ut: 3.462e+01
# lambda_r: 1.048e+00
# lam_coll_val: 5.956e+01
# It: 15300, Loss: 4.669e-01, Loss_res: 1.319e-01,  Loss_bcs: 3.908e-05, Loss_ut_ics: 2.663e-03 , loss_coll_u: 5.650e-05, Time: 19.85
# Compute NTK...
# lambda_u: 5.817e+03
# lambda_ut: 3.269e+01
# lambda_r: 1.049e+00
# lam_coll_val: 6.119e+01
# It: 15400, Loss: 4.516e-01, Loss_res: 1.192e-01,  Loss_bcs: 5.361e-05, Loss_ut_ics: 3.299e-04 , loss_coll_u: 6.378e-05, Time: 19.43
# Compute NTK...
# lambda_u: 5.796e+03
# lambda_ut: 3.113e+01
# lambda_r: 1.051e+00
# lam_coll_val: 6.199e+01
# It: 15500, Loss: 5.208e-01, Loss_res: 1.068e-01,  Loss_bcs: 6.692e-05, Loss_ut_ics: 5.760e-04 , loss_coll_u: 4.583e-05, Time: 19.29
# Compute NTK...
# lambda_u: 5.877e+03
# lambda_ut: 3.335e+01
# lambda_r: 1.048e+00
# lam_coll_val: 6.239e+01
# It: 15600, Loss: 5.848e-01, Loss_res: 1.505e-01,  Loss_bcs: 6.746e-05, Loss_ut_ics: 7.829e-04 , loss_coll_u: 7.138e-05, Time: 19.21
# Compute NTK...
# lambda_u: 5.528e+03
# lambda_ut: 3.041e+01
# lambda_r: 1.054e+00
# lam_coll_val: 5.637e+01
# It: 15700, Loss: 4.973e-01, Loss_res: 1.060e-01,  Loss_bcs: 6.012e-05, Loss_ut_ics: 1.657e-03 , loss_coll_u: 5.208e-05, Time: 19.04
# Compute NTK...
# lambda_u: 5.833e+03
# lambda_ut: 3.324e+01
# lambda_r: 1.050e+00
# lam_coll_val: 5.720e+01
# It: 15800, Loss: 8.769e-01, Loss_res: 1.569e-01,  Loss_bcs: 1.115e-04, Loss_ut_ics: 1.749e-03 , loss_coll_u: 5.871e-05, Time: 19.42
# Compute NTK...
# lambda_u: 5.774e+03
# lambda_ut: 3.414e+01
# lambda_r: 1.049e+00
# lam_coll_val: 5.948e+01
# It: 15900, Loss: 5.682e-01, Loss_res: 2.118e-01,  Loss_bcs: 5.073e-05, Loss_ut_ics: 1.464e-03 , loss_coll_u: 5.538e-05, Time: 19.14
# Compute NTK...
# lambda_u: 5.940e+03
# lambda_ut: 3.454e+01
# lambda_r: 1.048e+00
# lam_coll_val: 5.848e+01
# It: 16000, Loss: 5.242e-01, Loss_res: 1.346e-01,  Loss_bcs: 4.973e-05, Loss_ut_ics: 2.466e-03 , loss_coll_u: 4.220e-05, Time: 19.36
# Compute NTK...
# lambda_u: 5.974e+03
# lambda_ut: 3.446e+01
# lambda_r: 1.048e+00
# lam_coll_val: 6.024e+01
# It: 16100, Loss: 3.734e-01, Loss_res: 1.146e-01,  Loss_bcs: 3.865e-05, Loss_ut_ics: 5.608e-04 , loss_coll_u: 5.067e-05, Time: 19.35
# Compute NTK...
# lambda_u: 5.999e+03
# lambda_ut: 3.433e+01
# lambda_r: 1.047e+00
# lam_coll_val: 6.267e+01
# It: 16200, Loss: 4.125e-01, Loss_res: 9.839e-02,  Loss_bcs: 4.053e-05, Loss_ut_ics: 1.847e-03 , loss_coll_u: 4.737e-05, Time: 19.63
# Compute NTK...
# lambda_u: 5.848e+03
# lambda_ut: 3.413e+01
# lambda_r: 1.048e+00
# lam_coll_val: 6.083e+01
# It: 16300, Loss: 6.400e-01, Loss_res: 1.274e-01,  Loss_bcs: 6.156e-05, Loss_ut_ics: 4.196e-03 , loss_coll_u: 5.340e-05, Time: 19.55
# Compute NTK...
# lambda_u: 5.994e+03
# lambda_ut: 3.212e+01
# lambda_r: 1.050e+00
# lam_coll_val: 6.030e+01
# It: 16400, Loss: 3.040e-01, Loss_res: 1.167e-01,  Loss_bcs: 2.709e-05, Loss_ut_ics: 5.127e-04 , loss_coll_u: 4.158e-05, Time: 19.27
# Compute NTK...
# lambda_u: 5.703e+03
# lambda_ut: 3.384e+01
# lambda_r: 1.048e+00
# lam_coll_val: 6.219e+01
# It: 16500, Loss: 6.762e-01, Loss_res: 1.154e-01,  Loss_bcs: 5.981e-05, Loss_ut_ics: 6.245e-03 , loss_coll_u: 4.594e-05, Time: 19.50
# Compute NTK...
# lambda_u: 5.649e+03
# lambda_ut: 3.217e+01
# lambda_r: 1.050e+00
# lam_coll_val: 6.034e+01
# It: 16600, Loss: 2.932e-01, Loss_res: 7.811e-02,  Loss_bcs: 3.398e-05, Loss_ut_ics: 5.164e-04 , loss_coll_u: 4.374e-05, Time: 19.53
# Compute NTK...
# lambda_u: 5.320e+03
# lambda_ut: 2.872e+01
# lambda_r: 1.056e+00
# lam_coll_val: 5.527e+01
# It: 16700, Loss: 3.441e-01, Loss_res: 1.467e-01,  Loss_bcs: 3.226e-05, Loss_ut_ics: 5.417e-04 , loss_coll_u: 3.586e-05, Time: 19.19
# Compute NTK...
# lambda_u: 5.688e+03
# lambda_ut: 3.457e+01
# lambda_r: 1.048e+00
# lam_coll_val: 6.087e+01
# It: 16800, Loss: 3.852e-01, Loss_res: 1.506e-01,  Loss_bcs: 3.317e-05, Loss_ut_ics: 1.044e-03 , loss_coll_u: 4.492e-05, Time: 18.87
# Compute NTK...
# lambda_u: 5.818e+03
# lambda_ut: 3.501e+01
# lambda_r: 1.048e+00
# lam_coll_val: 5.871e+01
# It: 16900, Loss: 5.095e-01, Loss_res: 1.849e-01,  Loss_bcs: 3.698e-05, Loss_ut_ics: 2.806e-03 , loss_coll_u: 4.005e-05, Time: 18.94
# Compute NTK...
# lambda_u: 5.596e+03
# lambda_ut: 3.256e+01
# lambda_r: 1.050e+00
# lam_coll_val: 5.904e+01
# It: 17000, Loss: 2.665e-01, Loss_res: 1.042e-01,  Loss_bcs: 2.568e-05, Loss_ut_ics: 3.402e-04 , loss_coll_u: 3.892e-05, Time: 19.00
# Compute NTK...
# lambda_u: 5.858e+03
# lambda_ut: 3.085e+01
# lambda_r: 1.052e+00
# lam_coll_val: 5.952e+01
# It: 17100, Loss: 3.153e-01, Loss_res: 6.457e-02,  Loss_bcs: 3.902e-05, Loss_ut_ics: 5.359e-04 , loss_coll_u: 3.847e-05, Time: 19.02
# Compute NTK...
# lambda_u: 5.868e+03
# lambda_ut: 3.359e+01
# lambda_r: 1.048e+00
# lam_coll_val: 6.214e+01
# It: 17200, Loss: 5.255e-01, Loss_res: 2.208e-01,  Loss_bcs: 4.136e-05, Loss_ut_ics: 1.457e-03 , loss_coll_u: 3.966e-05, Time: 19.00
# Compute NTK...
# lambda_u: 5.447e+03
# lambda_ut: 2.973e+01
# lambda_r: 1.054e+00
# lam_coll_val: 5.624e+01
# It: 17300, Loss: 2.536e-01, Loss_res: 6.709e-02,  Loss_bcs: 3.129e-05, Loss_ut_ics: 3.428e-04 , loss_coll_u: 3.924e-05, Time: 18.97
# Compute NTK...
# lambda_u: 5.729e+03
# lambda_ut: 3.255e+01
# lambda_r: 1.050e+00
# lam_coll_val: 5.830e+01
# It: 17400, Loss: 2.466e-01, Loss_res: 6.693e-02,  Loss_bcs: 2.783e-05, Loss_ut_ics: 4.543e-04 , loss_coll_u: 3.482e-05, Time: 18.99
# Compute NTK...
# lambda_u: 5.754e+03
# lambda_ut: 3.446e+01
# lambda_r: 1.047e+00
# lam_coll_val: 6.465e+01
# It: 17500, Loss: 3.825e-01, Loss_res: 1.435e-01,  Loss_bcs: 3.357e-05, Loss_ut_ics: 1.064e-03 , loss_coll_u: 3.729e-05, Time: 18.91
# Compute NTK...
# lambda_u: 5.733e+03
# lambda_ut: 3.233e+01
# lambda_r: 1.051e+00
# lam_coll_val: 5.770e+01
# It: 17600, Loss: 3.295e-01, Loss_res: 5.968e-02,  Loss_bcs: 3.704e-05, Loss_ut_ics: 1.612e-03 , loss_coll_u: 4.012e-05, Time: 18.87
# Compute NTK...
# lambda_u: 5.647e+03
# lambda_ut: 3.150e+01
# lambda_r: 1.052e+00
# lam_coll_val: 5.715e+01
# It: 17700, Loss: 3.048e-01, Loss_res: 7.349e-02,  Loss_bcs: 3.160e-05, Loss_ut_ics: 1.485e-03 , loss_coll_u: 4.072e-05, Time: 19.01
# Compute NTK...
# lambda_u: 5.890e+03
# lambda_ut: 3.335e+01
# lambda_r: 1.049e+00
# lam_coll_val: 6.199e+01
# It: 17800, Loss: 3.333e-01, Loss_res: 7.197e-02,  Loss_bcs: 3.634e-05, Loss_ut_ics: 1.234e-03 , loss_coll_u: 4.331e-05, Time: 18.94
# Compute NTK...
# lambda_u: 5.737e+03
# lambda_ut: 3.285e+01
# lambda_r: 1.049e+00
# lam_coll_val: 6.225e+01
# It: 17900, Loss: 2.525e-01, Loss_res: 7.430e-02,  Loss_bcs: 2.393e-05, Loss_ut_ics: 1.048e-03 , loss_coll_u: 4.625e-05, Time: 18.97
# Compute NTK...
# lambda_u: 5.626e+03
# lambda_ut: 3.159e+01
# lambda_r: 1.051e+00
# lam_coll_val: 5.965e+01
# It: 18000, Loss: 3.410e-01, Loss_res: 8.409e-02,  Loss_bcs: 2.915e-05, Loss_ut_ics: 2.749e-03 , loss_coll_u: 3.019e-05, Time: 19.04
# Compute NTK...
# lambda_u: 5.983e+03
# lambda_ut: 3.486e+01
# lambda_r: 1.047e+00
# lam_coll_val: 6.294e+01
# It: 18100, Loss: 2.998e-01, Loss_res: 8.580e-02,  Loss_bcs: 3.052e-05, Loss_ut_ics: 7.180e-04 , loss_coll_u: 3.713e-05, Time: 18.97
# Compute NTK...
# lambda_u: 5.743e+03
# lambda_ut: 3.247e+01
# lambda_r: 1.050e+00
# lam_coll_val: 5.854e+01
# It: 18200, Loss: 2.520e-01, Loss_res: 8.714e-02,  Loss_bcs: 2.445e-05, Loss_ut_ics: 5.609e-04 , loss_coll_u: 3.165e-05, Time: 18.91
# Compute NTK...
# lambda_u: 5.903e+03
# lambda_ut: 3.328e+01
# lambda_r: 1.049e+00
# lam_coll_val: 6.142e+01
# It: 18300, Loss: 7.624e-01, Loss_res: 2.936e-01,  Loss_bcs: 5.638e-05, Loss_ut_ics: 3.578e-03 , loss_coll_u: 4.248e-05, Time: 18.96
# Compute NTK...
# lambda_u: 5.646e+03
# lambda_ut: 3.135e+01
# lambda_r: 1.051e+00
# lam_coll_val: 5.973e+01
# It: 18400, Loss: 2.760e-01, Loss_res: 6.036e-02,  Loss_bcs: 3.413e-05, Loss_ut_ics: 5.799e-04 , loss_coll_u: 2.912e-05, Time: 18.87
# Compute NTK...
# lambda_u: 5.938e+03
# lambda_ut: 3.250e+01
# lambda_r: 1.050e+00
# lam_coll_val: 5.927e+01
# It: 18500, Loss: 2.466e-01, Loss_res: 6.820e-02,  Loss_bcs: 2.637e-05, Loss_ut_ics: 5.072e-04 , loss_coll_u: 3.196e-05, Time: 18.92
# Compute NTK...
# lambda_u: 5.779e+03
# lambda_ut: 3.389e+01
# lambda_r: 1.049e+00
# lam_coll_val: 5.761e+01
# It: 18600, Loss: 3.296e-01, Loss_res: 9.659e-02,  Loss_bcs: 3.618e-05, Loss_ut_ics: 5.090e-04 , loss_coll_u: 3.449e-05, Time: 18.91
# Compute NTK...
# lambda_u: 5.727e+03
# lambda_ut: 3.302e+01
# lambda_r: 1.050e+00
# lam_coll_val: 5.745e+01
# It: 18700, Loss: 2.665e-01, Loss_res: 8.242e-02,  Loss_bcs: 2.757e-05, Loss_ut_ics: 6.184e-04 , loss_coll_u: 2.891e-05, Time: 21.54
# Compute NTK...
# lambda_u: 5.899e+03
# lambda_ut: 3.478e+01
# lambda_r: 1.047e+00
# lam_coll_val: 6.221e+01
# It: 18800, Loss: 2.961e-01, Loss_res: 7.439e-02,  Loss_bcs: 3.345e-05, Loss_ut_ics: 5.420e-04 , loss_coll_u: 3.192e-05, Time: 17.83
# Compute NTK...
# lambda_u: 5.959e+03
# lambda_ut: 3.451e+01
# lambda_r: 1.047e+00
# lam_coll_val: 6.409e+01
# It: 18900, Loss: 3.552e-01, Loss_res: 9.433e-02,  Loss_bcs: 3.354e-05, Loss_ut_ics: 1.582e-03 , loss_coll_u: 3.156e-05, Time: 19.66
# Compute NTK...
# lambda_u: 5.774e+03
# lambda_ut: 3.266e+01
# lambda_r: 1.051e+00
# lam_coll_val: 5.636e+01
# It: 19000, Loss: 3.366e-01, Loss_res: 7.277e-02,  Loss_bcs: 3.419e-05, Loss_ut_ics: 1.868e-03 , loss_coll_u: 3.049e-05, Time: 18.18
# Compute NTK...
# lambda_u: 5.719e+03
# lambda_ut: 3.254e+01
# lambda_r: 1.049e+00
# lam_coll_val: 6.445e+01
# It: 19100, Loss: 4.360e-01, Loss_res: 1.075e-01,  Loss_bcs: 2.171e-05, Loss_ut_ics: 6.060e-03 , loss_coll_u: 2.926e-05, Time: 19.57
# Compute NTK...
# lambda_u: 5.572e+03
# lambda_ut: 3.330e+01
# lambda_r: 1.050e+00
# lam_coll_val: 5.831e+01
# It: 19200, Loss: 2.260e-01, Loss_res: 7.746e-02,  Loss_bcs: 2.284e-05, Loss_ut_ics: 4.649e-04 , loss_coll_u: 3.423e-05, Time: 21.47
# Compute NTK...
# lambda_u: 5.662e+03
# lambda_ut: 3.429e+01
# lambda_r: 1.049e+00
# lam_coll_val: 5.817e+01
# It: 19300, Loss: 3.129e-01, Loss_res: 7.681e-02,  Loss_bcs: 3.214e-05, Loss_ut_ics: 1.422e-03 , loss_coll_u: 2.764e-05, Time: 19.53
# Compute NTK...
# lambda_u: 5.478e+03
# lambda_ut: 3.042e+01
# lambda_r: 1.053e+00
# lam_coll_val: 5.918e+01
# It: 19400, Loss: 1.948e-01, Loss_res: 4.430e-02,  Loss_bcs: 2.570e-05, Loss_ut_ics: 1.850e-04 , loss_coll_u: 2.920e-05, Time: 19.47
# Compute NTK...
# lambda_u: 5.802e+03
# lambda_ut: 3.383e+01
# lambda_r: 1.049e+00
# lam_coll_val: 5.902e+01
# It: 19500, Loss: 1.220e+00, Loss_res: 9.785e-02,  Loss_bcs: 4.993e-05, Loss_ut_ics: 2.440e-02 , loss_coll_u: 3.123e-05, Time: 19.94
# Compute NTK...
# lambda_u: 5.798e+03
# lambda_ut: 3.414e+01
# lambda_r: 1.047e+00
# lam_coll_val: 6.314e+01
# It: 19600, Loss: 4.088e-01, Loss_res: 7.967e-02,  Loss_bcs: 1.926e-05, Loss_ut_ics: 6.207e-03 , loss_coll_u: 2.785e-05, Time: 20.96
# Compute NTK...
# lambda_u: 5.570e+03
# lambda_ut: 3.168e+01
# ...
# It: 33200, Loss: 6.153e-02, Loss_res: 1.423e-02,  Loss_bcs: 7.098e-06, Loss_ut_ics: 1.163e-04 , loss_coll_u: 1.401e-05, Time: 20.04
# Compute NTK...
# lambda_u: 5.985e+03
# lambda_ut: 3.343e+01
# lambda_r: 1.049e+00
# lam_coll_val: 6.117e+01
# It: 33300, Loss: 6.458e-02, Loss_res: 1.692e-02,  Loss_bcs: 7.060e-06, Loss_ut_ics: 1.167e-04 , loss_coll_u: 1.123e-05, Time: 19.19
# Compute NTK...
# lambda_u: 6.062e+03
# lambda_ut: 3.267e+01
# lambda_r: 1.049e+00
# lam_coll_val: 6.211e+01
# It: 33400, Loss: 6.769e-02, Loss_res: 1.562e-02,  Loss_bcs: 7.577e-06, Loss_ut_ics: 1.397e-04 , loss_coll_u: 1.301e-05, Time: 19.54
# Compute NTK...
# lambda_u: 5.820e+03
# lambda_ut: 3.364e+01
# lambda_r: 1.049e+00
# lam_coll_val: 5.922e+01
# It: 33500, Loss: 5.566e-02, Loss_res: 1.324e-02,  Loss_bcs: 6.568e-06, Loss_ut_ics: 8.448e-05 , loss_coll_u: 1.177e-05, Time: 19.42
# Compute NTK...
# lambda_u: 5.304e+03
# lambda_ut: 2.827e+01
# lambda_r: 1.055e+00
# lam_coll_val: 5.906e+01
# It: 33600, Loss: 6.915e-02, Loss_res: 1.754e-02,  Loss_bcs: 7.707e-06, Loss_ut_ics: 3.222e-04 , loss_coll_u: 1.109e-05, Time: 20.57
# Compute NTK...
# lambda_u: 5.584e+03
# lambda_ut: 3.164e+01
# lambda_r: 1.052e+00
# lam_coll_val: 5.675e+01
# It: 33700, Loss: 8.388e-02, Loss_res: 1.718e-02,  Loss_bcs: 7.946e-06, Loss_ut_ics: 6.483e-04 , loss_coll_u: 1.618e-05, Time: 19.77
# Compute NTK...
# lambda_u: 5.821e+03
# lambda_ut: 3.316e+01
# lambda_r: 1.048e+00
# lam_coll_val: 6.343e+01
# It: 33800, Loss: 7.880e-02, Loss_res: 1.567e-02,  Loss_bcs: 9.042e-06, Loss_ut_ics: 2.670e-04 , loss_coll_u: 1.402e-05, Time: 19.95
# Compute NTK...
# lambda_u: 5.712e+03
# lambda_ut: 3.237e+01
# lambda_r: 1.050e+00
# lam_coll_val: 6.153e+01
# It: 33900, Loss: 6.548e-02, Loss_res: 1.819e-02,  Loss_bcs: 7.349e-06, Loss_ut_ics: 1.137e-04 , loss_coll_u: 1.186e-05, Time: 19.92
# Compute NTK...
# lambda_u: 5.925e+03
# lambda_ut: 3.229e+01
# lambda_r: 1.050e+00
# lam_coll_val: 6.206e+01
# It: 34000, Loss: 5.639e-02, Loss_res: 1.139e-02,  Loss_bcs: 6.722e-06, Loss_ut_ics: 1.218e-04 , loss_coll_u: 1.081e-05, Time: 19.37
# Compute NTK...
# lambda_u: 5.619e+03
# lambda_ut: 3.186e+01
# lambda_r: 1.051e+00
# lam_coll_val: 5.908e+01
# It: 34100, Loss: 7.360e-02, Loss_res: 2.333e-02,  Loss_bcs: 7.075e-06, Loss_ut_ics: 2.705e-04 , loss_coll_u: 1.188e-05, Time: 19.16
# Compute NTK...
# lambda_u: 5.717e+03
# lambda_ut: 3.090e+01
# lambda_r: 1.052e+00
# lam_coll_val: 5.906e+01
# It: 34200, Loss: 7.085e-02, Loss_res: 2.345e-02,  Loss_bcs: 7.337e-06, Loss_ut_ics: 1.110e-04 , loss_coll_u: 1.356e-05, Time: 20.42
# Compute NTK...
# lambda_u: 5.731e+03
# lambda_ut: 3.294e+01
# lambda_r: 1.048e+00
# lam_coll_val: 6.678e+01
# It: 34300, Loss: 6.068e-02, Loss_res: 1.464e-02,  Loss_bcs: 6.905e-06, Loss_ut_ics: 1.530e-04 , loss_coll_u: 1.085e-05, Time: 20.19
# Compute NTK...
# lambda_u: 5.819e+03
# lambda_ut: 3.120e+01
# lambda_r: 1.051e+00
# lam_coll_val: 6.126e+01
# It: 34400, Loss: 5.838e-02, Loss_res: 1.512e-02,  Loss_bcs: 6.763e-06, Loss_ut_ics: 8.127e-05 , loss_coll_u: 9.779e-06, Time: 19.37
# Compute NTK...
# lambda_u: 5.454e+03
# lambda_ut: 3.081e+01
# lambda_r: 1.051e+00
# lam_coll_val: 6.191e+01
# It: 34500, Loss: 5.448e-02, Loss_res: 1.479e-02,  Loss_bcs: 6.530e-06, Loss_ut_ics: 8.534e-05 , loss_coll_u: 1.103e-05, Time: 19.22
# Compute NTK...
# lambda_u: 5.851e+03
# lambda_ut: 3.170e+01
# lambda_r: 1.051e+00
# lam_coll_val: 5.951e+01
# It: 34600, Loss: 6.261e-02, Loss_res: 1.854e-02,  Loss_bcs: 5.699e-06, Loss_ut_ics: 2.850e-04 , loss_coll_u: 1.251e-05, Time: 19.44
# Compute NTK...
# lambda_u: 5.912e+03
# lambda_ut: 3.454e+01
# lambda_r: 1.046e+00
# lam_coll_val: 6.618e+01
# It: 34700, Loss: 6.814e-02, Loss_res: 2.168e-02,  Loss_bcs: 6.558e-06, Loss_ut_ics: 1.674e-04 , loss_coll_u: 1.373e-05, Time: 18.80
# Compute NTK...
# lambda_u: 5.377e+03
# lambda_ut: 3.157e+01
# lambda_r: 1.052e+00
# lam_coll_val: 5.750e+01
# It: 34800, Loss: 5.486e-02, Loss_res: 1.464e-02,  Loss_bcs: 6.586e-06, Loss_ut_ics: 1.079e-04 , loss_coll_u: 1.113e-05, Time: 11.44
# Compute NTK...
# lambda_u: 5.614e+03
# lambda_ut: 3.197e+01
# lambda_r: 1.051e+00
# lam_coll_val: 5.979e+01
# It: 34900, Loss: 6.160e-02, Loss_res: 1.669e-02,  Loss_bcs: 7.221e-06, Loss_ut_ics: 8.694e-05 , loss_coll_u: 1.242e-05, Time: 11.54
# Compute NTK...
# lambda_u: 5.804e+03
# lambda_ut: 3.153e+01
# lambda_r: 1.051e+00
# lam_coll_val: 6.050e+01
# It: 35000, Loss: 7.359e-02, Loss_res: 1.927e-02,  Loss_bcs: 8.252e-06, Loss_ut_ics: 1.508e-04 , loss_coll_u: 1.133e-05, Time: 11.54
# Compute NTK...
# lambda_u: 5.574e+03
# lambda_ut: 3.240e+01
# lambda_r: 1.050e+00
# lam_coll_val: 6.090e+01
# It: 35100, Loss: 6.208e-02, Loss_res: 1.525e-02,  Loss_bcs: 7.245e-06, Loss_ut_ics: 1.523e-04 , loss_coll_u: 1.247e-05, Time: 12.48
# Compute NTK...
# lambda_u: 5.729e+03
# lambda_ut: 3.019e+01
# lambda_r: 1.054e+00
# lam_coll_val: 5.660e+01
# It: 35200, Loss: 6.426e-02, Loss_res: 1.368e-02,  Loss_bcs: 7.885e-06, Loss_ut_ics: 1.305e-04 , loss_coll_u: 1.294e-05, Time: 12.18
# Compute NTK...
# lambda_u: 5.971e+03
# lambda_ut: 3.299e+01
# lambda_r: 1.048e+00
# lam_coll_val: 6.397e+01
# It: 35300, Loss: 5.655e-02, Loss_res: 1.266e-02,  Loss_bcs: 6.264e-06, Loss_ut_ics: 1.572e-04 , loss_coll_u: 1.074e-05, Time: 11.97
# Compute NTK...
# lambda_u: 5.599e+03
# lambda_ut: 3.072e+01
# lambda_r: 1.053e+00
# lam_coll_val: 5.691e+01
# It: 35400, Loss: 5.994e-02, Loss_res: 1.577e-02,  Loss_bcs: 7.271e-06, Loss_ut_ics: 6.297e-05 , loss_coll_u: 1.231e-05, Time: 11.18
# Compute NTK...
# lambda_u: 5.390e+03
# lambda_ut: 2.902e+01
# lambda_r: 1.054e+00
# lam_coll_val: 5.993e+01
# It: 35500, Loss: 6.293e-02, Loss_res: 1.624e-02,  Loss_bcs: 7.756e-06, Loss_ut_ics: 1.107e-04 , loss_coll_u: 1.319e-05, Time: 11.06
# Compute NTK...
# lambda_u: 5.693e+03
# lambda_ut: 3.127e+01
# lambda_r: 1.051e+00
# lam_coll_val: 6.035e+01
# It: 35600, Loss: 7.865e-02, Loss_res: 1.754e-02,  Loss_bcs: 9.953e-06, Loss_ut_ics: 9.054e-05 , loss_coll_u: 1.205e-05, Time: 11.44
# Compute NTK...
# lambda_u: 5.619e+03
# lambda_ut: 3.187e+01
# lambda_r: 1.051e+00
# lam_coll_val: 5.871e+01
# It: 35700, Loss: 8.006e-02, Loss_res: 1.973e-02,  Loss_bcs: 7.020e-06, Loss_ut_ics: 6.032e-04 , loss_coll_u: 1.126e-05, Time: 12.35
# Compute NTK...
# lambda_u: 5.555e+03
# lambda_ut: 3.019e+01
# lambda_r: 1.052e+00
# lam_coll_val: 6.184e+01
# It: 35800, Loss: 5.835e-02, Loss_res: 1.496e-02,  Loss_bcs: 6.972e-06, Loss_ut_ics: 1.055e-04 , loss_coll_u: 1.122e-05, Time: 12.07
# Compute NTK...
# lambda_u: 5.619e+03
# lambda_ut: 3.031e+01
# lambda_r: 1.053e+00
# lam_coll_val: 5.952e+01
# It: 35900, Loss: 5.621e-02, Loss_res: 1.620e-02,  Loss_bcs: 6.467e-06, Loss_ut_ics: 7.099e-05 , loss_coll_u: 1.117e-05, Time: 12.06
# Compute NTK...
# lambda_u: 5.737e+03
# lambda_ut: 3.350e+01
# lambda_r: 1.050e+00
# lam_coll_val: 5.760e+01
# It: 36000, Loss: 5.729e-02, Loss_res: 1.431e-02,  Loss_bcs: 6.572e-06, Loss_ut_ics: 1.144e-04 , loss_coll_u: 1.270e-05, Time: 11.16
# Compute NTK...
# lambda_u: 5.916e+03
# lambda_ut: 3.595e+01
# lambda_r: 1.046e+00
# lam_coll_val: 6.247e+01
# It: 36100, Loss: 6.362e-02, Loss_res: 1.700e-02,  Loss_bcs: 6.905e-06, Loss_ut_ics: 1.199e-04 , loss_coll_u: 1.092e-05, Time: 12.29
# Compute NTK...
# lambda_u: 5.632e+03
# lambda_ut: 3.118e+01
# lambda_r: 1.052e+00
# lam_coll_val: 5.803e+01
# It: 36200, Loss: 5.987e-02, Loss_res: 1.300e-02,  Loss_bcs: 7.073e-06, Loss_ut_ics: 1.819e-04 , loss_coll_u: 1.188e-05, Time: 11.31
# Compute NTK...
# lambda_u: 5.714e+03
# lambda_ut: 3.311e+01
# lambda_r: 1.050e+00
# lam_coll_val: 5.950e+01
# It: 36300, Loss: 5.790e-02, Loss_res: 1.306e-02,  Loss_bcs: 6.830e-06, Loss_ut_ics: 1.375e-04 , loss_coll_u: 1.028e-05, Time: 11.11
# Compute NTK...
# lambda_u: 5.291e+03
# lambda_ut: 3.008e+01
# lambda_r: 1.054e+00
# lam_coll_val: 5.673e+01
# It: 36400, Loss: 5.747e-02, Loss_res: 1.567e-02,  Loss_bcs: 6.834e-06, Loss_ut_ics: 1.382e-04 , loss_coll_u: 1.140e-05, Time: 11.07
# Compute NTK...
# lambda_u: 5.888e+03
# lambda_ut: 3.281e+01
# lambda_r: 1.050e+00
# lam_coll_val: 5.995e+01
# It: 36500, Loss: 5.933e-02, Loss_res: 1.443e-02,  Loss_bcs: 6.869e-06, Loss_ut_ics: 9.726e-05 , loss_coll_u: 9.025e-06, Time: 11.14
# Compute NTK...
# lambda_u: 5.712e+03
# lambda_ut: 3.067e+01
# lambda_r: 1.052e+00
# lam_coll_val: 6.121e+01
# It: 36600, Loss: 5.933e-02, Loss_res: 1.660e-02,  Loss_bcs: 6.720e-06, Loss_ut_ics: 9.154e-05 , loss_coll_u: 1.106e-05, Time: 11.08
# Compute NTK...
# lambda_u: 5.488e+03
# lambda_ut: 3.065e+01
# lambda_r: 1.052e+00
# lam_coll_val: 5.997e+01
# It: 36700, Loss: 5.530e-02, Loss_res: 1.278e-02,  Loss_bcs: 6.924e-06, Loss_ut_ics: 1.046e-04 , loss_coll_u: 1.094e-05, Time: 11.11
# Compute NTK...
# lambda_u: 5.606e+03
# lambda_ut: 3.262e+01
# lambda_r: 1.049e+00
# lam_coll_val: 6.363e+01
# It: 36800, Loss: 6.010e-02, Loss_res: 1.673e-02,  Loss_bcs: 6.490e-06, Loss_ut_ics: 1.650e-04 , loss_coll_u: 1.245e-05, Time: 11.07
# Compute NTK...
# lambda_u: 5.747e+03
# lambda_ut: 3.318e+01
# lambda_r: 1.049e+00
# lam_coll_val: 6.259e+01
# It: 36900, Loss: 5.887e-02, Loss_res: 1.876e-02,  Loss_bcs: 6.180e-06, Loss_ut_ics: 9.136e-05 , loss_coll_u: 1.046e-05, Time: 12.16
# Compute NTK...
# lambda_u: 5.827e+03
# lambda_ut: 3.349e+01
# lambda_r: 1.049e+00
# lam_coll_val: 6.079e+01
# It: 37000, Loss: 5.341e-02, Loss_res: 1.666e-02,  Loss_bcs: 5.552e-06, Loss_ut_ics: 8.475e-05 , loss_coll_u: 1.212e-05, Time: 12.19
# Compute NTK...
# lambda_u: 5.445e+03
# lambda_ut: 3.110e+01
# lambda_r: 1.053e+00
# lam_coll_val: 5.679e+01
# It: 37100, Loss: 5.184e-02, Loss_res: 1.597e-02,  Loss_bcs: 5.935e-06, Loss_ut_ics: 6.595e-05 , loss_coll_u: 1.170e-05, Time: 11.06
# Compute NTK...
# lambda_u: 5.565e+03
# lambda_ut: 3.147e+01
# lambda_r: 1.050e+00
# lam_coll_val: 6.216e+01
# It: 37200, Loss: 6.439e-02, Loss_res: 1.973e-02,  Loss_bcs: 6.587e-06, Loss_ut_ics: 2.000e-04 , loss_coll_u: 1.155e-05, Time: 11.11
# Compute NTK...
# lambda_u: 5.708e+03
# lambda_ut: 3.371e+01
# lambda_r: 1.050e+00
# lam_coll_val: 5.716e+01
# It: 37300, Loss: 6.190e-02, Loss_res: 1.625e-02,  Loss_bcs: 7.133e-06, Loss_ut_ics: 1.003e-04 , loss_coll_u: 1.292e-05, Time: 11.06
# Compute NTK...
# lambda_u: 5.690e+03
# lambda_ut: 3.203e+01
# lambda_r: 1.051e+00
# lam_coll_val: 5.886e+01
# It: 37400, Loss: 5.667e-02, Loss_res: 1.457e-02,  Loss_bcs: 6.452e-06, Loss_ut_ics: 1.229e-04 , loss_coll_u: 1.211e-05, Time: 11.67
# Compute NTK...
# lambda_u: 5.651e+03
# lambda_ut: 3.131e+01
# lambda_r: 1.052e+00
# lam_coll_val: 5.900e+01
# It: 37500, Loss: 5.257e-02, Loss_res: 1.515e-02,  Loss_bcs: 5.710e-06, Loss_ut_ics: 1.193e-04 , loss_coll_u: 1.074e-05, Time: 12.00
# Compute NTK...
# lambda_u: 5.905e+03
# lambda_ut: 3.394e+01
# lambda_r: 1.048e+00
# lam_coll_val: 6.285e+01
# It: 37600, Loss: 5.233e-02, Loss_res: 1.382e-02,  Loss_bcs: 5.538e-06, Loss_ut_ics: 1.311e-04 , loss_coll_u: 1.124e-05, Time: 11.14
# Compute NTK...
# lambda_u: 5.771e+03
# lambda_ut: 3.394e+01
# lambda_r: 1.048e+00
# lam_coll_val: 6.225e+01
# It: 37700, Loss: 5.632e-02, Loss_res: 1.341e-02,  Loss_bcs: 6.559e-06, Loss_ut_ics: 1.077e-04 , loss_coll_u: 1.229e-05, Time: 11.29
# Compute NTK...
# lambda_u: 5.873e+03
# lambda_ut: 3.339e+01
# lambda_r: 1.049e+00
# lam_coll_val: 5.907e+01
# It: 37800, Loss: 4.898e-02, Loss_res: 1.524e-02,  Loss_bcs: 5.088e-06, Loss_ut_ics: 7.279e-05 , loss_coll_u: 1.143e-05, Time: 11.19
# Compute NTK...
# lambda_u: 5.858e+03
# lambda_ut: 3.407e+01
# lambda_r: 1.048e+00
# lam_coll_val: 6.186e+01
# It: 37900, Loss: 5.614e-02, Loss_res: 1.253e-02,  Loss_bcs: 5.986e-06, Loss_ut_ics: 2.121e-04 , loss_coll_u: 1.163e-05, Time: 10.96
# Compute NTK...
# lambda_u: 5.809e+03
# lambda_ut: 3.217e+01
# lambda_r: 1.049e+00
# lam_coll_val: 6.396e+01
# It: 38000, Loss: 5.284e-02, Loss_res: 1.425e-02,  Loss_bcs: 5.717e-06, Loss_ut_ics: 1.232e-04 , loss_coll_u: 1.115e-05, Time: 12.71
# Compute NTK...
# lambda_u: 5.747e+03
# lambda_ut: 3.269e+01
# lambda_r: 1.051e+00
# lam_coll_val: 5.517e+01
# It: 38100, Loss: 5.158e-02, Loss_res: 1.169e-02,  Loss_bcs: 5.926e-06, Loss_ut_ics: 1.425e-04 , loss_coll_u: 1.039e-05, Time: 11.08
# Compute NTK...
# lambda_u: 5.685e+03
# lambda_ut: 3.112e+01
# lambda_r: 1.053e+00
# lam_coll_val: 5.632e+01
# It: 38200, Loss: 5.402e-02, Loss_res: 1.576e-02,  Loss_bcs: 5.741e-06, Loss_ut_ics: 1.355e-04 , loss_coll_u: 1.004e-05, Time: 10.94
# Compute NTK...
# lambda_u: 5.698e+03
# lambda_ut: 3.554e+01
# lambda_r: 1.046e+00
# lam_coll_val: 6.225e+01
# It: 38300, Loss: 5.754e-02, Loss_res: 1.252e-02,  Loss_bcs: 6.608e-06, Loss_ut_ics: 1.733e-04 , loss_coll_u: 1.014e-05, Time: 10.97
# Compute NTK...
# lambda_u: 5.575e+03
# lambda_ut: 3.082e+01
# lambda_r: 1.052e+00
# lam_coll_val: 5.824e+01
# It: 38400, Loss: 5.301e-02, Loss_res: 1.553e-02,  Loss_bcs: 6.059e-06, Loss_ut_ics: 7.275e-05 , loss_coll_u: 1.113e-05, Time: 10.90
# Compute NTK...
# lambda_u: 5.581e+03
# lambda_ut: 3.129e+01
# lambda_r: 1.051e+00
# lam_coll_val: 5.974e+01
# It: 38500, Loss: 5.767e-02, Loss_res: 1.687e-02,  Loss_bcs: 6.189e-06, Loss_ut_ics: 1.531e-04 , loss_coll_u: 9.934e-06, Time: 10.94
# Compute NTK...
# lambda_u: 5.856e+03
# lambda_ut: 3.161e+01
# lambda_r: 1.051e+00
# lam_coll_val: 6.029e+01
# It: 38600, Loss: 5.165e-02, Loss_res: 1.377e-02,  Loss_bcs: 5.736e-06, Loss_ut_ics: 9.052e-05 , loss_coll_u: 1.196e-05, Time: 10.95
# Compute NTK...
# lambda_u: 5.761e+03
# lambda_ut: 3.249e+01
# lambda_r: 1.051e+00
# lam_coll_val: 5.780e+01
# It: 38700, Loss: 5.589e-02, Loss_res: 1.404e-02,  Loss_bcs: 6.498e-06, Loss_ut_ics: 9.624e-05 , loss_coll_u: 9.911e-06, Time: 11.17
# Compute NTK...
# lambda_u: 5.665e+03
# lambda_ut: 3.276e+01
# lambda_r: 1.050e+00
# lam_coll_val: 6.072e+01
# It: 38800, Loss: 5.075e-02, Loss_res: 1.144e-02,  Loss_bcs: 6.291e-06, Loss_ut_ics: 7.576e-05 , loss_coll_u: 1.026e-05, Time: 10.96
# Compute NTK...
# lambda_u: 5.798e+03
# lambda_ut: 3.196e+01
# lambda_r: 1.050e+00
# lam_coll_val: 6.186e+01
# It: 38900, Loss: 5.824e-02, Loss_res: 1.207e-02,  Loss_bcs: 7.234e-06, Loss_ut_ics: 9.458e-05 , loss_coll_u: 9.832e-06, Time: 10.66
# Compute NTK...
# lambda_u: 5.894e+03
# lambda_ut: 3.309e+01
# lambda_r: 1.049e+00
# lam_coll_val: 6.017e+01
# It: 39000, Loss: 5.561e-02, Loss_res: 1.346e-02,  Loss_bcs: 6.150e-06, Loss_ut_ics: 1.400e-04 , loss_coll_u: 9.997e-06, Time: 10.75
# Compute NTK...
# lambda_u: 5.289e+03
# lambda_ut: 2.960e+01
# lambda_r: 1.055e+00
# lam_coll_val: 5.545e+01
# It: 39100, Loss: 5.084e-02, Loss_res: 1.526e-02,  Loss_bcs: 5.929e-06, Loss_ut_ics: 9.363e-05 , loss_coll_u: 1.101e-05, Time: 11.33
# Compute NTK...
# lambda_u: 5.765e+03
# lambda_ut: 3.159e+01
# lambda_r: 1.051e+00
# lam_coll_val: 5.963e+01
# It: 39200, Loss: 4.803e-02, Loss_res: 1.267e-02,  Loss_bcs: 5.267e-06, Loss_ut_ics: 1.193e-04 , loss_coll_u: 9.817e-06, Time: 11.03
# Compute NTK...
# lambda_u: 5.457e+03
# lambda_ut: 3.138e+01
# lambda_r: 1.051e+00
# lam_coll_val: 5.940e+01
# It: 39300, Loss: 4.761e-02, Loss_res: 1.146e-02,  Loss_bcs: 5.895e-06, Loss_ut_ics: 8.647e-05 , loss_coll_u: 1.146e-05, Time: 10.98
# Compute NTK...
# lambda_u: 5.858e+03
# lambda_ut: 3.419e+01
# lambda_r: 1.049e+00
# lam_coll_val: 5.844e+01
# It: 39400, Loss: 5.445e-02, Loss_res: 1.420e-02,  Loss_bcs: 5.444e-06, Loss_ut_ics: 2.059e-04 , loss_coll_u: 1.062e-05, Time: 12.26
# Compute NTK...
# lambda_u: 5.674e+03
# lambda_ut: 3.117e+01
# lambda_r: 1.052e+00
# lam_coll_val: 5.896e+01
# It: 39500, Loss: 4.917e-02, Loss_res: 1.287e-02,  Loss_bcs: 5.527e-06, Loss_ut_ics: 1.170e-04 , loss_coll_u: 1.049e-05, Time: 11.32
# Compute NTK...
# lambda_u: 5.541e+03
# lambda_ut: 3.179e+01
# lambda_r: 1.051e+00
# lam_coll_val: 5.810e+01
# It: 39600, Loss: 5.223e-02, Loss_res: 1.347e-02,  Loss_bcs: 6.309e-06, Loss_ut_ics: 7.804e-05 , loss_coll_u: 1.082e-05, Time: 12.34
# Compute NTK...
# lambda_u: 5.653e+03
# lambda_ut: 3.220e+01
# lambda_r: 1.051e+00
# lam_coll_val: 5.825e+01
# It: 39700, Loss: 5.348e-02, Loss_res: 1.285e-02,  Loss_bcs: 6.546e-06, Loss_ut_ics: 7.027e-05 , loss_coll_u: 1.214e-05, Time: 11.51
# Compute NTK...
# lambda_u: 5.836e+03
# lambda_ut: 3.426e+01
# lambda_r: 1.047e+00
# lam_coll_val: 6.274e+01
# It: 39800, Loss: 5.293e-02, Loss_res: 1.265e-02,  Loss_bcs: 6.101e-06, Loss_ut_ics: 9.969e-05 , loss_coll_u: 1.050e-05, Time: 11.33
# Compute NTK...
# lambda_u: 5.528e+03
# lambda_ut: 3.083e+01
# lambda_r: 1.052e+00
# lam_coll_val: 5.926e+01
# It: 39900, Loss: 5.014e-02, Loss_res: 1.169e-02,  Loss_bcs: 6.233e-06, Loss_ut_ics: 9.244e-05 , loss_coll_u: 9.165e-06, Time: 10.91
# Compute NTK...
# lambda_u: 5.798e+03
# lambda_ut: 3.188e+01
# lambda_r: 1.051e+00
# lam_coll_val: 5.845e+01
# elapsed: 6.37e+03
# Relative L2 error_u: 5.78e-03
# elapsed: 6.37e+03
# Relative L2 error_u: 5.78e-03
#
#
# Method:  mini_batch
#
# average of time_list: 6372.054662227631
# average of error_u_list: 0.005775199218516062

# %%
# Predictions
u_pred = model.predict_u(X_star)
r_pred = model.predict_r(X_star)
# Predictions
r_pred =r_pred.reshape(200,200)

error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)
error_r = np.linalg.norm(r_star - r_pred, 2)# / np.linalg.norm(r_star, 2)

# print('elapsed: {:.2e}'.format(elapsed))

print('Relative L2 error_u: {:.2e}'.format(error_u))
print('Relative L2 error_r: {:.2e}'.format(error_r))

# %%
result_dict
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_46790/2901373739.py in <module>
# ----> 1 result_dict
#
# NameError: name 'result_dict' is not defined

# %%
import scipy.io

mode = 'M3'
mbbatch_size = 128
ubatch_size = 5000
bcbatch_size = 500
iterations = 40000

time_list = []
error_u_list = []
error_v_list = []
error_p_list = []
    
methods = ["mini_batch" , "full_batch"]
result_dict =  dict((mtd, []) for mtd in methods)

##Mini Batch
time_list = []
error_u_list = [ ]


result_dict["mini_batch"] = [time_list ,error_u_list]

print("\n\nMethod: ", mtd)
print("\naverage of time_list:" , sum(time_list) / len(time_list) )
print("average of error_u_list:" , sum(error_u_list) / len(error_u_list) )

##Full Batch
time_list = []
error_u_list = [ ]

result_dict["full_batch"] = [time_list ,error_u_list]

print("\n\nMethod: ", mtd)
print("\naverage of time_list:" , sum(time_list) / len(time_list) )
print("average of error_u_list:" , sum(error_u_list) / len(error_u_list) )
print("average of error_v_list:" , sum(error_v_list) / len(error_v_list) )
print("average of error_p_list:" , sum(error_p_list) / len(error_p_list) )


scipy.io.savemat("./1DWave_database/uhem_1DWave_model_"+mode+"_result_mb"+str(mbbatch_size)+"_fb"+str(ubatch_size)+"_"+str(bcbatch_size)+"_"+str(iterations)+".mat" , result_dict)

# %%
# Train model
itertaions = 80001
log_NTK = True # Compute and store NTK matrix during training
update_lam = True # Compute and update the loss weights using the NTK

# %% [markdown]
# **Training Loss**

# %%
loss_res = model.loss_res_log
loss_bcs = model.loss_bcs_log
loss_u_t_ics = model.loss_ut_ics_log

fig = plt.figure(figsize=(6, 5))
plt.plot(loss_res, label='$\mathcal{L}_{r}$')
plt.plot(loss_bcs, label='$\mathcal{L}_{u}$')
plt.plot(loss_u_t_ics, label='$\mathcal{L}_{u_t}$')
plt.yscale('log')
plt.xlabel('iterations')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# **Model Prediction**

# %%
# Predictions
u_pred = model.predict_u(X_star)
r_pred = model.predict_r(X_star)
error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)

print('Relative L2 error_u: %e' % (error_u))

# %%
U_star = griddata(X_star, u_star.flatten(), (t, x), method='cubic')
r_star = griddata(X_star, r_star.flatten(), (t, x), method='cubic')
U_pred = griddata(X_star, u_pred.flatten(), (t, x), method='cubic')
R_pred = griddata(X_star, r_pred.flatten(), (t, x), method='cubic')


plt.figure(figsize=(18, 9))
plt.subplot(2, 3, 1)
plt.pcolor(t, x, U_star, cmap='jet')
plt.colorbar()
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.title('Exact u(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 2)
plt.pcolor(t, x, U_pred, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Predicted u(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 3)
plt.pcolor(t, x, np.abs(U_star - U_pred), cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Absolute error')
plt.tight_layout()

plt.subplot(2, 3, 4)
plt.pcolor(t, x, r_star, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Exact r(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 5)
plt.pcolor(t, x, R_pred, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Predicted r(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 6)
plt.pcolor(t, x, np.abs(r_star - R_pred), cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Absolute error')
plt.tight_layout()
plt.show()

# %% [markdown]
# **NTK Eigenvalues**

# %%
# Create empty lists for storing the eigenvalues of NTK
lam_K_u_log = []
lam_K_ut_log = []
lam_K_r_log = []

# Restore the NTK
K_u_list = model.K_u_log
K_ut_list = model.K_ut_log
K_r_list = model.K_r_log

K_list = []
    
for k in range(len(K_u_list)):
    K_u = K_u_list[k]
    K_ut = K_ut_list[k]
    K_r = K_r_list[k]
    
    # Compute eigenvalues
    lam_K_u, _ = np.linalg.eig(K_u)
    lam_K_ut, _ = np.linalg.eig(K_ut)
    lam_K_r, _ = np.linalg.eig(K_r)
    # Sort in descresing order
    lam_K_u = np.sort(np.real(lam_K_u))[::-1]
    lam_K_ut = np.sort(np.real(lam_K_ut))[::-1]
    lam_K_r = np.sort(np.real(lam_K_r))[::-1]
    
    # Store eigenvalues
    lam_K_u_log.append(lam_K_u)
    lam_K_ut_log.append(lam_K_ut)
    lam_K_r_log.append(lam_K_r)

# %%
#  Eigenvalues of NTK
fig = plt.figure(figsize=(18, 5))
plt.subplot(1,3,1)

plt.plot(lam_K_u_log[0], label = '$n=0$')
plt.plot(lam_K_u_log[1], '--', label = '$n=10,000$')
plt.plot(lam_K_u_log[4], '--', label = '$n=40,000$')
plt.plot(lam_K_u_log[-1], '--', label = '$n=80,000$')
plt.xscale('log')
plt.yscale('log')

plt.title(r'Eigenvalues of ${K}_u$')

plt.subplot(1,3,2)
plt.plot(lam_K_ut_log[0], label = '$n=0$')
plt.plot(lam_K_ut_log[1], '--',label = '$n=10,000$')
plt.plot(lam_K_ut_log[4], '--', label = '$n=40,000$')
plt.plot(lam_K_ut_log[-1], '--', label = '$n=80,000$')
plt.xscale('log')
plt.yscale('log')
plt.title(r'Eigenvalues of ${K}_{u_t}$')

ax =plt.subplot(1,3,3)
plt.plot(lam_K_r_log[0], label = '$n=0$')
plt.plot(lam_K_r_log[1], '--', label = '$n=10,000$')
plt.plot(lam_K_r_log[4], '--', label = '$n=40,000$')
plt.plot(lam_K_r_log[-1], '--', label = '$n=80,000$')
plt.xscale('log')
plt.yscale('log')
plt.title(r'Eigenvalues of ${K}_{r}$')
handles, labels = ax.get_legend_handles_labels()
fig.legend(handles, labels, loc="upper left", bbox_to_anchor=(0.35, -0.02),
            borderaxespad=0, bbox_transform=fig.transFigure, ncol=4)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Evolution of NTK Weights**

# %%
if update_lam == True:

  lam_u_log = model.lam_u_log
  lam_ut_log = model.lam_ut_log
  lam_r_log = model.lam_r_log

# %%
fig = plt.figure(figsize=(6, 5))
plt.plot(lam_u_log, label='$\lambda_u$')
plt.plot(lam_ut_log, label='$\lambda_{u_t}$')
plt.plot(lam_r_log, label='$\lambda_{r}$')
plt.xlabel('iterations')
plt.ylabel('$\lambda$')
plt.yscale('log')
plt.legend( )
plt.tight_layout()
plt.show()
