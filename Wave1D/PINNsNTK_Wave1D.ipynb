# %%
import tensorflow as tf
from Compute_Jacobian import jacobian # Please download 'Compute_Jacobian.py' in the repository 
import numpy as np
import timeit
from scipy.interpolate import griddata
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import os



os.environ["KMP_WARNINGS"] = "FALSE" 
import timeit

import sys

import scipy
import scipy.io
import time

# %%
class Sampler:
    # Initialize the class
    def __init__(self, dim, coords, func, name = None):
        self.dim = dim
        self.coords = coords
        self.func = func
        self.name = name
    def sample(self, N):
        x = self.coords[0:1,:] + (self.coords[1:2,:]-self.coords[0:1,:])*np.random.rand(N, self.dim)
        y = self.func(x)
        return x, y

# Define the exact solution and its derivatives
def u(x, a, c):
    """
    :param x: x = (t, x)
    """
    t = x[:,0:1]
    x = x[:,1:2]
    return np.sin(np.pi * x) * np.cos(c * np.pi * t) + a * np.sin(2 * c * np.pi* x) * np.cos(4 * c  * np.pi * t)

def u_t(x,a, c):
    t = x[:,0:1]
    x = x[:,1:2]
    u_t = -  c * np.pi * np.sin(np.pi * x) * np.sin(c * np.pi * t) -  a * 4 * c * np.pi * np.sin(2 * c * np.pi* x) * np.sin(4 * c * np.pi * t)
    return u_t

def u_tt(x, a, c):
    t = x[:,0:1]
    x = x[:,1:2]
    u_tt = -(c * np.pi)**2 * np.sin( np.pi * x) * np.cos(c * np.pi * t) - a * (4 * c * np.pi)**2 *  np.sin(2 * c * np.pi* x) * np.cos(4 * c * np.pi * t)
    return u_tt

def u_xx(x, a, c):
    t = x[:,0:1]
    x = x[:,1:2]
    u_xx = - np.pi**2 * np.sin( np.pi * x) * np.cos(c * np.pi * t) -  a * (2 * c * np.pi)** 2 * np.sin(2 * c * np.pi* x) * np.cos(4 * c * np.pi * t)
    return  u_xx


def r(x, a, c):
    return u_tt(x, a, c) - c**2 * u_xx(x, a, c)

def operator(u, t, x, c, sigma_t=1.0, sigma_x=1.0):
    u_t = tf.gradients(u, t)[0] / sigma_t
    u_x = tf.gradients(u, x)[0] / sigma_x
    u_tt = tf.gradients(u_t, t)[0] / sigma_t
    u_xx = tf.gradients(u_x, x)[0] / sigma_x
    residual = u_tt - c**2 * u_xx
    return residual

# %%
class PINN:
    # Initialize the class
    def __init__(self, layers, operator, ics_sampler, bcs_sampler, res_sampler, c, kernel_size , sess):
        # Normalization 
        X, _ = res_sampler.sample(np.int32(1e5))
        self.mu_X, self.sigma_X = X.mean(0), X.std(0)
        self.mu_t, self.sigma_t = self.mu_X[0], self.sigma_X[0]
        self.mu_x, self.sigma_x = self.mu_X[1], self.sigma_X[1]

        # Samplers
        self.operator = operator
        self.ics_sampler = ics_sampler
        self.bcs_sampler = bcs_sampler
        self.res_sampler = res_sampler

        self.sess = sess
        # Initialize network weights and biases
        self.layers = layers
        self.weights, self.biases = self.initialize_NN(layers)
        
        # weights
        self.lam_u_val = np.array(1.0)
        self.lam_ut_val = np.array(1.0)
        self.lam_r_val = np.array(1.0)
      
        # Wave constant
        self.c = tf.constant(c, dtype=tf.float32)
        
        self.kernel_size = kernel_size # Size of the NTK matrix

        # Define Tensorflow session
        self.sess = tf.Session(config=tf.ConfigProto(log_device_placement=False))

        # Define placeholders and computational graph
        self.t_u_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_u_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_ics_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_ics_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.u_ics_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_r_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_r_tf = tf.placeholder(tf.float32, shape=(None, 1))
        
        self.lam_u_tf = tf.placeholder(tf.float32, shape=self.lam_u_val.shape)
        self.lam_ut_tf = tf.placeholder(tf.float32, shape=self.lam_u_val.shape)
        self.lam_r_tf = tf.placeholder(tf.float32, shape=self.lam_u_val.shape)
        

        # Define placeholders for NTK computation
        D1 = self.kernel_size    # boundary
        D2 = self.kernel_size    # ut   
        D3 = self.kernel_size    # residual  D1 = D3 = 3D2

        self.t_u_ntk_tf = tf.placeholder(tf.float32, shape=(D1, 1))
        self.x_u_ntk_tf = tf.placeholder(tf.float32, shape=(D1, 1))
        
        self.t_ut_ntk_tf = tf.placeholder(tf.float32, shape=(D2, 1))
        self.x_ut_ntk_tf = tf.placeholder(tf.float32, shape=(D2, 1))
        
        self.t_r_ntk_tf = tf.placeholder(tf.float32, shape=(D3, 1))
        self.x_r_ntk_tf = tf.placeholder(tf.float32, shape=(D3, 1))

        # Evaluate predictions
        self.u_ics_pred = self.net_u(self.t_ics_tf, self.x_ics_tf)
        self.u_t_ics_pred = self.net_u_t(self.t_ics_tf, self.x_ics_tf)
        self.u_bc1_pred = self.net_u(self.t_bc1_tf, self.x_bc1_tf)
        self.u_bc2_pred = self.net_u(self.t_bc2_tf, self.x_bc2_tf)

        self.u_pred = self.net_u(self.t_u_tf, self.x_u_tf)
        self.r_pred = self.net_r(self.t_r_tf, self.x_r_tf)
        
        # Define predictions for NTK computation
        self.u_ntk_pred = self.net_u(self.t_u_ntk_tf, self.x_u_ntk_tf)
        self.ut_ntk_pred = self.net_u_t(self.t_ut_ntk_tf, self.x_ut_ntk_tf)
        self.r_ntk_pred = self.net_r(self.t_r_ntk_tf, self.x_r_ntk_tf)

        # Boundary loss and Initial loss
        self.loss_ics_u = tf.reduce_mean(tf.square(self.u_ics_tf - self.u_ics_pred))
        self.loss_ics_u_t = tf.reduce_mean(tf.square(self.u_t_ics_pred))
        self.loss_bc1 = tf.reduce_mean(tf.square(self.u_bc1_pred))
        self.loss_bc2 = tf.reduce_mean(tf.square(self.u_bc2_pred))

        self.loss_bcs = self.loss_ics_u + self.loss_bc1 + self.loss_bc2

        # Residual loss
        self.loss_res = tf.reduce_mean(tf.square(self.r_pred))

        # Total loss
        self.loss = self.lam_r_tf * self.loss_res + self.lam_u_tf * self.loss_bcs + self.lam_ut_tf * self.loss_ics_u_t 

        # Define optimizer with learning rate schedule
        self.global_step = tf.Variable(0, trainable=False)
        starter_learning_rate = 1e-3
        self.learning_rate = tf.train.exponential_decay(starter_learning_rate, self.global_step,
                                                        1000, 0.9, staircase=False)
        # Passing global_step to minimize() will increment it at each step.
        self.train_op = tf.train.AdamOptimizer(self.learning_rate).minimize(self.loss, global_step=self.global_step)

        # Logger
        self.loss_bcs_log = []
        self.loss_ut_ics_log = []
        self.loss_res_log = []
        self.saver = tf.train.Saver()
        
        # Compute the Jacobian for weights and biases in each hidden layer  
        self.J_u = self.compute_jacobian(self.u_ntk_pred)
        self.J_ut = self.compute_jacobian(self.ut_ntk_pred)
        self.J_r = self.compute_jacobian(self.r_ntk_pred)
        
        self.K_u = self.compute_ntk(self.J_u, D1, self.J_u, D1)
        self.K_ut = self.compute_ntk(self.J_ut, D2, self.J_ut, D2)
        self.K_r = self.compute_ntk(self.J_r, D3, self.J_r, D3)
        
        # NTK logger 
        self.K_u_log = []
        self.K_ut_log = []
        self.K_r_log = []
        
        # weights logger
        self.lam_u_log = []
        self.lam_ut_log = []
        self.lam_r_log = []
        
         # Initialize Tensorflow variables
        init = tf.global_variables_initializer()
        self.sess.run(init)

    # Initialize network weights and biases using Xavier initialization
    def initialize_NN(self, layers):
        # Xavier initialization
        def xavier_init(size):
            in_dim = size[0]
            out_dim = size[1]
            xavier_stddev = 1. / np.sqrt((in_dim + out_dim) / 2.)
            return tf.Variable(tf.random.normal([in_dim, out_dim], dtype=tf.float32) * xavier_stddev,
                               dtype=tf.float32)

        weights = []
        biases = []
        num_layers = len(layers)
        for l in range(0, num_layers - 1):
            W = xavier_init(size=[layers[l], layers[l + 1]])
            b = tf.Variable(tf.zeros([1, layers[l + 1]], dtype=tf.float32), dtype=tf.float32)
            weights.append(W)
            biases.append(b)
        return weights, biases

    # Evaluates the forward pass
    def forward_pass(self, H, layers, weights, biases):
        num_layers = len(layers)
        for l in range(0, num_layers - 2):
            W = weights[l]
            b = biases[l]
            H = tf.tanh(tf.add(tf.matmul(H, W), b))
        W = weights[-1]
        b = biases[-1]
        H = tf.add(tf.matmul(H, W), b)
        return H

    # Forward pass for u
    def net_u(self, t, x):
        u = self.forward_pass(tf.concat([t, x], 1),
                              self.layers,
                              self.weights,
                              self.biases)
        return u

    # Forward pass for du/dt
    def net_u_t(self, t, x):
        u_t = tf.gradients(self.net_u(t, x), t)[0] / self.sigma_t
        return u_t

    # Forward pass for the residual
    def net_r(self, t, x):
        u = self.net_u(t, x)
        residual = self.operator(u, t, x,
                                 self.c,
                                 self.sigma_t,
                                 self.sigma_x)
        return residual
    
    
    # Compute Jacobian for each weights and biases in each layer and retrun a list 
    def compute_jacobian(self, f):
        J_list =[]
        L = len(self.weights)    
        for i in range(L):
            J_w = jacobian(f, self.weights[i])
            J_list.append(J_w)
     
        for i in range(L):
            J_b = jacobian(f, self.biases[i])
            J_list.append(J_b)
        return J_list
    
    # Compute the empirical NTK = J J^T
    def compute_ntk(self, J1_list, D1, J2_list, D2):

        N = len(J1_list)
        
        Ker = tf.zeros((D1,D2))
        for k in range(N):
            J1 = tf.reshape(J1_list[k], shape=(D1,-1))
            J2 = tf.reshape(J2_list[k], shape=(D2,-1))
            
            K = tf.matmul(J1, tf.transpose(J2))
            Ker = Ker + K
        return Ker

    def fetch_minibatch(self, sampler, N):
        X, Y = sampler.sample(N)
        X = (X - self.mu_X) / self.sigma_X
        return X, Y

        # Trains the model by minimizing the MSE loss

    def trainmb(self, nIter=10000, batch_size=128, log_NTK=False, update_lam=False):

        start_time = timeit.default_timer()
        for it in range(nIter):
            # Fetch boundary mini-batches
            X_ics_batch, u_ics_batch = self.fetch_minibatch(self.ics_sampler, batch_size // 3)
            X_bc1_batch, _ = self.fetch_minibatch(self.bcs_sampler[0], batch_size // 3)
            X_bc2_batch, _ = self.fetch_minibatch(self.bcs_sampler[1], batch_size // 3)
            
            # Fetch residual mini-batch
            X_res_batch, _ = self.fetch_minibatch(self.res_sampler, batch_size)
            # Define a dictionary for associating placeholders with data
            tf_dict = {self.t_ics_tf: X_ics_batch[:, 0:1], self.x_ics_tf: X_ics_batch[:, 1:2],
                       self.u_ics_tf: u_ics_batch,
                       self.t_bc1_tf: X_bc1_batch[:, 0:1], self.x_bc1_tf: X_bc1_batch[:, 1:2],
                       self.t_bc2_tf: X_bc2_batch[:, 0:1], self.x_bc2_tf: X_bc2_batch[:, 1:2],
                       self.t_r_tf: X_res_batch[:, 0:1], self.x_r_tf: X_res_batch[:, 1:2],
                       self.lam_u_tf: self.lam_u_val,
                       self.lam_ut_tf: self.lam_ut_val,
                       self.lam_r_tf: self.lam_r_val}

            # Run the Tensorflow session to minimize the loss
            self.sess.run(self.train_op, tf_dict)

            # Print
            if it % 100 == 0:
                elapsed = timeit.default_timer() - start_time

                loss_value = self.sess.run(self.loss, tf_dict)
                loss_bcs_value = self.sess.run(self.loss_bcs, tf_dict)
                loss_ics_ut_value = self.sess.run(self.loss_ics_u_t, tf_dict)
                loss_res_value = self.sess.run(self.loss_res, tf_dict)

                # # Store losses
                # self.loss_bcs_log.append(loss_bcs_value)
                # self.loss_res_log.append(loss_res_value)
                # self.loss_ut_ics_log.append(loss_ics_ut_value)

                print('It: %d, Loss: %.3e, Loss_res: %.3e,  Loss_bcs: %.3e, Loss_ut_ics: %.3e,, Time: %.2f' %(it, loss_value, loss_res_value, loss_bcs_value, loss_ics_ut_value, elapsed))
                
                print('lambda_u: {:.3e}'.format(self.lam_u_val))
                print('lambda_ut: {:.3e}'.format(self.lam_ut_val))
                print('lambda_r: {:.3e}'.format(self.lam_r_val))
                sys.stdout.flush()
                start_time = timeit.default_timer()
            
          
                if it % 100 == 0:
                        print("Compute NTK...")
 
                        X_bc_batch = np.vstack([X_ics_batch, X_bc1_batch, X_bc2_batch])
                        X_ics_batch, u_ics_batch = self.fetch_minibatch(self.ics_sampler, batch_size )

                        tf_dict = {self.t_u_ntk_tf: X_bc_batch[:,0:1], self.x_u_ntk_tf: X_bc_batch[:, 1:2],
                                   self.t_ut_ntk_tf: X_ics_batch[:,0:1], self.x_ut_ntk_tf: X_ics_batch[:, 1:2],
                                   self.t_r_ntk_tf: X_res_batch[:,0:1], self.x_r_ntk_tf: X_res_batch[:, 1:2]}
                        
                        K_u_value, K_ut_value, K_r_value =  self.sess.run([self.K_u, self.K_ut, self.K_r], tf_dict)
                        
                        trace_K = np.trace(K_u_value) + np.trace(K_ut_value) +  np.trace(K_r_value)

                        # # Store NTK matrices
                        # self.K_u_log.append(K_u_value)
                        # self.K_ut_log.append(K_ut_value)
                        # self.K_r_log.append(K_r_value)
                        
                        # if update_lam:

                        self.lam_u_val = trace_K / np.trace(K_u_value)
                        self.lam_ut_val = trace_K /np.trace(K_ut_value)
                        self.lam_r_val = trace_K / np.trace(K_r_value)

                        #   # Store NTK weights
                        #   self.lam_u_log.append(self.lam_u_val)
                        #   self.lam_ut_log.append(self.lam_ut_val)
                        #   self.lam_r_log.append(self.lam_r_val)
                        
                        
    def train(self, nIter , bcbatch_size , ubatch_size):

        start_time = timeit.default_timer()

        # Fetch boundary mini-batches
        X_ics_batch, u_ics_batch = self.fetch_minibatch(self.ics_sampler, bcbatch_size)
        X_bc1_batch, _ = self.fetch_minibatch(self.bcs_sampler[0], bcbatch_size )
        X_bc2_batch, _ = self.fetch_minibatch(self.bcs_sampler[1], bcbatch_size )
        
        # Fetch residual mini-batch
        X_res_batch, _ = self.fetch_minibatch(self.res_sampler, ubatch_size)
        # print("inside trainmb: " , X_res_batch.shape)
        # Define a dictionary for associating placeholders with data
        tf_dict = {self.t_ics_tf: X_ics_batch[:, 0:1], self.x_ics_tf: X_ics_batch[:, 1:2],
                    self.u_ics_tf: u_ics_batch,
                    self.t_bc1_tf: X_bc1_batch[:, 0:1], self.x_bc1_tf: X_bc1_batch[:, 1:2],
                    self.t_bc2_tf: X_bc2_batch[:, 0:1], self.x_bc2_tf: X_bc2_batch[:, 1:2],
                    self.t_r_tf: X_res_batch[:, 0:1], self.x_r_tf: X_res_batch[:, 1:2],
                    self.lam_u_tf: self.lam_u_val,
                    self.lam_ut_tf: self.lam_ut_val,
                    self.lam_r_tf: self.lam_r_val
                    }
        
        # Fetch boundary mini-batches
        X_ics_batch, u_ics_batch = self.fetch_minibatch(self.ics_sampler, self.kernel_size // 3)
        X_bc1_batch, _ = self.fetch_minibatch(self.bcs_sampler[0], self.kernel_size // 3)
        X_bc2_batch, _ = self.fetch_minibatch(self.bcs_sampler[1], self.kernel_size // 3)

        X_bc_batch = np.vstack([X_ics_batch, X_bc1_batch, X_bc2_batch])
        X_res_batch, _ = self.fetch_minibatch(self.res_sampler, self.kernel_size)
        X_ics_batch, u_ics_batch = self.fetch_minibatch(self.ics_sampler, self.kernel_size )

        ntk_dict = {self.t_u_ntk_tf: X_bc_batch[:,0:1], self.x_u_ntk_tf: X_bc_batch[:, 1:2],
                                   self.t_ut_ntk_tf: X_ics_batch[:,0:1], self.x_ut_ntk_tf: X_ics_batch[:, 1:2],
                                   self.t_r_ntk_tf: X_res_batch[:,0:1], self.x_r_ntk_tf: X_res_batch[:, 1:2]}
        for it in range(nIter):

            # Run the Tensorflow session to minimize the loss
            self.sess.run(self.train_op, tf_dict)

            # Print
            if it % 100 == 0:
                elapsed = timeit.default_timer() - start_time

                loss_value = self.sess.run(self.loss, tf_dict)
                loss_bcs_value = self.sess.run(self.loss_bcs, tf_dict)
                loss_ics_ut_value = self.sess.run(self.loss_ics_u_t, tf_dict)
                loss_res_value = self.sess.run(self.loss_res, tf_dict)

                # # Store losses
                # self.loss_bcs_log.append(loss_bcs_value)
                # self.loss_res_log.append(loss_res_value)
                # self.loss_ut_ics_log.append(loss_ics_ut_value)

                print('It: %d, Loss: %.3e, Loss_res: %.3e,  Loss_bcs: %.3e, Loss_ut_ics: %.3e,, Time: %.2f' %(it, loss_value, loss_res_value, loss_bcs_value, loss_ics_ut_value, elapsed))
                
                print('lambda_u: {:.3e}'.format(self.lam_u_val))
                print('lambda_ut: {:.3e}'.format(self.lam_ut_val))
                print('lambda_r: {:.3e}'.format(self.lam_r_val))
                sys.stdout.flush()
                start_time = timeit.default_timer()
            
          
                if it % 100 == 0:
                        print("Compute NTK...")

                    # # Fetch boundary mini-batches
                    #     X_ics_batch, u_ics_batch = self.fetch_minibatch(self.ics_sampler, self.kernel_size // 3)
                    #     X_bc1_batch, _ = self.fetch_minibatch(self.bcs_sampler[0], self.kernel_size // 3)
                    #     X_bc2_batch, _ = self.fetch_minibatch(self.bcs_sampler[1], self.kernel_size // 3)
                        
                        # Fetch residual mini-batch
                
                        
                        K_u_value, K_ut_value, K_r_value =  self.sess.run([self.K_u, self.K_ut, self.K_r], ntk_dict)
                        
                        trace_K = np.trace(K_u_value) + np.trace(K_ut_value) +  np.trace(K_r_value)

                        # # Store NTK matrices
                        # self.K_u_log.append(K_u_value)
                        # self.K_ut_log.append(K_ut_value)
                        # self.K_r_log.append(K_r_value)
                        
                        # if update_lam:

                        self.lam_u_val = trace_K / np.trace(K_u_value)
                        self.lam_ut_val = trace_K /np.trace(K_ut_value)
                        self.lam_r_val = trace_K / np.trace(K_r_value)

                        #   # Store NTK weights
                        #   self.lam_u_log.append(self.lam_u_val)
                        #   self.lam_ut_log.append(self.lam_ut_val)
                        #   self.lam_r_log.append(self.lam_r_val)
                        


    # Evaluates predictions at test points
    def predict_u(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.t_u_tf: X_star[:, 0:1], self.x_u_tf: X_star[:, 1:2]}
        u_star = self.sess.run(self.u_pred, tf_dict)
        return u_star

        # Evaluates predictions at test points

    def predict_r(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.t_r_tf: X_star[:, 0:1], self.x_r_tf: X_star[:, 1:2]}
        r_star = self.sess.run(self.r_pred, tf_dict)
        return r_star
    
   ###############################################################################################################################################
   # 
   # ###############################################################################################################################################
   # 
   # ###############################################################################################################################################
   # 
   #

# %%
#test_method(mtd , layers,  X_u, Y_u, X_r, Y_r ,  X_star , u_star , r_star  , nIter ,batch_size , bcbatch_size , ubatch_size)
def test_method(method , layers,  ics_sampler, bcs_sampler, res_sampler, c ,kernel_size , X_star , u_star , r_star , nIter ,mbbatch_size , bcbatch_size , ubatch_size ):

    tf.reset_default_graph()
    gpu_options = tf.GPUOptions(visible_device_list="0")
    with tf.Session(config=tf.ConfigProto(gpu_options=gpu_options,allow_soft_placement=False, log_device_placement=False)) as sess:
        # sess.run(init)

        model = PINN(layers, operator, ics_sampler, bcs_sampler, res_sampler, c, kernel_size , sess)
        # Train model
        start_time = time.time()

        if method =="full_batch":
            print("full_batch method is used")
            model.train(nIter  , bcbatch_size , ubatch_size  )
        elif method =="mini_batch":
            print("mini_batch method is used")
            model.trainmb(nIter, mbbatch_size)
        else:
            print("unknown method!")
        elapsed = time.time() - start_time

        # Predictions
        u_pred = model.predict_u(X_star)
        r_pred = model.predict_r(X_star)
        # Predictions

        sess.close()   

    error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)

    print('elapsed: {:.2e}'.format(elapsed))

    print('Relative L2 error_u: {:.2e}'.format(error_u))


    return [elapsed, error_u  ]

###############################################################################################################################################

# %%
# Define PINN model
a = 0.5
c = 2

kernel_size = 300

# Domain boundaries
ics_coords = np.array([[0.0, 0.0],  [0.0, 1.0]])
bc1_coords = np.array([[0.0, 0.0],  [1.0, 0.0]])
bc2_coords = np.array([[0.0, 1.0],  [1.0, 1.0]])
dom_coords = np.array([[0.0, 0.0],  [1.0, 1.0]])

# Create initial conditions samplers
ics_sampler = Sampler(2, ics_coords, lambda x: u(x, a, c), name='Initial Condition 1')

# Create boundary conditions samplers
bc1 = Sampler(2, bc1_coords, lambda x: u(x, a, c), name='Dirichlet BC1')
bc2 = Sampler(2, bc2_coords, lambda x: u(x, a, c), name='Dirichlet BC2')
bcs_sampler = [bc1, bc2]

# Create residual sampler
res_sampler = Sampler(2, dom_coords, lambda x: r(x, a, c), name='Forcing')



nIter =10000
bcbatch_size = 350
ubatch_size = 5000
mbbatch_size = 300



# Define model
mode = 'M3'
layers = [2, 500, 500, 500, 1]


nn = 200
t = np.linspace(dom_coords[0, 0], dom_coords[1, 0], nn)[:, None]
x = np.linspace(dom_coords[0, 1], dom_coords[1, 1], nn)[:, None]
t, x = np.meshgrid(t, x)
X_star = np.hstack((t.flatten()[:, None], x.flatten()[:, None]))

u_star = u(X_star, a,c)
r_star = r(X_star, a, c)

iterations = 1
methods = [  "mini_batch"]

result_dict =  dict((mtd, []) for mtd in methods)

for mtd in methods:
    print("Method: ", mtd)
    time_list = []
    error_u_list = []
    
    for index in range(iterations):

        print("Epoch: ", str(index+1))

        # Create residual sampler

        [elapsed, error_u] = test_method(mtd , layers,  ics_sampler, bcs_sampler, res_sampler, c ,kernel_size , X_star , u_star , r_star , nIter ,mbbatch_size , bcbatch_size , ubatch_size )


        print('elapsed: {:.2e}'.format(elapsed))
        print('Relative L2 error_u: {:.2e}'.format(error_u))

        time_list.append(elapsed)
        error_u_list.append(error_u)

    print("\n\nMethod: ", mtd)
    print("\naverage of time_list:" , sum(time_list) / len(time_list) )
    print("average of error_u_list:" , sum(error_u_list) / len(error_u_list) )
    # print("average of error_r_list:" , sum(error_r_list) / len(error_r_list) )

    result_dict[mtd] = [time_list ,error_u_list]
    # scipy.io.savemat("M2_result_"+str(iterations)+"_"+mtd+".mat" , {'time_list':np.array(time_list),'error_u_list':np.array(error_u_list),'error_f_list':np.array(error_f_list)})

    scipy.io.savemat("./1DWave_database/mini_batch_1Dwave_"+mode+"_result_mb"+str(mbbatch_size)+"_fb"+str(ubatch_size)+"_bc"+str(mbbatch_size)+"_"+str(iterations)+".mat" , result_dict)

###############################################################################################################################################
# Out:
# Method:  mini_batch
# Epoch:  1
# WARNING:tensorflow:From /tmp/ipykernel_30174/2727038420.py:5: The name tf.GPUOptions is deprecated. Please use tf.compat.v1.GPUOptions instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_30174/2727038420.py:6: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_30174/2727038420.py:7: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_30174/2727038420.py:7: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_30174/1679846595.py:35: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# 2023-11-24 08:05:20.479468: I tensorflow/core/platform/cpu_feature_guard.cc:145] This TensorFlow binary is optimized with Intel(R) MKL-DNN to use the following CPU instructions in performance critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in non-MKL-DNN operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-24 08:05:20.499989: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2899885000 Hz
# 2023-11-24 08:05:20.500467: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55c492e381a0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-11-24 08:05:20.500482: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2023-11-24 08:05:20.513521: I tensorflow/core/common_runtime/process_util.cc:115] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# WARNING:tensorflow:From /tmp/ipykernel_30174/1679846595.py:101: The name tf.train.exponential_decay is deprecated. Please use tf.compat.v1.train.exponential_decay instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_30174/1679846595.py:104: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_30174/1679846595.py:110: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_30174/1679846595.py:132: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# mini_batch method is used
# It: 0, Loss: 2.303e+01, Loss_res: 5.652e+00,  Loss_bcs: 7.210e+00, Loss_ut_ics: 1.017e+01,, Time: 1.72
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# Compute NTK...
# It: 100, Loss: 3.173e+00, Loss_res: 2.017e-03,  Loss_bcs: 3.685e-01, Loss_ut_ics: 3.942e-02,, Time: 13.03
# lambda_u: 8.222e+00
# lambda_ut: 3.535e+00
# lambda_r: 1.679e+00
# Compute NTK...
# It: 200, Loss: 2.443e+00, Loss_res: 1.923e-02,  Loss_bcs: 3.386e-01, Loss_ut_ics: 4.236e-03,, Time: 10.74
# lambda_u: 7.044e+00
# lambda_ut: 2.187e+00
# lambda_r: 2.495e+00
# Compute NTK...
# It: 300, Loss: 2.615e+00, Loss_res: 8.047e-02,  Loss_bcs: 2.191e-01, Loss_ut_ics: 3.974e-02,, Time: 10.06
# lambda_u: 1.075e+01
# lambda_ut: 3.066e+00
# lambda_r: 1.722e+00
# Compute NTK...
# It: 400, Loss: 9.322e+00, Loss_res: 2.959e-01,  Loss_bcs: 2.110e-01, Loss_ut_ics: 8.006e-02,, Time: 10.36
# lambda_u: 3.967e+01
# lambda_ut: 7.485e+00
# lambda_r: 1.189e+00
# Compute NTK...
# It: 500, Loss: 1.456e+01, Loss_res: 7.334e-01,  Loss_bcs: 1.903e-01, Loss_ut_ics: 7.073e-02,, Time: 9.92
# lambda_u: 6.798e+01
# lambda_ut: 1.145e+01
# lambda_r: 1.114e+00
# Compute NTK...
# It: 600, Loss: 1.220e+01, Loss_res: 4.758e-01,  Loss_bcs: 1.345e-01, Loss_ut_ics: 1.859e-02,, Time: 10.23
# lambda_u: 8.506e+01
# lambda_ut: 1.283e+01
# lambda_r: 1.099e+00
# Compute NTK...
# It: 700, Loss: 1.909e+01, Loss_res: 9.270e-01,  Loss_bcs: 1.481e-01, Loss_ut_ics: 9.318e-02,, Time: 9.81
# lambda_u: 1.148e+02
# lambda_ut: 1.137e+01
# lambda_r: 1.107e+00
# Compute NTK...
# It: 800, Loss: 2.115e+01, Loss_res: 8.158e-01,  Loss_bcs: 1.192e-01, Loss_ut_ics: 5.621e-02,, Time: 9.82
# lambda_u: 1.634e+02
# lambda_ut: 1.388e+01
# lambda_r: 1.085e+00
# Compute NTK...
# It: 900, Loss: 2.362e+01, Loss_res: 1.377e+00,  Loss_bcs: 1.132e-01, Loss_ut_ics: 7.634e-02,, Time: 9.76
# lambda_u: 1.865e+02
# lambda_ut: 1.320e+01
# lambda_r: 1.088e+00
# Compute NTK...
# It: 1000, Loss: 2.549e+01, Loss_res: 1.231e+00,  Loss_bcs: 1.091e-01, Loss_ut_ics: 1.302e-01,, Time: 9.81
# lambda_u: 2.058e+02
# lambda_ut: 1.298e+01
# lambda_r: 1.089e+00
# Compute NTK...
# It: 1100, Loss: 2.076e+01, Loss_res: 5.641e-01,  Loss_bcs: 9.533e-02, Loss_ut_ics: 4.462e-02,, Time: 9.98
# lambda_u: 2.051e+02
# lambda_ut: 1.336e+01
# lambda_r: 1.087e+00
# Compute NTK...
# It: 1200, Loss: 3.942e+01, Loss_res: 1.639e+00,  Loss_bcs: 1.195e-01, Loss_ut_ics: 9.833e-02,, Time: 9.71
# lambda_u: 3.019e+02
# lambda_ut: 1.615e+01
# lambda_r: 1.070e+00
# Compute NTK...
# It: 1300, Loss: 3.692e+01, Loss_res: 1.315e+00,  Loss_bcs: 9.678e-02, Loss_ut_ics: 1.190e-01,, Time: 10.13
# lambda_u: 3.477e+02
# lambda_ut: 1.563e+01
# lambda_r: 1.072e+00
# Compute NTK...
# It: 1400, Loss: 4.237e+01, Loss_res: 3.780e+00,  Loss_bcs: 8.345e-02, Loss_ut_ics: 1.404e-01,, Time: 9.79
# lambda_u: 4.357e+02
# lambda_ut: 1.370e+01
# lambda_r: 1.081e+00
# Compute NTK...
# It: 1500, Loss: 3.383e+01, Loss_res: 2.297e+00,  Loss_bcs: 6.674e-02, Loss_ut_ics: 2.681e-01,, Time: 9.90
# lambda_u: 4.279e+02
# lambda_ut: 1.013e+01
# lambda_r: 1.112e+00
# Compute NTK...
# It: 1600, Loss: 4.142e+01, Loss_res: 4.818e+00,  Loss_bcs: 6.056e-02, Loss_ut_ics: 2.280e-01,, Time: 9.83
# lambda_u: 5.506e+02
# lambda_ut: 1.238e+01
# lambda_r: 1.090e+00
# Compute NTK...
# It: 1700, Loss: 5.411e+01, Loss_res: 3.403e+00,  Loss_bcs: 5.428e-02, Loss_ut_ics: 1.159e+00,, Time: 9.73
# lambda_u: 6.855e+02
# lambda_ut: 1.135e+01
# lambda_r: 1.098e+00
# Compute NTK...
# It: 1800, Loss: 4.439e+01, Loss_res: 2.547e+00,  Loss_bcs: 4.865e-02, Loss_ut_ics: 2.558e-01,, Time: 9.78
# lambda_u: 7.947e+02
# lambda_ut: 1.146e+01
# lambda_r: 1.097e+00
# Compute NTK...
# It: 1900, Loss: 3.788e+01, Loss_res: 2.639e+00,  Loss_bcs: 3.727e-02, Loss_ut_ics: 2.058e-01,, Time: 10.01
# lambda_u: 8.655e+02
# lambda_ut: 1.344e+01
# lambda_r: 1.082e+00
# Compute NTK...
# It: 2000, Loss: 6.054e+01, Loss_res: 4.478e+00,  Loss_bcs: 4.113e-02, Loss_ut_ics: 4.046e-01,, Time: 9.86
# lambda_u: 1.191e+03
# lambda_ut: 1.677e+01
# lambda_r: 1.064e+00
# Compute NTK...
# It: 2100, Loss: 5.924e+01, Loss_res: 6.308e+00,  Loss_bcs: 3.369e-02, Loss_ut_ics: 2.165e-01,, Time: 9.79
# lambda_u: 1.445e+03
# lambda_ut: 1.784e+01
# lambda_r: 1.060e+00
# Compute NTK...
# It: 2200, Loss: 3.580e+01, Loss_res: 3.435e+00,  Loss_bcs: 2.316e-02, Loss_ut_ics: 1.531e-01,, Time: 9.68
# lambda_u: 1.291e+03
# lambda_ut: 1.444e+01
# lambda_r: 1.075e+00
# Compute NTK...
# It: 2300, Loss: 3.696e+01, Loss_res: 4.296e+00,  Loss_bcs: 1.952e-02, Loss_ut_ics: 1.050e-01,, Time: 9.67
# lambda_u: 1.579e+03
# lambda_ut: 1.452e+01
# lambda_r: 1.075e+00
# Compute NTK...
# It: 2400, Loss: 2.967e+01, Loss_res: 3.436e+00,  Loss_bcs: 1.379e-02, Loss_ut_ics: 7.706e-02,, Time: 10.46
# lambda_u: 1.799e+03
# lambda_ut: 1.526e+01
# lambda_r: 1.071e+00
# Compute NTK...
# It: 2500, Loss: 2.332e+01, Loss_res: 4.202e+00,  Loss_bcs: 9.967e-03, Loss_ut_ics: 7.017e-02,, Time: 10.64
# lambda_u: 1.790e+03
# lambda_ut: 1.323e+01
# lambda_r: 1.082e+00
# Compute NTK...
# It: 2600, Loss: 2.935e+01, Loss_res: 6.150e+00,  Loss_bcs: 9.134e-03, Loss_ut_ics: 9.128e-02,, Time: 13.07
# lambda_u: 2.315e+03
# lambda_ut: 1.865e+01
# lambda_r: 1.057e+00
# Compute NTK...
# It: 2700, Loss: 2.623e+01, Loss_res: 5.210e+00,  Loss_bcs: 7.589e-03, Loss_ut_ics: 1.894e-01,, Time: 10.40
# lambda_u: 2.293e+03
# lambda_ut: 1.739e+01
# lambda_r: 1.061e+00
# Compute NTK...
# It: 2800, Loss: 2.601e+01, Loss_res: 5.990e+00,  Loss_bcs: 7.604e-03, Loss_ut_ics: 5.022e-02,, Time: 9.88
# lambda_u: 2.466e+03
# lambda_ut: 1.835e+01
# lambda_r: 1.058e+00
# Compute NTK...
# It: 2900, Loss: 2.249e+01, Loss_res: 4.601e+00,  Loss_bcs: 7.150e-03, Loss_ut_ics: 3.640e-02,, Time: 10.63
# lambda_u: 2.374e+03
# lambda_ut: 1.727e+01
# lambda_r: 1.062e+00
# Compute NTK...
# It: 3000, Loss: 2.056e+01, Loss_res: 5.365e+00,  Loss_bcs: 5.374e-03, Loss_ut_ics: 5.288e-02,, Time: 10.15
# lambda_u: 2.590e+03
# lambda_ut: 1.821e+01
# lambda_r: 1.059e+00
# Compute NTK...
# It: 3100, Loss: 2.133e+01, Loss_res: 5.319e+00,  Loss_bcs: 5.618e-03, Loss_ut_ics: 4.704e-02,, Time: 10.20
# lambda_u: 2.646e+03
# lambda_ut: 1.743e+01
# lambda_r: 1.061e+00
# Compute NTK...
# It: 3200, Loss: 2.780e+01, Loss_res: 7.967e+00,  Loss_bcs: 5.678e-03, Loss_ut_ics: 1.351e-01,, Time: 9.67
# lambda_u: 2.966e+03
# lambda_ut: 1.876e+01
# lambda_r: 1.057e+00
# Compute NTK...
# It: 3300, Loss: 1.721e+01, Loss_res: 3.415e+00,  Loss_bcs: 4.234e-03, Loss_ut_ics: 2.654e-02,, Time: 9.67
# lambda_u: 3.084e+03
# lambda_ut: 2.125e+01
# lambda_r: 1.050e+00
# Compute NTK...
# It: 3400, Loss: 1.950e+01, Loss_res: 5.502e+00,  Loss_bcs: 3.903e-03, Loss_ut_ics: 3.226e-02,, Time: 10.06
# lambda_u: 3.342e+03
# lambda_ut: 2.138e+01
# lambda_r: 1.049e+00
# Compute NTK...
# It: 3500, Loss: 1.915e+01, Loss_res: 5.454e+00,  Loss_bcs: 3.612e-03, Loss_ut_ics: 1.734e-02,, Time: 9.68
# lambda_u: 3.609e+03
# lambda_ut: 2.421e+01
# lambda_r: 1.043e+00
# Compute NTK...
# It: 3600, Loss: 2.218e+01, Loss_res: 6.144e+00,  Loss_bcs: 4.043e-03, Loss_ut_ics: 1.635e-02,, Time: 9.72
# lambda_u: 3.801e+03
# lambda_ut: 2.542e+01
# lambda_r: 1.041e+00
# Compute NTK...
# It: 3700, Loss: 2.157e+01, Loss_res: 4.439e+00,  Loss_bcs: 4.362e-03, Loss_ut_ics: 2.189e-02,, Time: 9.90
# lambda_u: 3.764e+03
# lambda_ut: 2.349e+01
# lambda_r: 1.045e+00
# Compute NTK...
# It: 3800, Loss: 2.008e+01, Loss_res: 4.588e+00,  Loss_bcs: 3.604e-03, Loss_ut_ics: 7.861e-02,, Time: 9.79
# lambda_u: 3.723e+03
# lambda_ut: 2.386e+01
# lambda_r: 1.044e+00
# Compute NTK...
# It: 3900, Loss: 2.193e+01, Loss_res: 7.949e+00,  Loss_bcs: 2.992e-03, Loss_ut_ics: 5.351e-02,, Time: 9.64
# lambda_u: 4.077e+03
# lambda_ut: 2.776e+01
# lambda_r: 1.038e+00
# Compute NTK...
# It: 4000, Loss: 1.910e+01, Loss_res: 3.951e+00,  Loss_bcs: 3.427e-03, Loss_ut_ics: 4.448e-02,, Time: 9.65
# lambda_u: 4.036e+03
# lambda_ut: 2.609e+01
# lambda_r: 1.040e+00
# Compute NTK...
# It: 4100, Loss: 2.040e+01, Loss_res: 6.118e+00,  Loss_bcs: 2.758e-03, Loss_ut_ics: 7.137e-02,, Time: 9.86
# lambda_u: 4.385e+03
# lambda_ut: 2.736e+01
# lambda_r: 1.038e+00
# Compute NTK...
# It: 4200, Loss: 2.476e+01, Loss_res: 7.893e+00,  Loss_bcs: 3.221e-03, Loss_ut_ics: 4.773e-02,, Time: 10.56
# lambda_u: 4.712e+03
# lambda_ut: 2.944e+01
# lambda_r: 1.035e+00
# Compute NTK...
# It: 4300, Loss: 2.357e+01, Loss_res: 6.769e+00,  Loss_bcs: 2.503e-03, Loss_ut_ics: 1.496e-01,, Time: 10.42
# lambda_u: 4.785e+03
# lambda_ut: 3.075e+01
# lambda_r: 1.034e+00
# Compute NTK...
# It: 4400, Loss: 1.476e+01, Loss_res: 3.834e+00,  Loss_bcs: 2.101e-03, Loss_ut_ics: 2.044e-02,, Time: 10.01
# lambda_u: 4.847e+03
# lambda_ut: 3.012e+01
# lambda_r: 1.035e+00
# Compute NTK...
# It: 4500, Loss: 1.786e+01, Loss_res: 4.983e+00,  Loss_bcs: 2.344e-03, Loss_ut_ics: 3.265e-02,, Time: 10.16
# lambda_u: 4.994e+03
# lambda_ut: 3.048e+01
# lambda_r: 1.034e+00
# Compute NTK...
# It: 4600, Loss: 1.747e+01, Loss_res: 3.827e+00,  Loss_bcs: 2.500e-03, Loss_ut_ics: 6.177e-02,, Time: 10.02
# lambda_u: 4.674e+03
# lambda_ut: 2.941e+01
# lambda_r: 1.035e+00
# Compute NTK...
# It: 4700, Loss: 1.874e+01, Loss_res: 3.721e+00,  Loss_bcs: 2.376e-03, Loss_ut_ics: 7.149e-02,, Time: 10.24
# lambda_u: 5.306e+03
# lambda_ut: 3.201e+01
# lambda_r: 1.032e+00
# Compute NTK...
# It: 4800, Loss: 1.375e+01, Loss_res: 2.602e+00,  Loss_bcs: 2.243e-03, Loss_ut_ics: 1.271e-02,, Time: 9.77
# lambda_u: 4.754e+03
# lambda_ut: 3.124e+01
# lambda_r: 1.033e+00
# Compute NTK...
# It: 4900, Loss: 2.127e+01, Loss_res: 4.883e+00,  Loss_bcs: 1.981e-03, Loss_ut_ics: 1.627e-01,, Time: 9.98
# lambda_u: 5.236e+03
# lambda_ut: 3.614e+01
# lambda_r: 1.029e+00
# Compute NTK...
# It: 5000, Loss: 1.083e+01, Loss_res: 2.533e+00,  Loss_bcs: 1.665e-03, Loss_ut_ics: 1.113e-02,, Time: 10.53
# lambda_u: 4.719e+03
# lambda_ut: 3.181e+01
# lambda_r: 1.033e+00
# Compute NTK...
# It: 5100, Loss: 1.210e+01, Loss_res: 3.599e+00,  Loss_bcs: 1.476e-03, Loss_ut_ics: 2.354e-02,, Time: 10.35
# lambda_u: 5.151e+03
# lambda_ut: 3.325e+01
# lambda_r: 1.031e+00
# Compute NTK...
# It: 5200, Loss: 9.845e+00, Loss_res: 2.933e+00,  Loss_bcs: 1.214e-03, Loss_ut_ics: 1.472e-02,, Time: 10.18
# lambda_u: 5.229e+03
# lambda_ut: 3.183e+01
# lambda_r: 1.033e+00
# Compute NTK...
# It: 5300, Loss: 8.778e+00, Loss_res: 2.232e+00,  Loss_bcs: 1.225e-03, Loss_ut_ics: 5.173e-03,, Time: 9.82
# lambda_u: 5.146e+03
# lambda_ut: 3.348e+01
# lambda_r: 1.031e+00
# Compute NTK...
# It: 5400, Loss: 1.082e+01, Loss_res: 2.988e+00,  Loss_bcs: 1.363e-03, Loss_ut_ics: 1.125e-02,, Time: 9.71
# lambda_u: 5.402e+03
# lambda_ut: 3.355e+01
# lambda_r: 1.031e+00
# Compute NTK...
# It: 5500, Loss: 1.044e+01, Loss_res: 3.266e+00,  Loss_bcs: 1.313e-03, Loss_ut_ics: 7.324e-03,, Time: 9.51
# lambda_u: 5.201e+03
# lambda_ut: 3.211e+01
# lambda_r: 1.032e+00
# Compute NTK...
# It: 5600, Loss: 7.508e+00, Loss_res: 1.925e+00,  Loss_bcs: 1.053e-03, Loss_ut_ics: 5.544e-03,, Time: 9.63
# lambda_u: 5.082e+03
# lambda_ut: 3.032e+01
# lambda_r: 1.034e+00
# Compute NTK...
# It: 5700, Loss: 9.677e+00, Loss_res: 2.852e+00,  Loss_bcs: 1.130e-03, Loss_ut_ics: 6.286e-03,, Time: 9.92
# lambda_u: 5.764e+03
# lambda_ut: 3.617e+01
# lambda_r: 1.029e+00
# Compute NTK...
# It: 5800, Loss: 8.507e+00, Loss_res: 2.554e+00,  Loss_bcs: 1.048e-03, Loss_ut_ics: 8.185e-03,, Time: 9.89
# lambda_u: 5.341e+03
# lambda_ut: 3.353e+01
# lambda_r: 1.031e+00
# Compute NTK...
# It: 5900, Loss: 9.097e+00, Loss_res: 3.356e+00,  Loss_bcs: 1.030e-03, Loss_ut_ics: 5.823e-03,, Time: 9.68
# lambda_u: 5.284e+03
# lambda_ut: 3.295e+01
# lambda_r: 1.032e+00
# Compute NTK...
# It: 6000, Loss: 8.689e+00, Loss_res: 2.405e+00,  Loss_bcs: 1.003e-03, Loss_ut_ics: 1.956e-02,, Time: 9.74
# lambda_u: 5.488e+03
# lambda_ut: 3.620e+01
# lambda_r: 1.029e+00
# Compute NTK...
# It: 6100, Loss: 9.238e+00, Loss_res: 3.040e+00,  Loss_bcs: 1.101e-03, Loss_ut_ics: 6.003e-03,, Time: 10.47
# lambda_u: 5.368e+03
# lambda_ut: 3.180e+01
# lambda_r: 1.033e+00
# Compute NTK...
# It: 6200, Loss: 8.573e+00, Loss_res: 2.611e+00,  Loss_bcs: 1.016e-03, Loss_ut_ics: 1.417e-02,, Time: 10.59
# lambda_u: 5.324e+03
# lambda_ut: 3.326e+01
# lambda_r: 1.031e+00
# Compute NTK...
# It: 6300, Loss: 7.738e+00, Loss_res: 1.795e+00,  Loss_bcs: 1.053e-03, Loss_ut_ics: 4.998e-03,, Time: 10.50
# lambda_u: 5.434e+03
# lambda_ut: 3.240e+01
# lambda_r: 1.032e+00
# Compute NTK...
# It: 6400, Loss: 7.147e+00, Loss_res: 1.701e+00,  Loss_bcs: 9.543e-04, Loss_ut_ics: 1.969e-02,, Time: 10.34
# lambda_u: 5.014e+03
# lambda_ut: 3.065e+01
# lambda_r: 1.034e+00
# Compute NTK...
# It: 6500, Loss: 6.275e+00, Loss_res: 1.509e+00,  Loss_bcs: 8.293e-04, Loss_ut_ics: 1.165e-02,, Time: 9.85
# lambda_u: 5.256e+03
# lambda_ut: 3.050e+01
# lambda_r: 1.034e+00
# Compute NTK...
# It: 6600, Loss: 7.305e+00, Loss_res: 1.599e+00,  Loss_bcs: 7.291e-04, Loss_ut_ics: 5.336e-02,, Time: 9.62
# lambda_u: 5.366e+03
# lambda_ut: 3.267e+01
# lambda_r: 1.032e+00
# Compute NTK...
# It: 6700, Loss: 7.531e+00, Loss_res: 1.937e+00,  Loss_bcs: 8.301e-04, Loss_ut_ics: 3.648e-02,, Time: 9.68
# lambda_u: 5.144e+03
# lambda_ut: 3.468e+01
# lambda_r: 1.030e+00
# Compute NTK...
# It: 6800, Loss: 8.076e+00, Loss_res: 3.289e+00,  Loss_bcs: 8.664e-04, Loss_ut_ics: 7.259e-03,, Time: 9.76
# lambda_u: 5.136e+03
# lambda_ut: 3.128e+01
# lambda_r: 1.033e+00
# Compute NTK...
# It: 6900, Loss: 5.390e+00, Loss_res: 1.703e+00,  Loss_bcs: 6.883e-04, Loss_ut_ics: 6.310e-03,, Time: 10.07
# lambda_u: 4.985e+03
# lambda_ut: 3.155e+01
# lambda_r: 1.033e+00
# Compute NTK...
# It: 7000, Loss: 4.302e+00, Loss_res: 1.256e+00,  Loss_bcs: 4.666e-04, Loss_ut_ics: 1.453e-02,, Time: 9.69
# lambda_u: 5.449e+03
# lambda_ut: 3.184e+01
# lambda_r: 1.033e+00
# Compute NTK...
# It: 7100, Loss: 5.825e+00, Loss_res: 1.652e+00,  Loss_bcs: 6.749e-04, Loss_ut_ics: 6.363e-03,, Time: 10.36
# lambda_u: 5.783e+03
# lambda_ut: 3.461e+01
# lambda_r: 1.030e+00
# Compute NTK...
# It: 7200, Loss: 3.107e+00, Loss_res: 7.966e-01,  Loss_bcs: 4.433e-04, Loss_ut_ics: 3.173e-03,, Time: 9.72
# lambda_u: 4.926e+03
# lambda_ut: 3.161e+01
# lambda_r: 1.033e+00
# Compute NTK...
# It: 7300, Loss: 4.792e+00, Loss_res: 1.428e+00,  Loss_bcs: 3.902e-04, Loss_ut_ics: 3.776e-02,, Time: 10.14
# lambda_u: 5.232e+03
# lambda_ut: 3.387e+01
# lambda_r: 1.031e+00
# Compute NTK...
# It: 7400, Loss: 5.070e+00, Loss_res: 1.212e+00,  Loss_bcs: 5.128e-04, Loss_ut_ics: 2.757e-02,, Time: 9.69
# lambda_u: 5.554e+03
# lambda_ut: 3.533e+01
# lambda_r: 1.029e+00
# Compute NTK...
# It: 7500, Loss: 4.105e+00, Loss_res: 1.315e+00,  Loss_bcs: 3.730e-04, Loss_ut_ics: 2.073e-02,, Time: 9.58
# lambda_u: 5.475e+03
# lambda_ut: 3.412e+01
# lambda_r: 1.030e+00
# Compute NTK...
# It: 7600, Loss: 3.272e+00, Loss_res: 8.394e-01,  Loss_bcs: 3.638e-04, Loss_ut_ics: 1.116e-02,, Time: 9.60
# lambda_u: 5.618e+03
# lambda_ut: 3.248e+01
# lambda_r: 1.032e+00
# Compute NTK...
# It: 7700, Loss: 3.124e+00, Loss_res: 1.147e+00,  Loss_bcs: 3.193e-04, Loss_ut_ics: 8.983e-03,, Time: 9.66
# lambda_u: 5.181e+03
# lambda_ut: 3.174e+01
# lambda_r: 1.033e+00
# Compute NTK...
# It: 7800, Loss: 2.499e+00, Loss_res: 5.850e-01,  Loss_bcs: 3.624e-04, Loss_ut_ics: 2.004e-03,, Time: 9.56
# lambda_u: 5.052e+03
# lambda_ut: 3.214e+01
# lambda_r: 1.032e+00
# Compute NTK...
# It: 7900, Loss: 3.926e+00, Loss_res: 8.309e-01,  Loss_bcs: 3.514e-04, Loss_ut_ics: 3.745e-02,, Time: 9.61
# lambda_u: 5.117e+03
# lambda_ut: 3.397e+01
# lambda_r: 1.031e+00
# Compute NTK...
# It: 8000, Loss: 3.096e+00, Loss_res: 6.996e-01,  Loss_bcs: 3.495e-04, Loss_ut_ics: 1.241e-02,, Time: 9.61
# lambda_u: 5.613e+03
# lambda_ut: 3.329e+01
# lambda_r: 1.031e+00
# Compute NTK...
# It: 8100, Loss: 4.277e+00, Loss_res: 1.496e+00,  Loss_bcs: 3.032e-04, Loss_ut_ics: 3.265e-02,, Time: 9.71
# lambda_u: 5.395e+03
# lambda_ut: 3.366e+01
# lambda_r: 1.031e+00
# Compute NTK...
# It: 8200, Loss: 1.773e+00, Loss_res: 5.042e-01,  Loss_bcs: 1.864e-04, Loss_ut_ics: 6.530e-03,, Time: 9.63
# lambda_u: 5.514e+03
# lambda_ut: 3.453e+01
# lambda_r: 1.030e+00
# Compute NTK...
# It: 8300, Loss: 1.425e+00, Loss_res: 6.105e-01,  Loss_bcs: 1.381e-04, Loss_ut_ics: 2.161e-03,, Time: 9.70
# lambda_u: 5.222e+03
# lambda_ut: 3.460e+01
# lambda_r: 1.030e+00
# Compute NTK...
# It: 8400, Loss: 3.036e+00, Loss_res: 7.322e-01,  Loss_bcs: 2.081e-04, Loss_ut_ics: 3.772e-02,, Time: 9.70
# lambda_u: 5.263e+03
# lambda_ut: 3.140e+01
# lambda_r: 1.033e+00
# Compute NTK...
# It: 8500, Loss: 2.617e+00, Loss_res: 7.659e-01,  Loss_bcs: 2.549e-04, Loss_ut_ics: 1.346e-02,, Time: 9.61
# lambda_u: 5.373e+03
# lambda_ut: 3.401e+01
# lambda_r: 1.030e+00
# Compute NTK...
# It: 8600, Loss: 1.530e+00, Loss_res: 4.446e-01,  Loss_bcs: 1.822e-04, Loss_ut_ics: 3.826e-03,, Time: 9.65
# lambda_u: 5.190e+03
# lambda_ut: 3.294e+01
# lambda_r: 1.032e+00
# Compute NTK...
# It: 8700, Loss: 1.013e+00, Loss_res: 4.262e-01,  Loss_bcs: 1.011e-04, Loss_ut_ics: 1.444e-03,, Time: 9.74
# lambda_u: 5.206e+03
# lambda_ut: 3.241e+01
# lambda_r: 1.032e+00
# Compute NTK...
# It: 8800, Loss: 1.590e+00, Loss_res: 4.784e-01,  Loss_bcs: 1.787e-04, Loss_ut_ics: 3.020e-03,, Time: 9.60
# lambda_u: 5.542e+03
# lambda_ut: 3.529e+01
# lambda_r: 1.029e+00
# Compute NTK...
# It: 8900, Loss: 1.281e+00, Loss_res: 3.488e-01,  Loss_bcs: 1.581e-04, Loss_ut_ics: 2.396e-03,, Time: 9.86
# lambda_u: 5.323e+03
# lambda_ut: 3.333e+01
# lambda_r: 1.031e+00
# Compute NTK...
# It: 9000, Loss: 1.980e+00, Loss_res: 4.336e-01,  Loss_bcs: 2.367e-04, Loss_ut_ics: 1.047e-02,, Time: 9.84
# lambda_u: 5.051e+03
# lambda_ut: 3.215e+01
# lambda_r: 1.032e+00
# Compute NTK...
# It: 9100, Loss: 2.301e+00, Loss_res: 7.335e-01,  Loss_bcs: 1.936e-04, Loss_ut_ics: 1.610e-02,, Time: 9.79
# lambda_u: 5.207e+03
# lambda_ut: 3.330e+01
# lambda_r: 1.031e+00
# Compute NTK...
# It: 9200, Loss: 1.347e+00, Loss_res: 2.552e-01,  Loss_bcs: 1.032e-04, Loss_ut_ics: 1.532e-02,, Time: 9.86
# lambda_u: 5.447e+03
# lambda_ut: 3.412e+01
# lambda_r: 1.030e+00
# Compute NTK...
# It: 9300, Loss: 9.933e-01, Loss_res: 3.951e-01,  Loss_bcs: 9.493e-05, Loss_ut_ics: 2.627e-03,, Time: 10.03
# lambda_u: 5.245e+03
# lambda_ut: 3.357e+01
# lambda_r: 1.031e+00
# Compute NTK...
# It: 9400, Loss: 9.909e-01, Loss_res: 2.292e-01,  Loss_bcs: 1.192e-04, Loss_ut_ics: 3.412e-03,, Time: 9.88
# lambda_u: 5.344e+03
# lambda_ut: 3.451e+01
# lambda_r: 1.030e+00
# Compute NTK...
# It: 9500, Loss: 9.826e-01, Loss_res: 3.070e-01,  Loss_bcs: 1.114e-04, Loss_ut_ics: 2.977e-03,, Time: 10.14
# lambda_u: 5.060e+03
# lambda_ut: 3.448e+01
# lambda_r: 1.030e+00
# Compute NTK...
# It: 9600, Loss: 7.760e-01, Loss_res: 2.373e-01,  Loss_bcs: 8.915e-05, Loss_ut_ics: 2.161e-03,, Time: 9.58
# lambda_u: 5.175e+03
# lambda_ut: 3.226e+01
# lambda_r: 1.032e+00
# Compute NTK...
# It: 9700, Loss: 1.176e+00, Loss_res: 3.334e-01,  Loss_bcs: 1.391e-04, Loss_ut_ics: 2.501e-03,, Time: 9.87
# lambda_u: 5.368e+03
# lambda_ut: 3.410e+01
# lambda_r: 1.030e+00
# Compute NTK...
# It: 9800, Loss: 1.588e+00, Loss_res: 4.586e-01,  Loss_bcs: 1.683e-04, Loss_ut_ics: 5.659e-03,, Time: 9.59
# lambda_u: 5.537e+03
# lambda_ut: 3.228e+01
# lambda_r: 1.032e+00
# Compute NTK...
# It: 9900, Loss: 1.383e+00, Loss_res: 4.005e-01,  Loss_bcs: 1.632e-04, Loss_ut_ics: 2.180e-03,, Time: 9.52
# lambda_u: 5.496e+03
# lambda_ut: 3.337e+01
# lambda_r: 1.031e+00
# Compute NTK...
# elapsed: 1.00e+03
# Relative L2 error_u: 1.94e-02
# Relative L2 error_r: 2.02e+02
# elapsed: 1.00e+03
# Relative L2 error_u: 1.94e-02
# Relative L2 error_v: 2.02e+02
#
#
# Method:  mini_batch
#
# average of time_list: 1003.2971272468567
# average of error_u_list: 0.019416644528221137
# average of error_r_list: 201.5968159700584

# %%
# Train model
itertaions = 80001
log_NTK = True # Compute and store NTK matrix during training
update_lam = True # Compute and update the loss weights using the NTK

# %% [markdown]
# **Training Loss**

# %%
loss_res = model.loss_res_log
loss_bcs = model.loss_bcs_log
loss_u_t_ics = model.loss_ut_ics_log

fig = plt.figure(figsize=(6, 5))
plt.plot(loss_res, label='$\mathcal{L}_{r}$')
plt.plot(loss_bcs, label='$\mathcal{L}_{u}$')
plt.plot(loss_u_t_ics, label='$\mathcal{L}_{u_t}$')
plt.yscale('log')
plt.xlabel('iterations')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# **Model Prediction**

# %%
# Predictions
u_pred = model.predict_u(X_star)
r_pred = model.predict_r(X_star)
error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)

print('Relative L2 error_u: %e' % (error_u))

# %%
U_star = griddata(X_star, u_star.flatten(), (t, x), method='cubic')
r_star = griddata(X_star, r_star.flatten(), (t, x), method='cubic')
U_pred = griddata(X_star, u_pred.flatten(), (t, x), method='cubic')
R_pred = griddata(X_star, r_pred.flatten(), (t, x), method='cubic')


plt.figure(figsize=(18, 9))
plt.subplot(2, 3, 1)
plt.pcolor(t, x, U_star, cmap='jet')
plt.colorbar()
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.title('Exact u(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 2)
plt.pcolor(t, x, U_pred, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Predicted u(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 3)
plt.pcolor(t, x, np.abs(U_star - U_pred), cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Absolute error')
plt.tight_layout()

plt.subplot(2, 3, 4)
plt.pcolor(t, x, r_star, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Exact r(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 5)
plt.pcolor(t, x, R_pred, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Predicted r(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 6)
plt.pcolor(t, x, np.abs(r_star - R_pred), cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Absolute error')
plt.tight_layout()
plt.show()

# %% [markdown]
# **NTK Eigenvalues**

# %%
# Create empty lists for storing the eigenvalues of NTK
lam_K_u_log = []
lam_K_ut_log = []
lam_K_r_log = []

# Restore the NTK
K_u_list = model.K_u_log
K_ut_list = model.K_ut_log
K_r_list = model.K_r_log

K_list = []
    
for k in range(len(K_u_list)):
    K_u = K_u_list[k]
    K_ut = K_ut_list[k]
    K_r = K_r_list[k]
    
    # Compute eigenvalues
    lam_K_u, _ = np.linalg.eig(K_u)
    lam_K_ut, _ = np.linalg.eig(K_ut)
    lam_K_r, _ = np.linalg.eig(K_r)
    # Sort in descresing order
    lam_K_u = np.sort(np.real(lam_K_u))[::-1]
    lam_K_ut = np.sort(np.real(lam_K_ut))[::-1]
    lam_K_r = np.sort(np.real(lam_K_r))[::-1]
    
    # Store eigenvalues
    lam_K_u_log.append(lam_K_u)
    lam_K_ut_log.append(lam_K_ut)
    lam_K_r_log.append(lam_K_r)

# %%
#  Eigenvalues of NTK
fig = plt.figure(figsize=(18, 5))
plt.subplot(1,3,1)

plt.plot(lam_K_u_log[0], label = '$n=0$')
plt.plot(lam_K_u_log[1], '--', label = '$n=10,000$')
plt.plot(lam_K_u_log[4], '--', label = '$n=40,000$')
plt.plot(lam_K_u_log[-1], '--', label = '$n=80,000$')
plt.xscale('log')
plt.yscale('log')

plt.title(r'Eigenvalues of ${K}_u$')

plt.subplot(1,3,2)
plt.plot(lam_K_ut_log[0], label = '$n=0$')
plt.plot(lam_K_ut_log[1], '--',label = '$n=10,000$')
plt.plot(lam_K_ut_log[4], '--', label = '$n=40,000$')
plt.plot(lam_K_ut_log[-1], '--', label = '$n=80,000$')
plt.xscale('log')
plt.yscale('log')
plt.title(r'Eigenvalues of ${K}_{u_t}$')

ax =plt.subplot(1,3,3)
plt.plot(lam_K_r_log[0], label = '$n=0$')
plt.plot(lam_K_r_log[1], '--', label = '$n=10,000$')
plt.plot(lam_K_r_log[4], '--', label = '$n=40,000$')
plt.plot(lam_K_r_log[-1], '--', label = '$n=80,000$')
plt.xscale('log')
plt.yscale('log')
plt.title(r'Eigenvalues of ${K}_{r}$')
handles, labels = ax.get_legend_handles_labels()
fig.legend(handles, labels, loc="upper left", bbox_to_anchor=(0.35, -0.02),
            borderaxespad=0, bbox_transform=fig.transFigure, ncol=4)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Evolution of NTK Weights**

# %%
if update_lam == True:

  lam_u_log = model.lam_u_log
  lam_ut_log = model.lam_ut_log
  lam_r_log = model.lam_r_log

# %%
fig = plt.figure(figsize=(6, 5))
plt.plot(lam_u_log, label='$\lambda_u$')
plt.plot(lam_ut_log, label='$\lambda_{u_t}$')
plt.plot(lam_r_log, label='$\lambda_{r}$')
plt.xlabel('iterations')
plt.ylabel('$\lambda$')
plt.yscale('log')
plt.legend( )
plt.tight_layout()
plt.show()
