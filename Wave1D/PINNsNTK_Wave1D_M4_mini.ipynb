# %%
import tensorflow as tf
from Compute_Jacobian import jacobian # Please download 'Compute_Jacobian.py' in the repository 
import numpy as np
import timeit
from scipy.interpolate import griddata
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import os



os.environ["KMP_WARNINGS"] = "FALSE" 
import timeit

import sys

import scipy
import scipy.io
import time

class Sampler:
    # Initialize the class
    def __init__(self, dim, coords, func, name = None):
        self.dim = dim
        self.coords = coords
        self.func = func
        self.name = name
    def sample(self, N):
        x = self.coords[0:1,:] + (self.coords[1:2,:]-self.coords[0:1,:])*np.random.rand(N, self.dim)
        y = self.func(x)
        return x, y

# Define the exact solution and its derivatives
def u(x, a, c):
    """
    :param x: x = (t, x)
    """
    t = x[:,0:1]
    x = x[:,1:2]
    return np.sin(np.pi * x) * np.cos(c * np.pi * t) + a * np.sin(2 * c * np.pi* x) * np.cos(4 * c  * np.pi * t)

def u_t(x,a, c):
    t = x[:,0:1]
    x = x[:,1:2]
    u_t = -  c * np.pi * np.sin(np.pi * x) * np.sin(c * np.pi * t) -  a * 4 * c * np.pi * np.sin(2 * c * np.pi* x) * np.sin(4 * c * np.pi * t)
    return u_t

def u_tt(x, a, c):
    t = x[:,0:1]
    x = x[:,1:2]
    u_tt = -(c * np.pi)**2 * np.sin( np.pi * x) * np.cos(c * np.pi * t) - a * (4 * c * np.pi)**2 *  np.sin(2 * c * np.pi* x) * np.cos(4 * c * np.pi * t)
    return u_tt

def u_xx(x, a, c):
    t = x[:,0:1]
    x = x[:,1:2]
    u_xx = - np.pi**2 * np.sin( np.pi * x) * np.cos(c * np.pi * t) -  a * (2 * c * np.pi)** 2 * np.sin(2 * c * np.pi* x) * np.cos(4 * c * np.pi * t)
    return  u_xx


def r(x, a, c):
    return u_tt(x, a, c) - c**2 * u_xx(x, a, c)

def operator(u, t, x, c, sigma_t=1.0, sigma_x=1.0):
    u_t = tf.gradients(u, t)[0] / sigma_t
    u_x = tf.gradients(u, x)[0] / sigma_x
    u_tt = tf.gradients(u_t, t)[0] / sigma_t
    u_xx = tf.gradients(u_x, x)[0] / sigma_x
    residual = u_tt - c**2 * u_xx
    return residual


class PINN:
    # Initialize the class
    def __init__(self, layers, operator, coll_sampler , ics_sampler, bcs_sampler, res_sampler, c, kernel_size , sess):
        # Normalization 
        X, _ = res_sampler.sample(np.int32(1e5))
        self.mu_X, self.sigma_X = X.mean(0), X.std(0)
        self.mu_t, self.sigma_t = self.mu_X[0], self.sigma_X[0]
        self.mu_x, self.sigma_x = self.mu_X[1], self.sigma_X[1]


        # Samplers
        self.operator = operator
        self.ics_sampler = ics_sampler
        self.bcs_sampler = bcs_sampler
        self.res_sampler = res_sampler
        self.coll_sampler = coll_sampler

        self.sess = sess
        # Initialize network weights and biases
        self.layers = layers
        self.weights, self.biases = self.initialize_NN(layers)
        
        # weights
        self.lam_coll_val = np.array(2.0)
        self.lam_u_val = np.array(2.0)
        self.lam_ut_val = np.array(2.0)
        self.lam_r_val = np.array(1.0)

        self.lam_bc1_val = np.array(2.0)
        self.lam_bc2_val = np.array(2.0)
        self.lam_res_val = np.array(2.0)
      
        
        self.weight_bc_val =  np.array(2.0) # tf.Variable([1.0], dtype=tf.float32)
        self.weight_ic_val =  np.array(2.0) # tf.Variable([1.0], dtype=tf.float32)

        self.weight_bc_tf =  tf.placeholder(tf.float32, shape=self.weight_bc_val.shape)
        self.weight_ic_tf =  tf.placeholder(tf.float32, shape=self.weight_ic_val.shape)

        # Wave constant
        self.c = tf.constant(c, dtype=tf.float32)
        
        self.kernel_size = kernel_size # Size of the NTK matrix

        # Define Tensorflow session
        self.sess = tf.Session(config=tf.ConfigProto(log_device_placement=False))

        # Define placeholders and computational graph
        self.t_u_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_u_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_ics_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_ics_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.u_ics_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_coll_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_coll_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.u_coll_tf = tf.placeholder(tf.float32, shape=(None, 1))
    
        self.t_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_r_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_r_tf = tf.placeholder(tf.float32, shape=(None, 1))
        
        self.lam_u_tf = tf.placeholder(tf.float32, shape=self.lam_u_val.shape)
        self.lam_ut_tf = tf.placeholder(tf.float32, shape=self.lam_u_val.shape)
        # self.lam_r_tf = tf.placeholder(tf.float32, shape=self.lam_u_val.shape)
        self.lam_bc1_tf = tf.placeholder(tf.float32, shape=self.lam_bc1_val.shape)
        self.lam_bc2_tf = tf.placeholder(tf.float32, shape=self.lam_bc2_val.shape)
        
        self.lam_res_tf = tf.placeholder(tf.float32, shape=self.lam_res_val.shape)
        self.lam_coll_tf = tf.placeholder(tf.float32, shape=self.lam_coll_val.shape)

        self.u_pred = self.net_u(self.t_u_tf, self.x_u_tf)


        # Evaluate predictions
        self.u_coll_pred = self.net_u(self.t_coll_tf, self.x_coll_tf)

        self.u_ics_pred = self.net_u(self.t_ics_tf, self.x_ics_tf)
        self.u_bc1_pred = self.net_u(self.t_bc1_tf, self.x_bc1_tf)
        self.u_bc2_pred = self.net_u(self.t_bc2_tf, self.x_bc2_tf)

        self.r_pred = self.net_r(self.t_r_tf, self.x_r_tf)
        
        
        # Boundary loss and Initial loss
        self.loss_coll_u = tf.reduce_mean(tf.square(self.u_coll_tf - self.u_coll_pred))

        self.loss_ics_u = tf.reduce_mean(tf.square(self.u_ics_tf - self.u_ics_pred))
        self.loss_ics_ut =  tf.reduce_mean(tf.square( tf.gradients(self.u_ics_pred, self.t_ics_tf)[0] / self.sigma_t))
        self.loss_bc1 = tf.reduce_mean(tf.square(self.u_bc1_pred)) #+ tf.reduce_mean(tf.square(self.u_bc2_pred))
        self.loss_bc2 = tf.reduce_mean(tf.square(self.u_bc2_pred))

        # Residual loss
        self.loss_res = tf.reduce_mean(tf.square(self.r_pred))

        # Total loss
        self.loss = self.loss_res + self.lam_coll_tf * self.loss_coll_u + self.lam_bc1_tf * self.loss_bc1 + self.lam_bc2_tf* self.loss_bc2 + self.lam_u_tf * (self.loss_ics_u + self.loss_ics_ut ) # + self.lam_ut_tf * self.loss_ics_u_t 

        self.count = 1
        self.loss_bc_avg = 0
        self.loss_ics_u_avg = 0
        self.loss_res_avg = 0

        # Define optimizer with learning rate schedule
        self.global_step = tf.Variable(0, trainable=False)
        starter_learning_rate = 1e-3
        self.learning_rate = tf.train.exponential_decay(starter_learning_rate, self.global_step,  1000, 0.9, staircase=False)
        # Passing global_step to minimize() will increment it at each step.
        self.train_op = tf.train.AdamOptimizer(self.learning_rate).minimize(self.loss, global_step=self.global_step , var_list=self.weights +  self.biases)

        # self.train_op_bc = tf.train.AdamOptimizer(self.learning_rate).minimize(-self.loss, global_step=self.global_step , var_list=self.weights +  self.biases)
        # self.train_op_ic = tf.train.AdamOptimizer(self.learning_rate).minimize(-self.loss, global_step=self.global_step , var_list=self.weights +  self.biases)
        
         # Initialize Tensorflow variables
        init = tf.global_variables_initializer()
        self.sess.run(init)

    # Initialize network weights and biases using Xavier initialization
    def initialize_NN(self, layers):
        # Xavier initialization
        def xavier_init(size):
            in_dim = size[0]
            out_dim = size[1]
            xavier_stddev = 1. / np.sqrt((in_dim + out_dim) / 2.)
            return tf.Variable(tf.random.normal([in_dim, out_dim], dtype=tf.float32) * xavier_stddev,  dtype=tf.float32)

        weights = []
        biases = []
        num_layers = len(layers)
        for l in range(0, num_layers - 1):
            W = xavier_init(size=[layers[l], layers[l + 1]])
            b = tf.Variable(tf.zeros([1, layers[l + 1]], dtype=tf.float32), dtype=tf.float32)
            weights.append(W)
            biases.append(b)
        return weights, biases

    # Evaluates the forward pass
    def forward_pass(self, H, layers, weights, biases):
        num_layers = len(layers)
        for l in range(0, num_layers - 2):
            W = weights[l]
            b = biases[l]
            H = tf.tanh(tf.add(tf.matmul(H, W), b))
        W = weights[-1]
        b = biases[-1]
        H = tf.add(tf.matmul(H, W), b)
        return H

    # Forward pass for u
    def net_u(self, t, x):
        u = self.forward_pass(tf.concat([t, x], 1),  self.layers, self.weights, self.biases)
        return u

    # Forward pass for du/dt
    def net_u_t(self, t, x):
        u_t = tf.gradients(self.net_u(t, x), t)[0] / self.sigma_t
        return u_t

    # Forward pass for the residual
    def net_r(self, t, x):
        u = self.net_u(t, x)
        residual = self.operator(u, t, x, self.c, self.sigma_t,  self.sigma_x)
        return residual
    
    

    def fetch_minibatch(self, sampler, N):
        X, Y = sampler.sample(N)
        X = (X - self.mu_X) / self.sigma_X
        return X, Y

        # Trains the model by minimizing the MSE loss

    def trainmb(self, nIter=10000, batch_size=128, log_NTK=False, update_lam=False):

        start_time = timeit.default_timer()
        # Fetch boundary mini-batches
        X_ics_batch, u_ics_batch = self.fetch_minibatch(self.ics_sampler, batch_size )
        X_coll_batch, u_coll_batch = self.fetch_minibatch(self.coll_sampler, batch_size )

        X_bc1_batch, _ = self.fetch_minibatch(self.bcs_sampler[0], batch_size )
        X_bc2_batch, _ = self.fetch_minibatch(self.bcs_sampler[1], batch_size )
        
        for it in range(1 , nIter):

            # Fetch residual mini-batch
            X_res_batch, _ = self.fetch_minibatch(self.res_sampler, batch_size)
            # Define a dictionary for associating placeholders with data
            tf_dict = {
                self.t_ics_tf: X_ics_batch[:, 0:1], 
                self.x_ics_tf: X_ics_batch[:, 1:2],
                self.u_ics_tf: u_ics_batch,
                self.t_coll_tf: X_coll_batch[:, 0:1], 
                self.x_coll_tf: X_coll_batch[:, 1:2],
                self.u_coll_tf: u_coll_batch,
                self.t_bc1_tf: X_bc1_batch[:, 0:1],
                self.x_bc1_tf: X_bc1_batch[:, 1:2],
                self.t_bc2_tf: X_bc2_batch[:, 0:1], 
                self.x_bc2_tf: X_bc2_batch[:, 1:2],
                self.t_r_tf: X_res_batch[:, 0:1], 
                self.x_r_tf: X_res_batch[:, 1:2],
                self.lam_coll_tf:self.lam_coll_val,
                self.lam_u_tf:self.lam_u_val,
                self.lam_bc1_tf:self.lam_bc1_val,
                self.lam_bc2_tf:self.lam_bc2_val
                       }

            # Run the Tensorflow session to minimize the loss
            self.sess.run(self.train_op, tf_dict)

            # Print
            if it % 100 == 0:
                elapsed = timeit.default_timer() - start_time

                loss , loss_bc1 , loss_bc2 , loss_ics_u , loss_ics_ut , loss_res, loss_coll_u = self.sess.run( [self.loss  , self.loss_bc1 ,self.loss_bc2 , self.loss_ics_u, self.loss_ics_ut, self.loss_res, self.loss_coll_u ] , tf_dict)

                print('It: %d, Loss: %.3e,  loss_bc1: %.3e,  loss_bc2: %.3e, loss_ics_u: %.3e, loss_ics_ut: %.3e,  Loss_res: %.3e,  loss_coll_u: %.3e , Time: %.2f' %(it, loss, loss_bc1 , loss_bc2 , loss_ics_u, loss_ics_ut , loss_res, loss_coll_u , elapsed))
                
 
                # start_time = timeit.default_timer()

                # self.loss_bc_avg += (loss_bc1 + loss_bc2 ) /self.count
                # self.loss_ics_u_avg += (loss_ics_u + loss_ics_ut )  /self.count
                # self.loss_res_avg += loss_res  /self.count
                # self.count +=1
          
                if it % 100== 0: 
                        alpha   = 1000
                        # self.lam_bc_val = alpha *  (loss_bc1 + loss_bc2 )
                        # # self.lam_bc2_val = alpha * loss_bc2
                        # self.lam_u_val = alpha * (loss_ics_u + loss_ics_ut )
                        # self.lam_res_val = 100 *loss_res
                        # _ , _ , weight_bc_val  , weight_ic_val = self.sess.run([self.train_op_bc , self.train_op_ic , self.weight_bc_tf , self.weight_ic_tf], tf_dict)

                        self.lam_u_val =  alpha *(loss_ics_u + loss_ics_ut )
                        self.lam_bc1_val = alpha * loss_bc1
                        self.lam_bc2_val = alpha * loss_bc2
                        self.lam_coll_val = alpha * loss_ics_u
                        print('lam_bc1_val: {:.3e}'.format(self.lam_bc1_val))
                        print('lam_bc2_val: {:.3e}'.format(self.lam_bc2_val))
                        print('lam_u_val: {:.3e}'.format(self.lam_u_val))
                        print('lam_coll_val: {:.3e}'.format(self.lam_coll_val))

                sys.stdout.flush()

####################################################################################################
    def train(self, nIter , bcbatch_size , ubatch_size):

        start_time = timeit.default_timer()

        # Fetch boundary mini-batches
        X_ics_batch, u_ics_batch = self.fetch_minibatch(self.ics_sampler, bcbatch_size)
        X_bc1_batch, _ = self.fetch_minibatch(self.bcs_sampler[0], bcbatch_size )
        X_bc2_batch, _ = self.fetch_minibatch(self.bcs_sampler[1], bcbatch_size )
        
        # Fetch residual mini-batch
        X_res_batch, _ = self.fetch_minibatch(self.res_sampler, ubatch_size)
        # print("inside trainmb: " , X_res_batch.shape)
        # Define a dictionary for associating placeholders with data
        tf_dict = {self.t_ics_tf: X_ics_batch[:, 0:1], 
                   self.x_ics_tf: X_ics_batch[:, 1:2],
                    self.u_ics_tf: u_ics_batch,
                    self.t_bc1_tf: X_bc1_batch[:, 0:1],
                    self.x_bc1_tf: X_bc1_batch[:, 1:2],
                    self.t_bc2_tf: X_bc2_batch[:, 0:1], 
                    self.x_bc2_tf: X_bc2_batch[:, 1:2],
                    self.t_r_tf: X_res_batch[:, 0:1], 
                    self.x_r_tf: X_res_batch[:, 1:2],
                    self.lam_u_tf: self.lam_u_val,
                    self.lam_bc_tf: self.lam_bc_val,
                    self.lam_res_tf: self.lam_res_val,
                    }
    
        for it in range(nIter):

            # Run the Tensorflow session to minimize the loss
            self.sess.run(self.train_op, tf_dict)

            # Print
            if it % 100 == 0:
                elapsed = timeit.default_timer() - start_time

                loss = self.sess.run(self.loss, tf_dict)
                loss_bc1 = self.sess.run(self.loss_bc1, tf_dict)
                # loss_bc2 = self.sess.run(self.loss_bc2, tf_dict)
                loss_ics_u = self.sess.run(self.loss_ics_u, tf_dict)
                loss_res = self.sess.run(self.loss_res, tf_dict)

             # Print
            if it % 100 == 0:
                elapsed = timeit.default_timer() - start_time

                loss , loss_bc1 , loss_bc2 , loss_ics_u , loss_ics_ut , loss_res = self.sess.run( [self.loss  , self.loss_bc1 ,self.loss_bc2 , self.loss_ics_u, self.loss_ics_ut, self.loss_res ] , tf_dict)

                print('It: %d, Loss: %.3e,  loss_bc1: %.3e,  loss_bc2: %.3e, loss_ics_u: %.3e, loss_ics_ut: %.3e,  Loss_res: %.3e , Time: %.2f' %(it, loss, loss_bc1 , loss_bc2 , loss_ics_u, loss_ics_ut , loss_res , elapsed))
                
              
 
                start_time = timeit.default_timer()

                # self.loss_bc_avg += (loss_bc1 + loss_bc2 ) /self.count
                # self.loss_ics_u_avg += (loss_ics_u + loss_ics_ut )  /self.count
                # self.loss_res_avg += loss_res  /self.count
                # self.count +=1
          
                if it % 100 == 0: 
                        alpha   = 10000
                        self.lam_bc_val = alpha *  (loss_bc1 + loss_bc2 )
                        # self.lam_bc2_val = alpha * loss_bc2
                        self.lam_u_val = alpha * (loss_ics_u + loss_ics_ut )
                        self.lam_res_val = 100 *loss_res
                        
                        print('loss_bc1: {:.3e}'.format(self.lam_bc_val))
                        # print('loss_bc2: {:.3e}'.format(self.lam_bc2_val))
                        print('loss_ics_u: {:.3e}'.format(self.lam_u_val))
                        print('loss_res_val: {:.3e}'.format(self.lam_res_val))

                sys.stdout.flush()


    # Evaluates predictions at test points
    def predict_u(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.t_u_tf: X_star[:, 0:1], self.x_u_tf: X_star[:, 1:2]}
        u_star = self.sess.run(self.u_pred, tf_dict)
        return u_star

        # Evaluates predictions at test points

    def predict_r(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.t_r_tf: X_star[:, 0:1], self.x_r_tf: X_star[:, 1:2]}
        r_star = self.sess.run(self.r_pred, tf_dict)
        return r_star
    
   ###############################################################################################################################################
   # 
   # ###############################################################################################################################################
   # 
   # ###############################################################################################################################################
   # 
   #

# %%
#test_method(mtd , layers,  X_u, Y_u, X_r, Y_r ,  X_star , u_star , r_star  , nIter ,batch_size , bcbatch_size , ubatch_size)
def test_method(method , layers,  ics_sampler, bcs_sampler, res_sampler, c ,kernel_size , X_star , u_star , r_star , nIter ,mbbatch_size , bcbatch_size , ubatch_size ):

    tf.reset_default_graph()
    gpu_options = tf.GPUOptions(visible_device_list="0")
    with tf.Session(config=tf.ConfigProto(gpu_options=gpu_options,allow_soft_placement=False, log_device_placement=False)) as sess:
        # sess.run(init)

        model = PINN(layers, operator, ics_sampler, bcs_sampler, res_sampler, c, kernel_size , sess)
        # Train model
        start_time = time.time()

        if method =="full_batch":
            print("full_batch method is used")
            model.train(nIter  , bcbatch_size , ubatch_size  )
        elif method =="mini_batch":
            print("mini_batch method is used")
            model.trainmb(nIter, mbbatch_size)
        else:
            print("unknown method!")
        elapsed = time.time() - start_time

        # Predictions
        u_pred = model.predict_u(X_star)
        # Predictions

        sess.close()   

    error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)

    print('elapsed: {:.2e}'.format(elapsed))

    print('Relative L2 error_u: {:.2e}'.format(error_u))


    return [elapsed, error_u  , model]

###############################################################################################################################################

# %%
# Define PINN model
a = 0.5
c = 2

kernel_size = 300

# Domain boundaries
ics_coords = np.array([[0.0, 0.0],  [0.0, 1.0]])
bc1_coords = np.array([[0.0, 0.0],  [1.0, 0.0]])
bc2_coords = np.array([[0.0, 1.0],  [1.0, 1.0]])
dom_coords = np.array([[0.0, 0.0],  [1.0, 1.0]])

# Create initial conditions samplers
ics_sampler = Sampler(2, ics_coords, lambda x: u(x, a, c), name='Initial Condition 1')

# Create boundary conditions samplers
bc1 = Sampler(2, bc1_coords, lambda x: u(x, a, c), name='Dirichlet BC1')
bc2 = Sampler(2, bc2_coords, lambda x: u(x, a, c), name='Dirichlet BC2')
bcs_sampler = [bc1, bc2]

# Create residual sampler
res_sampler = Sampler(2, dom_coords, lambda x: r(x, a, c), name='Forcing')
coll_sampler = Sampler(2, dom_coords, lambda x: u(x, a, c), name='coll')



nIter =40000
bcbatch_size = 500
ubatch_size = 5000
mbbatch_size = 300



# Define model
mode = 'M4'
layers = [2, 500, 500, 500, 1]


nn = 200
t = np.linspace(dom_coords[0, 0], dom_coords[1, 0], nn)[:, None]
x = np.linspace(dom_coords[0, 1], dom_coords[1, 1], nn)[:, None]
t, x = np.meshgrid(t, x)
X_star = np.hstack((t.flatten()[:, None], x.flatten()[:, None]))

u_star = u(X_star, a,c)
r_star = r(X_star, a, c)

iterations = 1
methods = [  "mini_batch"]

result_dict =  dict((mtd, []) for mtd in methods)

for mtd in methods:
    print("Method: ", mtd)
    time_list = []
    error_u_list = []
    error_r_list = []
    
    for index in range(iterations):

        print("Epoch: ", str(index+1))

        # Create residual sampler

        # [elapsed, error_u , model] = test_method(mtd , layers,  ics_sampler, bcs_sampler, res_sampler, c ,kernel_size , X_star , u_star , r_star , nIter ,mbbatch_size , bcbatch_size , ubatch_size )
        tf.reset_default_graph()
        gpu_options = tf.GPUOptions(visible_device_list="0")
        with tf.Session(config=tf.ConfigProto(gpu_options=gpu_options,allow_soft_placement=False, log_device_placement=False)) as sess:
            # sess.run(init)

            model = PINN(layers, operator,coll_sampler ,  ics_sampler, bcs_sampler, res_sampler, c, kernel_size , sess)
            # Train model
            start_time = time.time()

            if mtd =="full_batch":
                print("full_batch method is used")
                model.train(nIter  , bcbatch_size , ubatch_size  )
            elif mtd =="mini_batch":
                print("mini_batch method is used")
                model.trainmb(nIter, mbbatch_size)
            else:
                print("unknown method!")
            elapsed = time.time() - start_time

            # Predictions
            u_pred = model.predict_u(X_star)
            r_pred = model.predict_r(X_star)
            # Predictions

            sess.close()   

            error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)
            error_r = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)

            print('elapsed: {:.2e}'.format(elapsed))

            print('Relative L2 error_u: {:.2e}'.format(error_u))
            print('Relative L2 error_r: {:.2e}'.format(error_r))


        print('elapsed: {:.2e}'.format(elapsed))
        print('Relative L2 error_u: {:.2e}'.format(error_u))
        print('Relative L2 error_r: {:.2e}'.format(error_r))

        time_list.append(elapsed)
        error_u_list.append(error_u)
        error_r_list.append(error_r)

    print("\n\nMethod: ", mtd)
    print("\naverage of time_list:" , sum(time_list) / len(time_list) )
    print("average of error_u_list:" , sum(error_u_list) / len(error_u_list) )
    print("average of error_r_list:" , sum(error_r_list) / len(error_r_list) )

    result_dict[mtd] = [time_list ,error_u_list,error_r_list]
    # scipy.io.savemat("M2_result_"+str(iterations)+"_"+mtd+".mat" , {'time_list':np.array(time_list),'error_u_list':np.array(error_u_list),'error_f_list':np.array(error_f_list)})

    scipy.io.savemat("./1DWave_database/"+mtd+"_1Dwave_"+mode+"_result_mb"+str(mbbatch_size)+"_fb"+str(ubatch_size)+"_bc"+str(mbbatch_size)+"_"+str(iterations)+".mat" , result_dict)

###############################################################################################################################################
# Out:
# Method:  mini_batch
# Epoch:  1
# WARNING:tensorflow:From /tmp/ipykernel_10282/547303282.py:66: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_10282/547303282.py:67: The name tf.GPUOptions is deprecated. Please use tf.compat.v1.GPUOptions instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_10282/547303282.py:68: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_10282/547303282.py:68: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
# WARNING:tensorflow:From /tmp/ipykernel_10282/2267549477.py:110: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# 2023-11-28 09:58:57.403474: I tensorflow/core/platform/cpu_feature_guard.cc:145] This TensorFlow binary is optimized with Intel(R) MKL-DNN to use the following CPU instructions in performance critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in non-MKL-DNN operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-28 09:58:57.431670: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2899885000 Hz
# 2023-11-28 09:58:57.432176: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5585bc8c50c0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-11-28 09:58:57.432195: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2023-11-28 09:58:57.437329: I tensorflow/core/common_runtime/process_util.cc:115] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# WARNING:tensorflow:From /tmp/ipykernel_10282/2267549477.py:186: The name tf.train.exponential_decay is deprecated. Please use tf.compat.v1.train.exponential_decay instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_10282/2267549477.py:188: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_10282/2267549477.py:194: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# mini_batch method is used
# It: 100, Loss: 1.658e+00,  loss_bc1: 2.795e-02,  loss_bc2: 1.873e-02, loss_ics_u: 3.940e-01, loss_ics_ut: 3.312e-02,  Loss_res: 2.591e-04,  loss_coll_u: 3.550e-01 , Time: 5.55
# lam_bc1_val: 2.795e+01
# lam_bc2_val: 1.873e+01
# lam_u_val: 4.271e+02
# lam_coll_val: 3.940e+02
# It: 200, Loss: 1.396e+02,  loss_bc1: 6.609e-02,  loss_bc2: 2.241e-02, loss_ics_u: 1.404e-01, loss_ics_ut: 1.012e-02,  Loss_res: 1.648e+01,  loss_coll_u: 1.437e-01 , Time: 9.57
# lam_bc1_val: 6.609e+01
# lam_bc2_val: 2.241e+01
# lam_u_val: 1.505e+02
# lam_coll_val: 1.404e+02
# It: 300, Loss: 5.095e+01,  loss_bc1: 4.703e-02,  loss_bc2: 6.838e-02, loss_ics_u: 1.249e-01, loss_ics_ut: 8.274e-02,  Loss_res: 3.125e+00,  loss_coll_u: 8.505e-02 , Time: 13.13
# lam_bc1_val: 4.703e+01
# lam_bc2_val: 6.838e+01
# lam_u_val: 2.077e+02
# lam_coll_val: 1.249e+02
# It: 400, Loss: 3.818e+01,  loss_bc1: 4.505e-02,  loss_bc2: 2.719e-02, loss_ics_u: 1.026e-01, loss_ics_ut: 1.965e-03,  Loss_res: 2.500e+00,  loss_coll_u: 7.986e-02 , Time: 16.65
# lam_bc1_val: 4.505e+01
# lam_bc2_val: 2.719e+01
# lam_u_val: 1.046e+02
# lam_coll_val: 1.026e+02
# It: 500, Loss: 2.169e+01,  loss_bc1: 3.638e-02,  loss_bc2: 3.593e-02, loss_ics_u: 1.022e-01, loss_ics_ut: 2.249e-03,  Loss_res: 6.669e-01,  loss_coll_u: 7.298e-02 , Time: 20.42
# lam_bc1_val: 3.638e+01
# lam_bc2_val: 3.593e+01
# lam_u_val: 1.044e+02
# lam_coll_val: 1.022e+02
# It: 600, Loss: 2.095e+01,  loss_bc1: 4.108e-02,  loss_bc2: 2.904e-02, loss_ics_u: 9.941e-02, loss_ics_ut: 2.518e-03,  Loss_res: 4.224e-01,  loss_coll_u: 7.194e-02 , Time: 24.47
# lam_bc1_val: 4.108e+01
# lam_bc2_val: 2.904e+01
# lam_u_val: 1.019e+02
# lam_coll_val: 9.941e+01
# It: 700, Loss: 2.017e+01,  loss_bc1: 3.565e-02,  loss_bc2: 2.944e-02, loss_ics_u: 9.865e-02, loss_ics_ut: 2.858e-03,  Loss_res: 3.791e-01,  loss_coll_u: 7.166e-02 , Time: 29.10
# lam_bc1_val: 3.565e+01
# lam_bc2_val: 2.944e+01
# lam_u_val: 1.015e+02
# lam_coll_val: 9.865e+01
# It: 800, Loss: 1.965e+01,  loss_bc1: 3.612e-02,  loss_bc2: 2.772e-02, loss_ics_u: 9.733e-02, loss_ics_ut: 2.786e-03,  Loss_res: 4.172e-01,  loss_coll_u: 7.057e-02 , Time: 33.34
# lam_bc1_val: 3.612e+01
# lam_bc2_val: 2.772e+01
# lam_u_val: 1.001e+02
# lam_coll_val: 9.733e+01
# It: 900, Loss: 1.927e+01,  loss_bc1: 3.448e-02,  loss_bc2: 2.662e-02, loss_ics_u: 9.620e-02, loss_ics_ut: 4.850e-03,  Loss_res: 2.935e-01,  loss_coll_u: 7.066e-02 , Time: 37.50
# lam_bc1_val: 3.448e+01
# lam_bc2_val: 2.662e+01
# lam_u_val: 1.010e+02
# lam_coll_val: 9.620e+01
# It: 1000, Loss: 1.893e+01,  loss_bc1: 3.751e-02,  loss_bc2: 3.103e-02, loss_ics_u: 9.385e-02, loss_ics_ut: 4.509e-03,  Loss_res: 3.377e-01,  loss_coll_u: 6.790e-02 , Time: 41.97
# lam_bc1_val: 3.751e+01
# lam_bc2_val: 3.103e+01
# lam_u_val: 9.836e+01
# lam_coll_val: 9.385e+01
# It: 1100, Loss: 1.947e+01,  loss_bc1: 3.410e-02,  loss_bc2: 2.852e-02, loss_ics_u: 9.533e-02, loss_ics_ut: 1.236e-02,  Loss_res: 3.650e-01,  loss_coll_u: 6.763e-02 , Time: 46.12
# lam_bc1_val: 3.410e+01
# lam_bc2_val: 2.852e+01
# lam_u_val: 1.077e+02
# lam_coll_val: 9.533e+01
# It: 1200, Loss: 3.300e+01,  loss_bc1: 3.358e-02,  loss_bc2: 1.772e-02, loss_ics_u: 9.348e-02, loss_ics_ut: 1.205e-01,  Loss_res: 5.880e-01,  loss_coll_u: 8.094e-02 , Time: 50.26
# lam_bc1_val: 3.358e+01
# lam_bc2_val: 1.772e+01
# lam_u_val: 2.140e+02
# lam_coll_val: 9.348e+01
# It: 1300, Loss: 5.741e+01,  loss_bc1: 5.934e-02,  loss_bc2: 2.657e-02, loss_ics_u: 1.500e-01, loss_ics_ut: 4.785e-03,  Loss_res: 2.889e+00,  loss_coll_u: 2.026e-01 , Time: 54.33
# lam_bc1_val: 5.934e+01
# lam_bc2_val: 2.657e+01
# lam_u_val: 1.548e+02
# lam_coll_val: 1.500e+02
# It: 1400, Loss: 3.710e+01,  loss_bc1: 3.485e-02,  loss_bc2: 4.402e-02, loss_ics_u: 1.222e-01, loss_ics_ut: 2.721e-03,  Loss_res: 1.796e+00,  loss_coll_u: 8.491e-02 , Time: 58.38
# lam_bc1_val: 3.485e+01
# lam_bc2_val: 4.402e+01
# lam_u_val: 1.249e+02
# lam_coll_val: 1.222e+02
# It: 1500, Loss: 2.683e+01,  loss_bc1: 3.662e-02,  loss_bc2: 2.793e-02, loss_ics_u: 1.134e-01, loss_ics_ut: 1.407e-03,  Loss_res: 1.000e+00,  loss_coll_u: 7.353e-02 , Time: 62.49
# lam_bc1_val: 3.662e+01
# lam_bc2_val: 2.793e+01
# lam_u_val: 1.149e+02
# lam_coll_val: 1.134e+02
# It: 1600, Loss: 2.348e+01,  loss_bc1: 3.342e-02,  loss_bc2: 3.197e-02, loss_ics_u: 1.113e-01, loss_ics_ut: 8.673e-04,  Loss_res: 9.132e-01,  loss_coll_u: 6.675e-02 , Time: 66.53
# lam_bc1_val: 3.342e+01
# lam_bc2_val: 3.197e+01
# lam_u_val: 1.121e+02
# lam_coll_val: 1.113e+02
# It: 1700, Loss: 2.201e+01,  loss_bc1: 3.182e-02,  loss_bc2: 2.409e-02, loss_ics_u: 1.098e-01, loss_ics_ut: 6.369e-04,  Loss_res: 5.858e-01,  loss_coll_u: 6.475e-02 , Time: 70.76
# lam_bc1_val: 3.182e+01
# lam_bc2_val: 2.409e+01
# lam_u_val: 1.104e+02
# lam_coll_val: 1.098e+02
# It: 1800, Loss: 2.065e+01,  loss_bc1: 2.934e-02,  loss_bc2: 2.404e-02, loss_ics_u: 1.085e-01, loss_ics_ut: 6.268e-04,  Loss_res: 2.651e-01,  loss_coll_u: 6.215e-02 , Time: 74.93
# lam_bc1_val: 2.934e+01
# lam_bc2_val: 2.404e+01
# lam_u_val: 1.091e+02
# lam_coll_val: 1.085e+02
# It: 1900, Loss: 2.004e+01,  loss_bc1: 2.701e-02,  loss_bc2: 2.100e-02, loss_ics_u: 1.075e-01, loss_ics_ut: 1.388e-03,  Loss_res: 2.830e-01,  loss_coll_u: 6.067e-02 , Time: 79.06
# lam_bc1_val: 2.701e+01
# lam_bc2_val: 2.100e+01
# lam_u_val: 1.089e+02
# lam_coll_val: 1.075e+02
# It: 2000, Loss: 1.930e+01,  loss_bc1: 2.483e-02,  loss_bc2: 1.796e-02, loss_ics_u: 1.061e-01, loss_ics_ut: 4.085e-04,  Loss_res: 2.533e-01,  loss_coll_u: 5.959e-02 , Time: 83.14
# lam_bc1_val: 2.483e+01
# lam_bc2_val: 1.796e+01
# lam_u_val: 1.065e+02
# lam_coll_val: 1.061e+02
# It: 2100, Loss: 1.888e+01,  loss_bc1: 2.366e-02,  loss_bc2: 1.493e-02, loss_ics_u: 1.045e-01, loss_ics_ut: 4.280e-03,  Loss_res: 2.292e-01,  loss_coll_u: 5.857e-02 , Time: 87.23
# lam_bc1_val: 2.366e+01
# lam_bc2_val: 1.493e+01
# lam_u_val: 1.088e+02
# lam_coll_val: 1.045e+02
# It: 2200, Loss: 1.812e+01,  loss_bc1: 2.200e-02,  loss_bc2: 1.618e-02, loss_ics_u: 1.019e-01, loss_ics_ut: 2.223e-04,  Loss_res: 2.945e-01,  loss_coll_u: 5.704e-02 , Time: 91.33
# lam_bc1_val: 2.200e+01
# lam_bc2_val: 1.618e+01
# lam_u_val: 1.021e+02
# lam_coll_val: 1.019e+02
# It: 2300, Loss: 1.664e+01,  loss_bc1: 1.990e-02,  loss_bc2: 1.304e-02, loss_ics_u: 9.913e-02, loss_ics_ut: 1.814e-04,  Loss_res: 1.440e-01,  loss_coll_u: 5.606e-02 , Time: 95.40
# lam_bc1_val: 1.990e+01
# lam_bc2_val: 1.304e+01
# lam_u_val: 9.932e+01
# lam_coll_val: 9.913e+01
# It: 2400, Loss: 1.580e+01,  loss_bc1: 1.859e-02,  loss_bc2: 1.177e-02, loss_ics_u: 9.602e-02, loss_ics_ut: 7.414e-04,  Loss_res: 2.104e-01,  loss_coll_u: 5.507e-02 , Time: 99.45
# lam_bc1_val: 1.859e+01
# lam_bc2_val: 1.177e+01
# lam_u_val: 9.676e+01
# lam_coll_val: 9.602e+01
# It: 2500, Loss: 1.746e+01,  loss_bc1: 1.779e-02,  loss_bc2: 1.443e-02, loss_ics_u: 9.285e-02, loss_ics_ut: 2.520e-02,  Loss_res: 2.764e-01,  loss_coll_u: 5.478e-02 , Time: 103.56
# lam_bc1_val: 1.779e+01
# lam_bc2_val: 1.443e+01
# lam_u_val: 1.180e+02
# lam_coll_val: 9.285e+01
# It: 2600, Loss: 1.626e+01,  loss_bc1: 1.780e-02,  loss_bc2: 1.105e-02, loss_ics_u: 8.996e-02, loss_ics_ut: 6.894e-05,  Loss_res: 1.855e-01,  loss_coll_u: 5.356e-02 , Time: 107.63
# lam_bc1_val: 1.780e+01
# lam_bc2_val: 1.105e+01
# lam_u_val: 9.003e+01
# lam_coll_val: 8.996e+01
# It: 2700, Loss: 1.319e+01,  loss_bc1: 1.557e-02,  loss_bc2: 1.072e-02, loss_ics_u: 8.638e-02, loss_ics_ut: 2.285e-04,  Loss_res: 2.625e-01,  loss_coll_u: 5.267e-02 , Time: 111.65
# lam_bc1_val: 1.557e+01
# lam_bc2_val: 1.072e+01
# lam_u_val: 8.661e+01
# lam_coll_val: 8.638e+01
# It: 2800, Loss: 1.227e+01,  loss_bc1: 1.538e-02,  loss_bc2: 9.856e-03, loss_ics_u: 8.255e-02, loss_ics_ut: 9.307e-04,  Loss_res: 2.200e-01,  loss_coll_u: 5.183e-02 , Time: 115.71
# lam_bc1_val: 1.538e+01
# lam_bc2_val: 9.856e+00
# lam_u_val: 8.348e+01
# lam_coll_val: 8.255e+01
# It: 2900, Loss: 1.973e+01,  loss_bc1: 1.585e-02,  loss_bc2: 1.385e-02, loss_ics_u: 8.021e-02, loss_ics_ut: 9.512e-02,  Loss_res: 4.621e-01,  loss_coll_u: 5.148e-02 , Time: 119.74
# lam_bc1_val: 1.585e+01
# lam_bc2_val: 1.385e+01
# lam_u_val: 1.753e+02
# lam_coll_val: 8.021e+01
# It: 3000, Loss: 2.982e+01,  loss_bc1: 5.001e-02,  loss_bc2: 1.750e-02, loss_ics_u: 1.163e-01, loss_ics_ut: 2.087e-03,  Loss_res: 2.107e+00,  loss_coll_u: 7.382e-02 , Time: 123.81
# lam_bc1_val: 5.001e+01
# lam_bc2_val: 1.750e+01
# lam_u_val: 1.184e+02
# lam_coll_val: 1.163e+02
# It: 3100, Loss: 2.171e+01,  loss_bc1: 2.122e-02,  loss_bc2: 1.814e-02, loss_ics_u: 1.088e-01, loss_ics_ut: 6.068e-04,  Loss_res: 7.652e-01,  loss_coll_u: 5.694e-02 , Time: 127.85
# lam_bc1_val: 2.122e+01
# lam_bc2_val: 1.814e+01
# lam_u_val: 1.094e+02
# lam_coll_val: 1.088e+02
# It: 3200, Loss: 1.828e+01,  loss_bc1: 2.162e-02,  loss_bc2: 1.524e-02, loss_ics_u: 1.016e-01, loss_ics_ut: 1.830e-04,  Loss_res: 4.020e-01,  loss_coll_u: 5.518e-02 , Time: 131.91
# lam_bc1_val: 2.162e+01
# lam_bc2_val: 1.524e+01
# lam_u_val: 1.018e+02
# lam_coll_val: 1.016e+02
# It: 3300, Loss: 1.611e+01,  loss_bc1: 1.770e-02,  loss_bc2: 1.332e-02, loss_ics_u: 9.543e-02, loss_ics_ut: 3.019e-04,  Loss_res: 2.437e-01,  loss_coll_u: 5.448e-02 , Time: 136.00
# lam_bc1_val: 1.770e+01
# lam_bc2_val: 1.332e+01
# lam_u_val: 9.573e+01
# lam_coll_val: 9.543e+01
# It: 3400, Loss: 1.465e+01,  loss_bc1: 1.600e-02,  loss_bc2: 1.254e-02, loss_ics_u: 9.168e-02, loss_ics_ut: 6.719e-04,  Loss_res: 2.009e-01,  loss_coll_u: 5.401e-02 , Time: 140.09
# lam_bc1_val: 1.600e+01
# lam_bc2_val: 1.254e+01
# lam_u_val: 9.235e+01
# lam_coll_val: 9.168e+01
# It: 3500, Loss: 1.380e+01,  loss_bc1: 1.441e-02,  loss_bc2: 1.177e-02, loss_ics_u: 8.944e-02, loss_ics_ut: 8.499e-04,  Loss_res: 1.689e-01,  loss_coll_u: 5.358e-02 , Time: 144.14
# lam_bc1_val: 1.441e+01
# lam_bc2_val: 1.177e+01
# lam_u_val: 9.029e+01
# lam_coll_val: 8.944e+01
# It: 3600, Loss: 1.323e+01,  loss_bc1: 1.429e-02,  loss_bc2: 1.121e-02, loss_ics_u: 8.768e-02, loss_ics_ut: 9.098e-04,  Loss_res: 1.413e-01,  loss_coll_u: 5.312e-02 , Time: 148.20
# lam_bc1_val: 1.429e+01
# lam_bc2_val: 1.121e+01
# lam_u_val: 8.859e+01
# lam_coll_val: 8.768e+01
# It: 3700, Loss: 1.274e+01,  loss_bc1: 1.302e-02,  loss_bc2: 1.060e-02, loss_ics_u: 8.610e-02, loss_ics_ut: 1.033e-03,  Loss_res: 1.157e-01,  loss_coll_u: 5.248e-02 , Time: 152.25
# lam_bc1_val: 1.302e+01
# lam_bc2_val: 1.060e+01
# lam_u_val: 8.714e+01
# lam_coll_val: 8.610e+01
# It: 3800, Loss: 1.233e+01,  loss_bc1: 1.277e-02,  loss_bc2: 1.063e-02, loss_ics_u: 8.420e-02, loss_ics_ut: 1.105e-03,  Loss_res: 1.410e-01,  loss_coll_u: 5.200e-02 , Time: 156.42
# lam_bc1_val: 1.277e+01
# lam_bc2_val: 1.063e+01
# lam_u_val: 8.531e+01
# lam_coll_val: 8.420e+01
# It: 3900, Loss: 1.183e+01,  loss_bc1: 1.218e-02,  loss_bc2: 1.031e-02, loss_ics_u: 8.218e-02, loss_ics_ut: 1.173e-03,  Loss_res: 1.176e-01,  loss_coll_u: 5.151e-02 , Time: 160.57
# lam_bc1_val: 1.218e+01
# lam_bc2_val: 1.031e+01
# lam_u_val: 8.335e+01
# lam_coll_val: 8.218e+01
# It: 4000, Loss: 1.140e+01,  loss_bc1: 1.190e-02,  loss_bc2: 9.646e-03, loss_ics_u: 8.038e-02, loss_ics_ut: 1.370e-03,  Loss_res: 1.443e-01,  loss_coll_u: 5.106e-02 , Time: 164.74
# lam_bc1_val: 1.190e+01
# lam_bc2_val: 9.646e+00
# lam_u_val: 8.175e+01
# lam_coll_val: 8.038e+01
# It: 4100, Loss: 1.095e+01,  loss_bc1: 1.145e-02,  loss_bc2: 9.703e-03, loss_ics_u: 7.855e-02, loss_ics_ut: 1.273e-03,  Loss_res: 1.232e-01,  loss_coll_u: 5.061e-02 , Time: 168.84
# lam_bc1_val: 1.145e+01
# lam_bc2_val: 9.703e+00
# lam_u_val: 7.982e+01
# lam_u_val: 7.255e+01
# lam_coll_val: 6.786e+01
# It: 5000, Loss: 8.740e+00,  loss_bc1: 1.187e-02,  loss_bc2: 9.497e-03, loss_ics_u: 6.685e-02, loss_ics_ut: 2.747e-03,  Loss_res: 1.886e-01,  loss_coll_u: 4.826e-02 , Time: 205.23
# lam_bc1_val: 1.187e+01
# lam_bc2_val: 9.497e+00
# lam_u_val: 6.959e+01
# lam_coll_val: 6.685e+01
# It: 5100, Loss: 8.375e+00,  loss_bc1: 1.155e-02,  loss_bc2: 8.722e-03, loss_ics_u: 6.658e-02, loss_ics_ut: 1.300e-03,  Loss_res: 2.283e-01,  loss_coll_u: 4.791e-02 , Time: 209.26
# lam_bc1_val: 1.155e+01
# lam_bc2_val: 8.722e+00
# lam_u_val: 6.788e+01
# lam_coll_val: 6.658e+01
# It: 5200, Loss: 8.417e+00,  loss_bc1: 1.151e-02,  loss_bc2: 9.091e-03, loss_ics_u: 6.517e-02, loss_ics_ut: 6.727e-03,  Loss_res: 1.605e-01,  loss_coll_u: 4.752e-02 , Time: 213.32
# lam_bc1_val: 1.151e+01
# lam_bc2_val: 9.091e+00
# lam_u_val: 7.190e+01
# lam_coll_val: 6.517e+01
# It: 5300, Loss: 8.183e+00,  loss_bc1: 1.190e-02,  loss_bc2: 1.060e-02, loss_ics_u: 6.362e-02, loss_ics_ut: 1.526e-03,  Loss_res: 1.708e-01,  loss_coll_u: 4.749e-02 , Time: 217.41
# lam_bc1_val: 1.190e+01
# lam_bc2_val: 1.060e+01
# lam_u_val: 6.515e+01
# lam_coll_val: 6.362e+01
# It: 5400, Loss: 7.837e+00,  loss_bc1: 1.071e-02,  loss_bc2: 9.101e-03, loss_ics_u: 6.300e-02, loss_ics_ut: 2.282e-03,  Loss_res: 3.764e-01,  loss_coll_u: 4.690e-02 , Time: 221.44
# lam_bc1_val: 1.071e+01
# lam_bc2_val: 9.101e+00
# lam_u_val: 6.528e+01
# lam_coll_val: 6.300e+01
# It: 5500, Loss: 7.679e+00,  loss_bc1: 1.274e-02,  loss_bc2: 9.437e-03, loss_ics_u: 6.138e-02, loss_ics_ut: 5.340e-03,  Loss_res: 1.589e-01,  loss_coll_u: 4.671e-02 , Time: 225.50
# lam_bc1_val: 1.274e+01
# lam_bc2_val: 9.437e+00
# lam_u_val: 6.672e+01
# lam_coll_val: 6.138e+01
# It: 5600, Loss: 7.383e+00,  loss_bc1: 1.109e-02,  loss_bc2: 1.039e-02, loss_ics_u: 6.151e-02, loss_ics_ut: 1.459e-03,  Loss_res: 9.769e-02,  loss_coll_u: 4.635e-02 , Time: 229.52
# lam_bc1_val: 1.109e+01
# lam_bc2_val: 1.039e+01
# lam_u_val: 6.296e+01
# lam_coll_val: 6.151e+01
# It: 5700, Loss: 7.258e+00,  loss_bc1: 1.067e-02,  loss_bc2: 8.837e-03, loss_ics_u: 6.043e-02, loss_ics_ut: 4.580e-03,  Loss_res: 1.421e-01,  loss_coll_u: 4.573e-02 , Time: 233.56
# lam_bc1_val: 1.067e+01
# lam_bc2_val: 8.837e+00
# lam_u_val: 6.501e+01
# lam_coll_val: 6.043e+01
# It: 5800, Loss: 7.162e+00,  loss_bc1: 1.172e-02,  loss_bc2: 1.023e-02, loss_ics_u: 5.907e-02, loss_ics_ut: 1.556e-03,  Loss_res: 2.443e-01,  loss_coll_u: 4.569e-02 , Time: 237.60
# lam_bc1_val: 1.172e+01
# lam_bc2_val: 1.023e+01
# lam_u_val: 6.063e+01
# lam_coll_val: 5.907e+01
# It: 5900, Loss: 7.094e+00,  loss_bc1: 1.189e-02,  loss_bc2: 9.750e-03, loss_ics_u: 5.849e-02, loss_ics_ut: 2.360e-03,  Loss_res: 4.647e-01,  loss_coll_u: 4.573e-02 , Time: 241.61
# lam_bc1_val: 1.189e+01
# lam_bc2_val: 9.750e+00
# lam_u_val: 6.085e+01
# lam_coll_val: 5.849e+01
# It: 6000, Loss: 6.658e+00,  loss_bc1: 1.129e-02,  loss_bc2: 9.841e-03, loss_ics_u: 5.750e-02, loss_ics_ut: 2.148e-03,  Loss_res: 1.692e-01,  loss_coll_u: 4.495e-02 , Time: 245.66
# lam_bc1_val: 1.129e+01
# lam_bc2_val: 9.841e+00
# lam_u_val: 5.964e+01
# lam_coll_val: 5.750e+01
# It: 6100, Loss: 6.336e+00,  loss_bc1: 1.005e-02,  loss_bc2: 8.950e-03, loss_ics_u: 5.679e-02, loss_ics_ut: 1.573e-03,  Loss_res: 9.790e-02,  loss_coll_u: 4.445e-02 , Time: 249.69
# lam_bc1_val: 1.005e+01
# lam_bc2_val: 8.950e+00
# lam_u_val: 5.836e+01
# lam_coll_val: 5.679e+01
# It: 6200, Loss: 7.140e+00,  loss_bc1: 1.100e-02,  loss_bc2: 9.124e-03, loss_ics_u: 5.592e-02, loss_ics_ut: 1.800e-02,  Loss_res: 1.371e-01,  loss_coll_u: 4.395e-02 , Time: 253.74
# lam_bc1_val: 1.100e+01
# lam_bc2_val: 9.124e+00
# lam_u_val: 7.393e+01
# lam_coll_val: 5.592e+01
# It: 6300, Loss: 7.533e+00,  loss_bc1: 1.312e-02,  loss_bc2: 9.894e-03, loss_ics_u: 6.089e-02, loss_ics_ut: 9.005e-04,  Loss_res: 1.949e-01,  loss_coll_u: 4.533e-02 , Time: 258.03
# lam_bc1_val: 1.312e+01
# lam_bc2_val: 9.894e+00
# lam_u_val: 6.180e+01
# lam_coll_val: 6.089e+01
# It: 6400, Loss: 6.715e+00,  loss_bc1: 1.131e-02,  loss_bc2: 8.559e-03, loss_ics_u: 5.865e-02, loss_ics_ut: 7.969e-04,  Loss_res: 1.230e-01,  loss_coll_u: 4.410e-02 , Time: 262.09
# lam_bc1_val: 1.131e+01
# lam_bc2_val: 8.559e+00
# lam_u_val: 5.944e+01
# lam_coll_val: 5.865e+01
# It: 6500, Loss: 6.274e+00,  loss_bc1: 1.134e-02,  loss_bc2: 9.014e-03, loss_ics_u: 5.655e-02, loss_ics_ut: 7.913e-04,  Loss_res: 1.208e-01,  loss_coll_u: 4.330e-02 , Time: 266.09
# lam_bc1_val: 1.134e+01
# lam_bc2_val: 9.014e+00
# lam_u_val: 5.734e+01
# lam_coll_val: 5.655e+01
# It: 6600, Loss: 5.941e+00,  loss_bc1: 1.111e-02,  loss_bc2: 8.242e-03, loss_ics_u: 5.515e-02, loss_ics_ut: 1.088e-03,  Loss_res: 1.173e-01,  loss_coll_u: 4.241e-02 , Time: 270.14
# lam_bc1_val: 1.111e+01
# lam_bc2_val: 8.242e+00
# lam_u_val: 5.624e+01
# lam_coll_val: 5.515e+01
# It: 6700, Loss: 5.801e+00,  loss_bc1: 1.078e-02,  loss_bc2: 8.096e-03, loss_ics_u: 5.358e-02, loss_ics_ut: 1.100e-03,  Loss_res: 2.512e-01,  loss_coll_u: 4.149e-02 , Time: 274.19
# lam_bc1_val: 1.078e+01
# lam_bc2_val: 8.096e+00
# lam_u_val: 5.468e+01
# lam_coll_val: 5.358e+01
# It: 6800, Loss: 5.401e+00,  loss_bc1: 9.167e-03,  loss_bc2: 8.768e-03, loss_ics_u: 5.249e-02, loss_ics_ut: 7.461e-04,  Loss_res: 1.282e-01,  loss_coll_u: 4.092e-02 , Time: 278.23
# lam_bc1_val: 9.167e+00
# lam_bc2_val: 8.768e+00
# lam_u_val: 5.323e+01
# lam_coll_val: 5.249e+01
# It: 6900, Loss: 5.239e+00,  loss_bc1: 1.110e-02,  loss_bc2: 8.288e-03, loss_ics_u: 5.024e-02, loss_ics_ut: 1.919e-03,  Loss_res: 1.836e-01,  loss_coll_u: 4.010e-02 , Time: 282.39
# lam_bc1_val: 1.110e+01
# lam_bc2_val: 8.288e+00
# lam_u_val: 5.216e+01
# lam_coll_val: 5.024e+01
# It: 7000, Loss: 5.301e+00,  loss_bc1: 9.728e-03,  loss_bc2: 7.545e-03, loss_ics_u: 4.913e-02, loss_ics_ut: 5.395e-03,  Loss_res: 3.165e-01,  loss_coll_u: 3.921e-02 , Time: 286.44
# lam_bc1_val: 9.728e+00
# lam_bc2_val: 7.545e+00
# lam_u_val: 5.452e+01
# lam_coll_val: 4.913e+01
# It: 7100, Loss: 5.343e+00,  loss_bc1: 9.682e-03,  loss_bc2: 6.986e-03, loss_ics_u: 4.868e-02, loss_ics_ut: 4.684e-03,  Loss_res: 3.830e-01,  loss_coll_u: 3.875e-02 , Time: 290.48
# lam_bc1_val: 9.682e+00
# lam_bc2_val: 6.986e+00
# lam_u_val: 5.336e+01
# lam_coll_val: 4.868e+01
# It: 7200, Loss: 6.073e+00,  loss_bc1: 9.672e-03,  loss_bc2: 7.821e-03, loss_ics_u: 4.688e-02, loss_ics_ut: 2.630e-02,  Loss_res: 1.585e-01,  loss_coll_u: 3.823e-02 , Time: 294.58
# lam_bc1_val: 9.672e+00
# lam_bc2_val: 7.821e+00
# lam_u_val: 7.318e+01
# lam_coll_val: 4.688e+01
# It: 7300, Loss: 6.165e+00,  loss_bc1: 1.457e-02,  loss_bc2: 9.876e-03, loss_ics_u: 5.276e-02, loss_ics_ut: 7.383e-04,  Loss_res: 1.270e-01,  loss_coll_u: 4.064e-02 , Time: 298.64
# lam_bc1_val: 1.457e+01
# lam_bc2_val: 9.876e+00
# lam_u_val: 5.350e+01
# lam_coll_val: 5.276e+01
# It: 7400, Loss: 5.093e+00,  loss_bc1: 9.581e-03,  loss_bc2: 6.908e-03, loss_ics_u: 5.094e-02, loss_ics_ut: 4.741e-04,  Loss_res: 9.125e-02,  loss_coll_u: 3.873e-02 , Time: 302.71
# lam_bc1_val: 9.581e+00
# lam_bc2_val: 6.908e+00
# lam_u_val: 5.141e+01
# lam_coll_val: 5.094e+01
# It: 7500, Loss: 4.697e+00,  loss_bc1: 1.049e-02,  loss_bc2: 7.378e-03, loss_ics_u: 4.800e-02, loss_ics_ut: 5.642e-04,  Loss_res: 1.281e-01,  loss_coll_u: 3.770e-02 , Time: 306.73
# lam_bc1_val: 1.049e+01
# lam_bc2_val: 7.378e+00
# lam_u_val: 4.856e+01
# lam_coll_val: 4.800e+01
# It: 7600, Loss: 4.366e+00,  loss_bc1: 9.451e-03,  loss_bc2: 7.154e-03, loss_ics_u: 4.618e-02, loss_ics_ut: 9.682e-04,  Loss_res: 1.727e-01,  loss_coll_u: 3.651e-02 , Time: 310.77
# lam_bc1_val: 9.451e+00
# lam_bc2_val: 7.154e+00
# lam_u_val: 4.715e+01
# lam_coll_val: 4.618e+01
# It: 7700, Loss: 4.051e+00,  loss_bc1: 9.655e-03,  loss_bc2: 6.364e-03, loss_ics_u: 4.432e-02, loss_ics_ut: 8.583e-04,  Loss_res: 1.496e-01,  loss_coll_u: 3.541e-02 , Time: 314.81
# lam_bc1_val: 9.655e+00
# lam_bc2_val: 6.364e+00
# lam_u_val: 4.517e+01
# lam_coll_val: 4.432e+01
# It: 7800, Loss: 4.102e+00,  loss_bc1: 8.633e-03,  loss_bc2: 6.646e-03, loss_ics_u: 4.260e-02, loss_ics_ut: 1.486e-03,  Loss_res: 4.431e-01,  loss_coll_u: 3.479e-02 , Time: 318.84
# lam_bc1_val: 8.633e+00
# lam_bc2_val: 6.646e+00
# lam_u_val: 4.409e+01
# lam_coll_val: 4.260e+01
# It: 7900, Loss: 3.594e+00,  loss_bc1: 9.089e-03,  loss_bc2: 6.443e-03, loss_ics_u: 4.060e-02, loss_ics_ut: 8.987e-04,  Loss_res: 1.999e-01,  loss_coll_u: 3.388e-02 , Time: 322.89
# lam_bc1_val: 9.089e+00
# lam_bc2_val: 6.443e+00
# lam_u_val: 4.150e+01
# lam_coll_val: 4.060e+01
# It: 8000, Loss: 3.278e+00,  loss_bc1: 8.762e-03,  loss_bc2: 5.458e-03, loss_ics_u: 3.879e-02, loss_ics_ut: 1.281e-03,  Loss_res: 1.692e-01,  loss_coll_u: 3.279e-02 , Time: 327.17
# lam_bc1_val: 8.762e+00
# lam_bc2_val: 5.458e+00
# lam_u_val: 4.007e+01
# lam_coll_val: 3.879e+01
# It: 8100, Loss: 3.023e+00,  loss_bc1: 8.393e-03,  loss_bc2: 5.093e-03, loss_ics_u: 3.710e-02, loss_ics_ut: 9.843e-04,  Loss_res: 1.580e-01,  loss_coll_u: 3.192e-02 , Time: 334.82
# lam_bc1_val: 8.393e+00
# lam_bc2_val: 5.093e+00
# lam_u_val: 3.808e+01
# lam_coll_val: 3.710e+01
# It: 8200, Loss: 2.775e+00,  loss_bc1: 8.070e-03,  loss_bc2: 4.959e-03, loss_ics_u: 3.514e-02, loss_ics_ut: 1.525e-03,  Loss_res: 1.357e-01,  loss_coll_u: 3.099e-02 , Time: 339.69
# lam_bc1_val: 8.070e+00
# lam_bc2_val: 4.959e+00
# lam_u_val: 3.666e+01
# lam_coll_val: 3.514e+01
# It: 8300, Loss: 2.753e+00,  loss_bc1: 9.480e-03,  loss_bc2: 4.437e-03, loss_ics_u: 3.338e-02, loss_ics_ut: 1.141e-03,  Loss_res: 3.145e-01,  loss_coll_u: 3.057e-02 , Time: 344.80
# lam_bc1_val: 9.480e+00
# lam_bc2_val: 4.437e+00
# lam_u_val: 3.452e+01
# lam_coll_val: 3.338e+01
# It: 8400, Loss: 2.393e+00,  loss_bc1: 6.898e-03,  loss_bc2: 5.041e-03, loss_ics_u: 3.195e-02, loss_ics_ut: 1.712e-03,  Loss_res: 1.445e-01,  loss_coll_u: 2.992e-02 , Time: 349.19
# lam_bc1_val: 6.898e+00
# lam_bc2_val: 5.041e+00
# lam_u_val: 3.366e+01
# lam_coll_val: 3.195e+01
# It: 8500, Loss: 2.242e+00,  loss_bc1: 7.407e-03,  loss_bc2: 4.609e-03, loss_ics_u: 2.994e-02, loss_ics_ut: 1.534e-03,  Loss_res: 1.794e-01,  loss_coll_u: 2.908e-02 , Time: 353.48
# lam_bc1_val: 7.407e+00
# lam_bc2_val: 4.609e+00
# lam_u_val: 3.147e+01
# lam_coll_val: 2.994e+01
# It: 8600, Loss: 2.243e+00,  loss_bc1: 7.350e-03,  loss_bc2: 4.570e-03, loss_ics_u: 2.858e-02, loss_ics_ut: 2.946e-03,  Loss_res: 3.137e-01,  loss_coll_u: 2.878e-02 , Time: 357.99
# lam_bc1_val: 7.350e+00
# lam_bc2_val: 4.570e+00
# lam_u_val: 3.153e+01
# lam_coll_val: 2.858e+01
# It: 8700, Loss: 2.001e+00,  loss_bc1: 8.263e-03,  loss_bc2: 4.486e-03, loss_ics_u: 2.677e-02, loss_ics_ut: 1.240e-03,  Loss_res: 2.269e-01,  loss_coll_u: 2.832e-02 , Time: 362.31
# lam_bc1_val: 8.263e+00
# lam_bc2_val: 4.486e+00
# lam_u_val: 2.801e+01
# lam_coll_val: 2.677e+01
# It: 8800, Loss: 1.811e+00,  loss_bc1: 6.743e-03,  loss_bc2: 3.811e-03, loss_ics_u: 2.587e-02, loss_ics_ut: 2.550e-03,  Loss_res: 2.061e-01,  loss_coll_u: 2.750e-02 , Time: 366.55
# lam_bc1_val: 6.743e+00
# lam_bc2_val: 3.811e+00
# lam_u_val: 2.842e+01
# lam_coll_val: 2.587e+01
# It: 8900, Loss: 1.930e+00,  loss_bc1: 7.431e-03,  loss_bc2: 4.509e-03, loss_ics_u: 2.428e-02, loss_ics_ut: 1.063e-02,  Loss_res: 1.661e-01,  loss_coll_u: 2.725e-02 , Time: 370.73
# lam_bc1_val: 7.431e+00
# lam_bc2_val: 4.509e+00
# lam_u_val: 3.491e+01
# lam_coll_val: 2.428e+01
# It: 9000, Loss: 1.964e+00,  loss_bc1: 7.538e-03,  loss_bc2: 4.656e-03, loss_ics_u: 3.074e-02, loss_ics_ut: 5.618e-04,  Loss_res: 8.906e-02,  loss_coll_u: 2.907e-02 , Time: 375.09
# lam_bc1_val: 7.538e+00
# lam_bc2_val: 4.656e+00
# lam_u_val: 3.130e+01
# lam_coll_val: 3.074e+01
# It: 9100, Loss: 1.944e+00,  loss_bc1: 6.877e-03,  loss_bc2: 3.997e-03, loss_ics_u: 2.864e-02, loss_ics_ut: 7.727e-04,  Loss_res: 9.465e-02,  loss_coll_u: 2.792e-02 , Time: 379.27
# lam_bc1_val: 6.877e+00
# lam_bc2_val: 3.997e+00
# lam_u_val: 2.942e+01
# lam_coll_val: 2.864e+01
# It: 9200, Loss: 1.759e+00,  loss_bc1: 7.291e-03,  loss_bc2: 3.757e-03, loss_ics_u: 2.663e-02, loss_ics_ut: 1.002e-03,  Loss_res: 1.065e-01,  loss_coll_u: 2.706e-02 , Time: 383.45
# lam_bc1_val: 7.291e+00
# lam_bc2_val: 3.757e+00
# lam_u_val: 2.763e+01
# lam_coll_val: 2.663e+01
# It: 9300, Loss: 1.587e+00,  loss_bc1: 6.070e-03,  loss_bc2: 4.253e-03, loss_ics_u: 2.538e-02, loss_ics_ut: 7.324e-04,  Loss_res: 9.595e-02,  loss_coll_u: 2.663e-02 , Time: 387.65
# lam_bc1_val: 6.070e+00
# lam_bc2_val: 4.253e+00
# lam_u_val: 2.611e+01
# lam_coll_val: 2.538e+01
# It: 9400, Loss: 1.463e+00,  loss_bc1: 6.901e-03,  loss_bc2: 3.593e-03, loss_ics_u: 2.387e-02, loss_ics_ut: 7.432e-04,  Loss_res: 1.068e-01,  loss_coll_u: 2.585e-02 , Time: 392.04
# lam_bc1_val: 6.901e+00
# lam_bc2_val: 3.593e+00
# lam_u_val: 2.461e+01
# lam_coll_val: 2.387e+01
# It: 9500, Loss: 1.709e+00,  loss_bc1: 7.313e-03,  loss_bc2: 3.188e-03, loss_ics_u: 2.285e-02, loss_ics_ut: 1.656e-03,  Loss_res: 4.222e-01,  loss_coll_u: 2.604e-02 , Time: 396.43
# lam_bc1_val: 7.313e+00
# lam_bc2_val: 3.188e+00
# lam_u_val: 2.451e+01
# lam_coll_val: 2.285e+01
# It: 9600, Loss: 1.286e+00,  loss_bc1: 6.530e-03,  loss_bc2: 3.640e-03, loss_ics_u: 2.165e-02, loss_ics_ut: 7.616e-04,  Loss_res: 9.647e-02,  loss_coll_u: 2.544e-02 , Time: 400.87
# lam_bc1_val: 6.530e+00
# lam_bc2_val: 3.640e+00
# lam_u_val: 2.241e+01
# lam_coll_val: 2.165e+01
# It: 9700, Loss: 1.198e+00,  loss_bc1: 7.639e-03,  loss_bc2: 3.512e-03, loss_ics_u: 2.051e-02, loss_ics_ut: 9.828e-04,  Loss_res: 1.097e-01,  loss_coll_u: 2.512e-02 , Time: 405.13
# lam_bc1_val: 7.639e+00
# lam_bc2_val: 3.512e+00
# lam_u_val: 2.150e+01
# lam_coll_val: 2.051e+01
# It: 9800, Loss: 1.154e+00,  loss_bc1: 5.914e-03,  loss_bc2: 2.960e-03, loss_ics_u: 2.020e-02, loss_ics_ut: 8.131e-04,  Loss_res: 1.429e-01,  loss_coll_u: 2.456e-02 , Time: 409.46
# lam_bc1_val: 5.914e+00
# lam_bc2_val: 2.960e+00
# lam_u_val: 2.102e+01
# lam_coll_val: 2.020e+01
# It: 9900, Loss: 1.219e+00,  loss_bc1: 6.647e-03,  loss_bc2: 3.334e-03, loss_ics_u: 1.883e-02, loss_ics_ut: 7.040e-04,  Loss_res: 2.716e-01,  loss_coll_u: 2.416e-02 , Time: 413.73
# lam_bc1_val: 6.647e+00
# lam_bc2_val: 3.334e+00
# lam_u_val: 1.953e+01
# lam_coll_val: 1.883e+01
# It: 10000, Loss: 1.002e+00,  loss_bc1: 6.233e-03,  loss_bc2: 2.937e-03, loss_ics_u: 1.826e-02, loss_ics_ut: 3.319e-03,  Loss_res: 8.258e-02,  loss_coll_u: 2.371e-02 , Time: 417.98
# lam_bc1_val: 6.233e+00
# lam_bc2_val: 2.937e+00
# lam_u_val: 2.158e+01
# lam_coll_val: 1.826e+01
# It: 10100, Loss: 1.104e+00,  loss_bc1: 6.822e-03,  loss_bc2: 3.300e-03, loss_ics_u: 1.708e-02, loss_ics_ut: 9.102e-04,  Loss_res: 2.336e-01,  loss_coll_u: 2.355e-02 , Time: 422.24
# lam_bc1_val: 6.822e+00
# lam_bc2_val: 3.300e+00
# lam_u_val: 1.799e+01
# lam_coll_val: 1.708e+01
# It: 10200, Loss: 1.104e+00,  loss_bc1: 5.718e-03,  loss_bc2: 3.594e-03, loss_ics_u: 1.688e-02, loss_ics_ut: 3.797e-03,  Loss_res: 2.782e-01,  loss_coll_u: 2.362e-02 , Time: 428.29
# lam_bc1_val: 5.718e+00
# lam_bc2_val: 3.594e+00
# lam_u_val: 2.068e+01
# lam_coll_val: 1.688e+01
# It: 10300, Loss: 1.062e+00,  loss_bc1: 6.881e-03,  loss_bc2: 3.185e-03, loss_ics_u: 1.579e-02, loss_ics_ut: 3.314e-03,  Loss_res: 2.192e-01,  loss_coll_u: 2.352e-02 , Time: 432.88
# lam_bc1_val: 6.881e+00
# lam_bc2_val: 3.185e+00
# lam_u_val: 1.910e+01
# lam_coll_val: 1.579e+01
# It: 10400, Loss: 8.624e-01,  loss_bc1: 6.035e-03,  loss_bc2: 3.166e-03, loss_ics_u: 1.516e-02, loss_ics_ut: 1.094e-03,  Loss_res: 1.358e-01,  loss_coll_u: 2.309e-02 , Time: 437.38
# lam_bc1_val: 6.035e+00
# lam_bc2_val: 3.166e+00
# lam_u_val: 1.626e+01
# lam_coll_val: 1.516e+01
# It: 10500, Loss: 9.035e-01,  loss_bc1: 5.570e-03,  loss_bc2: 2.624e-03, loss_ics_u: 1.500e-02, loss_ics_ut: 6.320e-03,  Loss_res: 1.696e-01,  loss_coll_u: 2.277e-02 , Time: 442.96
# lam_bc1_val: 5.570e+00
# lam_bc2_val: 2.624e+00
# lam_u_val: 2.132e+01
# lam_coll_val: 1.500e+01
# It: 10600, Loss: 1.234e+00,  loss_bc1: 6.773e-03,  loss_bc2: 3.529e-03, loss_ics_u: 1.367e-02, loss_ics_ut: 1.224e-02,  Loss_res: 2.933e-01,  loss_coll_u: 2.271e-02 , Time: 448.74
# lam_bc1_val: 6.773e+00
# lam_bc2_val: 3.529e+00
# lam_u_val: 2.592e+01
# lam_coll_val: 1.367e+01
# It: 10700, Loss: 9.637e-01,  loss_bc1: 7.138e-03,  loss_bc2: 3.026e-03, loss_ics_u: 1.864e-02, loss_ics_ut: 6.099e-04,  Loss_res: 6.265e-02,  loss_coll_u: 2.510e-02 , Time: 453.06
# lam_bc1_val: 7.138e+00
# lam_bc2_val: 3.026e+00
# lam_u_val: 1.925e+01
# lam_coll_val: 1.864e+01
# It: 10800, Loss: 8.930e-01,  loss_bc1: 6.111e-03,  loss_bc2: 2.561e-03, loss_ics_u: 1.745e-02, loss_ics_ut: 3.529e-04,  Loss_res: 5.604e-02,  loss_coll_u: 2.376e-02 , Time: 457.24
# lam_bc1_val: 6.111e+00
# lam_bc2_val: 2.561e+00
# lam_u_val: 1.780e+01
# lam_coll_val: 1.745e+01
# It: 10900, Loss: 8.303e-01,  loss_bc1: 6.041e-03,  loss_bc2: 2.732e-03, loss_ics_u: 1.633e-02, loss_ics_ut: 5.908e-04,  Loss_res: 8.173e-02,  loss_coll_u: 2.312e-02 , Time: 461.38
# lam_bc1_val: 6.041e+00
# lam_bc2_val: 2.732e+00
# lam_u_val: 1.692e+01
# lam_coll_val: 1.633e+01
# It: 11000, Loss: 7.547e-01,  loss_bc1: 6.372e-03,  loss_bc2: 2.731e-03, loss_ics_u: 1.529e-02, loss_ics_ut: 5.183e-04,  Loss_res: 7.233e-02,  loss_coll_u: 2.260e-02 , Time: 465.63
# lam_bc1_val: 6.372e+00
# lam_bc2_val: 2.731e+00
# lam_u_val: 1.581e+01
# lam_coll_val: 1.529e+01
# It: 11100, Loss: 6.655e-01,  loss_bc1: 6.122e-03,  loss_bc2: 2.647e-03, loss_ics_u: 1.472e-02, loss_ics_ut: 4.152e-04,  Loss_res: 4.147e-02,  loss_coll_u: 2.215e-02 , Time: 469.85
# lam_bc1_val: 6.122e+00
# lam_bc2_val: 2.647e+00
# lam_u_val: 1.513e+01
# lam_coll_val: 1.472e+01
# It: 11200, Loss: 6.914e-01,  loss_bc1: 6.147e-03,  loss_bc2: 2.777e-03, loss_ics_u: 1.401e-02, loss_ics_ut: 9.807e-04,  Loss_res: 9.769e-02,  loss_coll_u: 2.187e-02 , Time: 474.01
# lam_bc1_val: 6.147e+00
# lam_bc2_val: 2.777e+00
# lam_u_val: 1.499e+01
# lam_coll_val: 1.401e+01
# It: 11300, Loss: 6.391e-01,  loss_bc1: 5.857e-03,  loss_bc2: 2.470e-03, loss_ics_u: 1.359e-02, loss_ics_ut: 1.461e-03,  Loss_res: 6.941e-02,  loss_coll_u: 2.151e-02 , Time: 478.28
# lam_bc1_val: 5.857e+00
# lam_bc2_val: 2.470e+00
# lam_u_val: 1.505e+01
# lam_coll_val: 1.359e+01
# It: 11400, Loss: 8.400e-01,  loss_bc1: 6.810e-03,  loss_bc2: 2.436e-03, loss_ics_u: 1.293e-02, loss_ics_ut: 6.818e-04,  Loss_res: 2.949e-01,  loss_coll_u: 2.166e-02 , Time: 484.50
# lam_bc1_val: 6.810e+00
# lam_bc2_val: 2.436e+00
# lam_u_val: 1.361e+01
# lam_coll_val: 1.293e+01
# It: 11500, Loss: 5.873e-01,  loss_bc1: 5.995e-03,  loss_bc2: 2.386e-03, loss_ics_u: 1.264e-02, loss_ics_ut: 7.266e-04,  Loss_res: 8.357e-02,  loss_coll_u: 2.129e-02 , Time: 488.83
# lam_bc1_val: 5.995e+00
# lam_bc2_val: 2.386e+00
# lam_u_val: 1.336e+01
# lam_coll_val: 1.264e+01
# It: 11600, Loss: 8.149e-01,  loss_bc1: 5.898e-03,  loss_bc2: 2.482e-03, loss_ics_u: 1.202e-02, loss_ics_ut: 3.706e-03,  Loss_res: 2.966e-01,  loss_coll_u: 2.112e-02 , Time: 493.12
# lam_bc1_val: 5.898e+00
# lam_bc2_val: 2.482e+00
# lam_u_val: 1.573e+01
# lam_coll_val: 1.202e+01
# It: 11700, Loss: 6.614e-01,  loss_bc1: 6.437e-03,  loss_bc2: 2.430e-03, loss_ics_u: 1.146e-02, loss_ics_ut: 6.060e-04,  Loss_res: 1.769e-01,  loss_coll_u: 2.086e-02 , Time: 497.39
# lam_bc1_val: 6.437e+00
# lam_bc2_val: 2.430e+00
# lam_u_val: 1.206e+01
# lam_coll_val: 1.146e+01
# It: 11800, Loss: 5.224e-01,  loss_bc1: 5.714e-03,  loss_bc2: 2.481e-03, loss_ics_u: 1.140e-02, loss_ics_ut: 1.125e-03,  Loss_res: 8.798e-02,  loss_coll_u: 2.099e-02 , Time: 501.66
# lam_bc1_val: 5.714e+00
# lam_bc2_val: 2.481e+00
# lam_u_val: 1.252e+01
# lam_coll_val: 1.140e+01
# It: 11900, Loss: 5.240e-01,  loss_bc1: 6.190e-03,  loss_bc2: 2.425e-03, loss_ics_u: 1.097e-02, loss_ics_ut: 1.005e-03,  Loss_res: 9.256e-02,  loss_coll_u: 2.106e-02 , Time: 505.95
# lam_bc1_val: 6.190e+00
# lam_bc2_val: 2.425e+00
# lam_u_val: 1.197e+01
# lam_coll_val: 1.097e+01
# It: 12000, Loss: 4.519e-01,  loss_bc1: 6.044e-03,  loss_bc2: 2.353e-03, loss_ics_u: 1.056e-02, loss_ics_ut: 5.634e-04,  Loss_res: 4.687e-02,  loss_coll_u: 2.085e-02 , Time: 510.31
# lam_bc1_val: 6.044e+00
# lam_bc2_val: 2.353e+00
# lam_u_val: 1.113e+01
# lam_coll_val: 1.056e+01
# It: 12100, Loss: 4.522e-01,  loss_bc1: 6.349e-03,  loss_bc2: 2.082e-03, loss_ics_u: 1.046e-02, loss_ics_ut: 7.962e-04,  Loss_res: 6.815e-02,  loss_coll_u: 2.040e-02 , Time: 514.61
# lam_bc1_val: 6.349e+00
# lam_bc2_val: 2.082e+00
# lam_u_val: 1.126e+01
# lam_coll_val: 1.046e+01
# It: 12200, Loss: 4.379e-01,  loss_bc1: 5.939e-03,  loss_bc2: 2.135e-03, loss_ics_u: 1.002e-02, loss_ics_ut: 3.715e-04,  Loss_res: 6.818e-02,  loss_coll_u: 2.014e-02 , Time: 519.04
# lam_bc1_val: 5.939e+00
# lam_bc2_val: 2.135e+00
# lam_u_val: 1.039e+01
# lam_coll_val: 1.002e+01
# It: 12300, Loss: 4.805e-01,  loss_bc1: 5.959e-03,  loss_bc2: 2.717e-03, loss_ics_u: 9.619e-03, loss_ics_ut: 6.217e-04,  Loss_res: 1.292e-01,  loss_coll_u: 2.034e-02 , Time: 523.38
# lam_bc1_val: 5.959e+00
# lam_bc2_val: 2.717e+00
# lam_u_val: 1.024e+01
# lam_coll_val: 9.619e+00
# It: 12400, Loss: 4.136e-01,  loss_bc1: 5.640e-03,  loss_bc2: 2.161e-03, loss_ics_u: 9.743e-03, loss_ics_ut: 1.246e-03,  Loss_res: 6.667e-02,  loss_coll_u: 2.027e-02 , Time: 527.75
# lam_bc1_val: 5.640e+00
# lam_bc2_val: 2.161e+00
# lam_u_val: 1.099e+01
# lam_coll_val: 9.743e+00
# It: 12500, Loss: 6.747e-01,  loss_bc1: 5.909e-03,  loss_bc2: 2.346e-03, loss_ics_u: 9.084e-03, loss_ics_ut: 1.019e-03,  Loss_res: 3.289e-01,  loss_coll_u: 2.015e-02 , Time: 532.14
# lam_bc1_val: 5.909e+00
# lam_bc2_val: 2.346e+00
# lam_u_val: 1.010e+01
# lam_coll_val: 9.084e+00
# It: 12600, Loss: 4.950e-01,  loss_bc1: 5.498e-03,  loss_bc2: 2.150e-03, loss_ics_u: 9.240e-03, loss_ics_ut: 2.809e-03,  Loss_res: 1.528e-01,  loss_coll_u: 2.013e-02 , Time: 536.53
# lam_bc1_val: 5.498e+00
# lam_bc2_val: 2.150e+00
# lam_u_val: 1.205e+01
# lam_coll_val: 9.240e+00
# It: 12700, Loss: 4.090e-01,  loss_bc1: 6.157e-03,  loss_bc2: 2.121e-03, loss_ics_u: 8.696e-03, loss_ics_ut: 3.579e-04,  Loss_res: 7.714e-02,  loss_coll_u: 1.995e-02 , Time: 542.63
# lam_bc1_val: 6.157e+00
# lam_bc2_val: 2.121e+00
# lam_u_val: 9.054e+00
# lam_coll_val: 8.696e+00
# It: 12800, Loss: 3.715e-01,  loss_bc1: 5.453e-03,  loss_bc2: 2.166e-03, loss_ics_u: 8.799e-03, loss_ics_ut: 5.332e-04,  Loss_res: 7.714e-02,  loss_coll_u: 1.974e-02 , Time: 547.25
# lam_bc1_val: 5.453e+00
# lam_bc2_val: 2.166e+00
# lam_u_val: 9.332e+00
# lam_coll_val: 8.799e+00
# It: 12900, Loss: 4.025e-01,  loss_bc1: 5.406e-03,  loss_bc2: 2.198e-03, loss_ics_u: 8.510e-03, loss_ics_ut: 1.602e-03,  Loss_res: 1.024e-01,  loss_coll_u: 1.949e-02 , Time: 551.77
# lam_bc1_val: 5.406e+00
# lam_bc2_val: 2.198e+00
# lam_u_val: 1.011e+01
# lam_coll_val: 8.510e+00
# It: 13000, Loss: 3.560e-01,  loss_bc1: 5.857e-03,  loss_bc2: 2.172e-03, loss_ics_u: 7.947e-03, loss_ics_ut: 8.430e-04,  Loss_res: 6.697e-02,  loss_coll_u: 1.923e-02 , Time: 556.15
# lam_bc1_val: 5.857e+00
# lam_bc2_val: 2.172e+00
# lam_u_val: 8.790e+00
# lam_coll_val: 7.947e+00
# It: 13100, Loss: 3.900e-01,  loss_bc1: 5.667e-03,  loss_bc2: 2.096e-03, loss_ics_u: 8.640e-03, loss_ics_ut: 2.219e-03,  Loss_res: 9.671e-02,  loss_coll_u: 2.014e-02 , Time: 561.11
# lam_bc1_val: 5.667e+00
# lam_bc2_val: 2.096e+00
# lam_u_val: 1.086e+01
# lam_coll_val: 8.640e+00
# It: 13200, Loss: 3.538e-01,  loss_bc1: 6.034e-03,  loss_bc2: 2.050e-03, loss_ics_u: 7.647e-03, loss_ics_ut: 6.157e-04,  Loss_res: 5.922e-02,  loss_coll_u: 1.925e-02 , Time: 565.34
# lam_bc1_val: 6.034e+00
# lam_bc2_val: 2.050e+00
# lam_u_val: 8.262e+00
# lam_coll_val: 7.647e+00
# It: 13300, Loss: 2.902e-01,  loss_bc1: 5.509e-03,  loss_bc2: 2.250e-03, loss_ics_u: 8.016e-03, loss_ics_ut: 4.937e-04,  Loss_res: 2.760e-02,  loss_coll_u: 2.019e-02 , Time: 569.57
# lam_bc1_val: 5.509e+00
# lam_bc2_val: 2.250e+00
# lam_u_val: 8.510e+00
# lam_coll_val: 8.016e+00
# It: 13400, Loss: 3.478e-01,  loss_bc1: 5.636e-03,  loss_bc2: 2.007e-03, loss_ics_u: 7.797e-03, loss_ics_ut: 1.288e-03,  Loss_res: 7.861e-02,  loss_coll_u: 1.951e-02 , Time: 573.94
# lam_bc1_val: 5.636e+00
# lam_bc2_val: 2.007e+00
# lam_u_val: 9.085e+00
# lam_coll_val: 7.797e+00
# It: 13500, Loss: 3.368e-01,  loss_bc1: 5.383e-03,  loss_bc2: 2.038e-03, loss_ics_u: 7.576e-03, loss_ics_ut: 9.357e-04,  Loss_res: 7.517e-02,  loss_coll_u: 1.922e-02 , Time: 578.20
# lam_bc1_val: 5.383e+00
# lam_bc2_val: 2.038e+00
# lam_u_val: 8.511e+00
# lam_coll_val: 7.576e+00
# It: 13600, Loss: 3.865e-01,  loss_bc1: 5.944e-03,  loss_bc2: 1.999e-03, loss_ics_u: 7.083e-03, loss_ics_ut: 5.542e-04,  Loss_res: 1.424e-01,  loss_coll_u: 1.888e-02 , Time: 582.41
# lam_bc1_val: 5.944e+00
# lam_bc2_val: 1.999e+00
# lam_u_val: 7.637e+00
# lam_coll_val: 7.083e+00
# It: 13700, Loss: 3.024e-01,  loss_bc1: 5.583e-03,  loss_bc2: 1.904e-03, loss_ics_u: 7.335e-03, loss_ics_ut: 6.829e-04,  Loss_res: 7.127e-02,  loss_coll_u: 1.876e-02 , Time: 586.66
# lam_bc1_val: 5.583e+00
# lam_bc2_val: 1.904e+00
# lam_u_val: 8.018e+00
# lam_coll_val: 7.335e+00
# It: 13800, Loss: 2.790e-01,  loss_bc1: 5.380e-03,  loss_bc2: 2.090e-03, loss_ics_u: 6.999e-03, loss_ics_ut: 1.707e-03,  Loss_res: 3.890e-02,  loss_coll_u: 1.858e-02 , Time: 590.86
# lam_bc1_val: 5.380e+00
# lam_bc2_val: 2.090e+00
# lam_u_val: 8.706e+00
# lam_coll_val: 6.999e+00
# It: 13900, Loss: 2.732e-01,  loss_bc1: 5.761e-03,  loss_bc2: 2.211e-03, loss_ics_u: 6.523e-03, loss_ics_ut: 1.798e-03,  Loss_res: 3.740e-02,  loss_coll_u: 1.825e-02 , Time: 595.51
# lam_bc1_val: 5.761e+00
# lam_bc2_val: 2.211e+00
# lam_u_val: 8.321e+00
# lam_coll_val: 6.523e+00
# It: 14000, Loss: 3.135e-01,  loss_bc1: 5.303e-03,  loss_bc2: 2.072e-03, loss_ics_u: 6.576e-03, loss_ics_ut: 1.088e-03,  Loss_res: 9.556e-02,  loss_coll_u: 1.825e-02 , Time: 599.85
# lam_bc1_val: 5.303e+00
# lam_bc2_val: 2.072e+00
# lam_u_val: 7.664e+00
# lam_coll_val: 6.576e+00
# It: 14100, Loss: 3.445e-01,  loss_bc1: 5.494e-03,  loss_bc2: 1.813e-03, loss_ics_u: 6.687e-03, loss_ics_ut: 7.611e-03,  Loss_res: 8.185e-02,  loss_coll_u: 1.828e-02 , Time: 603.96
# lam_bc1_val: 5.494e+00
# lam_bc2_val: 1.813e+00
# lam_u_val: 1.430e+01
# lam_coll_val: 6.687e+00
# It: 14200, Loss: 3.641e-01,  loss_bc1: 5.786e-03,  loss_bc2: 2.211e-03, loss_ics_u: 9.653e-03, loss_ics_ut: 3.432e-04,  Loss_res: 3.582e-02,  loss_coll_u: 2.237e-02 , Time: 608.02
# lam_bc1_val: 5.786e+00
# lam_bc2_val: 2.211e+00
# lam_u_val: 9.996e+00
# lam_coll_val: 9.653e+00
# It: 14300, Loss: 3.485e-01,  loss_bc1: 5.350e-03,  loss_bc2: 1.955e-03, loss_ics_u: 9.122e-03, loss_ics_ut: 2.414e-04,  Loss_res: 2.466e-02,  loss_coll_u: 2.020e-02 , Time: 612.08
# lam_bc1_val: 5.350e+00
# lam_bc2_val: 1.955e+00
# lam_u_val: 9.364e+00
# lam_coll_val: 9.122e+00
# It: 14400, Loss: 3.190e-01,  loss_bc1: 5.348e-03,  loss_bc2: 2.096e-03, loss_ics_u: 8.513e-03, loss_ics_ut: 2.641e-04,  Loss_res: 2.558e-02,  loss_coll_u: 1.957e-02 , Time: 616.13
# lam_bc1_val: 5.348e+00
# lam_bc2_val: 2.096e+00
# lam_u_val: 8.778e+00
# lam_coll_val: 8.513e+00
# It: 14500, Loss: 3.283e-01,  loss_bc1: 5.423e-03,  loss_bc2: 2.108e-03, loss_ics_u: 8.080e-03, loss_ics_ut: 4.414e-04,  Loss_res: 5.764e-02,  loss_coll_u: 1.907e-02 , Time: 620.18
# lam_bc1_val: 5.423e+00
# lam_bc2_val: 2.108e+00
# lam_u_val: 8.522e+00
# lam_coll_val: 8.080e+00
# It: 14600, Loss: 2.852e-01,  loss_bc1: 5.455e-03,  loss_bc2: 1.981e-03, loss_ics_u: 7.848e-03, loss_ics_ut: 3.697e-04,  Loss_res: 3.087e-02,  loss_coll_u: 1.863e-02 , Time: 624.22
# lam_bc1_val: 5.455e+00
# lam_bc2_val: 1.981e+00
# lam_u_val: 8.218e+00
# lam_coll_val: 7.848e+00
# It: 14700, Loss: 2.690e-01,  loss_bc1: 5.342e-03,  loss_bc2: 1.991e-03, loss_ics_u: 7.561e-03, loss_ics_ut: 1.899e-04,  Loss_res: 2.894e-02,  loss_coll_u: 1.826e-02 , Time: 628.29
# lam_bc1_val: 5.342e+00
# lam_bc2_val: 1.991e+00
# lam_u_val: 7.751e+00
# lam_coll_val: 7.561e+00
# It: 14800, Loss: 2.592e-01,  loss_bc1: 5.176e-03,  loss_bc2: 2.015e-03, loss_ics_u: 7.382e-03, loss_ics_ut: 2.900e-04,  Loss_res: 3.169e-02,  loss_coll_u: 1.804e-02 , Time: 632.34
# lam_bc1_val: 5.176e+00
# lam_bc2_val: 2.015e+00
# lam_u_val: 7.672e+00
# lam_coll_val: 7.382e+00
# It: 14900, Loss: 2.482e-01,  loss_bc1: 5.105e-03,  loss_bc2: 1.951e-03, loss_ics_u: 7.197e-03, loss_ics_ut: 2.380e-04,  Loss_res: 2.973e-02,  loss_coll_u: 1.775e-02 , Time: 636.39
# lam_bc1_val: 5.105e+00
# lam_bc2_val: 1.951e+00
# lam_u_val: 7.435e+00
# lam_coll_val: 7.197e+00
# It: 15000, Loss: 2.519e-01,  loss_bc1: 5.195e-03,  loss_bc2: 1.849e-03, loss_ics_u: 6.936e-03, loss_ics_ut: 2.055e-04,  Loss_res: 4.320e-02,  loss_coll_u: 1.743e-02 , Time: 640.41
# lam_bc1_val: 5.195e+00
# lam_bc2_val: 1.849e+00
# lam_u_val: 7.141e+00
# lam_coll_val: 6.936e+00
# It: 15100, Loss: 2.371e-01,  loss_bc1: 5.081e-03,  loss_bc2: 1.829e-03, loss_ics_u: 6.884e-03, loss_ics_ut: 1.948e-04,  Loss_res: 3.623e-02,  loss_coll_u: 1.739e-02 , Time: 644.46
# lam_bc1_val: 5.081e+00
# lam_bc2_val: 1.829e+00
# lam_u_val: 7.079e+00
# lam_coll_val: 6.884e+00
# It: 15200, Loss: 2.513e-01,  loss_bc1: 4.999e-03,  loss_bc2: 2.008e-03, loss_ics_u: 6.617e-03, loss_ics_ut: 9.261e-04,  Loss_res: 5.097e-02,  loss_coll_u: 1.712e-02 , Time: 648.50
# lam_bc1_val: 4.999e+00
# lam_bc2_val: 2.008e+00
# lam_u_val: 7.544e+00
# lam_coll_val: 6.617e+00
# It: 15300, Loss: 2.655e-01,  loss_bc1: 4.897e-03,  loss_bc2: 1.883e-03, loss_ics_u: 6.525e-03, loss_ics_ut: 6.349e-04,  Loss_res: 7.112e-02,  loss_coll_u: 1.694e-02 , Time: 652.56
# lam_bc1_val: 4.897e+00
# lam_bc2_val: 1.883e+00
# lam_u_val: 7.160e+00
# lam_coll_val: 6.525e+00
# It: 15400, Loss: 2.981e-01,  loss_bc1: 5.089e-03,  loss_bc2: 1.884e-03, loss_ics_u: 6.379e-03, loss_ics_ut: 1.161e-03,  Loss_res: 1.046e-01,  loss_coll_u: 1.701e-02 , Time: 656.57
# lam_bc1_val: 5.089e+00
# lam_bc2_val: 1.884e+00
# lam_u_val: 7.539e+00
# lam_coll_val: 6.379e+00
# It: 15500, Loss: 2.266e-01,  loss_bc1: 4.868e-03,  loss_bc2: 1.977e-03, loss_ics_u: 6.140e-03, loss_ics_ut: 3.018e-04,  Loss_res: 4.251e-02,  loss_coll_u: 1.678e-02 , Time: 660.73
# lam_bc1_val: 4.868e+00
# lam_bc2_val: 1.977e+00
# lam_u_val: 6.442e+00
# lam_coll_val: 6.140e+00
# It: 15600, Loss: 2.753e-01,  loss_bc1: 5.046e-03,  loss_bc2: 2.072e-03, loss_ics_u: 5.893e-03, loss_ics_ut: 6.544e-04,  Loss_res: 1.028e-01,  loss_coll_u: 1.657e-02 , Time: 664.78
# lam_bc1_val: 5.046e+00
# lam_bc2_val: 2.072e+00
# lam_u_val: 6.547e+00
# lam_coll_val: 5.893e+00
# It: 15700, Loss: 3.194e-01,  loss_bc1: 5.061e-03,  loss_bc2: 1.874e-03, loss_ics_u: 5.936e-03, loss_ics_ut: 7.428e-04,  Loss_res: 1.490e-01,  loss_coll_u: 1.651e-02 , Time: 668.84
# lam_bc1_val: 5.061e+00
# lam_bc2_val: 1.874e+00
# lam_u_val: 6.678e+00
# lam_coll_val: 5.936e+00
# It: 15800, Loss: 1.948e-01,  loss_bc1: 4.752e-03,  loss_bc2: 1.982e-03, loss_ics_u: 5.895e-03, loss_ics_ut: 3.613e-04,  Loss_res: 2.751e-02,  loss_coll_u: 1.647e-02 , Time: 672.86
# lam_bc1_val: 4.752e+00
# lam_bc2_val: 1.982e+00
# lam_u_val: 6.256e+00
# lam_coll_val: 5.895e+00
# It: 15900, Loss: 1.977e-01,  loss_bc1: 4.873e-03,  loss_bc2: 1.864e-03, loss_ics_u: 5.649e-03, loss_ics_ut: 3.006e-04,  Loss_res: 3.772e-02,  loss_coll_u: 1.627e-02 , Time: 676.90
# lam_bc1_val: 4.873e+00
# lam_bc2_val: 1.864e+00
# lam_u_val: 5.950e+00
# lam_coll_val: 5.649e+00
# It: 16000, Loss: 1.951e-01,  loss_bc1: 4.729e-03,  loss_bc2: 1.852e-03, loss_ics_u: 5.632e-03, loss_ics_ut: 5.342e-04,  Loss_res: 4.213e-02,  loss_coll_u: 1.589e-02 , Time: 680.92
# lam_bc1_val: 4.729e+00
# lam_bc2_val: 1.852e+00
# lam_u_val: 6.167e+00
# lam_coll_val: 5.632e+00
# It: 16100, Loss: 2.771e-01,  loss_bc1: 4.863e-03,  loss_bc2: 1.889e-03, loss_ics_u: 5.446e-03, loss_ics_ut: 2.899e-03,  Loss_res: 1.107e-01,  loss_coll_u: 1.570e-02 , Time: 684.95
# lam_bc1_val: 4.863e+00
# lam_bc2_val: 1.889e+00
# lam_u_val: 8.344e+00
# lam_coll_val: 5.446e+00
# It: 16200, Loss: 3.112e-01,  loss_bc1: 4.918e-03,  loss_bc2: 1.968e-03, loss_ics_u: 5.183e-03, loss_ics_ut: 2.636e-04,  Loss_res: 1.526e-01,  loss_coll_u: 1.571e-02 , Time: 689.00
# lam_bc1_val: 4.918e+00
# lam_bc2_val: 1.968e+00
# lam_u_val: 5.447e+00
# lam_coll_val: 5.183e+00
# It: 16300, Loss: 2.375e-01,  loss_bc1: 4.524e-03,  loss_bc2: 1.932e-03, loss_ics_u: 5.323e-03, loss_ics_ut: 8.472e-04,  Loss_res: 9.631e-02,  loss_coll_u: 1.574e-02 , Time: 693.11
# lam_bc1_val: 4.524e+00
# lam_bc2_val: 1.932e+00
# lam_u_val: 6.170e+00
# lam_coll_val: 5.323e+00
# It: 16400, Loss: 2.119e-01,  loss_bc1: 4.419e-03,  loss_bc2: 2.001e-03, loss_ics_u: 5.254e-03, loss_ics_ut: 2.153e-03,  Loss_res: 5.932e-02,  loss_coll_u: 1.561e-02 , Time: 697.27
# lam_bc1_val: 4.419e+00
# lam_bc2_val: 2.001e+00
# lam_u_val: 7.407e+00
# lam_coll_val: 5.254e+00
# It: 16500, Loss: 1.883e-01,  loss_bc1: 4.973e-03,  loss_bc2: 2.173e-03, loss_ics_u: 4.760e-03, loss_ics_ut: 4.525e-04,  Loss_res: 4.126e-02,  loss_coll_u: 1.562e-02 , Time: 701.40
# lam_bc1_val: 4.973e+00
# lam_bc2_val: 2.173e+00
# lam_u_val: 5.212e+00
# lam_coll_val: 4.760e+00
# It: 16600, Loss: 2.942e-01,  loss_bc1: 4.735e-03,  loss_bc2: 1.917e-03, loss_ics_u: 5.020e-03, loss_ics_ut: 2.257e-03,  Loss_res: 1.555e-01,  loss_coll_u: 1.535e-02 , Time: 705.68
# lam_bc1_val: 4.735e+00
# lam_bc2_val: 1.917e+00
# lam_u_val: 7.277e+00
# lam_coll_val: 5.020e+00
# It: 16700, Loss: 2.132e-01,  loss_bc1: 4.664e-03,  loss_bc2: 2.140e-03, loss_ics_u: 4.761e-03, loss_ics_ut: 2.681e-03,  Loss_res: 5.559e-02,  loss_coll_u: 1.539e-02 , Time: 711.40
# lam_bc1_val: 4.664e+00
# lam_bc2_val: 2.140e+00
# lam_u_val: 7.441e+00
# lam_coll_val: 4.761e+00
# It: 16800, Loss: 5.787e-01,  loss_bc1: 5.932e-03,  loss_bc2: 2.598e-03, loss_ics_u: 4.615e-03, loss_ics_ut: 1.085e-02,  Loss_res: 3.530e-01,  loss_coll_u: 1.626e-02 , Time: 715.47
# lam_bc1_val: 5.932e+00
# lam_bc2_val: 2.598e+00
# lam_u_val: 1.547e+01
# lam_coll_val: 4.615e+00
# It: 16900, Loss: 2.372e-01,  loss_bc1: 4.606e-03,  loss_bc2: 2.160e-03, loss_ics_u: 5.902e-03, loss_ics_ut: 3.479e-04,  Loss_res: 2.804e-02,  loss_coll_u: 1.723e-02 , Time: 719.64
# lam_bc1_val: 4.606e+00
# lam_bc2_val: 2.160e+00
# lam_u_val: 6.250e+00
# lam_coll_val: 5.902e+00
# ...
# lam_bc1_val: 2.140e+00
# lam_bc2_val: 1.202e+00
# lam_u_val: 1.771e+00
# lam_coll_val: 1.513e+00
# It: 34300, Loss: 2.488e-02,  loss_bc1: 2.137e-03,  loss_bc2: 1.207e-03, loss_ics_u: 1.507e-03, loss_ics_ut: 2.615e-04,  Loss_res: 7.132e-03,  loss_coll_u: 5.677e-03 , Time: 1418.81
# lam_bc1_val: 2.137e+00
# lam_bc2_val: 1.207e+00
# lam_u_val: 1.769e+00
# lam_coll_val: 1.507e+00
# It: 34400, Loss: 2.406e-02,  loss_bc1: 2.103e-03,  loss_bc2: 1.197e-03, loss_ics_u: 1.543e-03, loss_ics_ut: 2.567e-04,  Loss_res: 6.363e-03,  loss_coll_u: 5.690e-03 , Time: 1422.66
# lam_bc1_val: 2.103e+00
# lam_bc2_val: 1.197e+00
# lam_u_val: 1.800e+00
# lam_coll_val: 1.543e+00
# It: 34500, Loss: 2.493e-02,  loss_bc1: 2.144e-03,  loss_bc2: 1.183e-03, loss_ics_u: 1.485e-03, loss_ics_ut: 2.748e-04,  Loss_res: 7.125e-03,  loss_coll_u: 5.645e-03 , Time: 1426.53
# lam_bc1_val: 2.144e+00
# lam_bc2_val: 1.183e+00
# lam_u_val: 1.760e+00
# lam_coll_val: 1.485e+00
# It: 34600, Loss: 2.285e-02,  loss_bc1: 2.144e-03,  loss_bc2: 1.195e-03, loss_ics_u: 1.476e-03, loss_ics_ut: 9.383e-05,  Loss_res: 5.748e-03,  loss_coll_u: 5.605e-03 , Time: 1430.68
# lam_bc1_val: 2.144e+00
# lam_bc2_val: 1.195e+00
# lam_u_val: 1.570e+00
# lam_coll_val: 1.476e+00
# It: 34700, Loss: 2.369e-02,  loss_bc1: 2.100e-03,  loss_bc2: 1.159e-03, loss_ics_u: 1.514e-03, loss_ics_ut: 1.200e-04,  Loss_res: 6.973e-03,  loss_coll_u: 5.599e-03 , Time: 1434.90
# lam_bc1_val: 2.100e+00
# lam_bc2_val: 1.159e+00
# lam_u_val: 1.634e+00
# lam_coll_val: 1.514e+00
# It: 34800, Loss: 2.332e-02,  loss_bc1: 2.120e-03,  loss_bc2: 1.183e-03, loss_ics_u: 1.475e-03, loss_ics_ut: 1.151e-04,  Loss_res: 6.472e-03,  loss_coll_u: 5.566e-03 , Time: 1439.02
# lam_bc1_val: 2.120e+00
# lam_bc2_val: 1.183e+00
# lam_u_val: 1.590e+00
# lam_coll_val: 1.475e+00
# It: 34900, Loss: 2.681e-02,  loss_bc1: 2.084e-03,  loss_bc2: 1.169e-03, loss_ics_u: 1.532e-03, loss_ics_ut: 4.716e-04,  Loss_res: 9.638e-03,  loss_coll_u: 5.551e-03 , Time: 1443.83
# lam_bc1_val: 2.084e+00
# lam_bc2_val: 1.169e+00
# lam_u_val: 2.003e+00
# lam_coll_val: 1.532e+00
# It: 35000, Loss: 2.451e-02,  loss_bc1: 2.124e-03,  loss_bc2: 1.230e-03, loss_ics_u: 1.426e-03, loss_ics_ut: 1.354e-04,  Loss_res: 7.055e-03,  loss_coll_u: 5.523e-03 , Time: 1448.28
# lam_bc1_val: 2.124e+00
# lam_bc2_val: 1.230e+00
# lam_u_val: 1.561e+00
# lam_coll_val: 1.426e+00
# It: 35100, Loss: 2.428e-02,  loss_bc1: 2.104e-03,  loss_bc2: 1.157e-03, loss_ics_u: 1.477e-03, loss_ics_ut: 5.041e-04,  Loss_res: 7.461e-03,  loss_coll_u: 5.492e-03 , Time: 1452.60
# lam_bc1_val: 2.104e+00
# lam_bc2_val: 1.157e+00
# lam_u_val: 1.982e+00
# lam_coll_val: 1.477e+00
# It: 35200, Loss: 2.548e-02,  loss_bc1: 2.105e-03,  loss_bc2: 1.205e-03, loss_ics_u: 1.419e-03, loss_ics_ut: 2.928e-04,  Loss_res: 8.141e-03,  loss_coll_u: 5.500e-03 , Time: 1456.82
# lam_bc1_val: 2.105e+00
# lam_bc2_val: 1.205e+00
# lam_u_val: 1.711e+00
# lam_coll_val: 1.419e+00
# It: 35300, Loss: 2.590e-02,  loss_bc1: 2.127e-03,  loss_bc2: 1.169e-03, loss_ics_u: 1.448e-03, loss_ics_ut: 2.418e-04,  Loss_res: 9.414e-03,  loss_coll_u: 5.434e-03 , Time: 1461.11
# lam_bc1_val: 2.127e+00
# lam_bc2_val: 1.169e+00
# lam_u_val: 1.690e+00
# lam_coll_val: 1.448e+00
# It: 35400, Loss: 2.820e-02,  loss_bc1: 2.091e-03,  loss_bc2: 1.156e-03, loss_ics_u: 1.473e-03, loss_ics_ut: 2.810e-04,  Loss_res: 1.154e-02,  loss_coll_u: 5.456e-03 , Time: 1465.09
# lam_bc1_val: 2.091e+00
# lam_bc2_val: 1.156e+00
# lam_u_val: 1.754e+00
# lam_coll_val: 1.473e+00
# It: 35500, Loss: 2.332e-02,  loss_bc1: 2.093e-03,  loss_bc2: 1.175e-03, loss_ics_u: 1.423e-03, loss_ics_ut: 2.604e-04,  Loss_res: 6.663e-03,  loss_coll_u: 5.415e-03 , Time: 1469.12
# lam_bc1_val: 2.093e+00
# lam_bc2_val: 1.175e+00
# lam_u_val: 1.683e+00
# lam_coll_val: 1.423e+00
# It: 35600, Loss: 2.212e-02,  loss_bc1: 2.074e-03,  loss_bc2: 1.157e-03, loss_ics_u: 1.458e-03, loss_ics_ut: 1.833e-04,  Loss_res: 5.987e-03,  loss_coll_u: 5.393e-03 , Time: 1473.17
# lam_bc1_val: 2.074e+00
# lam_bc2_val: 1.157e+00
# lam_u_val: 1.641e+00
# lam_coll_val: 1.458e+00
# It: 35700, Loss: 2.337e-02,  loss_bc1: 2.065e-03,  loss_bc2: 1.180e-03, loss_ics_u: 1.447e-03, loss_ics_ut: 1.016e-04,  Loss_res: 7.364e-03,  loss_coll_u: 5.362e-03 , Time: 1477.45
# lam_bc1_val: 2.065e+00
# lam_bc2_val: 1.180e+00
# lam_u_val: 1.549e+00
# lam_coll_val: 1.447e+00
# It: 35800, Loss: 2.880e-02,  loss_bc1: 2.098e-03,  loss_bc2: 1.131e-03, loss_ics_u: 1.469e-03, loss_ics_ut: 4.301e-04,  Loss_res: 1.250e-02,  loss_coll_u: 5.316e-03 , Time: 1481.45
# lam_bc1_val: 2.098e+00
# lam_bc2_val: 1.131e+00
# lam_u_val: 1.899e+00
# lam_coll_val: 1.469e+00
# It: 35900, Loss: 2.502e-02,  loss_bc1: 2.077e-03,  loss_bc2: 1.172e-03, loss_ics_u: 1.415e-03, loss_ics_ut: 3.469e-04,  Loss_res: 8.178e-03,  loss_coll_u: 5.316e-03 , Time: 1485.49
# lam_bc1_val: 2.077e+00
# lam_bc2_val: 1.172e+00
# lam_u_val: 1.761e+00
# lam_coll_val: 1.415e+00
# It: 36000, Loss: 2.629e-02,  loss_bc1: 2.075e-03,  loss_bc2: 1.173e-03, loss_ics_u: 1.411e-03, loss_ics_ut: 1.388e-04,  Loss_res: 1.039e-02,  loss_coll_u: 5.289e-03 , Time: 1489.68
# lam_bc1_val: 2.075e+00
# lam_bc2_val: 1.173e+00
# lam_u_val: 1.550e+00
# lam_coll_val: 1.411e+00
# It: 36100, Loss: 3.112e-02,  loss_bc1: 2.042e-03,  loss_bc2: 1.187e-03, loss_ics_u: 1.465e-03, loss_ics_ut: 1.686e-03,  Loss_res: 1.316e-02,  loss_coll_u: 5.279e-03 , Time: 1493.69
# lam_bc1_val: 2.042e+00
# lam_bc2_val: 1.187e+00
# lam_u_val: 3.151e+00
# lam_coll_val: 1.465e+00
# It: 36200, Loss: 2.432e-02,  loss_bc1: 2.158e-03,  loss_bc2: 1.261e-03, loss_ics_u: 1.250e-03, loss_ics_ut: 1.256e-04,  Loss_res: 6.336e-03,  loss_coll_u: 5.288e-03 , Time: 1497.87
# lam_bc1_val: 2.158e+00
# lam_bc2_val: 1.261e+00
# lam_u_val: 1.375e+00
# lam_coll_val: 1.250e+00
# It: 36300, Loss: 3.329e-02,  loss_bc1: 2.004e-03,  loss_bc2: 1.178e-03, loss_ics_u: 1.435e-03, loss_ics_ut: 3.222e-04,  Loss_res: 1.844e-02,  loss_coll_u: 5.297e-03 , Time: 1502.07
# lam_bc1_val: 2.004e+00
# lam_bc2_val: 1.178e+00
# lam_u_val: 1.758e+00
# lam_coll_val: 1.435e+00
# It: 36400, Loss: 2.140e-02,  loss_bc1: 2.021e-03,  loss_bc2: 1.166e-03, loss_ics_u: 1.410e-03, loss_ics_ut: 1.173e-04,  Loss_res: 5.714e-03,  loss_coll_u: 5.277e-03 , Time: 1506.31
# lam_bc1_val: 2.021e+00
# lam_bc2_val: 1.166e+00
# lam_u_val: 1.527e+00
# lam_coll_val: 1.410e+00
# It: 36500, Loss: 2.571e-02,  loss_bc1: 2.031e-03,  loss_bc2: 1.160e-03, loss_ics_u: 1.392e-03, loss_ics_ut: 2.670e-04,  Loss_res: 1.035e-02,  loss_coll_u: 5.227e-03 , Time: 1510.21
# lam_bc1_val: 2.031e+00
# lam_bc2_val: 1.160e+00
# lam_u_val: 1.659e+00
# lam_coll_val: 1.392e+00
# It: 36600, Loss: 2.260e-02,  loss_bc1: 2.063e-03,  loss_bc2: 1.149e-03, loss_ics_u: 1.383e-03, loss_ics_ut: 1.531e-04,  Loss_res: 7.306e-03,  loss_coll_u: 5.193e-03 , Time: 1514.21
# lam_bc1_val: 2.063e+00
# lam_bc2_val: 1.149e+00
# lam_u_val: 1.536e+00
# lam_coll_val: 1.383e+00
# It: 36700, Loss: 2.375e-02,  loss_bc1: 2.035e-03,  loss_bc2: 1.156e-03, loss_ics_u: 1.384e-03, loss_ics_ut: 1.700e-04,  Loss_res: 8.678e-03,  loss_coll_u: 5.176e-03 , Time: 1518.23
# lam_bc1_val: 2.035e+00
# lam_bc2_val: 1.156e+00
# lam_u_val: 1.554e+00
# lam_coll_val: 1.384e+00
# It: 36800, Loss: 2.127e-02,  loss_bc1: 2.034e-03,  loss_bc2: 1.156e-03, loss_ics_u: 1.379e-03, loss_ics_ut: 1.474e-04,  Loss_res: 6.298e-03,  loss_coll_u: 5.149e-03 , Time: 1522.35
# lam_bc1_val: 2.034e+00
# lam_bc2_val: 1.156e+00
# lam_u_val: 1.526e+00
# lam_coll_val: 1.379e+00
# It: 36900, Loss: 2.139e-02,  loss_bc1: 2.009e-03,  loss_bc2: 1.145e-03, loss_ics_u: 1.404e-03, loss_ics_ut: 1.269e-04,  Loss_res: 6.548e-03,  loss_coll_u: 5.144e-03 , Time: 1526.68
# lam_bc1_val: 2.009e+00
# lam_bc2_val: 1.145e+00
# lam_u_val: 1.531e+00
# lam_coll_val: 1.404e+00
# It: 37000, Loss: 2.307e-02,  loss_bc1: 2.032e-03,  loss_bc2: 1.168e-03, loss_ics_u: 1.365e-03, loss_ics_ut: 2.175e-04,  Loss_res: 8.041e-03,  loss_coll_u: 5.117e-03 , Time: 1530.59
# lam_bc1_val: 2.032e+00
# lam_bc2_val: 1.168e+00
# lam_u_val: 1.582e+00
# lam_coll_val: 1.365e+00
# It: 37100, Loss: 2.290e-02,  loss_bc1: 2.010e-03,  loss_bc2: 1.147e-03, loss_ics_u: 1.396e-03, loss_ics_ut: 1.454e-04,  Loss_res: 8.082e-03,  loss_coll_u: 5.092e-03 , Time: 1534.47
# lam_bc1_val: 2.010e+00
# lam_bc2_val: 1.147e+00
# lam_u_val: 1.541e+00
# lam_coll_val: 1.396e+00
# It: 37200, Loss: 2.150e-02,  loss_bc1: 2.002e-03,  loss_bc2: 1.140e-03, loss_ics_u: 1.387e-03, loss_ics_ut: 9.486e-05,  Loss_res: 6.797e-03,  loss_coll_u: 5.077e-03 , Time: 1538.32
# lam_bc1_val: 2.002e+00
# lam_bc2_val: 1.140e+00
# lam_u_val: 1.482e+00
# lam_coll_val: 1.387e+00
# It: 37300, Loss: 2.354e-02,  loss_bc1: 2.037e-03,  loss_bc2: 1.125e-03, loss_ics_u: 1.396e-03, loss_ics_ut: 1.868e-04,  Loss_res: 8.815e-03,  loss_coll_u: 5.054e-03 , Time: 1542.25
# lam_bc1_val: 2.037e+00
# lam_bc2_val: 1.125e+00
# lam_u_val: 1.583e+00
# lam_coll_val: 1.396e+00
# It: 37400, Loss: 1.958e-02,  loss_bc1: 1.987e-03,  loss_bc2: 1.136e-03, loss_ics_u: 1.405e-03, loss_ics_ut: 1.025e-04,  Loss_res: 4.812e-03,  loss_coll_u: 5.052e-03 , Time: 1546.24
# lam_bc1_val: 1.987e+00
# lam_bc2_val: 1.136e+00
# lam_u_val: 1.508e+00
# lam_coll_val: 1.405e+00
# It: 37500, Loss: 2.137e-02,  loss_bc1: 2.002e-03,  loss_bc2: 1.138e-03, loss_ics_u: 1.384e-03, loss_ics_ut: 1.205e-04,  Loss_res: 6.767e-03,  loss_coll_u: 5.024e-03 , Time: 1550.21
# lam_bc1_val: 2.002e+00
# lam_bc2_val: 1.138e+00
# lam_u_val: 1.504e+00
# lam_coll_val: 1.384e+00
# It: 37600, Loss: 2.311e-02,  loss_bc1: 1.989e-03,  loss_bc2: 1.140e-03, loss_ics_u: 1.371e-03, loss_ics_ut: 4.171e-04,  Loss_res: 8.174e-03,  loss_coll_u: 5.037e-03 , Time: 1554.71
# lam_bc1_val: 1.989e+00
# lam_bc2_val: 1.140e+00
# lam_u_val: 1.788e+00
# lam_coll_val: 1.371e+00
# It: 37700, Loss: 2.360e-02,  loss_bc1: 2.011e-03,  loss_bc2: 1.132e-03, loss_ics_u: 1.338e-03, loss_ics_ut: 1.978e-04,  Loss_res: 8.682e-03,  loss_coll_u: 5.017e-03 , Time: 1559.03
# lam_bc1_val: 2.011e+00
# lam_bc2_val: 1.132e+00
# lam_u_val: 1.536e+00
# lam_coll_val: 1.338e+00
# It: 37800, Loss: 2.201e-02,  loss_bc1: 1.979e-03,  loss_bc2: 1.137e-03, loss_ics_u: 1.370e-03, loss_ics_ut: 1.144e-04,  Loss_res: 7.789e-03,  loss_coll_u: 4.985e-03 , Time: 1562.96
# lam_bc1_val: 1.979e+00
# lam_bc2_val: 1.137e+00
# lam_u_val: 1.485e+00
# lam_coll_val: 1.370e+00
# It: 37900, Loss: 1.950e-02,  loss_bc1: 1.992e-03,  loss_bc2: 1.114e-03, loss_ics_u: 1.384e-03, loss_ics_ut: 1.195e-04,  Loss_res: 5.273e-03,  loss_coll_u: 4.951e-03 , Time: 1566.91
# lam_bc1_val: 1.992e+00
# lam_bc2_val: 1.114e+00
# lam_u_val: 1.503e+00
# lam_coll_val: 1.384e+00
# It: 38000, Loss: 1.976e-02,  loss_bc1: 1.971e-03,  loss_bc2: 1.127e-03, loss_ics_u: 1.372e-03, loss_ics_ut: 8.208e-05,  Loss_res: 5.557e-03,  loss_coll_u: 4.942e-03 , Time: 1571.05
# lam_bc1_val: 1.971e+00
# lam_bc2_val: 1.127e+00
# lam_u_val: 1.454e+00
# lam_coll_val: 1.372e+00
# It: 38100, Loss: 2.544e-02,  loss_bc1: 1.975e-03,  loss_bc2: 1.132e-03, loss_ics_u: 1.364e-03, loss_ics_ut: 9.801e-05,  Loss_res: 1.138e-02,  loss_coll_u: 4.935e-03 , Time: 1575.43
# lam_bc1_val: 1.975e+00
# lam_bc2_val: 1.132e+00
# lam_u_val: 1.462e+00
# lam_coll_val: 1.364e+00
# It: 38200, Loss: 1.904e-02,  loss_bc1: 1.962e-03,  loss_bc2: 1.123e-03, loss_ics_u: 1.369e-03, loss_ics_ut: 9.343e-05,  Loss_res: 5.030e-03,  loss_coll_u: 4.934e-03 , Time: 1579.41
# lam_bc1_val: 1.962e+00
# lam_bc2_val: 1.123e+00
# lam_u_val: 1.462e+00
# lam_coll_val: 1.369e+00
# It: 38300, Loss: 1.922e-02,  loss_bc1: 1.991e-03,  loss_bc2: 1.105e-03, loss_ics_u: 1.355e-03, loss_ics_ut: 8.568e-05,  Loss_res: 5.277e-03,  loss_coll_u: 4.885e-03 , Time: 1583.49
# lam_bc1_val: 1.991e+00
# lam_bc2_val: 1.105e+00
# lam_u_val: 1.441e+00
# lam_coll_val: 1.355e+00
# It: 38400, Loss: 1.901e-02,  loss_bc1: 1.948e-03,  loss_bc2: 1.119e-03, loss_ics_u: 1.373e-03, loss_ics_ut: 1.006e-04,  Loss_res: 5.149e-03,  loss_coll_u: 4.887e-03 , Time: 1587.75
# lam_bc1_val: 1.948e+00
# lam_bc2_val: 1.119e+00
# lam_u_val: 1.474e+00
# lam_coll_val: 1.373e+00
# It: 38500, Loss: 2.103e-02,  loss_bc1: 1.960e-03,  loss_bc2: 1.112e-03, loss_ics_u: 1.370e-03, loss_ics_ut: 1.173e-04,  Loss_res: 7.115e-03,  loss_coll_u: 4.851e-03 , Time: 1591.62
# lam_bc1_val: 1.960e+00
# lam_bc2_val: 1.112e+00
# lam_u_val: 1.487e+00
# lam_coll_val: 1.370e+00
# It: 38600, Loss: 1.988e-02,  loss_bc1: 1.946e-03,  loss_bc2: 1.133e-03, loss_ics_u: 1.353e-03, loss_ics_ut: 3.270e-04,  Loss_res: 5.663e-03,  loss_coll_u: 4.845e-03 , Time: 1595.45
# lam_bc1_val: 1.946e+00
# lam_bc2_val: 1.133e+00
# lam_u_val: 1.680e+00
# lam_coll_val: 1.353e+00
# It: 38700, Loss: 1.938e-02,  loss_bc1: 1.967e-03,  loss_bc2: 1.129e-03, loss_ics_u: 1.317e-03, loss_ics_ut: 1.657e-04,  Loss_res: 5.257e-03,  loss_coll_u: 4.825e-03 , Time: 1599.48
# lam_bc1_val: 1.967e+00
# lam_bc2_val: 1.129e+00
# lam_u_val: 1.483e+00
# lam_coll_val: 1.317e+00
# It: 38800, Loss: 2.890e-02,  loss_bc1: 1.934e-03,  loss_bc2: 1.108e-03, loss_ics_u: 1.344e-03, loss_ics_ut: 2.964e-04,  Loss_res: 1.505e-02,  loss_coll_u: 4.825e-03 , Time: 1603.50
# lam_bc1_val: 1.934e+00
# lam_bc2_val: 1.108e+00
# lam_u_val: 1.640e+00
# lam_coll_val: 1.344e+00
# It: 38900, Loss: 1.995e-02,  loss_bc1: 1.973e-03,  loss_bc2: 1.110e-03, loss_ics_u: 1.312e-03, loss_ics_ut: 1.780e-04,  Loss_res: 6.000e-03,  loss_coll_u: 4.805e-03 , Time: 1607.79
# lam_bc1_val: 1.973e+00
# lam_bc2_val: 1.110e+00
# lam_u_val: 1.490e+00
# lam_coll_val: 1.312e+00
# It: 39000, Loss: 1.882e-02,  loss_bc1: 1.971e-03,  loss_bc2: 1.098e-03, loss_ics_u: 1.330e-03, loss_ics_ut: 2.173e-04,  Loss_res: 5.136e-03,  loss_coll_u: 4.780e-03 , Time: 1611.75
# lam_bc1_val: 1.971e+00
# lam_bc2_val: 1.098e+00
# lam_u_val: 1.548e+00
# lam_coll_val: 1.330e+00
# It: 39100, Loss: 1.895e-02,  loss_bc1: 1.953e-03,  loss_bc2: 1.119e-03, loss_ics_u: 1.304e-03, loss_ics_ut: 1.384e-04,  Loss_res: 5.301e-03,  loss_coll_u: 4.766e-03 , Time: 1616.02
# lam_bc1_val: 1.953e+00
# lam_bc2_val: 1.119e+00
# lam_u_val: 1.443e+00
# lam_coll_val: 1.304e+00
# It: 39200, Loss: 1.933e-02,  loss_bc1: 1.939e-03,  loss_bc2: 1.117e-03, loss_ics_u: 1.311e-03, loss_ics_ut: 7.349e-05,  Loss_res: 6.076e-03,  loss_coll_u: 4.767e-03 , Time: 1620.18
# lam_bc1_val: 1.939e+00
# lam_bc2_val: 1.117e+00
# lam_u_val: 1.385e+00
# lam_coll_val: 1.311e+00
# It: 39300, Loss: 1.919e-02,  loss_bc1: 1.922e-03,  loss_bc2: 1.097e-03, loss_ics_u: 1.352e-03, loss_ics_ut: 1.016e-04,  Loss_res: 6.008e-03,  loss_coll_u: 4.742e-03 , Time: 1625.11
# lam_bc1_val: 1.922e+00
# lam_bc2_val: 1.097e+00
# lam_u_val: 1.454e+00
# lam_coll_val: 1.352e+00
# It: 39400, Loss: 1.855e-02,  loss_bc1: 1.903e-03,  loss_bc2: 1.122e-03, loss_ics_u: 1.355e-03, loss_ics_ut: 1.096e-04,  Loss_res: 5.138e-03,  loss_coll_u: 4.724e-03 , Time: 1631.32
# lam_bc1_val: 1.903e+00
# lam_bc2_val: 1.122e+00
# lam_u_val: 1.465e+00
# lam_coll_val: 1.355e+00
# It: 39500, Loss: 1.885e-02,  loss_bc1: 1.930e-03,  loss_bc2: 1.095e-03, loss_ics_u: 1.322e-03, loss_ics_ut: 9.005e-05,  Loss_res: 5.496e-03,  loss_coll_u: 4.714e-03 , Time: 1635.55
# lam_bc1_val: 1.930e+00
# lam_bc2_val: 1.095e+00
# lam_u_val: 1.412e+00
# lam_coll_val: 1.322e+00
# It: 39600, Loss: 1.981e-02,  loss_bc1: 1.940e-03,  loss_bc2: 1.083e-03, loss_ics_u: 1.335e-03, loss_ics_ut: 1.607e-04,  Loss_res: 6.589e-03,  loss_coll_u: 4.676e-03 , Time: 1639.61
# lam_bc1_val: 1.940e+00
# lam_bc2_val: 1.083e+00
# lam_u_val: 1.495e+00
# lam_coll_val: 1.335e+00
# It: 39700, Loss: 1.920e-02,  loss_bc1: 1.928e-03,  loss_bc2: 1.102e-03, loss_ics_u: 1.317e-03, loss_ics_ut: 1.098e-04,  Loss_res: 5.898e-03,  loss_coll_u: 4.673e-03 , Time: 1643.59
# lam_bc1_val: 1.928e+00
# lam_bc2_val: 1.102e+00
# lam_u_val: 1.426e+00
# lam_coll_val: 1.317e+00
# It: 39800, Loss: 1.790e-02,  loss_bc1: 1.902e-03,  loss_bc2: 1.102e-03, loss_ics_u: 1.329e-03, loss_ics_ut: 1.654e-04,  Loss_res: 4.737e-03,  loss_coll_u: 4.671e-03 , Time: 1647.48
# lam_bc1_val: 1.902e+00
# lam_bc2_val: 1.102e+00
# lam_u_val: 1.494e+00
# lam_coll_val: 1.329e+00
# It: 39900, Loss: 1.865e-02,  loss_bc1: 1.930e-03,  loss_bc2: 1.098e-03, loss_ics_u: 1.300e-03, loss_ics_ut: 1.899e-04,  Loss_res: 5.375e-03,  loss_coll_u: 4.641e-03 , Time: 1651.41
# lam_bc1_val: 1.930e+00
# lam_bc2_val: 1.098e+00
# lam_u_val: 1.490e+00
# lam_coll_val: 1.300e+00
# elapsed: 1.66e+03
# Relative L2 error_u: 1.37e-01
# Relative L2 error_r: 1.37e-01
# elapsed: 1.66e+03
# Relative L2 error_u: 1.37e-01
# Relative L2 error_r: 1.37e-01
#
#
# Method:  mini_batch
#
# average of time_list: 1655.3007152080536
# average of error_u_list: 0.13695443951065084
# average of error_r_list: 0.13695443951065084

# %%
# Predictions
u_pred = model.predict_u(X_star)
r_pred = model.predict_r(X_star)
# Predictions

error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)
error_r = np.linalg.norm(r_star - r_pred, 2)# / np.linalg.norm(r_star, 2)

# print('elapsed: {:.2e}'.format(elapsed))

print('Relative L2 error_u: {:.2e}'.format(error_u))
print('Relative L2 error_r: {:.2e}'.format(error_r))
# Out:
# Relative L2 error_u: 1.37e-01
# Relative L2 error_r: 1.91e+01

# %%
# Predictions
u_pred = model.predict_u(X_star)
# Predictions

error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)

print('elapsed: {:.2e}'.format(elapsed))

print('Relative L2 error_u: {:.2e}'.format(error_u))
# Out:
# elapsed: 1.66e+03
# Relative L2 error_u: 1.37e-01

# %%
r_pred =r_pred.reshape(200,200)

U_star = griddata(X_star, u_star.flatten(), (t, x), method='cubic')
r_star = griddata(X_star, r_star.flatten(), (t, x), method='cubic')
U_pred = griddata(X_star, u_pred.flatten(), (t, x), method='cubic')
# R_pred = griddata(X_star, r_pred.flatten(), (t, x), method='cubic')


plt.figure(figsize=(18, 9))
plt.subplot(2, 3, 1)
plt.pcolor(t, x, U_star, cmap='jet')
plt.colorbar()
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.title('Exact u(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 2)
plt.pcolor(t, x, U_pred, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Predicted u(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 3)
plt.pcolor(t, x, np.abs(U_star - U_pred), cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Absolute error')
plt.tight_layout()

plt.subplot(2, 3, 4)
plt.pcolor(t, x, r_star, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Exact r(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 5)
plt.pcolor(t, x, r_pred, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Predicted r(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 6)
plt.pcolor(t, x, np.abs(r_star - r_pred), cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Absolute error')
plt.tight_layout()
plt.show()

# %%
# Define PINN model
a = 0.5
c = 2

kernel_size = 300

# Domain boundaries
ics_coords = np.array([[0.0, 0.0],  [0.0, 1.0]])
bc1_coords = np.array([[0.0, 0.0],  [1.0, 0.0]])
bc2_coords = np.array([[0.0, 1.0],  [1.0, 1.0]])
dom_coords = np.array([[0.0, 0.0],  [1.0, 1.0]])

# Create initial conditions samplers
ics_sampler = Sampler(2, ics_coords, lambda x: u(x, a, c), name='Initial Condition 1')

# Create boundary conditions samplers
bc1 = Sampler(2, bc1_coords, lambda x: u(x, a, c), name='Dirichlet BC1')
bc2 = Sampler(2, bc2_coords, lambda x: u(x, a, c), name='Dirichlet BC2')
bcs_sampler = [bc1, bc2]

# Create residual sampler
res_sampler = Sampler(2, dom_coords, lambda x: r(x, a, c), name='Forcing')



nIter =40000
bcbatch_size = 500
ubatch_size = 5000
mbbatch_size = 300



# Define model
mode = 'M4'
layers = [2, 500, 500, 500, 1]


nn = 200
t = np.linspace(dom_coords[0, 0], dom_coords[1, 0], nn)[:, None]
x = np.linspace(dom_coords[0, 1], dom_coords[1, 1], nn)[:, None]
t, x = np.meshgrid(t, x)
X_star = np.hstack((t.flatten()[:, None], x.flatten()[:, None]))

u_star = u(X_star, a,c)
r_star = r(X_star, a, c)

iterations = 1
methods = [  "mini_batch"]

result_dict =  dict((mtd, []) for mtd in methods)

for mtd in methods:
    print("Method: ", mtd)
    time_list = []
    error_u_list = []
    
    for index in range(iterations):

        print("Epoch: ", str(index+1))

        # Create residual sampler

        [elapsed, error_u , model] = test_method(mtd , layers,  ics_sampler, bcs_sampler, res_sampler, c ,kernel_size , X_star , u_star , r_star , nIter ,mbbatch_size , bcbatch_size , ubatch_size )


        print('elapsed: {:.2e}'.format(elapsed))
        print('Relative L2 error_u: {:.2e}'.format(error_u))

        time_list.append(elapsed)
        error_u_list.append(error_u)

    print("\n\nMethod: ", mtd)
    print("\naverage of time_list:" , sum(time_list) / len(time_list) )
    print("average of error_u_list:" , sum(error_u_list) / len(error_u_list) )
    # print("average of error_r_list:" , sum(error_r_list) / len(error_r_list) )

    result_dict[mtd] = [time_list ,error_u_list]
    # scipy.io.savemat("M2_result_"+str(iterations)+"_"+mtd+".mat" , {'time_list':np.array(time_list),'error_u_list':np.array(error_u_list),'error_f_list':np.array(error_f_list)})

    scipy.io.savemat("./1DWave_database/"+mtd+"_1Dwave_"+mode+"_result_mb"+str(mbbatch_size)+"_fb"+str(ubatch_size)+"_bc"+str(mbbatch_size)+"_"+str(iterations)+".mat" , result_dict)

###############################################################################################################################################
# Out:
# Method:  mini_batch
# Epoch:  1
# WARNING:tensorflow:From /tmp/ipykernel_9685/1247141941.py:4: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_9685/1247141941.py:5: The name tf.GPUOptions is deprecated. Please use tf.compat.v1.GPUOptions instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_9685/1247141941.py:6: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_9685/1247141941.py:6: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_9685/930390821.py:39: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# 2023-11-26 15:05:13.752303: I tensorflow/core/platform/cpu_feature_guard.cc:145] This TensorFlow binary is optimized with Intel(R) MKL-DNN to use the following CPU instructions in performance critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in non-MKL-DNN operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-26 15:05:13.777152: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2899885000 Hz
# 2023-11-26 15:05:13.777588: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55e5d2b18e20 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-11-26 15:05:13.777603: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2023-11-26 15:05:13.781503: I tensorflow/core/common_runtime/process_util.cc:115] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# WARNING:tensorflow:From /tmp/ipykernel_9685/930390821.py:94: The name tf.train.exponential_decay is deprecated. Please use tf.compat.v1.train.exponential_decay instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_9685/930390821.py:96: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_9685/930390821.py:99: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# mini_batch method is used
# It: 0, Loss: 4.827e+01,  loss_bc1: 2.607e+00,  loss_bc2: 2.707e+00, loss_ics_u: 1.369e+00, loss_ics_ut: 8.358e+00,  Loss_res: 9.092e+00 , Time: 1.51
# loss_bc1: 5.314e+04
# loss_ics_u: 9.728e+04
# loss_res_val: 9.092e+02
# It: 100, Loss: 3.623e+04,  loss_bc1: 9.761e-02,  loss_bc2: 3.962e-02, loss_ics_u: 2.837e-01, loss_ics_ut: 1.377e-02,  Loss_res: 2.132e-03 , Time: 3.01
# loss_bc1: 5.383e+04
# loss_ics_u: 9.876e+04
# loss_res_val: 9.093e+02
# It: 200, Loss: 2.505e+04,  loss_bc1: 5.122e-02,  loss_bc2: 4.537e-02, loss_ics_u: 1.893e-01, loss_ics_ut: 1.101e-03,  Loss_res: 1.152e+00 , Time: 3.09
# loss_bc1: 5.415e+04
# loss_ics_u: 9.940e+04
# loss_res_val: 9.478e+02
# It: 300, Loss: 2.490e+04,  loss_bc1: 4.457e-02,  loss_bc2: 2.164e-02, loss_ics_u: 1.861e-01, loss_ics_ut: 1.787e-02,  Loss_res: 1.107e+00 , Time: 3.01
# loss_bc1: 5.431e+04
# loss_ics_u: 9.991e+04
# loss_res_val: 9.754e+02
# It: 400, Loss: 1.634e+04,  loss_bc1: 4.384e-02,  loss_bc2: 1.383e-02, loss_ics_u: 1.133e-01, loss_ics_ut: 9.906e-03,  Loss_res: 9.158e-01 , Time: 3.06
# loss_bc1: 5.443e+04
# loss_ics_u: 1.002e+05
# loss_res_val: 9.938e+02
# It: 500, Loss: 1.856e+04,  loss_bc1: 4.399e-02,  loss_bc2: 1.034e-02, loss_ics_u: 1.456e-01, loss_ics_ut: 4.305e-03,  Loss_res: 5.937e-01 , Time: 3.24
# loss_bc1: 5.452e+04
# loss_ics_u: 1.004e+05
# loss_res_val: 1.004e+03
# It: 600, Loss: 1.909e+04,  loss_bc1: 3.961e-02,  loss_bc2: 1.190e-02, loss_ics_u: 1.491e-01, loss_ics_ut: 5.215e-03,  Loss_res: 7.827e-01 , Time: 3.95
# loss_bc1: 5.459e+04
# loss_ics_u: 1.006e+05
# loss_res_val: 1.015e+03
# It: 700, Loss: 1.693e+04,  loss_bc1: 4.032e-02,  loss_bc2: 1.039e-02, loss_ics_u: 1.326e-01, loss_ics_ut: 3.295e-03,  Loss_res: 4.722e-01 , Time: 3.54
# loss_bc1: 5.466e+04
# loss_ics_u: 1.008e+05
# loss_res_val: 1.021e+03
# It: 800, Loss: 1.511e+04,  loss_bc1: 2.885e-02,  loss_bc2: 1.549e-02, loss_ics_u: 1.116e-01, loss_ics_ut: 1.007e-02,  Loss_res: 4.158e-01 , Time: 3.46
# loss_bc1: 5.471e+04
# loss_ics_u: 1.009e+05
# loss_res_val: 1.025e+03
# It: 900, Loss: 1.714e+04,  loss_bc1: 4.178e-02,  loss_bc2: 1.996e-02, loss_ics_u: 1.290e-01, loss_ics_ut: 3.116e-03,  Loss_res: 4.123e-01 , Time: 4.13
# loss_bc1: 5.477e+04
# loss_ics_u: 1.011e+05
# loss_res_val: 1.029e+03
# It: 1000, Loss: 1.952e+04,  loss_bc1: 3.226e-02,  loss_bc2: 1.252e-02, loss_ics_u: 1.257e-01, loss_ics_ut: 3.995e-02,  Loss_res: 3.136e-01 , Time: 3.39
# loss_bc1: 5.481e+04
# loss_ics_u: 1.012e+05
# loss_res_val: 1.032e+03
# It: 1100, Loss: 1.535e+04,  loss_bc1: 3.257e-02,  loss_bc2: 1.375e-02, loss_ics_u: 9.781e-02, loss_ics_ut: 2.019e-02,  Loss_res: 8.393e-01 , Time: 3.31
# loss_bc1: 5.485e+04
# loss_ics_u: 1.013e+05
# loss_res_val: 1.039e+03
# It: 1200, Loss: 1.411e+04,  loss_bc1: 3.429e-02,  loss_bc2: 1.448e-02, loss_ics_u: 1.087e-01, loss_ics_ut: 1.978e-03,  Loss_res: 2.106e-01 , Time: 3.51
# loss_bc1: 5.488e+04
# loss_ics_u: 1.014e+05
# loss_res_val: 1.041e+03
# It: 1300, Loss: 1.362e+04,  loss_bc1: 2.497e-02,  loss_bc2: 1.457e-02, loss_ics_u: 1.066e-01, loss_ics_ut: 3.287e-03,  Loss_res: 2.997e-01 , Time: 3.47
# loss_bc1: 5.491e+04
# loss_ics_u: 1.015e+05
# loss_res_val: 1.043e+03
# It: 1400, Loss: 1.558e+04,  loss_bc1: 3.440e-02,  loss_bc2: 1.363e-02, loss_ics_u: 1.062e-01, loss_ics_ut: 1.845e-02,  Loss_res: 2.815e-01 , Time: 3.46
# loss_bc1: 5.494e+04
# loss_ics_u: 1.016e+05
# loss_res_val: 1.045e+03
# It: 1500, Loss: 1.183e+04,  loss_bc1: 1.758e-02,  loss_bc2: 1.232e-02, loss_ics_u: 9.498e-02, loss_ics_ut: 1.531e-03,  Loss_res: 3.694e-01 , Time: 3.61
# loss_bc1: 5.496e+04
# loss_ics_u: 1.016e+05
# loss_res_val: 1.047e+03
# It: 1600, Loss: 1.500e+04,  loss_bc1: 2.720e-02,  loss_bc2: 1.249e-02, loss_ics_u: 1.002e-01, loss_ics_ut: 2.433e-02,  Loss_res: 1.572e-01 , Time: 3.43
# loss_bc1: 5.499e+04
# loss_ics_u: 1.017e+05
# loss_res_val: 1.048e+03
# It: 1700, Loss: 1.510e+04,  loss_bc1: 2.644e-02,  loss_bc2: 1.344e-02, loss_ics_u: 1.142e-01, loss_ics_ut: 7.314e-03,  Loss_res: 5.243e-01 , Time: 3.41
# loss_bc1: 5.501e+04
# loss_ics_u: 1.018e+05
# loss_res_val: 1.051e+03
# It: 1800, Loss: 1.216e+04,  loss_bc1: 2.343e-02,  loss_bc2: 9.552e-03, loss_ics_u: 9.835e-02, loss_ics_ut: 1.144e-03,  Loss_res: 2.145e-01 , Time: 3.42
# loss_bc1: 5.503e+04
# loss_ics_u: 1.018e+05
# loss_res_val: 1.052e+03
# It: 1900, Loss: 1.553e+04,  loss_bc1: 2.711e-02,  loss_bc2: 1.268e-02, loss_ics_u: 1.154e-01, loss_ics_ut: 1.373e-02,  Loss_res: 1.879e-01 , Time: 3.32
# loss_bc1: 5.505e+04
# loss_ics_u: 1.019e+05
# loss_res_val: 1.053e+03
# It: 2000, Loss: 1.373e+04,  loss_bc1: 1.808e-02,  loss_bc2: 9.872e-03, loss_ics_u: 1.044e-01, loss_ics_ut: 1.305e-02,  Loss_res: 2.167e-01 , Time: 3.40
# loss_bc1: 5.506e+04
# loss_ics_u: 1.019e+05
# loss_res_val: 1.054e+03
# It: 2100, Loss: 1.357e+04,  loss_bc1: 1.812e-02,  loss_bc2: 1.200e-02, loss_ics_u: 1.121e-01, loss_ics_ut: 2.765e-03,  Loss_res: 1.928e-01 , Time: 3.42
# loss_bc1: 5.507e+04
# loss_ics_u: 1.020e+05
# loss_res_val: 1.055e+03
# It: 2200, Loss: 1.536e+04,  loss_bc1: 2.163e-02,  loss_bc2: 1.349e-02, loss_ics_u: 1.110e-01, loss_ics_ut: 1.290e-02,  Loss_res: 7.527e-01 , Time: 3.37
# loss_bc1: 5.509e+04
# loss_ics_u: 1.020e+05
# loss_res_val: 1.058e+03
# It: 2300, Loss: 1.280e+04,  loss_bc1: 3.042e-02,  loss_bc2: 1.270e-02, loss_ics_u: 9.456e-02, loss_ics_ut: 5.691e-03,  Loss_res: 1.876e-01 , Time: 3.48
# loss_bc1: 5.511e+04
# loss_ics_u: 1.021e+05
# loss_res_val: 1.059e+03
# It: 2400, Loss: 1.228e+04,  loss_bc1: 2.248e-02,  loss_bc2: 1.306e-02, loss_ics_u: 9.533e-02, loss_ics_ut: 3.357e-03,  Loss_res: 2.351e-01 , Time: 3.39
# loss_bc1: 5.512e+04
# loss_ics_u: 1.021e+05
# loss_res_val: 1.060e+03
# It: 2500, Loss: 1.329e+04,  loss_bc1: 2.375e-02,  loss_bc2: 1.531e-02, loss_ics_u: 1.048e-01, loss_ics_ut: 1.362e-03,  Loss_res: 2.777e-01 , Time: 3.43
# loss_bc1: 5.514e+04
# loss_ics_u: 1.022e+05
# loss_res_val: 1.061e+03
# It: 2600, Loss: 1.297e+04,  loss_bc1: 3.540e-02,  loss_bc2: 1.187e-02, loss_ics_u: 8.898e-02, loss_ics_ut: 9.161e-03,  Loss_res: 3.154e-01 , Time: 3.51
# loss_bc1: 5.515e+04
# loss_ics_u: 1.022e+05
# loss_res_val: 1.062e+03
# It: 2700, Loss: 1.206e+04,  loss_bc1: 2.014e-02,  loss_bc2: 1.088e-02, loss_ics_u: 9.354e-02, loss_ics_ut: 3.421e-03,  Loss_res: 4.164e-01 , Time: 6.67
# loss_bc1: 5.516e+04
# loss_ics_u: 1.022e+05
# loss_res_val: 1.064e+03
# It: 2800, Loss: 1.186e+04,  loss_bc1: 1.765e-02,  loss_bc2: 1.423e-02, loss_ics_u: 8.974e-02, loss_ics_ut: 4.060e-03,  Loss_res: 4.857e-01 , Time: 5.40
# loss_bc1: 5.517e+04
# loss_ics_u: 1.023e+05
# loss_res_val: 1.065e+03
# It: 2900, Loss: 1.183e+04,  loss_bc1: 2.330e-02,  loss_bc2: 1.183e-02, loss_ics_u: 9.238e-02, loss_ics_ut: 1.615e-03,  Loss_res: 2.651e-01 , Time: 4.08
# loss_bc1: 5.519e+04
# loss_ics_u: 1.023e+05
# loss_res_val: 1.066e+03
# It: 3000, Loss: 1.106e+04,  loss_bc1: 1.882e-02,  loss_bc2: 1.360e-02, loss_ics_u: 8.589e-02, loss_ics_ut: 2.512e-03,  Loss_res: 2.104e-01 , Time: 3.62
# loss_bc1: 5.520e+04
# loss_ics_u: 1.023e+05
# loss_res_val: 1.067e+03
# It: 3100, Loss: 1.217e+04,  loss_bc1: 1.682e-02,  loss_bc2: 1.417e-02, loss_ics_u: 9.728e-02, loss_ics_ut: 3.035e-03,  Loss_res: 1.825e-01 , Time: 3.72
# loss_bc1: 5.521e+04
# loss_ics_u: 1.024e+05
# loss_res_val: 1.068e+03
# It: 3200, Loss: 1.279e+04,  loss_bc1: 2.165e-02,  loss_bc2: 1.391e-02, loss_ics_u: 1.014e-01, loss_ics_ut: 1.403e-03,  Loss_res: 2.820e-01 , Time: 3.77
# loss_bc1: 5.522e+04
# loss_ics_u: 1.024e+05
# loss_res_val: 1.068e+03
# It: 3300, Loss: 1.278e+04,  loss_bc1: 1.976e-02,  loss_bc2: 1.281e-02, loss_ics_u: 9.681e-02, loss_ics_ut: 8.132e-03,  Loss_res: 2.258e-01 , Time: 3.69
# loss_bc1: 5.523e+04
# loss_ics_u: 1.024e+05
# loss_res_val: 1.069e+03
# It: 3400, Loss: 1.175e+04,  loss_bc1: 1.895e-02,  loss_bc2: 1.062e-02, loss_ics_u: 8.754e-02, loss_ics_ut: 8.988e-03,  Loss_res: 2.168e-01 , Time: 5.01
# loss_bc1: 5.524e+04
# loss_ics_u: 1.024e+05
# loss_res_val: 1.070e+03
# It: 3500, Loss: 1.352e+04,  loss_bc1: 2.627e-02,  loss_bc2: 1.540e-02, loss_ics_u: 9.328e-02, loss_ics_ut: 1.242e-02,  Loss_res: 3.605e-01 , Time: 4.93
# loss_bc1: 5.525e+04
# loss_ics_u: 1.025e+05
# loss_res_val: 1.071e+03
# It: 3600, Loss: 1.178e+04,  loss_bc1: 1.230e-02,  loss_bc2: 1.581e-02, loss_ics_u: 9.504e-02, loss_ics_ut: 1.773e-03,  Loss_res: 2.854e-01 , Time: 3.83
# loss_bc1: 5.525e+04
# loss_ics_u: 1.025e+05
# loss_res_val: 1.072e+03
# It: 3700, Loss: 1.004e+04,  loss_bc1: 1.245e-02,  loss_bc2: 1.195e-02, loss_ics_u: 8.049e-02, loss_ics_ut: 9.335e-04,  Loss_res: 3.182e-01 , Time: 3.72
# loss_bc1: 5.526e+04
# loss_ics_u: 1.025e+05
# loss_res_val: 1.072e+03
# It: 3800, Loss: 1.094e+04,  loss_bc1: 1.485e-02,  loss_bc2: 1.429e-02, loss_ics_u: 8.671e-02, loss_ics_ut: 2.771e-03,  Loss_res: 1.492e-01 , Time: 3.73
# loss_bc1: 5.527e+04
# loss_ics_u: 1.025e+05
# loss_res_val: 1.073e+03
# It: 3900, Loss: 1.187e+04,  loss_bc1: 1.513e-02,  loss_bc2: 1.681e-02, loss_ics_u: 9.083e-02, loss_ics_ut: 5.614e-03,  Loss_res: 2.001e-01 , Time: 4.29
# loss_bc1: 5.528e+04
# loss_ics_u: 1.026e+05
# loss_res_val: 1.073e+03
# It: 4000, Loss: 1.123e+04,  loss_bc1: 1.934e-02,  loss_bc2: 1.184e-02, loss_ics_u: 8.309e-02, loss_ics_ut: 5.893e-03,  Loss_res: 3.518e-01 , Time: 5.47
# loss_bc1: 5.528e+04
# loss_ics_u: 1.026e+05
# loss_res_val: 1.074e+03
# It: 4100, Loss: 1.055e+04,  loss_bc1: 1.644e-02,  loss_bc2: 1.278e-02, loss_ics_u: 7.779e-02, loss_ics_ut: 2.122e-03,  Loss_res: 6.881e-01 , Time: 3.78
# loss_bc1: 5.529e+04
# loss_ics_u: 1.026e+05
# loss_res_val: 1.076e+03
# It: 4200, Loss: 1.050e+04,  loss_bc1: 1.844e-02,  loss_bc2: 1.345e-02, loss_ics_u: 8.115e-02, loss_ics_ut: 2.330e-03,  Loss_res: 1.545e-01 , Time: 4.83
# loss_bc1: 5.530e+04
# loss_ics_u: 1.026e+05
# loss_res_val: 1.076e+03
# It: 4300, Loss: 1.040e+04,  loss_bc1: 1.675e-02,  loss_bc2: 1.380e-02, loss_ics_u: 8.116e-02, loss_ics_ut: 1.082e-03,  Loss_res: 2.527e-01 , Time: 3.56
# loss_bc1: 5.531e+04
# loss_ics_u: 1.026e+05
# loss_res_val: 1.077e+03
# It: 4400, Loss: 1.019e+04,  loss_bc1: 1.965e-02,  loss_bc2: 1.077e-02, loss_ics_u: 7.849e-02, loss_ics_ut: 1.886e-03,  Loss_res: 2.424e-01 , Time: 3.47
# loss_bc1: 5.531e+04
# loss_ics_u: 1.027e+05
# loss_res_val: 1.077e+03
# It: 4500, Loss: 1.124e+04,  loss_bc1: 1.991e-02,  loss_bc2: 1.265e-02, loss_ics_u: 8.266e-02, loss_ics_ut: 6.039e-03,  Loss_res: 3.074e-01 , Time: 3.41
# loss_bc1: 5.532e+04
# loss_ics_u: 1.027e+05
# loss_res_val: 1.078e+03
# It: 4600, Loss: 9.086e+03,  loss_bc1: 1.352e-02,  loss_bc2: 1.160e-02, loss_ics_u: 6.719e-02, loss_ics_ut: 5.677e-03,  Loss_res: 1.992e-01 , Time: 3.43
# loss_bc1: 5.532e+04
# loss_ics_u: 1.027e+05
# loss_res_val: 1.078e+03
# It: 4700, Loss: 1.027e+04,  loss_bc1: 9.919e-03,  loss_bc2: 9.886e-03, loss_ics_u: 8.505e-02, loss_ics_ut: 1.872e-03,  Loss_res: 2.314e-01 , Time: 3.48
# loss_bc1: 5.533e+04
# loss_ics_u: 1.027e+05
# loss_res_val: 1.079e+03
# It: 4800, Loss: 1.084e+04,  loss_bc1: 1.596e-02,  loss_bc2: 9.479e-03, loss_ics_u: 8.293e-02, loss_ics_ut: 6.096e-03,  Loss_res: 2.698e-01 , Time: 3.39
# loss_bc1: 5.533e+04
# loss_ics_u: 1.027e+05
# loss_res_val: 1.079e+03
# It: 4900, Loss: 1.044e+04,  loss_bc1: 1.507e-02,  loss_bc2: 1.129e-02, loss_ics_u: 8.004e-02, loss_ics_ut: 4.682e-03,  Loss_res: 2.575e-01 , Time: 3.37
# loss_bc1: 5.534e+04
# loss_ics_u: 1.028e+05
# loss_res_val: 1.080e+03
# It: 5000, Loss: 1.036e+04,  loss_bc1: 1.212e-02,  loss_bc2: 7.684e-03, loss_ics_u: 8.220e-02, loss_ics_ut: 3.851e-03,  Loss_res: 3.909e-01 , Time: 3.35
# loss_bc1: 5.534e+04
# loss_ics_u: 1.028e+05
# loss_res_val: 1.081e+03
# It: 5100, Loss: 1.002e+04,  loss_bc1: 1.284e-02,  loss_bc2: 1.022e-02, loss_ics_u: 7.480e-02, loss_ics_ut: 7.888e-03,  Loss_res: 2.322e-01 , Time: 3.31
# loss_bc1: 5.535e+04
# loss_ics_u: 1.028e+05
# loss_res_val: 1
= test_method(mtd , layers,  ics_sampler, bcs_sampler, res_sampler, c ,kernel_size , X_star , u_star , r_star , nIter ,mbbatch_size , bcbatch_size , ubatch_size )


        print('elapsed: {:.2e}'.format(elapsed))
        print('Relative L2 error_u: {:.2e}'.format(error_u))

        time_list.append(elapsed)
        error_u_list.append(error_u)

    print("\n\nMethod: ", mtd)
    print("\naverage of time_list:" , sum(time_list) / len(time_list) )
    print("average of error_u_list:" , sum(error_u_list) / len(error_u_list) )
    # print("average of error_r_list:" , sum(error_r_list) / len(error_r_list) )

    result_dict[mtd] = [time_list ,error_u_list]
    # scipy.io.savemat("M2_result_"+str(iterations)+"_"+mtd+".mat" , {'time_list':np.array(time_list),'error_u_list':np.array(error_u_list),'error_f_list':np.array(error_f_list)})

    scipy.io.savemat("./1DWave_database/"+mtd+"_1Dwave_"+mode+"_result_mb"+str(mbbatch_size)+"_fb"+str(ubatch_size)+"_bc"+str(mbbatch_size)+"_"+str(iterations)+".mat" , result_dict)

###############################################################################################################################################
# Out:
# Method:  mini_batch
# Epoch:  1
# mini_batch method is used
# It: 100, Loss: 9.238e-01,  loss_bc1: 6.848e-02, loss_ics_u: 3.931e-01,  Loss_res: 6.576e-04 , Time: 4.89
# It: 200, Loss: 6.458e-01,  loss_bc1: 7.923e-02, loss_ics_u: 2.403e-01,  Loss_res: 6.826e-03 , Time: 3.53
# It: 300, Loss: 6.600e-01,  loss_bc1: 8.652e-02, loss_ics_u: 2.341e-01,  Loss_res: 1.875e-02 , Time: 3.44
# It: 400, Loss: 5.494e-01,  loss_bc1: 6.093e-02, loss_ics_u: 2.009e-01,  Loss_res: 2.586e-02 , Time: 3.43
# It: 500, Loss: 5.235e-01,  loss_bc1: 4.314e-02, loss_ics_u: 2.099e-01,  Loss_res: 1.742e-02 , Time: 3.35
# It: 600, Loss: 4.532e-01,  loss_bc1: 4.553e-02, loss_ics_u: 1.763e-01,  Loss_res: 9.461e-03 , Time: 3.27
# It: 700, Loss: 4.660e-01,  loss_bc1: 4.488e-02, loss_ics_u: 1.662e-01,  Loss_res: 4.375e-02 , Time: 3.38
# It: 800, Loss: 4.010e-01,  loss_bc1: 5.502e-02, loss_ics_u: 1.294e-01,  Loss_res: 3.213e-02 , Time: 3.22
# It: 900, Loss: 3.889e-01,  loss_bc1: 4.886e-02, loss_ics_u: 1.423e-01,  Loss_res: 6.523e-03 , Time: 3.26
# It: 1000, Loss: 4.760e-01,  loss_bc1: 3.239e-02, loss_ics_u: 1.614e-01,  Loss_res: 8.841e-02 , Time: 3.23
# loss_bc1: 3.239e+00
# loss_ics_u: 1.614e+01
# It: 1100, Loss: 4.028e+00,  loss_bc1: 2.087e-01, loss_ics_u: 2.050e-01,  Loss_res: 4.341e-02 , Time: 3.24
# It: 1200, Loss: 4.036e+00,  loss_bc1: 2.012e-01, loss_ics_u: 2.079e-01,  Loss_res: 2.821e-02 , Time: 3.24
# It: 1300, Loss: 3.089e+00,  loss_bc1: 1.975e-01, loss_ics_u: 1.486e-01,  Loss_res: 5.050e-02 , Time: 3.29
# It: 1400, Loss: 3.631e+00,  loss_bc1: 9.093e-02, loss_ics_u: 2.015e-01,  Loss_res: 8.446e-02 , Time: 3.25
# It: 1500, Loss: 3.205e+00,  loss_bc1: 1.203e-01, loss_ics_u: 1.708e-01,  Loss_res: 5.864e-02 , Time: 3.28
# It: 1600, Loss: 2.442e+00,  loss_bc1: 6.459e-02, loss_ics_u: 1.321e-01,  Loss_res: 1.004e-01 , Time: 3.25
# It: 1700, Loss: 1.988e+00,  loss_bc1: 5.784e-02, loss_ics_u: 1.060e-01,  Loss_res: 9.038e-02 , Time: 3.28
# It: 1800, Loss: 2.086e+00,  loss_bc1: 6.114e-02, loss_ics_u: 1.096e-01,  Loss_res: 1.187e-01 , Time: 3.30
# It: 1900, Loss: 1.798e+00,  loss_bc1: 5.601e-02, loss_ics_u: 9.710e-02,  Loss_res: 4.957e-02 , Time: 3.27
# It: 2000, Loss: 2.066e+00,  loss_bc1: 5.252e-02, loss_ics_u: 1.144e-01,  Loss_res: 4.957e-02 , Time: 3.29
# loss_bc1: 5.252e+00
# loss_ics_u: 1.144e+01
# loss_bc1: 2.016e+00
# loss_ics_u: 6.464e+00
# It: 8100, Loss: 5.165e-01,  loss_bc1: 2.897e-02, loss_ics_u: 6.732e-02,  Loss_res: 2.294e-02 , Time: 3.25
# It: 8200, Loss: 5.093e-01,  loss_bc1: 2.612e-02, loss_ics_u: 6.808e-02,  Loss_res: 1.660e-02 , Time: 3.39
# It: 8300, Loss: 4.938e-01,  loss_bc1: 2.461e-02, loss_ics_u: 6.506e-02,  Loss_res: 2.366e-02 , Time: 3.26
# It: 8400, Loss: 4.566e-01,  loss_bc1: 2.211e-02, loss_ics_u: 6.029e-02,  Loss_res: 2.233e-02 , Time: 3.28
# It: 8500, Loss: 5.714e-01,  loss_bc1: 2.626e-02, loss_ics_u: 7.673e-02,  Loss_res: 2.248e-02 , Time: 3.28
# It: 8600, Loss: 5.056e-01,  loss_bc1: 1.853e-02, loss_ics_u: 7.116e-02,  Loss_res: 8.203e-03 , Time: 3.30
# It: 8700, Loss: 4.594e-01,  loss_bc1: 2.381e-02, loss_ics_u: 6.117e-02,  Loss_res: 1.599e-02 , Time: 3.26
# It: 8800, Loss: 5.830e-01,  loss_bc1: 3.105e-02, loss_ics_u: 6.247e-02,  Loss_res: 1.166e-01 , Time: 3.31
# It: 8900, Loss: 4.775e-01,  loss_bc1: 2.004e-02, loss_ics_u: 6.605e-02,  Loss_res: 1.014e-02 , Time: 3.55

# %%
# Define PINN model
a = 0.5
c = 2

kernel_size = 300

# Domain boundaries
ics_coords = np.array([[0.0, 0.0],  [0.0, 1.0]])
bc1_coords = np.array([[0.0, 0.0],  [1.0, 0.0]])
bc2_coords = np.array([[0.0, 1.0],  [1.0, 1.0]])
dom_coords = np.array([[0.0, 0.0],  [1.0, 1.0]])

# Create initial conditions samplers
ics_sampler = Sampler(2, ics_coords, lambda x: u(x, a, c), name='Initial Condition 1')

# Create boundary conditions samplers
bc1 = Sampler(2, bc1_coords, lambda x: u(x, a, c), name='Dirichlet BC1')
bc2 = Sampler(2, bc2_coords, lambda x: u(x, a, c), name='Dirichlet BC2')
bcs_sampler = [bc1, bc2]

# Create residual sampler
res_sampler = Sampler(2, dom_coords, lambda x: r(x, a, c), name='Forcing')



nIter =40000
bcbatch_size = 500
ubatch_size = 5000
mbbatch_size = 300



# Define model
mode = 'M4'
layers = [2, 500, 500, 500, 1]


nn = 200
t = np.linspace(dom_coords[0, 0], dom_coords[1, 0], nn)[:, None]
x = np.linspace(dom_coords[0, 1], dom_coords[1, 1], nn)[:, None]
t, x = np.meshgrid(t, x)
X_star = np.hstack((t.flatten()[:, None], x.flatten()[:, None]))

u_star = u(X_star, a,c)
r_star = r(X_star, a, c)

iterations = 1
methods = [  "mini_batch"]

result_dict =  dict((mtd, []) for mtd in methods)

for mtd in methods:
    print("Method: ", mtd)
    time_list = []
    error_u_list = []
    
    for index in range(iterations):

        print("Epoch: ", str(index+1))

        # Create residual sampler

        [elapsed, error_u] = test_method(mtd , layers,  ics_sampler, bcs_sampler, res_sampler, c ,kernel_size , X_star , u_star , r_star , nIter ,mbbatch_size , bcbatch_size , ubatch_size )


        print('elapsed: {:.2e}'.format(elapsed))
        print('Relative L2 error_u: {:.2e}'.format(error_u))

        time_list.append(elapsed)
        error_u_list.append(error_u)

    print("\n\nMethod: ", mtd)
    print("\naverage of time_list:" , sum(time_list) / len(time_list) )
    print("average of error_u_list:" , sum(error_u_list) / len(error_u_list) )
    # print("average of error_r_list:" , sum(error_r_list) / len(error_r_list) )

    result_dict[mtd] = [time_list ,error_u_list]
    # scipy.io.savemat("M2_result_"+str(iterations)+"_"+mtd+".mat" , {'time_list':np.array(time_list),'error_u_list':np.array(error_u_list),'error_f_list':np.array(error_f_list)})

    scipy.io.savemat("./1DWave_database/"+mtd+"_1Dwave_"+mode+"_result_mb"+str(mbbatch_size)+"_fb"+str(ubatch_size)+"_bc"+str(mbbatch_size)+"_"+str(iterations)+".mat" , result_dict)

###############################################################################################################################################

# %%
import scipy.io

mode = 'M4'
mbbatch_size = 128
ubatch_size = 5000
bcbatch_size = 500
iterations = 40000

time_list = []
error_u_list = []
error_v_list = []
error_p_list = []
    
methods = ["mini_batch" , "full_batch"]
result_dict =  dict((mtd, []) for mtd in methods)

##Mini Batch
time_list = []
error_u_list = [ ]


result_dict["mini_batch"] = [time_list ,error_u_list]

print("\n\nMethod: ", mtd)
print("\naverage of time_list:" , sum(time_list) / len(time_list) )
print("average of error_u_list:" , sum(error_u_list) / len(error_u_list) )

##Full Batch
time_list = []
error_u_list = [ ]
error_v_list = []
error_p_list = []

result_dict["full_batch"] = [time_list ,error_u_list ,error_v_list ,  error_p_list]

print("\n\nMethod: ", mtd)
print("\naverage of time_list:" , sum(time_list) / len(time_list) )
print("average of error_u_list:" , sum(error_u_list) / len(error_u_list) )
print("average of error_v_list:" , sum(error_v_list) / len(error_v_list) )
print("average of error_p_list:" , sum(error_p_list) / len(error_p_list) )


scipy.io.savemat("./dataset/1DWave_database_"+mode+"_result_mb"+str(mbbatch_size)+"_fb"+str(ubatch_size)+"_"+str(bcbatch_size)+"_"+str(iterations)+".mat" , result_dict)

# %%
# Train model
itertaions = 80001
log_NTK = True # Compute and store NTK matrix during training
update_lam = True # Compute and update the loss weights using the NTK

# %% [markdown]
# **Training Loss**

# %%
loss_res = model.loss_res_log
loss_bcs = model.loss_bcs_log
loss_u_t_ics = model.loss_ut_ics_log

fig = plt.figure(figsize=(6, 5))
plt.plot(loss_res, label='$\mathcal{L}_{r}$')
plt.plot(loss_bcs, label='$\mathcal{L}_{u}$')
plt.plot(loss_u_t_ics, label='$\mathcal{L}_{u_t}$')
plt.yscale('log')
plt.xlabel('iterations')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# **Model Prediction**

# %%
# Predictions
u_pred = model.predict_u(X_star)
r_pred = model.predict_r(X_star)
error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)

print('Relative L2 error_u: %e' % (error_u))

# %%
U_star = griddata(X_star, u_star.flatten(), (t, x), method='cubic')
r_star = griddata(X_star, r_star.flatten(), (t, x), method='cubic')
U_pred = griddata(X_star, u_pred.flatten(), (t, x), method='cubic')
# R_pred = griddata(X_star, r_pred.flatten(), (t, x), method='cubic')


plt.figure(figsize=(18, 9))
plt.subplot(2, 3, 1)
plt.pcolor(t, x, U_star, cmap='jet')
plt.colorbar()
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.title('Exact u(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 2)
plt.pcolor(t, x, U_pred, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Predicted u(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 3)
plt.pcolor(t, x, np.abs(U_star - U_pred), cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Absolute error')
plt.tight_layout()

plt.subplot(2, 3, 4)
plt.pcolor(t, x, r_star, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Exact r(t, x)')
plt.tight_layout()

# plt.subplot(2, 3, 5)
# plt.pcolor(t, x, R_pred, cmap='jet')
# plt.colorbar()
# plt.xlabel('$t$')
# plt.ylabel('$x$')
# plt.title('Predicted r(t, x)')
# plt.tight_layout()

# plt.subplot(2, 3, 6)
# plt.pcolor(t, x, np.abs(r_star - R_pred), cmap='jet')
# plt.colorbar()
# plt.xlabel('$t$')
# plt.ylabel('$x$')
# plt.title('Absolute error')
# plt.tight_layout()
# plt.show()

# %% [markdown]
# **NTK Eigenvalues**

# %%
# Create empty lists for storing the eigenvalues of NTK
lam_K_u_log = []
lam_K_ut_log = []
lam_K_r_log = []

# Restore the NTK
K_u_list = model.K_u_log
K_ut_list = model.K_ut_log
K_r_list = model.K_r_log

K_list = []
    
for k in range(len(K_u_list)):
    K_u = K_u_list[k]
    K_ut = K_ut_list[k]
    K_r = K_r_list[k]
    
    # Compute eigenvalues
    lam_K_u, _ = np.linalg.eig(K_u)
    lam_K_ut, _ = np.linalg.eig(K_ut)
    lam_K_r, _ = np.linalg.eig(K_r)
    # Sort in descresing order
    lam_K_u = np.sort(np.real(lam_K_u))[::-1]
    lam_K_ut = np.sort(np.real(lam_K_ut))[::-1]
    lam_K_r = np.sort(np.real(lam_K_r))[::-1]
    
    # Store eigenvalues
    lam_K_u_log.append(lam_K_u)
    lam_K_ut_log.append(lam_K_ut)
    lam_K_r_log.append(lam_K_r)

# %%
#  Eigenvalues of NTK
fig = plt.figure(figsize=(18, 5))
plt.subplot(1,3,1)

plt.plot(lam_K_u_log[0], label = '$n=0$')
plt.plot(lam_K_u_log[1], '--', label = '$n=10,000$')
plt.plot(lam_K_u_log[4], '--', label = '$n=40,000$')
plt.plot(lam_K_u_log[-1], '--', label = '$n=80,000$')
plt.xscale('log')
plt.yscale('log')

plt.title(r'Eigenvalues of ${K}_u$')

plt.subplot(1,3,2)
plt.plot(lam_K_ut_log[0], label = '$n=0$')
plt.plot(lam_K_ut_log[1], '--',label = '$n=10,000$')
plt.plot(lam_K_ut_log[4], '--', label = '$n=40,000$')
plt.plot(lam_K_ut_log[-1], '--', label = '$n=80,000$')
plt.xscale('log')
plt.yscale('log')
plt.title(r'Eigenvalues of ${K}_{u_t}$')

ax =plt.subplot(1,3,3)
plt.plot(lam_K_r_log[0], label = '$n=0$')
plt.plot(lam_K_r_log[1], '--', label = '$n=10,000$')
plt.plot(lam_K_r_log[4], '--', label = '$n=40,000$')
plt.plot(lam_K_r_log[-1], '--', label = '$n=80,000$')
plt.xscale('log')
plt.yscale('log')
plt.title(r'Eigenvalues of ${K}_{r}$')
handles, labels = ax.get_legend_handles_labels()
fig.legend(handles, labels, loc="upper left", bbox_to_anchor=(0.35, -0.02),
            borderaxespad=0, bbox_transform=fig.transFigure, ncol=4)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Evolution of NTK Weights**

# %%
if update_lam == True:

  lam_u_log = model.lam_u_log
  lam_ut_log = model.lam_ut_log
  lam_r_log = model.lam_r_log

# %%
fig = plt.figure(figsize=(6, 5))
plt.plot(lam_u_log, label='$\lambda_u$')
plt.plot(lam_ut_log, label='$\lambda_{u_t}$')
plt.plot(lam_r_log, label='$\lambda_{r}$')
plt.xlabel('iterations')
plt.ylabel('$\lambda$')
plt.yscale('log')
plt.legend( )
plt.tight_layout()
plt.show()
